# %% [markdown]
# # Exploration of the Global disaster response dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_path = './datasets/global_disaster_response_2018_2024.csv'
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#          date        country disaster_type  severity_index  casualties  \
# 0  2021-01-31         Brazil    Earthquake            5.99         111
# 1  2018-12-23         Brazil  Extreme Heat            6.53         100
# 2  2020-08-10          India     Hurricane            1.55          22
# 3  2022-09-15      Indonesia  Extreme Heat            4.55          94
# 4  2022-09-28  United States      Wildfire            3.80          64
#
#    economic_loss_usd  response_time_hours  aid_amount_usd  \
# 0         7934365.71                15.62       271603.79
# 1         8307648.99                 5.03       265873.81
# 2          765136.99                32.54        49356.49
# 3         1308251.31                 7.83       237512.88
# 4         2655864.36                21.90       188910.69
#
#    response_efficiency_score  recovery_days  latitude  longitude
# 0                      83.21             67   -30.613   -122.557
# ...

# %% [markdown]
# ## Data preparation

# %% [markdown]
# operations to be carried out:
# - remove all rows with NaN data or incident_type
# - encode state, lat/long
# - one-hot encode disaster_type

# %% [markdown]
# remove NaN rows

# %%
df.isna().sum()
# Out:
# date                         0
# country                      0
# disaster_type                0
# severity_index               0
# casualties                   0
# economic_loss_usd            0
# response_time_hours          0
# aid_amount_usd               0
# response_efficiency_score    0
# recovery_days                0
# latitude                     0
# longitude                    0
# dtype: int64

# %% [markdown]
# filter out useless incident types

# %%
set(df["disaster_type"])
# Out:
# {'Drought',
#  'Earthquake',
#  'Extreme Heat',
#  'Flood',
#  'Hurricane',
#  'Landslide',
#  'Storm Surge',
#  'Tornado',
#  'Volcanic Eruption',
#  'Wildfire'}

# %%
df['disaster_type'].value_counts()
# Out:
# disaster_type
# Landslide            5130
# Earthquake           5068
# Flood                5039
# Hurricane            5002
# Extreme Heat         5001
# Storm Surge          4988
# Volcanic Eruption    4983
# Wildfire             4954
# Tornado              4939
# Drought              4896
# Name: count, dtype: int64

# %%
df['disaster_type'].value_counts()
# Out:
# disaster_type
# Landslide            5130
# Earthquake           5068
# Flood                5039
# Hurricane            5002
# Extreme Heat         5001
# Storm Surge          4988
# Volcanic Eruption    4983
# Wildfire             4954
# Tornado              4939
# Drought              4896
# Name: count, dtype: int64

# %%
print("Final dataset size: ", int(df.size / len(df.columns)))
# Out:
# Final dataset size:  50000
