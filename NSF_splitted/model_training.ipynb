# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wildfire'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES"]#, "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE'
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 100
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = Y_train.shape[1]

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=12,
    hidden_features=[128, 128],
    bins=8
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 306216 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 000 | Time 0.49s | Train NLL 2.774 | Val NLL 2.272 | LR 1.10e-03
# Epoch 001 | Time 0.32s | Train NLL 1.387 | Val NLL 0.859 | LR 1.70e-03
# Epoch 002 | Time 0.32s | Train NLL 0.593 | Val NLL 1.157 | LR 2.30e-03
# Epoch 003 | Time 0.33s | Train NLL 1.884 | Val NLL 1.223 | LR 2.90e-03
# Epoch 004 | Time 0.36s | Train NLL 0.506 | Val NLL 1.616 | LR 3.50e-03
# Epoch 005 | Time 0.30s | Train NLL 1.759 | Val NLL 3.068 | LR 4.10e-03
# Epoch 006 | Time 0.36s | Train NLL 1.728 | Val NLL 0.917 | LR 4.70e-03
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 007 | Time 0.57s | Train NLL 0.380 | Val NLL 1.217 | LR 5.00e-03
# Epoch 008 | Time 0.44s | Train NLL 0.578 | Val NLL -0.050 | LR 5.00e-03
# Epoch 009 | Time 0.37s | Train NLL -0.524 | Val NLL -0.319 | LR 4.99e-03
# Epoch 010 | Time 0.31s | Train NLL -1.119 | Val NLL -0.566 | LR 4.98e-03
# Epoch 011 | Time 0.31s | Train NLL -1.315 | Val NLL -1.043 | LR 4.97e-03
# Epoch 012 | Time 0.32s | Train NLL -1.115 | Val NLL -1.225 | LR 4.96e-03
# Epoch 013 | Time 0.41s | Train NLL -0.848 | Val NLL -0.095 | LR 4.94e-03
# Epoch 014 | Time 0.46s | Train NLL -0.545 | Val NLL -0.699 | LR 4.92e-03
# Epoch 015 | Time 0.30s | Train NLL -1.035 | Val NLL -1.224 | LR 4.90e-03
# Epoch 016 | Time 0.35s | Train NLL -1.331 | Val NLL -1.440 | LR 4.87e-03
# Epoch 017 | Time 0.45s | Train NLL -1.861 | Val NLL -2.339 | LR 4.84e-03
# Epoch 018 | Time 0.36s | Train NLL -1.478 | Val NLL -0.453 | LR 4.81e-03
# Epoch 019 | Time 0.33s | Train NLL -1.660 | Val NLL -1.385 | LR 4.78e-03
# Epoch 020 | Time 0.30s | Train NLL -2.242 | Val NLL -2.098 | LR 4.74e-03
# Epoch 021 | Time 0.33s | Train NLL -2.278 | Val NLL -2.383 | LR 4.70e-03
# Epoch 022 | Time 0.32s | Train NLL -2.140 | Val NLL -2.607 | LR 4.66e-03
# Epoch 023 | Time 0.35s | Train NLL -2.867 | Val NLL -1.972 | LR 4.62e-03
# Epoch 024 | Time 0.33s | Train NLL -2.121 | Val NLL -0.703 | LR 4.57e-03
# Epoch 025 | Time 0.31s | Train NLL -0.785 | Val NLL 0.225 | LR 4.52e-03
# Epoch 026 | Time 0.29s | Train NLL -1.040 | Val NLL -0.342 | LR 4.47e-03
# Epoch 027 | Time 0.32s | Train NLL -1.141 | Val NLL -2.155 | LR 4.42e-03
# Epoch 028 | Time 0.32s | Train NLL -2.110 | Val NLL -1.616 | LR 4.36e-03
# Epoch 029 | Time 0.38s | Train NLL -2.270 | Val NLL -1.628 | LR 4.31e-03
# Epoch 030 | Time 0.32s | Train NLL -2.234 | Val NLL -2.073 | LR 4.25e-03
# Epoch 031 | Time 0.82s | Train NLL -2.717 | Val NLL -2.497 | LR 4.18e-03
# Epoch 032 | Time 0.43s | Train NLL -3.399 | Val NLL -2.604 | LR 4.12e-03
# Epoch 033 | Time 0.42s | Train NLL -3.190 | Val NLL -1.868 | LR 4.06e-03
# Epoch 034 | Time 0.39s | Train NLL -2.910 | Val NLL -2.867 | LR 3.99e-03
# Epoch 035 | Time 0.56s | Train NLL -2.342 | Val NLL 0.366 | LR 3.92e-03
# Epoch 036 | Time 0.47s | Train NLL -0.788 | Val NLL -1.153 | LR 3.85e-03
# Epoch 037 | Time 0.42s | Train NLL -2.082 | Val NLL -1.538 | LR 3.78e-03
# Epoch 038 | Time 0.40s | Train NLL -2.248 | Val NLL -1.511 | LR 3.70e-03
# Epoch 039 | Time 0.37s | Train NLL -2.500 | Val NLL -3.197 | LR 3.63e-03
# Epoch 040 | Time 0.45s | Train NLL -2.899 | Val NLL -1.903 | LR 3.55e-03
# Epoch 041 | Time 0.53s | Train NLL -2.091 | Val NLL -3.234 | LR 3.47e-03
# Epoch 042 | Time 0.46s | Train NLL -2.679 | Val NLL -3.422 | LR 3.40e-03
# Epoch 043 | Time 0.37s | Train NLL -2.919 | Val NLL -2.953 | LR 3.32e-03
# Epoch 044 | Time 0.35s | Train NLL -3.427 | Val NLL -3.645 | LR 3.24e-03
# Epoch 045 | Time 0.33s | Train NLL -2.913 | Val NLL -3.207 | LR 3.15e-03
# Epoch 046 | Time 0.34s | Train NLL -3.580 | Val NLL -2.672 | LR 3.07e-03
# Epoch 047 | Time 0.33s | Train NLL -2.929 | Val NLL -3.889 | LR 2.99e-03
# Epoch 048 | Time 0.34s | Train NLL -3.861 | Val NLL -3.516 | LR 2.91e-03
# Epoch 049 | Time 0.33s | Train NLL -3.929 | Val NLL -3.093 | LR 2.82e-03
# Epoch 050 | Time 0.33s | Train NLL -4.071 | Val NLL -3.536 | LR 2.74e-03
# Epoch 051 | Time 0.31s | Train NLL -4.316 | Val NLL -3.828 | LR 2.65e-03
# Epoch 052 | Time 0.31s | Train NLL -4.520 | Val NLL -4.453 | LR 2.57e-03
# Epoch 053 | Time 0.32s | Train NLL -4.953 | Val NLL -4.074 | LR 2.48e-03
# Epoch 054 | Time 0.51s | Train NLL -4.845 | Val NLL -4.151 | LR 2.40e-03
# Epoch 055 | Time 0.48s | Train NLL -4.752 | Val NLL -4.989 | LR 2.31e-03
# Epoch 056 | Time 0.40s | Train NLL -5.168 | Val NLL -4.299 | LR 2.23e-03
# Epoch 057 | Time 0.37s | Train NLL -4.641 | Val NLL -3.924 | LR 2.15e-03
# Epoch 058 | Time 0.33s | Train NLL -5.030 | Val NLL -5.291 | LR 2.06e-03
# Epoch 059 | Time 0.33s | Train NLL -5.266 | Val NLL -4.866 | LR 1.98e-03
# Epoch 060 | Time 0.33s | Train NLL -5.517 | Val NLL -4.778 | LR 1.90e-03
# Epoch 061 | Time 0.33s | Train NLL -5.726 | Val NLL -5.211 | LR 1.82e-03
# Epoch 062 | Time 0.34s | Train NLL -5.927 | Val NLL -5.357 | LR 1.73e-03
# Epoch 063 | Time 0.40s | Train NLL -5.965 | Val NLL -3.831 | LR 1.65e-03
# Epoch 064 | Time 0.33s | Train NLL -4.308 | Val NLL -2.667 | LR 1.57e-03
# Epoch 065 | Time 0.35s | Train NLL -2.509 | Val NLL -1.842 | LR 1.50e-03
# Epoch 066 | Time 0.33s | Train NLL -4.016 | Val NLL -4.716 | LR 1.42e-03
# Epoch 067 | Time 0.37s | Train NLL -5.021 | Val NLL -5.443 | LR 1.34e-03
# Epoch 068 | Time 0.36s | Train NLL -5.816 | Val NLL -4.662 | LR 1.27e-03
# Epoch 069 | Time 0.42s | Train NLL -5.356 | Val NLL -5.548 | LR 1.20e-03
# Epoch 070 | Time 0.43s | Train NLL -5.478 | Val NLL -5.691 | LR 1.13e-03
# Epoch 071 | Time 0.41s | Train NLL -5.082 | Val NLL -4.029 | LR 1.06e-03
# Epoch 072 | Time 0.40s | Train NLL -5.199 | Val NLL -4.547 | LR 9.88e-04
# Epoch 073 | Time 0.42s | Train NLL -4.033 | Val NLL -3.404 | LR 9.21e-04
# Epoch 074 | Time 0.38s | Train NLL -4.436 | Val NLL -3.989 | LR 8.57e-04
# Epoch 075 | Time 0.38s | Train NLL -5.391 | Val NLL -5.367 | LR 7.94e-04
# Epoch 076 | Time 0.35s | Train NLL -6.026 | Val NLL -4.933 | LR 7.33e-04
# Epoch 077 | Time 0.35s | Train NLL -5.500 | Val NLL -5.593 | LR 6.75e-04
# Epoch 078 | Time 0.38s | Train NLL -5.635 | Val NLL -5.047 | LR 6.18e-04
# Epoch 079 | Time 0.39s | Train NLL -5.787 | Val NLL -5.831 | LR 5.64e-04
# Epoch 080 | Time 0.37s | Train NLL -6.377 | Val NLL -5.832 | LR 5.12e-04
# Epoch 081 | Time 0.36s | Train NLL -6.421 | Val NLL -6.169 | LR 4.62e-04
# Epoch 082 | Time 0.40s | Train NLL -6.649 | Val NLL -5.960 | LR 4.14e-04
# Epoch 083 | Time 0.43s | Train NLL -6.500 | Val NLL -6.208 | LR 3.69e-04
# Epoch 084 | Time 0.39s | Train NLL -6.685 | Val NLL -5.936 | LR 3.27e-04
# Epoch 085 | Time 0.37s | Train NLL -6.763 | Val NLL -6.256 | LR 2.87e-04
# Epoch 086 | Time 0.40s | Train NLL -6.787 | Val NLL -6.547 | LR 2.49e-04
# Epoch 087 | Time 0.37s | Train NLL -7.042 | Val NLL -6.532 | LR 2.14e-04
# Epoch 088 | Time 0.38s | Train NLL -7.020 | Val NLL -6.543 | LR 1.82e-04
# Epoch 089 | Time 0.36s | Train NLL -7.146 | Val NLL -6.427 | LR 1.53e-04
# Epoch 090 | Time 0.37s | Train NLL -7.053 | Val NLL -6.700 | LR 1.26e-04
# Epoch 091 | Time 0.38s | Train NLL -7.277 | Val NLL -6.689 | LR 1.02e-04
# Epoch 092 | Time 0.36s | Train NLL -7.339 | Val NLL -6.746 | LR 8.02e-05
# Epoch 093 | Time 0.39s | Train NLL -7.377 | Val NLL -6.794 | LR 6.16e-05
# Epoch 094 | Time 0.39s | Train NLL -7.432 | Val NLL -6.814 | LR 4.59e-05
# Epoch 095 | Time 0.47s | Train NLL -7.412 | Val NLL -6.851 | LR 3.30e-05
# Epoch 096 | Time 0.50s | Train NLL -7.404 | Val NLL -6.875 | LR 2.29e-05
# Epoch 097 | Time 0.52s | Train NLL -7.536 | Val NLL -6.887 | LR 1.58e-05
# Epoch 098 | Time 0.48s | Train NLL -7.536 | Val NLL -6.897 | LR 1.14e-05
# Epoch 099 | Time 0.52s | Train NLL -7.508 | Val NLL -6.911 | LR 1.00e-05

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 000 | Time 0.49s | Train NLL 2.774 | Val NLL 2.272 | LR 1.10e-03
# Epoch 001 | Time 0.32s | Train NLL 1.387 | Val NLL 0.859 | LR 1.70e-03
# Epoch 002 | Time 0.32s | Train NLL 0.593 | Val NLL 1.157 | LR 2.30e-03
# Epoch 003 | Time 0.33s | Train NLL 1.884 | Val NLL 1.223 | LR 2.90e-03
# Epoch 004 | Time 0.36s | Train NLL 0.506 | Val NLL 1.616 | LR 3.50e-03
# Epoch 005 | Time 0.30s | Train NLL 1.759 | Val NLL 3.068 | LR 4.10e-03
# Epoch 006 | Time 0.36s | Train NLL 1.728 | Val NLL 0.917 | LR 4.70e-03
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 007 | Time 0.57s | Train NLL 0.380 | Val NLL 1.217 | LR 5.00e-03
# Epoch 008 | Time 0.44s | Train NLL 0.578 | Val NLL -0.050 | LR 5.00e-03
# Epoch 009 | Time 0.37s | Train NLL -0.524 | Val NLL -0.319 | LR 4.99e-03
# Epoch 010 | Time 0.31s | Train NLL -1.119 | Val NLL -0.566 | LR 4.98e-03
# Epoch 011 | Time 0.31s | Train NLL -1.315 | Val NLL -1.043 | LR 4.97e-03
# Epoch 012 | Time 0.32s | Train NLL -1.115 | Val NLL -1.225 | LR 4.96e-03
# Epoch 013 | Time 0.41s | Train NLL -0.848 | Val NLL -0.095 | LR 4.94e-03
# Epoch 014 | Time 0.46s | Train NLL -0.545 | Val NLL -0.699 | LR 4.92e-03
# Epoch 015 | Time 0.30s | Train NLL -1.035 | Val NLL -1.224 | LR 4.90e-03
# Epoch 016 | Time 0.35s | Train NLL -1.331 | Val NLL -1.440 | LR 4.87e-03
# Epoch 017 | Time 0.45s | Train NLL -1.861 | Val NLL -2.339 | LR 4.84e-03
# Epoch 018 | Time 0.36s | Train NLL -1.478 | Val NLL -0.453 | LR 4.81e-03
# Epoch 019 | Time 0.33s | Train NLL -1.660 | Val NLL -1.385 | LR 4.78e-03
# Epoch 020 | Time 0.30s | Train NLL -2.242 | Val NLL -2.098 | LR 4.74e-03
# Epoch 021 | Time 0.33s | Train NLL -2.278 | Val NLL -2.383 | LR 4.70e-03
# Epoch 022 | Time 0.32s | Train NLL -2.140 | Val NLL -2.607 | LR 4.66e-03
# Epoch 023 | Time 0.35s | Train NLL -2.867 | Val NLL -1.972 | LR 4.62e-03
# Epoch 024 | Time 0.33s | Train NLL -2.121 | Val NLL -0.703 | LR 4.57e-03
# Epoch 025 | Time 0.31s | Train NLL -0.785 | Val NLL 0.225 | LR 4.52e-03
# Epoch 026 | Time 0.29s | Train NLL -1.040 | Val NLL -0.342 | LR 4.47e-03
# Epoch 027 | Time 0.32s | Train NLL -1.141 | Val NLL -2.155 | LR 4.42e-03
# Epoch 028 | Time 0.32s | Train NLL -2.110 | Val NLL -1.616 | LR 4.36e-03
# Epoch 029 | Time 0.38s | Train NLL -2.270 | Val NLL -1.628 | LR 4.31e-03
# Epoch 030 | Time 0.32s | Train NLL -2.234 | Val NLL -2.073 | LR 4.25e-03
# Epoch 031 | Time 0.82s | Train NLL -2.717 | Val NLL -2.497 | LR 4.18e-03
# Epoch 032 | Time 0.43s | Train NLL -3.399 | Val NLL -2.604 | LR 4.12e-03
# Epoch 033 | Time 0.42s | Train NLL -3.190 | Val NLL -1.868 | LR 4.06e-03
# Epoch 034 | Time 0.39s | Train NLL -2.910 | Val NLL -2.867 | LR 3.99e-03
# Epoch 035 | Time 0.56s | Train NLL -2.342 | Val NLL 0.366 | LR 3.92e-03
# Epoch 036 | Time 0.47s | Train NLL -0.788 | Val NLL -1.153 | LR 3.85e-03
# Epoch 037 | Time 0.42s | Train NLL -2.082 | Val NLL -1.538 | LR 3.78e-03
# Epoch 038 | Time 0.40s | Train NLL -2.248 | Val NLL -1.511 | LR 3.70e-03
# Epoch 039 | Time 0.37s | Train NLL -2.500 | Val NLL -3.197 | LR 3.63e-03
# Epoch 040 | Time 0.45s | Train NLL -2.899 | Val NLL -1.903 | LR 3.55e-03
# Epoch 041 | Time 0.53s | Train NLL -2.091 | Val NLL -3.234 | LR 3.47e-03
# Epoch 042 | Time 0.46s | Train NLL -2.679 | Val NLL -3.422 | LR 3.40e-03
# Epoch 043 | Time 0.37s | Train NLL -2.919 | Val NLL -2.953 | LR 3.32e-03
# Epoch 044 | Time 0.35s | Train NLL -3.427 | Val NLL -3.645 | LR 3.24e-03
# Epoch 045 | Time 0.33s | Train NLL -2.913 | Val NLL -3.207 | LR 3.15e-03
# Epoch 046 | Time 0.34s | Train NLL -3.580 | Val NLL -2.672 | LR 3.07e-03
# Epoch 047 | Time 0.33s | Train NLL -2.929 | Val NLL -3.889 | LR 2.99e-03
# Epoch 048 | Time 0.34s | Train NLL -3.861 | Val NLL -3.516 | LR 2.91e-03
# Epoch 049 | Time 0.33s | Train NLL -3.929 | Val NLL -3.093 | LR 2.82e-03
# Epoch 050 | Time 0.33s | Train NLL -4.071 | Val NLL -3.536 | LR 2.74e-03
# Epoch 051 | Time 0.31s | Train NLL -4.316 | Val NLL -3.828 | LR 2.65e-03
# Epoch 052 | Time 0.31s | Train NLL -4.520 | Val NLL -4.453 | LR 2.57e-03
# Epoch 053 | Time 0.32s | Train NLL -4.953 | Val NLL -4.074 | LR 2.48e-03
# Epoch 054 | Time 0.51s | Train NLL -4.845 | Val NLL -4.151 | LR 2.40e-03
# Epoch 055 | Time 0.48s | Train NLL -4.752 | Val NLL -4.989 | LR 2.31e-03
# Epoch 056 | Time 0.40s | Train NLL -5.168 | Val NLL -4.299 | LR 2.23e-03
# Epoch 057 | Time 0.37s | Train NLL -4.641 | Val NLL -3.924 | LR 2.15e-03
# Epoch 058 | Time 0.33s | Train NLL -5.030 | Val NLL -5.291 | LR 2.06e-03
# Epoch 059 | Time 0.33s | Train NLL -5.266 | Val NLL -4.866 | LR 1.98e-03
# Epoch 060 | Time 0.33s | Train NLL -5.517 | Val NLL -4.778 | LR 1.90e-03
# Epoch 061 | Time 0.33s | Train NLL -5.726 | Val NLL -5.211 | LR 1.82e-03
# Epoch 062 | Time 0.34s | Train NLL -5.927 | Val NLL -5.357 | LR 1.73e-03
# Epoch 063 | Time 0.40s | Train NLL -5.965 | Val NLL -3.831 | LR 1.65e-03
# Epoch 064 | Time 0.33s | Train NLL -4.308 | Val NLL -2.667 | LR 1.57e-03
# Epoch 065 | Time 0.35s | Train NLL -2.509 | Val NLL -1.842 | LR 1.50e-03
# Epoch 066 | Time 0.33s | Train NLL -4.016 | Val NLL -4.716 | LR 1.42e-03
# Epoch 067 | Time 0.37s | Train NLL -5.021 | Val NLL -5.443 | LR 1.34e-03
# Epoch 068 | Time 0.36s | Train NLL -5.816 | Val NLL -4.662 | LR 1.27e-03
# Epoch 069 | Time 0.42s | Train NLL -5.356 | Val NLL -5.548 | LR 1.20e-03
# Epoch 070 | Time 0.43s | Train NLL -5.478 | Val NLL -5.691 | LR 1.13e-03
# Epoch 071 | Time 0.41s | Train NLL -5.082 | Val NLL -4.029 | LR 1.06e-03
# Epoch 072 | Time 0.40s | Train NLL -5.199 | Val NLL -4.547 | LR 9.88e-04
# Epoch 073 | Time 0.42s | Train NLL -4.033 | Val NLL -3.404 | LR 9.21e-04
# Epoch 074 | Time 0.38s | Train NLL -4.436 | Val NLL -3.989 | LR 8.57e-04
# Epoch 075 | Time 0.38s | Train NLL -5.391 | Val NLL -5.367 | LR 7.94e-04
# Epoch 076 | Time 0.35s | Train NLL -6.026 | Val NLL -4.933 | LR 7.33e-04
# Epoch 077 | Time 0.35s | Train NLL -5.500 | Val NLL -5.593 | LR 6.75e-04
# Epoch 078 | Time 0.38s | Train NLL -5.635 | Val NLL -5.047 | LR 6.18e-04
# Epoch 079 | Time 0.39s | Train NLL -5.787 | Val NLL -5.831 | LR 5.64e-04
# Epoch 080 | Time 0.37s | Train NLL -6.377 | Val NLL -5.832 | LR 5.12e-04
# Epoch 081 | Time 0.36s | Train NLL -6.421 | Val NLL -6.169 | LR 4.62e-04
# Epoch 082 | Time 0.40s | Train NLL -6.649 | Val NLL -5.960 | LR 4.14e-04
# Epoch 083 | Time 0.43s | Train NLL -6.500 | Val NLL -6.208 | LR 3.69e-04
# Epoch 084 | Time 0.39s | Train NLL -6.685 | Val NLL -5.936 | LR 3.27e-04
# Epoch 085 | Time 0.37s | Train NLL -6.763 | Val NLL -6.256 | LR 2.87e-04
# Epoch 086 | Time 0.40s | Train NLL -6.787 | Val NLL -6.547 | LR 2.49e-04
# Epoch 087 | Time 0.37s | Train NLL -7.042 | Val NLL -6.532 | LR 2.14e-04
# Epoch 088 | Time 0.38s | Train NLL -7.020 | Val NLL -6.543 | LR 1.82e-04
# Epoch 089 | Time 0.36s | Train NLL -7.146 | Val NLL -6.427 | LR 1.53e-04
# Epoch 090 | Time 0.37s | Train NLL -7.053 | Val NLL -6.700 | LR 1.26e-04
# Epoch 091 | Time 0.38s | Train NLL -7.277 | Val NLL -6.689 | LR 1.02e-04
# Epoch 092 | Time 0.36s | Train NLL -7.339 | Val NLL -6.746 | LR 8.02e-05
# Epoch 093 | Time 0.39s | Train NLL -7.377 | Val NLL -6.794 | LR 6.16e-05
# Epoch 094 | Time 0.39s | Train NLL -7.432 | Val NLL -6.814 | LR 4.59e-05
# Epoch 095 | Time 0.47s | Train NLL -7.412 | Val NLL -6.851 | LR 3.30e-05
# Epoch 096 | Time 0.50s | Train NLL -7.404 | Val NLL -6.875 | LR 2.29e-05
# Epoch 097 | Time 0.52s | Train NLL -7.536 | Val NLL -6.887 | LR 1.58e-05
# Epoch 098 | Time 0.48s | Train NLL -7.536 | Val NLL -6.897 | LR 1.14e-05
# Epoch 099 | Time 0.52s | Train NLL -7.508 | Val NLL -6.911 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
def run_inference_and_plot(flow, test_loader, y_scaler, target_cols):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample()
            # Ensure y_hat and y_batch are 2D
            if y_hat.ndim == 1:
                y_hat = y_hat.unsqueeze(1)
            if y_batch.ndim == 1:
                y_batch = y_batch.unsqueeze(1)
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    # Plot for the single target
    plt.figure(figsize=(5,4))
    plt.scatter(y_true[:, 0], y_pred[:, 0], alpha=0.5)
    plt.xlabel(f"True {target_cols[0]}")
    plt.ylabel(f"Predicted {target_cols[0]}")
    plt.title(f"True vs Predicted: {target_cols[0]}")
    plt.plot([y_true[:, 0].min(), y_true[:, 0].max()], [y_true[:, 0].min(), y_true[:, 0].max()], 'r--')
    plt.grid()
    plt.show()

run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 49892384.00
# Average absolute difference in CASUALTIES: 0.66
