# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Drought'
RUN_PATH = Path(f"../runs/best_flow_{EVENT_GROUP.lower()}.pt")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE'
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(
    X, Y, test_size=0.3, random_state=42
)

X_val, X_test, Y_val, Y_test = train_test_split(
    X_temp, Y_temp, test_size=0.5, random_state=42
)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors
X_train = torch.tensor(X_train)
Y_train = torch.tensor(Y_train)

X_val = torch.tensor(X_val)
Y_val = torch.tensor(Y_val)

X_test = torch.tensor(X_test)
Y_test = torch.tensor(Y_test)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
LEARNING_RATE = 1e-3
BATCH_SIZE = 256

# %%
X_DIM = X_train.shape[1]
Y_DIM = 2   # DAMAGES, CASUALTIES

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=LEARNING_RATE, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []
        
history = TrainingHistory()

best_val_loss = np.inf
for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0
    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        loss = -flow(x).log_prob(y).mean()
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)

    # Validation
    flow.eval()
    val_loss = 0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()
    val_loss /= len(val_loader)
    scheduler.step(val_loss)

    # Save history
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]['lr'])
    
    print(
        f"Epoch {epoch:02d} | Time: {time.time() - t0:.2f}s : "
        f"Train NLL: {train_loss:.3f}, "
        f"Val NLL: {val_loss:.3f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        # save model with only the weights
        torch.save(flow.state_dict(), RUN_PATH)
# Out:
# Epoch 00 | Time: 2.80s : Train NLL: -1.360, Val NLL: -4.346
# Epoch 01 | Time: 4.73s : Train NLL: -3.897, Val NLL: -4.816
# Epoch 02 | Time: 4.63s : Train NLL: -3.974, Val NLL: -5.252
# Epoch 03 | Time: 9.85s : Train NLL: -2.995, Val NLL: -5.353
# Epoch 04 | Time: 4.74s : Train NLL: -4.758, Val NLL: -3.567
# Epoch 05 | Time: 3.81s : Train NLL: -4.666, Val NLL: -2.243
# Epoch 06 | Time: 3.70s : Train NLL: -4.092, Val NLL: -5.792
# Epoch 07 | Time: 3.07s : Train NLL: -4.185, Val NLL: -6.325
# Epoch 08 | Time: 3.60s : Train NLL: -5.018, Val NLL: -5.418
# Epoch 09 | Time: 3.41s : Train NLL: -5.206, Val NLL: -5.703
# Epoch 10 | Time: 4.55s : Train NLL: -5.351, Val NLL: -4.353
# Epoch 11 | Time: 3.30s : Train NLL: -4.456, Val NLL: -2.388
# Epoch 12 | Time: 3.50s : Train NLL: -4.650, Val NLL: -6.756
# Epoch 13 | Time: 3.69s : Train NLL: -5.576, Val NLL: -6.930
# Epoch 14 | Time: 2.87s : Train NLL: -4.614, Val NLL: -3.523
# Epoch 15 | Time: 2.91s : Train NLL: -5.422, Val NLL: -4.782
# Epoch 16 | Time: 3.80s : Train NLL: -4.382, Val NLL: -6.920
# Epoch 17 | Time: 4.72s : Train NLL: -5.702, Val NLL: -5.995
# Epoch 18 | Time: 3.92s : Train NLL: -5.196, Val NLL: -5.235
# Epoch 19 | Time: 4.31s : Train NLL: -5.105, Val NLL: -5.378
# Epoch 20 | Time: 3.71s : Train NLL: -4.931, Val NLL: -4.756
# Epoch 21 | Time: 3.39s : Train NLL: -5.399, Val NLL: -8.685
# Epoch 22 | Time: 4.06s : Train NLL: -6.158, Val NLL: -7.409
# Epoch 23 | Time: 3.51s : Train NLL: -6.720, Val NLL: -6.856
# Epoch 24 | Time: 2.94s : Train NLL: -5.874, Val NLL: -3.641
# Epoch 25 | Time: 3.25s : Train NLL: -4.680, Val NLL: -6.416
# Epoch 26 | Time: 2.89s : Train NLL: -6.033, Val NLL: -4.464
# Epoch 27 | Time: 2.88s : Train NLL: -4.781, Val NLL: -5.013
# Epoch 28 | Time: 3.01s : Train NLL: -5.805, Val NLL: -7.695
# Epoch 29 | Time: 3.93s : Train NLL: -6.002, Val NLL: -4.375
# Epoch 30 | Time: 2.93s : Train NLL: -5.931, Val NLL: -8.560
# Epoch 31 | Time: 2.87s : Train NLL: -5.560, Val NLL: -5.418
# Epoch 32 | Time: 2.94s : Train NLL: -5.577, Val NLL: -7.056
# Epoch 33 | Time: 2.88s : Train NLL: -6.409, Val NLL: -5.230
# Epoch 34 | Time: 2.87s : Train NLL: -4.327, Val NLL: 1.151
# Epoch 35 | Time: 2.88s : Train NLL: -4.613, Val NLL: -2.988
# Epoch 36 | Time: 2.88s : Train NLL: -4.677, Val NLL: -3.111
# Epoch 37 | Time: 2.84s : Train NLL: -5.346, Val NLL: -3.296
# Epoch 38 | Time: 2.80s : Train NLL: -5.891, Val NLL: -8.202
# Epoch 39 | Time: 2.87s : Train NLL: -7.274, Val NLL: -4.776
# Epoch 40 | Time: 2.85s : Train NLL: -7.320, Val NLL: -9.576
# Epoch 41 | Time: 2.97s : Train NLL: -7.707, Val NLL: -6.063
# Epoch 42 | Time: 2.78s : Train NLL: -7.595, Val NLL: -9.160
# Epoch 43 | Time: 3.08s : Train NLL: -8.045, Val NLL: -9.488
# Epoch 44 | Time: 3.07s : Train NLL: -7.909, Val NLL: -10.064
# Epoch 45 | Time: 2.97s : Train NLL: -8.129, Val NLL: -9.696
# Epoch 46 | Time: 3.07s : Train NLL: -8.714, Val NLL: -8.142
# Epoch 47 | Time: 2.78s : Train NLL: -8.730, Val NLL: -11.048
# Epoch 48 | Time: 2.97s : Train NLL: -7.874, Val NLL: -7.649
# Epoch 49 | Time: 2.84s : Train NLL: -6.583, Val NLL: -8.431
# Epoch 50 | Time: 2.93s : Train NLL: -7.646, Val NLL: -10.201
# Epoch 51 | Time: 2.85s : Train NLL: -6.077, Val NLL: -4.880
# Epoch 52 | Time: 2.78s : Train NLL: -6.035, Val NLL: -4.136
# Epoch 53 | Time: 2.78s : Train NLL: -7.343, Val NLL: -7.214
# Epoch 54 | Time: 2.87s : Train NLL: -7.043, Val NLL: -5.852
# Epoch 55 | Time: 2.80s : Train NLL: -5.496, Val NLL: -2.965
# Epoch 56 | Time: 3.07s : Train NLL: -5.670, Val NLL: -5.231
# Epoch 57 | Time: 2.95s : Train NLL: -6.556, Val NLL: -7.750
# Epoch 58 | Time: 2.85s : Train NLL: -7.632, Val NLL: -5.572
# Epoch 59 | Time: 2.88s : Train NLL: -7.830, Val NLL: -10.576
# Epoch 60 | Time: 2.87s : Train NLL: -8.300, Val NLL: -8.371
# Epoch 61 | Time: 2.80s : Train NLL: -7.711, Val NLL: -7.982
# Epoch 62 | Time: 2.85s : Train NLL: -7.127, Val NLL: -7.810
# Epoch 63 | Time: 2.98s : Train NLL: -7.767, Val NLL: -9.573
# Epoch 64 | Time: 3.32s : Train NLL: -9.237, Val NLL: -10.910
# Epoch 65 | Time: 3.10s : Train NLL: -9.983, Val NLL: -6.525
# Epoch 66 | Time: 2.90s : Train NLL: -9.682, Val NLL: -11.838
# Epoch 67 | Time: 3.20s : Train NLL: -8.925, Val NLL: -10.489
# Epoch 68 | Time: 2.87s : Train NLL: -10.213, Val NLL: -10.632
# Epoch 69 | Time: 2.82s : Train NLL: -10.397, Val NLL: -11.935
# Epoch 70 | Time: 3.02s : Train NLL: -9.956, Val NLL: -10.987
# Epoch 71 | Time: 2.87s : Train NLL: -8.163, Val NLL: -6.446
# Epoch 72 | Time: 3.18s : Train NLL: -8.561, Val NLL: -9.858
# Epoch 73 | Time: 3.49s : Train NLL: -10.379, Val NLL: -8.654
# Epoch 74 | Time: 3.27s : Train NLL: -8.918, Val NLL: -8.478
# Epoch 75 | Time: 2.90s : Train NLL: -9.456, Val NLL: -11.313
# Epoch 76 | Time: 2.90s : Train NLL: -10.810, Val NLL: -10.361
# Epoch 77 | Time: 2.84s : Train NLL: -10.016, Val NLL: -7.437
# Epoch 78 | Time: 2.86s : Train NLL: -9.129, Val NLL: -10.540
# Epoch 79 | Time: 2.82s : Train NLL: -9.955, Val NLL: -11.731
# Epoch 80 | Time: 2.82s : Train NLL: -10.052, Val NLL: -11.800
# Epoch 81 | Time: 3.05s : Train NLL: -9.659, Val NLL: -11.324
# Epoch 82 | Time: 2.87s : Train NLL: -9.990, Val NLL: -11.631
# Epoch 83 | Time: 3.03s : Train NLL: -10.288, Val NLL: -11.526
# Epoch 84 | Time: 2.97s : Train NLL: -9.202, Val NLL: -9.386
# Epoch 85 | Time: 3.38s : Train NLL: -10.610, Val NLL: -11.649
# Epoch 86 | Time: 3.00s : Train NLL: -11.552, Val NLL: -12.846
# Epoch 87 | Time: 3.33s : Train NLL: -11.433, Val NLL: -9.202
# Epoch 88 | Time: 2.85s : Train NLL: -10.801, Val NLL: -10.626
# Epoch 89 | Time: 2.85s : Train NLL: -11.361, Val NLL: -11.603
# Epoch 90 | Time: 2.92s : Train NLL: -11.244, Val NLL: -11.425
# Epoch 91 | Time: 2.93s : Train NLL: -11.665, Val NLL: -12.339
# Epoch 92 | Time: 2.85s : Train NLL: -11.889, Val NLL: -13.307
# Epoch 93 | Time: 2.92s : Train NLL: -12.126, Val NLL: -9.837
# Epoch 94 | Time: 2.77s : Train NLL: -10.632, Val NLL: -10.884
# Epoch 95 | Time: 2.83s : Train NLL: -9.628, Val NLL: -11.464
# Epoch 96 | Time: 2.88s : Train NLL: -11.786, Val NLL: -12.950
# Epoch 97 | Time: 2.88s : Train NLL: -11.763, Val NLL: -12.055
# Epoch 98 | Time: 2.80s : Train NLL: -10.616, Val NLL: -11.520
# Epoch 99 | Time: 2.85s : Train NLL: -12.211, Val NLL: -12.892
# Epoch 100 | Time: 2.87s : Train NLL: -11.704, Val NLL: -10.975
# Epoch 101 | Time: 2.92s : Train NLL: -10.974, Val NLL: -12.301
# Epoch 102 | Time: 2.83s : Train NLL: -10.707, Val NLL: -12.752
# Epoch 103 | Time: 2.83s : Train NLL: -11.864, Val NLL: -11.939
# Epoch 104 | Time: 2.85s : Train NLL: -11.553, Val NLL: -12.129
# Epoch 105 | Time: 2.95s : Train NLL: -11.967, Val NLL: -11.561
# Epoch 106 | Time: 3.30s : Train NLL: -10.706, Val NLL: -12.207
# Epoch 107 | Time: 2.80s : Train NLL: -11.709, Val NLL: -12.267
# Epoch 108 | Time: 2.95s : Train NLL: -11.663, Val NLL: -11.750
# Epoch 109 | Time: 2.90s : Train NLL: -12.240, Val NLL: -12.515
# Epoch 110 | Time: 2.94s : Train NLL: -12.793, Val NLL: -13.523
# Epoch 111 | Time: 3.00s : Train NLL: -12.950, Val NLL: -14.254
# Epoch 112 | Time: 3.00s : Train NLL: -12.306, Val NLL: -12.339
# Epoch 113 | Time: 2.98s : Train NLL: -12.725, Val NLL: -14.340
# Epoch 114 | Time: 2.92s : Train NLL: -12.207, Val NLL: -14.316
# Epoch 115 | Time: 2.92s : Train NLL: -12.896, Val NLL: -13.949
# Epoch 116 | Time: 2.85s : Train NLL: -12.843, Val NLL: -14.330
# Epoch 117 | Time: 2.95s : Train NLL: -13.301, Val NLL: -12.639
# Epoch 118 | Time: 2.85s : Train NLL: -12.596, Val NLL: -13.229
# Epoch 119 | Time: 2.82s : Train NLL: -12.949, Val NLL: -13.368
# Epoch 120 | Time: 2.87s : Train NLL: -12.442, Val NLL: -13.115
# Epoch 121 | Time: 2.83s : Train NLL: -12.967, Val NLL: -13.190
# Epoch 122 | Time: 2.82s : Train NLL: -12.520, Val NLL: -14.138
# Epoch 123 | Time: 2.78s : Train NLL: -12.227, Val NLL: -14.219
# Epoch 124 | Time: 2.80s : Train NLL: -12.894, Val NLL: -11.643
# Epoch 125 | Time: 2.84s : Train NLL: -12.782, Val NLL: -13.717
# Epoch 126 | Time: 2.93s : Train NLL: -13.040, Val NLL: -13.925
# Epoch 127 | Time: 3.08s : Train NLL: -13.351, Val NLL: -14.250
# Epoch 128 | Time: 2.89s : Train NLL: -13.310, Val NLL: -12.158
# Epoch 129 | Time: 2.99s : Train NLL: -12.334, Val NLL: -14.853
# Epoch 130 | Time: 2.95s : Train NLL: -12.839, Val NLL: -14.187
# Epoch 131 | Time: 3.27s : Train NLL: -11.199, Val NLL: -13.030
# Epoch 132 | Time: 3.15s : Train NLL: -12.897, Val NLL: -12.844
# Epoch 133 | Time: 2.85s : Train NLL: -12.523, Val NLL: -13.870
# Epoch 134 | Time: 2.78s : Train NLL: -13.037, Val NLL: -13.785
# Epoch 135 | Time: 2.87s : Train NLL: -13.654, Val NLL: -14.388
# Epoch 136 | Time: 2.92s : Train NLL: -13.256, Val NLL: -13.816
# Epoch 137 | Time: 2.81s : Train NLL: -11.965, Val NLL: -10.391
# Epoch 138 | Time: 2.90s : Train NLL: -12.041, Val NLL: -13.149
# Epoch 139 | Time: 2.85s : Train NLL: -12.225, Val NLL: -12.975
# Epoch 140 | Time: 2.85s : Train NLL: -12.471, Val NLL: -14.558
# Epoch 141 | Time: 2.84s : Train NLL: -12.963, Val NLL: -12.104
# Epoch 142 | Time: 2.83s : Train NLL: -12.476, Val NLL: -13.825
# Epoch 143 | Time: 2.87s : Train NLL: -12.717, Val NLL: -11.830
# Epoch 144 | Time: 2.86s : Train NLL: -12.687, Val NLL: -12.431
# Epoch 145 | Time: 2.82s : Train NLL: -11.480, Val NLL: -14.479
# Epoch 146 | Time: 2.85s : Train NLL: -13.742, Val NLL: -14.792
# Epoch 147 | Time: 3.02s : Train NLL: -14.006, Val NLL: -14.100
# Epoch 148 | Time: 2.93s : Train NLL: -13.489, Val NLL: -13.564
# Epoch 149 | Time: 2.82s : Train NLL: -13.922, Val NLL: -14.837
# Epoch 150 | Time: 3.00s : Train NLL: -13.798, Val NLL: -12.928
# Epoch 151 | Time: 2.85s : Train NLL: -12.890, Val NLL: -13.707
# Epoch 152 | Time: 2.80s : Train NLL: -13.485, Val NLL: -14.471
# Epoch 153 | Time: 2.91s : Train NLL: -14.042, Val NLL: -13.470
# Epoch 154 | Time: 2.82s : Train NLL: -13.712, Val NLL: -14.872
# Epoch 155 | Time: 2.88s : Train NLL: -14.088, Val NLL: -14.055
# Epoch 156 | Time: 2.82s : Train NLL: -14.156, Val NLL: -15.079
# Epoch 157 | Time: 3.05s : Train NLL: -13.577, Val NLL: -13.184
# Epoch 158 | Time: 2.75s : Train NLL: -13.985, Val NLL: -13.080
# Epoch 159 | Time: 2.92s : Train NLL: -13.063, Val NLL: -13.447
# Epoch 160 | Time: 2.86s : Train NLL: -13.653, Val NLL: -15.437
# Epoch 161 | Time: 2.92s : Train NLL: -14.185, Val NLL: -14.078
# Epoch 162 | Time: 2.83s : Train NLL: -14.386, Val NLL: -15.415
# Epoch 163 | Time: 2.96s : Train NLL: -14.370, Val NLL: -14.516
# Epoch 164 | Time: 2.90s : Train NLL: -14.034, Val NLL: -12.464
# Epoch 165 | Time: 2.82s : Train NLL: -12.875, Val NLL: -13.591
# Epoch 166 | Time: 2.88s : Train NLL: -12.848, Val NLL: -14.248
# Epoch 167 | Time: 2.90s : Train NLL: -14.467, Val NLL: -13.265
# Epoch 168 | Time: 3.10s : Train NLL: -13.770, Val NLL: -14.443
# Epoch 169 | Time: 3.10s : Train NLL: -13.290, Val NLL: -13.679
# Epoch 170 | Time: 2.82s : Train NLL: -13.383, Val NLL: -14.877
# Epoch 171 | Time: 2.90s : Train NLL: -14.062, Val NLL: -15.492
# Epoch 172 | Time: 3.10s : Train NLL: -14.229, Val NLL: -15.532
# Epoch 173 | Time: 3.28s : Train NLL: -13.209, Val NLL: -10.203
# Epoch 174 | Time: 3.12s : Train NLL: -13.762, Val NLL: -15.131
# Epoch 175 | Time: 3.00s : Train NLL: -13.798, Val NLL: -15.232
# Epoch 176 | Time: 2.90s : Train NLL: -13.829, Val NLL: -15.158
# Epoch 177 | Time: 2.97s : Train NLL: -13.672, Val NLL: -14.754
# Epoch 178 | Time: 2.87s : Train NLL: -13.690, Val NLL: -15.019
# Epoch 179 | Time: 2.95s : Train NLL: -13.344, Val NLL: -12.463
# Epoch 180 | Time: 2.88s : Train NLL: -13.969, Val NLL: -13.869
# Epoch 181 | Time: 2.96s : Train NLL: -13.781, Val NLL: -14.616
# Epoch 182 | Time: 2.86s : Train NLL: -13.512, Val NLL: -14.290
# Epoch 183 | Time: 2.82s : Train NLL: -13.446, Val NLL: -13.595
# Epoch 184 | Time: 2.87s : Train NLL: -13.717, Val NLL: -15.566
# Epoch 185 | Time: 2.95s : Train NLL: -13.783, Val NLL: -14.141
# Epoch 186 | Time: 2.87s : Train NLL: -14.465, Val NLL: -14.470
# Epoch 187 | Time: 2.83s : Train NLL: -14.245, Val NLL: -14.986
# Epoch 188 | Time: 2.85s : Train NLL: -14.016, Val NLL: -13.288
# Epoch 189 | Time: 3.35s : Train NLL: -13.861, Val NLL: -13.534
# Epoch 190 | Time: 3.20s : Train NLL: -13.865, Val NLL: -14.648
# Epoch 191 | Time: 3.02s : Train NLL: -14.002, Val NLL: -15.819
# Epoch 192 | Time: 3.17s : Train NLL: -13.300, Val NLL: -15.899
# Epoch 193 | Time: 3.02s : Train NLL: -14.294, Val NLL: -15.825
# Epoch 194 | Time: 3.10s : Train NLL: -13.391, Val NLL: -13.863
# Epoch 195 | Time: 2.93s : Train NLL: -13.558, Val NLL: -14.682
# Epoch 196 | Time: 2.87s : Train NLL: -14.392, Val NLL: -15.398
# Epoch 197 | Time: 3.03s : Train NLL: -13.786, Val NLL: -15.549
# Epoch 198 | Time: 2.97s : Train NLL: -13.795, Val NLL: -15.392
# Epoch 199 | Time: 2.97s : Train NLL: -14.290, Val NLL: -15.233

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Run inference for the test set and plot results for damages and casualties
def run_inference_and_plot(flow, test_loader, y_scaler, target_cols):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            # Get the distribution and sample from it
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze(1)  # shape: [batch, 2]
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    # Inverse scale
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    # Plot for each target
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.scatter(y_true[:, 0], y_pred[:, 0], alpha=0.5)
    plt.xlabel(f"True {target_cols[0]}")
    plt.ylabel(f"Predicted {target_cols[0]}")
    plt.title(f"True vs Predicted: {target_cols[0]}")
    plt.plot([y_true[:, 0].min(), y_true[:, 0].max()], [y_true[:, 0].min(), y_true[:, 0].max()], 'r--')
    plt.grid()
    plt.subplot(1,2,2)
    plt.scatter(y_true[:, 1], y_pred[:, 1], alpha=0.5)
    plt.xlabel(f"True {target_cols[1]}")
    plt.ylabel(f"Predicted {target_cols[1]}")
    plt.title(f"True vs Predicted: {target_cols[1]}")
    plt.plot([y_true[:, 1].min(), y_true[:, 1].max()], [y_true[:, 1].min(), y_true[:, 1].max()], 'r--')
    plt.grid()
    plt.show()

run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS)
