# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils
from utils import TrainingHistory

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wildfire'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = Y_train.shape[1]

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 000 | Time 0.40s | Train NLL 2.151 | Val NLL 1.761 | LR 8.00e-04
# Epoch 001 | Time 0.22s | Train NLL 0.259 | Val NLL 1.118 | LR 1.10e-03
# Epoch 002 | Time 0.25s | Train NLL 0.816 | Val NLL 0.504 | LR 1.40e-03
# Epoch 003 | Time 0.20s | Train NLL 0.897 | Val NLL 0.770 | LR 1.70e-03
# Epoch 004 | Time 0.20s | Train NLL 1.146 | Val NLL 0.795 | LR 2.00e-03
# Epoch 005 | Time 0.20s | Train NLL 0.409 | Val NLL 0.380 | LR 2.30e-03
# Epoch 006 | Time 0.20s | Train NLL -0.303 | Val NLL -0.527 | LR 2.60e-03
# Epoch 007 | Time 0.19s | Train NLL -0.618 | Val NLL -1.609 | LR 2.90e-03
# Epoch 008 | Time 0.20s | Train NLL -0.211 | Val NLL 2.331 | LR 3.20e-03
# Epoch 009 | Time 0.20s | Train NLL 1.117 | Val NLL -0.195 | LR 3.50e-03
# Epoch 010 | Time 0.21s | Train NLL -0.165 | Val NLL 0.464 | LR 3.80e-03
# Epoch 011 | Time 0.19s | Train NLL 1.252 | Val NLL -0.344 | LR 4.10e-03
# Epoch 012 | Time 0.19s | Train NLL -0.399 | Val NLL -0.007 | LR 4.40e-03
# Epoch 013 | Time 0.20s | Train NLL -1.207 | Val NLL -2.402 | LR 4.70e-03
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 014 | Time 0.19s | Train NLL -2.720 | Val NLL -0.421 | LR 5.00e-03
# Epoch 015 | Time 0.20s | Train NLL -0.263 | Val NLL -1.455 | LR 5.00e-03
# Epoch 016 | Time 0.20s | Train NLL -0.285 | Val NLL 1.842 | LR 5.00e-03
# Epoch 017 | Time 0.20s | Train NLL 0.744 | Val NLL -0.507 | LR 5.00e-03
# Epoch 018 | Time 0.19s | Train NLL 0.076 | Val NLL -0.725 | LR 4.99e-03
# Epoch 019 | Time 0.20s | Train NLL -0.825 | Val NLL -0.316 | LR 4.99e-03
# Epoch 020 | Time 0.23s | Train NLL -0.477 | Val NLL -0.801 | LR 4.99e-03
# Epoch 021 | Time 0.19s | Train NLL -0.891 | Val NLL -1.690 | LR 4.98e-03
# Epoch 022 | Time 0.22s | Train NLL -1.073 | Val NLL -0.495 | LR 4.98e-03
# Epoch 023 | Time 0.22s | Train NLL -0.851 | Val NLL -1.157 | LR 4.97e-03
# Epoch 024 | Time 0.19s | Train NLL -1.292 | Val NLL -2.093 | LR 4.96e-03
# Epoch 025 | Time 0.20s | Train NLL -2.797 | Val NLL -2.213 | LR 4.96e-03
# Epoch 026 | Time 0.19s | Train NLL -2.610 | Val NLL -1.310 | LR 4.95e-03
# Epoch 027 | Time 0.19s | Train NLL -2.235 | Val NLL -1.732 | LR 4.94e-03
# Epoch 028 | Time 0.20s | Train NLL -3.029 | Val NLL -3.268 | LR 4.93e-03
# Epoch 029 | Time 0.19s | Train NLL -3.730 | Val NLL -2.832 | LR 4.92e-03
# Epoch 030 | Time 0.20s | Train NLL -3.170 | Val NLL -3.676 | LR 4.91e-03
# Epoch 031 | Time 0.22s | Train NLL -3.997 | Val NLL -4.614 | LR 4.90e-03
# Epoch 032 | Time 0.19s | Train NLL -3.229 | Val NLL -1.405 | LR 4.88e-03
# Epoch 033 | Time 0.20s | Train NLL -2.573 | Val NLL -2.308 | LR 4.87e-03
# Epoch 034 | Time 0.19s | Train NLL -2.084 | Val NLL 0.443 | LR 4.86e-03
# Epoch 035 | Time 0.20s | Train NLL -0.906 | Val NLL 0.261 | LR 4.84e-03
# Epoch 036 | Time 0.19s | Train NLL -1.612 | Val NLL -0.858 | LR 4.83e-03
# Epoch 037 | Time 0.20s | Train NLL -1.790 | Val NLL -1.436 | LR 4.81e-03
# Epoch 038 | Time 0.19s | Train NLL -2.361 | Val NLL -2.385 | LR 4.80e-03
# Epoch 039 | Time 0.20s | Train NLL -2.464 | Val NLL -1.765 | LR 4.78e-03
# Epoch 040 | Time 0.19s | Train NLL -2.602 | Val NLL -0.141 | LR 4.76e-03
# Epoch 041 | Time 0.20s | Train NLL 0.142 | Val NLL -1.924 | LR 4.74e-03
# Epoch 042 | Time 0.22s | Train NLL -0.977 | Val NLL -0.489 | LR 4.72e-03
# Epoch 043 | Time 0.19s | Train NLL -2.009 | Val NLL -2.266 | LR 4.70e-03
# Epoch 044 | Time 0.20s | Train NLL -2.714 | Val NLL -2.406 | LR 4.68e-03
# Epoch 045 | Time 0.19s | Train NLL -2.268 | Val NLL -2.817 | LR 4.66e-03
# Epoch 046 | Time 0.20s | Train NLL -2.306 | Val NLL -2.266 | LR 4.64e-03
# Epoch 047 | Time 0.19s | Train NLL -1.306 | Val NLL -1.855 | LR 4.62e-03
# Epoch 048 | Time 0.20s | Train NLL -2.670 | Val NLL -2.926 | LR 4.60e-03
# Epoch 049 | Time 0.19s | Train NLL -3.370 | Val NLL -2.746 | LR 4.57e-03
# Epoch 050 | Time 0.20s | Train NLL -3.413 | Val NLL -3.936 | LR 4.55e-03
# Epoch 051 | Time 0.22s | Train NLL -3.053 | Val NLL -1.979 | LR 4.52e-03
# Epoch 052 | Time 0.20s | Train NLL -3.953 | Val NLL -3.031 | LR 4.50e-03
# Epoch 053 | Time 0.21s | Train NLL -3.605 | Val NLL -3.573 | LR 4.47e-03
# Epoch 054 | Time 0.19s | Train NLL -3.043 | Val NLL -0.096 | LR 4.45e-03
# Epoch 055 | Time 0.20s | Train NLL -0.970 | Val NLL -1.502 | LR 4.42e-03
# Epoch 056 | Time 0.20s | Train NLL -1.385 | Val NLL -2.340 | LR 4.39e-03
# Epoch 057 | Time 0.20s | Train NLL -1.143 | Val NLL -1.586 | LR 4.36e-03
# Epoch 058 | Time 0.19s | Train NLL -2.092 | Val NLL -1.245 | LR 4.34e-03
# Epoch 059 | Time 0.20s | Train NLL -2.126 | Val NLL -0.949 | LR 4.31e-03
# Epoch 060 | Time 0.20s | Train NLL -1.750 | Val NLL -2.124 | LR 4.28e-03
# Epoch 061 | Time 0.19s | Train NLL -2.577 | Val NLL 1.289 | LR 4.25e-03
# Epoch 062 | Time 0.20s | Train NLL 0.900 | Val NLL 1.236 | LR 4.22e-03
# Epoch 063 | Time 0.19s | Train NLL -1.188 | Val NLL -2.230 | LR 4.18e-03
# Epoch 064 | Time 0.22s | Train NLL -2.161 | Val NLL -1.834 | LR 4.15e-03
# Epoch 065 | Time 0.20s | Train NLL -3.898 | Val NLL -2.823 | LR 4.12e-03
# Epoch 066 | Time 0.19s | Train NLL -3.063 | Val NLL -1.172 | LR 4.09e-03
# Epoch 067 | Time 0.20s | Train NLL -2.323 | Val NLL -2.201 | LR 4.06e-03
# Epoch 068 | Time 0.19s | Train NLL -3.244 | Val NLL -0.936 | LR 4.02e-03
# Epoch 069 | Time 0.20s | Train NLL -2.334 | Val NLL -2.940 | LR 3.99e-03
# Epoch 070 | Time 0.20s | Train NLL -2.777 | Val NLL -1.797 | LR 3.95e-03
# Epoch 071 | Time 0.19s | Train NLL -2.915 | Val NLL -1.448 | LR 3.92e-03
# Epoch 072 | Time 0.20s | Train NLL -1.283 | Val NLL -0.478 | LR 3.88e-03
# Epoch 073 | Time 0.19s | Train NLL -1.299 | Val NLL -1.835 | LR 3.85e-03
# Epoch 074 | Time 0.20s | Train NLL -2.845 | Val NLL -3.332 | LR 3.81e-03
# Epoch 075 | Time 0.21s | Train NLL -2.570 | Val NLL -4.049 | LR 3.78e-03
# Epoch 076 | Time 0.19s | Train NLL -3.313 | Val NLL 0.119 | LR 3.74e-03
# Epoch 077 | Time 0.20s | Train NLL 0.953 | Val NLL -3.706 | LR 3.70e-03
# Epoch 078 | Time 0.19s | Train NLL -3.908 | Val NLL -4.544 | LR 3.67e-03
# Epoch 079 | Time 0.19s | Train NLL -5.020 | Val NLL -2.288 | LR 3.63e-03
# Epoch 080 | Time 0.20s | Train NLL -1.583 | Val NLL -0.479 | LR 3.59e-03
# Epoch 081 | Time 0.19s | Train NLL -1.420 | Val NLL -2.357 | LR 3.55e-03
# Epoch 082 | Time 0.19s | Train NLL -3.288 | Val NLL -3.102 | LR 3.51e-03
# Epoch 083 | Time 0.20s | Train NLL -2.554 | Val NLL -1.293 | LR 3.47e-03
# Epoch 084 | Time 0.30s | Train NLL 0.455 | Val NLL -1.455 | LR 3.44e-03
# Epoch 085 | Time 0.19s | Train NLL -1.898 | Val NLL -2.924 | LR 3.40e-03
# Epoch 086 | Time 0.21s | Train NLL -3.283 | Val NLL -0.998 | LR 3.36e-03
# Epoch 087 | Time 0.19s | Train NLL -2.105 | Val NLL -0.558 | LR 3.32e-03
# Epoch 088 | Time 0.20s | Train NLL -1.865 | Val NLL -3.445 | LR 3.28e-03
# Epoch 089 | Time 0.19s | Train NLL -3.010 | Val NLL -2.708 | LR 3.24e-03
# Epoch 090 | Time 0.19s | Train NLL -3.287 | Val NLL -3.012 | LR 3.19e-03
# Epoch 091 | Time 0.20s | Train NLL -3.339 | Val NLL -2.846 | LR 3.15e-03
# Epoch 092 | Time 0.20s | Train NLL -3.787 | Val NLL -2.360 | LR 3.11e-03
# Epoch 093 | Time 0.20s | Train NLL -3.430 | Val NLL -4.095 | LR 3.07e-03
# Epoch 094 | Time 0.25s | Train NLL -3.657 | Val NLL -5.263 | LR 3.03e-03
# Epoch 095 | Time 0.30s | Train NLL -3.674 | Val NLL -3.611 | LR 2.99e-03
# Epoch 096 | Time 0.29s | Train NLL -3.951 | Val NLL -3.390 | LR 2.95e-03
# Epoch 097 | Time 0.30s | Train NLL -4.625 | Val NLL -4.837 | LR 2.91e-03
# Epoch 098 | Time 0.31s | Train NLL -4.173 | Val NLL -3.569 | LR 2.86e-03
# Epoch 099 | Time 0.28s | Train NLL -4.286 | Val NLL -3.710 | LR 2.82e-03
# Epoch 100 | Time 0.31s | Train NLL -4.185 | Val NLL -0.887 | LR 2.78e-03
# Epoch 101 | Time 0.28s | Train NLL -3.874 | Val NLL -4.951 | LR 2.74e-03
# Epoch 102 | Time 0.30s | Train NLL -3.825 | Val NLL -3.854 | LR 2.70e-03
# Epoch 103 | Time 0.30s | Train NLL -4.106 | Val NLL -3.566 | LR 2.65e-03
# Epoch 104 | Time 0.30s | Train NLL -3.872 | Val NLL -3.974 | LR 2.61e-03
# Epoch 105 | Time 0.30s | Train NLL -3.955 | Val NLL -4.522 | LR 2.57e-03
# Epoch 106 | Time 0.28s | Train NLL -4.974 | Val NLL -4.694 | LR 2.53e-03
# Epoch 107 | Time 0.31s | Train NLL -5.084 | Val NLL -2.992 | LR 2.48e-03
# Epoch 108 | Time 0.28s | Train NLL -4.211 | Val NLL -3.671 | LR 2.44e-03
# Epoch 109 | Time 0.30s | Train NLL -4.846 | Val NLL -1.777 | LR 2.40e-03
# Epoch 110 | Time 0.31s | Train NLL -1.710 | Val NLL -6.167 | LR 2.36e-03
# Epoch 111 | Time 0.30s | Train NLL -3.773 | Val NLL -2.398 | LR 2.31e-03
# Epoch 112 | Time 0.28s | Train NLL -2.330 | Val NLL -4.439 | LR 2.27e-03
# Epoch 113 | Time 0.31s | Train NLL -2.180 | Val NLL 0.133 | LR 2.23e-03
# Epoch 114 | Time 0.28s | Train NLL -1.343 | Val NLL 5.378 | LR 2.19e-03
# Epoch 115 | Time 0.30s | Train NLL 1.227 | Val NLL 0.725 | LR 2.15e-03
# Epoch 116 | Time 0.28s | Train NLL 0.994 | Val NLL -1.318 | LR 2.10e-03
# Epoch 117 | Time 0.30s | Train NLL -1.641 | Val NLL -2.879 | LR 2.06e-03
# Epoch 118 | Time 0.30s | Train NLL -2.793 | Val NLL 0.173 | LR 2.02e-03
# Epoch 119 | Time 0.30s | Train NLL -1.226 | Val NLL -3.520 | LR 1.98e-03
# Epoch 120 | Time 0.28s | Train NLL -4.647 | Val NLL -4.927 | LR 1.94e-03
# Epoch 121 | Time 0.31s | Train NLL -5.465 | Val NLL -5.364 | LR 1.90e-03
# Epoch 122 | Time 0.30s | Train NLL -5.317 | Val NLL -5.257 | LR 1.86e-03
# Epoch 123 | Time 0.28s | Train NLL -3.919 | Val NLL -3.156 | LR 1.82e-03
# Epoch 124 | Time 0.31s | Train NLL -3.970 | Val NLL -1.653 | LR 1.77e-03
# Epoch 125 | Time 0.30s | Train NLL -2.533 | Val NLL -0.652 | LR 1.73e-03
# Epoch 126 | Time 0.28s | Train NLL -0.869 | Val NLL 0.499 | LR 1.69e-03
# Epoch 127 | Time 0.31s | Train NLL -1.652 | Val NLL -2.668 | LR 1.65e-03
# Epoch 128 | Time 0.30s | Train NLL -3.501 | Val NLL -5.409 | LR 1.61e-03
# Epoch 129 | Time 0.30s | Train NLL -4.982 | Val NLL -4.213 | LR 1.57e-03
# Epoch 130 | Time 0.30s | Train NLL -4.718 | Val NLL -4.114 | LR 1.54e-03
# Epoch 131 | Time 0.28s | Train NLL -4.568 | Val NLL -4.028 | LR 1.50e-03
# Epoch 132 | Time 0.31s | Train NLL -5.038 | Val NLL -4.850 | LR 1.46e-03
# Epoch 133 | Time 0.29s | Train NLL -5.393 | Val NLL -4.025 | LR 1.42e-03
# Epoch 134 | Time 0.30s | Train NLL -3.945 | Val NLL -2.680 | LR 1.38e-03
# Epoch 135 | Time 0.28s | Train NLL -3.021 | Val NLL -0.878 | LR 1.34e-03
# Epoch 136 | Time 0.30s | Train NLL -2.467 | Val NLL -1.787 | LR 1.31e-03
# Epoch 137 | Time 0.30s | Train NLL -1.714 | Val NLL -2.484 | LR 1.27e-03
# Epoch 138 | Time 0.28s | Train NLL -0.930 | Val NLL -3.376 | LR 1.23e-03
# Epoch 139 | Time 0.30s | Train NLL -4.030 | Val NLL -3.883 | LR 1.20e-03
# Epoch 140 | Time 0.29s | Train NLL -4.457 | Val NLL -4.540 | LR 1.16e-03
# Epoch 141 | Time 0.30s | Train NLL -5.159 | Val NLL -5.050 | LR 1.13e-03
# Epoch 142 | Time 0.30s | Train NLL -5.575 | Val NLL -5.089 | LR 1.09e-03
# Epoch 143 | Time 0.30s | Train NLL -5.972 | Val NLL -5.762 | LR 1.06e-03
# Epoch 144 | Time 0.30s | Train NLL -6.270 | Val NLL -5.870 | LR 1.02e-03
# Epoch 145 | Time 0.30s | Train NLL -5.540 | Val NLL -4.377 | LR 9.88e-04
# Epoch 146 | Time 0.28s | Train NLL -3.336 | Val NLL -1.793 | LR 9.54e-04
# Epoch 147 | Time 0.30s | Train NLL -5.732 | Val NLL -6.997 | LR 9.21e-04
# Epoch 148 | Time 0.30s | Train NLL -6.837 | Val NLL -5.398 | LR 8.89e-04
# Epoch 149 | Time 0.30s | Train NLL -5.570 | Val NLL -4.944 | LR 8.57e-04
# Epoch 150 | Time 0.30s | Train NLL -6.753 | Val NLL -5.187 | LR 8.25e-04
# Epoch 151 | Time 0.30s | Train NLL -5.983 | Val NLL -5.422 | LR 7.94e-04
# Epoch 152 | Time 0.30s | Train NLL -6.409 | Val NLL -6.251 | LR 7.63e-04
# Epoch 153 | Time 0.30s | Train NLL -7.030 | Val NLL -7.111 | LR 7.33e-04
# Epoch 154 | Time 0.30s | Train NLL -7.178 | Val NLL -7.261 | LR 7.04e-04
# Epoch 155 | Time 0.32s | Train NLL -7.190 | Val NLL -7.070 | LR 6.75e-04
# Epoch 156 | Time 0.28s | Train NLL -7.468 | Val NLL -6.682 | LR 6.46e-04
# Epoch 157 | Time 0.30s | Train NLL -7.446 | Val NLL -6.904 | LR 6.18e-04
# Epoch 158 | Time 0.31s | Train NLL -7.430 | Val NLL -7.116 | LR 5.91e-04
# Epoch 159 | Time 0.33s | Train NLL -7.745 | Val NLL -7.573 | LR 5.64e-04
# Epoch 160 | Time 0.30s | Train NLL -7.801 | Val NLL -7.791 | LR 5.37e-04
# Epoch 161 | Time 0.31s | Train NLL -8.042 | Val NLL -7.774 | LR 5.12e-04
# Epoch 162 | Time 0.30s | Train NLL -8.023 | Val NLL -7.756 | LR 4.87e-04
# Epoch 163 | Time 0.28s | Train NLL -8.268 | Val NLL -7.824 | LR 4.62e-04
# Epoch 164 | Time 0.30s | Train NLL -8.358 | Val NLL -8.050 | LR 4.38e-04
# Epoch 165 | Time 0.30s | Train NLL -8.288 | Val NLL -7.942 | LR 4.14e-04
# Epoch 166 | Time 0.30s | Train NLL -8.310 | Val NLL -8.171 | LR 3.92e-04
# Epoch 167 | Time 0.30s | Train NLL -8.515 | Val NLL -8.150 | LR 3.69e-04
# Epoch 168 | Time 0.31s | Train NLL -8.630 | Val NLL -8.284 | LR 3.48e-04
# Epoch 169 | Time 0.31s | Train NLL -8.672 | Val NLL -8.381 | LR 3.27e-04
# Epoch 170 | Time 0.30s | Train NLL -8.852 | Val NLL -8.691 | LR 3.06e-04
# Epoch 171 | Time 0.28s | Train NLL -7.654 | Val NLL -6.495 | LR 2.87e-04
# Epoch 172 | Time 0.31s | Train NLL -7.518 | Val NLL -5.626 | LR 2.68e-04
# Epoch 173 | Time 0.28s | Train NLL -6.006 | Val NLL -5.847 | LR 2.49e-04
# Epoch 174 | Time 0.30s | Train NLL -7.187 | Val NLL -6.613 | LR 2.31e-04
# Epoch 175 | Time 0.30s | Train NLL -6.217 | Val NLL -6.341 | LR 2.14e-04
# Epoch 176 | Time 0.40s | Train NLL -5.286 | Val NLL -5.151 | LR 1.98e-04
# Epoch 177 | Time 0.32s | Train NLL -6.168 | Val NLL -5.185 | LR 1.82e-04
# Epoch 178 | Time 0.30s | Train NLL -6.891 | Val NLL -6.456 | LR 1.67e-04
# Epoch 179 | Time 0.28s | Train NLL -6.842 | Val NLL -6.844 | LR 1.53e-04
# Epoch 180 | Time 0.30s | Train NLL -7.977 | Val NLL -6.847 | LR 1.39e-04
# Epoch 181 | Time 0.31s | Train NLL -8.070 | Val NLL -7.932 | LR 1.26e-04
# Epoch 182 | Time 0.33s | Train NLL -8.820 | Val NLL -8.188 | LR 1.13e-04
# Epoch 183 | Time 0.30s | Train NLL -8.761 | Val NLL -7.667 | LR 1.02e-04
# Epoch 184 | Time 0.29s | Train NLL -8.569 | Val NLL -8.576 | LR 9.05e-05
# Epoch 185 | Time 0.30s | Train NLL -8.986 | Val NLL -8.590 | LR 8.02e-05
# Epoch 186 | Time 0.28s | Train NLL -9.119 | Val NLL -8.706 | LR 7.06e-05
# Epoch 187 | Time 0.30s | Train NLL -9.267 | Val NLL -8.807 | LR 6.16e-05
# Epoch 188 | Time 0.28s | Train NLL -9.291 | Val NLL -8.823 | LR 5.34e-05
# Epoch 189 | Time 0.30s | Train NLL -9.259 | Val NLL -8.872 | LR 4.59e-05
# Epoch 190 | Time 0.30s | Train NLL -9.402 | Val NLL -8.899 | LR 3.91e-05
# Epoch 191 | Time 0.30s | Train NLL -9.439 | Val NLL -8.922 | LR 3.30e-05
# Epoch 192 | Time 0.30s | Train NLL -9.552 | Val NLL -8.948 | LR 2.76e-05
# Epoch 193 | Time 0.31s | Train NLL -9.448 | Val NLL -8.972 | LR 2.29e-05
# Epoch 194 | Time 0.30s | Train NLL -9.493 | Val NLL -8.990 | LR 1.90e-05
# Epoch 195 | Time 0.30s | Train NLL -9.527 | Val NLL -8.995 | LR 1.58e-05
# Epoch 196 | Time 0.30s | Train NLL -9.465 | Val NLL -9.010 | LR 1.32e-05
# Epoch 197 | Time 0.30s | Train NLL -9.503 | Val NLL -9.022 | LR 1.14e-05
# Epoch 198 | Time 0.20s | Train NLL -9.488 | Val NLL -9.030 | LR 1.04e-05
# Epoch 199 | Time 0.19s | Train NLL -9.612 | Val NLL -9.050 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 49806024.00
# Average absolute difference in CASUALTIES: 0.63

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
