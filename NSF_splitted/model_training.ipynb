# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

from utils import TrainingHistory

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Avalanche'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     Unnamed: 0  DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65          65      0.0           0             0.0       1.00      0.154204
# 72          72      0.0           0             0.0       0.88      0.353445
# 74          74      0.0           0             0.0       1.00      0.353445
# 76          76    100.0           0             0.0       1.75      0.353445
# 82          82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 24 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = Y_train.shape[1]

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# Epoch 000 | Time 0.11s | Train NLL 2.828 | Val NLL 2.134 | LR 5.00e-04
# Epoch 001 | Time 0.08s | Train NLL 2.213 | Val NLL 2.134 | LR 5.00e-04
# Epoch 002 | Time 0.11s | Train NLL 2.213 | Val NLL 1.542 | LR 5.00e-04
# Epoch 003 | Time 0.09s | Train NLL 1.620 | Val NLL 1.503 | LR 5.00e-04
# Epoch 004 | Time 0.11s | Train NLL 1.578 | Val NLL 1.503 | LR 5.00e-04
# Epoch 005 | Time 0.12s | Train NLL 1.578 | Val NLL 1.029 | LR 4.99e-04
# Epoch 006 | Time 0.10s | Train NLL 1.074 | Val NLL 0.867 | LR 4.99e-04
# Epoch 007 | Time 0.12s | Train NLL 0.898 | Val NLL 0.443 | LR 4.99e-04
# Epoch 008 | Time 0.12s | Train NLL 0.469 | Val NLL 0.208 | LR 4.98e-04
# Epoch 009 | Time 0.11s | Train NLL -0.021 | Val NLL 0.487 | LR 4.98e-04
# Epoch 010 | Time 0.11s | Train NLL 0.248 | Val NLL 0.487 | LR 4.97e-04
# Epoch 011 | Time 0.09s | Train NLL 0.248 | Val NLL 0.517 | LR 4.96e-04
# Epoch 012 | Time 0.10s | Train NLL 0.464 | Val NLL -0.493 | LR 4.96e-04
# Epoch 013 | Time 0.09s | Train NLL -0.009 | Val NLL -0.290 | LR 4.95e-04
# Epoch 014 | Time 0.09s | Train NLL 0.225 | Val NLL -0.039 | LR 4.94e-04
# Epoch 015 | Time 0.09s | Train NLL 0.224 | Val NLL -0.039 | LR 4.93e-04
# Epoch 016 | Time 0.09s | Train NLL 0.224 | Val NLL -0.667 | LR 4.92e-04
# Epoch 017 | Time 0.09s | Train NLL -0.516 | Val NLL 0.608 | LR 4.91e-04
# Epoch 018 | Time 0.09s | Train NLL 0.368 | Val NLL 0.514 | LR 4.90e-04
# Epoch 019 | Time 0.09s | Train NLL 0.426 | Val NLL -0.529 | LR 4.89e-04
# Epoch 020 | Time 0.09s | Train NLL -0.337 | Val NLL -0.556 | LR 4.88e-04
# Epoch 021 | Time 0.09s | Train NLL -0.588 | Val NLL -0.379 | LR 4.87e-04
# Epoch 022 | Time 0.08s | Train NLL -0.438 | Val NLL -0.858 | LR 4.86e-04
# Epoch 023 | Time 0.09s | Train NLL -0.786 | Val NLL -1.168 | LR 4.84e-04
# Epoch 024 | Time 0.12s | Train NLL -1.109 | Val NLL -1.176 | LR 4.83e-04
# Epoch 025 | Time 0.09s | Train NLL -1.136 | Val NLL -1.577 | LR 4.81e-04
# Epoch 026 | Time 0.09s | Train NLL -1.257 | Val NLL -1.577 | LR 4.80e-04
# Epoch 027 | Time 0.09s | Train NLL -1.257 | Val NLL -1.192 | LR 4.78e-04
# Epoch 028 | Time 0.10s | Train NLL -1.071 | Val NLL -1.190 | LR 4.77e-04
# Epoch 029 | Time 0.09s | Train NLL -1.178 | Val NLL -1.541 | LR 4.75e-04
# Epoch 030 | Time 0.09s | Train NLL -1.485 | Val NLL -1.765 | LR 4.73e-04
# Epoch 031 | Time 0.09s | Train NLL -1.705 | Val NLL -2.169 | LR 4.72e-04
# Epoch 032 | Time 0.09s | Train NLL -2.036 | Val NLL -1.263 | LR 4.70e-04
# Epoch 033 | Time 0.09s | Train NLL -1.118 | Val NLL -0.983 | LR 4.68e-04
# Epoch 034 | Time 0.09s | Train NLL -0.897 | Val NLL -1.502 | LR 4.66e-04
# Epoch 035 | Time 0.09s | Train NLL -1.384 | Val NLL -1.937 | LR 4.64e-04
# Epoch 036 | Time 0.11s | Train NLL -1.649 | Val NLL -1.742 | LR 4.62e-04
# Epoch 037 | Time 0.12s | Train NLL -1.470 | Val NLL -1.691 | LR 4.60e-04
# Epoch 038 | Time 0.09s | Train NLL -1.569 | Val NLL -2.049 | LR 4.58e-04
# Epoch 039 | Time 0.09s | Train NLL -2.042 | Val NLL -2.682 | LR 4.55e-04
# Epoch 040 | Time 0.10s | Train NLL -2.371 | Val NLL -2.906 | LR 4.53e-04
# Epoch 041 | Time 0.13s | Train NLL -2.595 | Val NLL -2.511 | LR 4.51e-04
# Epoch 042 | Time 0.09s | Train NLL -2.450 | Val NLL -2.425 | LR 4.49e-04
# Epoch 043 | Time 0.09s | Train NLL -2.364 | Val NLL -2.594 | LR 4.46e-04
# Epoch 044 | Time 0.09s | Train NLL -2.737 | Val NLL -1.857 | LR 4.44e-04
# Epoch 045 | Time 0.11s | Train NLL -2.268 | Val NLL -1.877 | LR 4.41e-04
# Epoch 046 | Time 0.10s | Train NLL -2.325 | Val NLL -2.170 | LR 4.39e-04
# Epoch 047 | Time 0.08s | Train NLL -2.490 | Val NLL -2.238 | LR 4.36e-04
# Epoch 048 | Time 0.09s | Train NLL -2.548 | Val NLL -2.107 | LR 4.34e-04
# Epoch 049 | Time 0.09s | Train NLL -2.287 | Val NLL -2.127 | LR 4.31e-04
# Epoch 050 | Time 0.08s | Train NLL -2.435 | Val NLL -2.784 | LR 4.28e-04
# Epoch 051 | Time 0.08s | Train NLL -2.778 | Val NLL -2.931 | LR 4.26e-04
# Epoch 052 | Time 0.08s | Train NLL -2.856 | Val NLL -2.847 | LR 4.23e-04
# Epoch 053 | Time 0.09s | Train NLL -2.645 | Val NLL -3.165 | LR 4.20e-04
# Epoch 054 | Time 0.09s | Train NLL -3.119 | Val NLL -2.532 | LR 4.17e-04
# Epoch 055 | Time 0.08s | Train NLL -2.654 | Val NLL -2.500 | LR 4.14e-04
# Epoch 056 | Time 0.08s | Train NLL -2.638 | Val NLL -3.199 | LR 4.11e-04
# Epoch 057 | Time 0.09s | Train NLL -3.310 | Val NLL -2.946 | LR 4.08e-04
# Epoch 058 | Time 0.08s | Train NLL -2.616 | Val NLL -2.755 | LR 4.05e-04
# Epoch 059 | Time 0.08s | Train NLL -2.664 | Val NLL -2.801 | LR 4.02e-04
# Epoch 060 | Time 0.09s | Train NLL -3.127 | Val NLL -3.278 | LR 3.99e-04
# Epoch 061 | Time 0.08s | Train NLL -3.092 | Val NLL -3.492 | LR 3.96e-04
# Epoch 062 | Time 0.08s | Train NLL -3.329 | Val NLL -2.751 | LR 3.93e-04
# Epoch 063 | Time 0.09s | Train NLL -2.542 | Val NLL -2.903 | LR 3.90e-04
# Epoch 064 | Time 0.09s | Train NLL -2.517 | Val NLL -3.660 | LR 3.86e-04
# Epoch 065 | Time 0.08s | Train NLL -3.537 | Val NLL -2.764 | LR 3.83e-04
# Epoch 066 | Time 0.09s | Train NLL -3.043 | Val NLL -1.783 | LR 3.80e-04
# Epoch 067 | Time 0.08s | Train NLL -2.239 | Val NLL -2.603 | LR 3.76e-04
# Epoch 068 | Time 0.08s | Train NLL -2.796 | Val NLL -3.394 | LR 3.73e-04
# Epoch 069 | Time 0.08s | Train NLL -3.670 | Val NLL -2.569 | LR 3.70e-04
# Epoch 070 | Time 0.08s | Train NLL -2.422 | Val NLL -1.993 | LR 3.66e-04
# Epoch 071 | Time 0.08s | Train NLL -1.711 | Val NLL -2.406 | LR 3.63e-04
# Epoch 072 | Time 0.08s | Train NLL -2.149 | Val NLL -2.791 | LR 3.59e-04
# Epoch 073 | Time 0.08s | Train NLL -2.522 | Val NLL -2.628 | LR 3.56e-04
# Epoch 074 | Time 0.08s | Train NLL -2.776 | Val NLL -2.628 | LR 3.52e-04
# Epoch 075 | Time 0.08s | Train NLL -2.776 | Val NLL -1.856 | LR 3.49e-04
# Epoch 076 | Time 0.09s | Train NLL -2.032 | Val NLL -1.977 | LR 3.45e-04
# Epoch 077 | Time 0.08s | Train NLL -1.992 | Val NLL -2.121 | LR 3.42e-04
# Epoch 078 | Time 0.10s | Train NLL -2.029 | Val NLL -2.139 | LR 3.38e-04
# Epoch 079 | Time 0.13s | Train NLL -2.073 | Val NLL -3.356 | LR 3.34e-04
# Epoch 080 | Time 0.08s | Train NLL -3.243 | Val NLL -3.575 | LR 3.31e-04
# Epoch 081 | Time 0.09s | Train NLL -3.641 | Val NLL -3.015 | LR 3.27e-04
# Epoch 082 | Time 0.09s | Train NLL -3.135 | Val NLL -3.302 | LR 3.23e-04
# Epoch 083 | Time 0.09s | Train NLL -3.457 | Val NLL -4.101 | LR 3.20e-04
# Epoch 084 | Time 0.10s | Train NLL -4.047 | Val NLL -3.920 | LR 3.16e-04
# Epoch 085 | Time 0.09s | Train NLL -3.914 | Val NLL -4.038 | LR 3.12e-04
# Epoch 086 | Time 0.09s | Train NLL -4.161 | Val NLL -3.814 | LR 3.08e-04
# Epoch 087 | Time 0.09s | Train NLL -4.078 | Val NLL -3.762 | LR 3.05e-04
# Epoch 088 | Time 0.08s | Train NLL -3.843 | Val NLL -3.862 | LR 3.01e-04
# Epoch 089 | Time 0.08s | Train NLL -4.017 | Val NLL -3.515 | LR 2.97e-04
# Epoch 090 | Time 0.09s | Train NLL -3.649 | Val NLL -3.361 | LR 2.93e-04
# Epoch 091 | Time 0.08s | Train NLL -3.456 | Val NLL -4.069 | LR 2.90e-04
# Epoch 092 | Time 0.09s | Train NLL -4.072 | Val NLL -3.757 | LR 2.86e-04
# Epoch 093 | Time 0.08s | Train NLL -3.779 | Val NLL -3.176 | LR 2.82e-04
# Epoch 094 | Time 0.08s | Train NLL -3.340 | Val NLL -3.746 | LR 2.78e-04
# Epoch 095 | Time 0.08s | Train NLL -3.898 | Val NLL -4.031 | LR 2.74e-04
# Epoch 096 | Time 0.09s | Train NLL -4.207 | Val NLL -4.094 | LR 2.70e-04
# Epoch 097 | Time 0.08s | Train NLL -4.167 | Val NLL -4.343 | LR 2.67e-04
# Epoch 098 | Time 0.09s | Train NLL -4.332 | Val NLL -4.099 | LR 2.63e-04
# Epoch 099 | Time 0.08s | Train NLL -4.257 | Val NLL -4.117 | LR 2.59e-04
# Epoch 100 | Time 0.08s | Train NLL -4.233 | Val NLL -4.389 | LR 2.55e-04
# Epoch 101 | Time 0.08s | Train NLL -4.498 | Val NLL -4.311 | LR 2.51e-04
# Epoch 102 | Time 0.09s | Train NLL -4.494 | Val NLL -4.404 | LR 2.47e-04
# Epoch 103 | Time 0.08s | Train NLL -4.646 | Val NLL -4.598 | LR 2.43e-04
# Epoch 104 | Time 0.08s | Train NLL -4.886 | Val NLL -4.602 | LR 2.40e-04
# Epoch 105 | Time 0.09s | Train NLL -4.782 | Val NLL -4.334 | LR 2.36e-04
# Epoch 106 | Time 0.08s | Train NLL -4.564 | Val NLL -4.157 | LR 2.32e-04
# Epoch 107 | Time 0.08s | Train NLL -4.639 | Val NLL -4.216 | LR 2.28e-04
# Epoch 108 | Time 0.08s | Train NLL -4.708 | Val NLL -4.538 | LR 2.24e-04
# Epoch 109 | Time 0.09s | Train NLL -4.902 | Val NLL -5.064 | LR 2.20e-04
# Epoch 110 | Time 0.08s | Train NLL -5.020 | Val NLL -4.333 | LR 2.17e-04
# Epoch 111 | Time 0.08s | Train NLL -4.585 | Val NLL -4.419 | LR 2.13e-04
# Epoch 112 | Time 0.08s | Train NLL -4.497 | Val NLL -4.697 | LR 2.09e-04
# Epoch 113 | Time 0.08s | Train NLL -4.645 | Val NLL -4.273 | LR 2.05e-04
# Epoch 114 | Time 0.08s | Train NLL -4.284 | Val NLL -4.542 | LR 2.02e-04
# Epoch 115 | Time 0.08s | Train NLL -4.602 | Val NLL -5.138 | LR 1.98e-04
# Epoch 116 | Time 0.09s | Train NLL -5.229 | Val NLL -4.805 | LR 1.94e-04
# Epoch 117 | Time 0.09s | Train NLL -4.796 | Val NLL -4.804 | LR 1.90e-04
# Epoch 118 | Time 0.08s | Train NLL -4.606 | Val NLL -4.842 | LR 1.87e-04
# Epoch 119 | Time 0.09s | Train NLL -5.019 | Val NLL -4.975 | LR 1.83e-04
# Epoch 120 | Time 0.09s | Train NLL -5.059 | Val NLL -4.671 | LR 1.79e-04
# Epoch 121 | Time 0.09s | Train NLL -4.955 | Val NLL -4.957 | LR 1.76e-04
# Epoch 122 | Time 0.08s | Train NLL -5.372 | Val NLL -4.547 | LR 1.72e-04
# Epoch 123 | Time 0.10s | Train NLL -4.955 | Val NLL -4.421 | LR 1.68e-04
# Epoch 124 | Time 0.09s | Train NLL -4.592 | Val NLL -5.009 | LR 1.65e-04
# Epoch 125 | Time 0.09s | Train NLL -4.899 | Val NLL -5.223 | LR 1.61e-04
# Epoch 126 | Time 0.11s | Train NLL -5.375 | Val NLL -4.472 | LR 1.58e-04
# Epoch 127 | Time 0.09s | Train NLL -4.939 | Val NLL -4.193 | LR 1.54e-04
# Epoch 128 | Time 0.09s | Train NLL -4.721 | Val NLL -4.801 | LR 1.51e-04
# Epoch 129 | Time 0.09s | Train NLL -5.249 | Val NLL -5.445 | LR 1.47e-04
# Epoch 130 | Time 0.09s | Train NLL -5.646 | Val NLL -5.265 | LR 1.44e-04
# Epoch 131 | Time 0.09s | Train NLL -5.345 | Val NLL -4.977 | LR 1.40e-04
# Epoch 132 | Time 0.09s | Train NLL -5.181 | Val NLL -5.246 | LR 1.37e-04
# Epoch 133 | Time 0.09s | Train NLL -5.553 | Val NLL -5.428 | LR 1.34e-04
# Epoch 134 | Time 0.09s | Train NLL -5.624 | Val NLL -5.221 | LR 1.30e-04
# Epoch 135 | Time 0.12s | Train NLL -5.433 | Val NLL -5.079 | LR 1.27e-04
# Epoch 136 | Time 0.10s | Train NLL -5.572 | Val NLL -5.484 | LR 1.24e-04
# Epoch 137 | Time 0.09s | Train NLL -6.021 | Val NLL -5.276 | LR 1.20e-04
# Epoch 138 | Time 0.09s | Train NLL -5.638 | Val NLL -5.084 | LR 1.17e-04
# Epoch 139 | Time 0.09s | Train NLL -5.366 | Val NLL -5.198 | LR 1.14e-04
# Epoch 140 | Time 0.09s | Train NLL -5.610 | Val NLL -5.326 | LR 1.11e-04
# Epoch 141 | Time 0.09s | Train NLL -5.975 | Val NLL -5.174 | LR 1.08e-04
# Epoch 142 | Time 0.09s | Train NLL -5.899 | Val NLL -5.144 | LR 1.05e-04
# Epoch 143 | Time 0.08s | Train NLL -5.795 | Val NLL -5.594 | LR 1.02e-04
# Epoch 144 | Time 0.09s | Train NLL -5.991 | Val NLL -5.801 | LR 9.88e-05
# Epoch 145 | Time 0.09s | Train NLL -6.239 | Val NLL -5.009 | LR 9.59e-05
# Epoch 146 | Time 0.09s | Train NLL -5.548 | Val NLL -5.009 | LR 9.30e-05
# Epoch 147 | Time 0.12s | Train NLL -5.548 | Val NLL -4.905 | LR 9.01e-05
# Epoch 148 | Time 0.08s | Train NLL -5.448 | Val NLL -5.276 | LR 8.73e-05
# Epoch 149 | Time 0.09s | Train NLL -6.003 | Val NLL -5.671 | LR 8.45e-05
# Epoch 150 | Time 0.09s | Train NLL -5.965 | Val NLL -5.422 | LR 8.18e-05
# Epoch 151 | Time 0.10s | Train NLL -5.731 | Val NLL -5.386 | LR 7.91e-05
# Epoch 152 | Time 0.10s | Train NLL -5.820 | Val NLL -5.396 | LR 7.64e-05
# Epoch 153 | Time 0.09s | Train NLL -6.072 | Val NLL -5.509 | LR 7.38e-05
# Epoch 154 | Time 0.09s | Train NLL -6.193 | Val NLL -5.742 | LR 7.12e-05
# Epoch 155 | Time 0.09s | Train NLL -6.288 | Val NLL -5.839 | LR 6.87e-05
# Epoch 156 | Time 0.11s | Train NLL -6.476 | Val NLL -5.846 | LR 6.62e-05
# Epoch 157 | Time 0.11s | Train NLL -6.550 | Val NLL -5.865 | LR 6.38e-05
# Epoch 158 | Time 0.10s | Train NLL -6.591 | Val NLL -5.904 | LR 6.14e-05
# Epoch 159 | Time 0.10s | Train NLL -6.635 | Val NLL -6.139 | LR 5.91e-05
# Epoch 160 | Time 0.11s | Train NLL -6.719 | Val NLL -6.126 | LR 5.68e-05
# Epoch 161 | Time 0.10s | Train NLL -6.786 | Val NLL -6.008 | LR 5.46e-05
# Epoch 162 | Time 0.09s | Train NLL -6.671 | Val NLL -5.998 | LR 5.24e-05
# Epoch 163 | Time 0.08s | Train NLL -6.727 | Val NLL -6.038 | LR 5.02e-05
# Epoch 164 | Time 0.08s | Train NLL -6.611 | Val NLL -6.088 | LR 4.81e-05
# Epoch 165 | Time 0.11s | Train NLL -6.614 | Val NLL -6.197 | LR 4.61e-05
# Epoch 166 | Time 0.11s | Train NLL -6.838 | Val NLL -6.021 | LR 4.41e-05
# Epoch 167 | Time 0.12s | Train NLL -6.813 | Val NLL -6.150 | LR 4.22e-05
# Epoch 168 | Time 0.10s | Train NLL -6.894 | Val NLL -6.171 | LR 4.03e-05
# Epoch 169 | Time 0.09s | Train NLL -6.933 | Val NLL -6.234 | LR 3.85e-05
# Epoch 170 | Time 0.10s | Train NLL -6.969 | Val NLL -6.190 | LR 3.67e-05
# Epoch 171 | Time 0.12s | Train NLL -6.920 | Val NLL -6.216 | LR 3.50e-05
# Epoch 172 | Time 0.10s | Train NLL -6.991 | Val NLL -6.125 | LR 3.33e-05
# Epoch 173 | Time 0.11s | Train NLL -6.994 | Val NLL -6.086 | LR 3.17e-05
# Epoch 174 | Time 0.11s | Train NLL -7.038 | Val NLL -6.043 | LR 3.02e-05
# Epoch 175 | Time 0.11s | Train NLL -6.981 | Val NLL -6.130 | LR 2.87e-05
# Epoch 176 | Time 0.10s | Train NLL -7.089 | Val NLL -6.167 | LR 2.72e-05
# Epoch 177 | Time 0.10s | Train NLL -7.079 | Val NLL -6.196 | LR 2.58e-05
# Epoch 178 | Time 0.10s | Train NLL -7.033 | Val NLL -6.305 | LR 2.45e-05
# Epoch 179 | Time 0.11s | Train NLL -7.117 | Val NLL -6.192 | LR 2.32e-05
# Epoch 180 | Time 0.10s | Train NLL -7.096 | Val NLL -6.192 | LR 2.20e-05
# Epoch 181 | Time 0.12s | Train NLL -7.096 | Val NLL -6.219 | LR 2.08e-05
# Epoch 182 | Time 0.08s | Train NLL -7.090 | Val NLL -6.207 | LR 1.97e-05
# Epoch 183 | Time 0.09s | Train NLL -7.014 | Val NLL -6.187 | LR 1.87e-05
# Epoch 184 | Time 0.11s | Train NLL -7.026 | Val NLL -6.296 | LR 1.77e-05
# Epoch 185 | Time 0.09s | Train NLL -7.180 | Val NLL -6.328 | LR 1.68e-05
# Epoch 186 | Time 0.09s | Train NLL -7.144 | Val NLL -6.328 | LR 1.59e-05
# Epoch 187 | Time 0.09s | Train NLL -7.075 | Val NLL -6.370 | LR 1.51e-05
# Epoch 188 | Time 0.09s | Train NLL -7.127 | Val NLL -6.300 | LR 1.43e-05
# Epoch 189 | Time 0.12s | Train NLL -7.084 | Val NLL -6.231 | LR 1.36e-05
# Epoch 190 | Time 0.11s | Train NLL -7.039 | Val NLL -6.292 | LR 1.30e-05
# Epoch 191 | Time 0.10s | Train NLL -7.163 | Val NLL -6.367 | LR 1.24e-05
# Epoch 192 | Time 0.09s | Train NLL -7.288 | Val NLL -6.332 | LR 1.19e-05
# Epoch 193 | Time 0.11s | Train NLL -7.288 | Val NLL -6.321 | LR 1.15e-05
# Epoch 194 | Time 0.10s | Train NLL -7.282 | Val NLL -6.314 | LR 1.11e-05
# Epoch 195 | Time 0.13s | Train NLL -7.257 | Val NLL -6.324 | LR 1.08e-05
# Epoch 196 | Time 0.08s | Train NLL -7.273 | Val NLL -6.344 | LR 1.05e-05
# Epoch 197 | Time 0.09s | Train NLL -7.335 | Val NLL -6.375 | LR 1.03e-05
# Epoch 198 | Time 0.10s | Train NLL -7.362 | Val NLL -6.394 | LR 1.01e-05
# Epoch 199 | Time 0.09s | Train NLL -7.359 | Val NLL -6.393 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 5.19

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
