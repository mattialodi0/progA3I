# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Flood'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 4.66s | Train NLL 3.278 | Val NLL 0.664 | LR 1.00e-03
# Epoch 001 | Time 3.53s | Train NLL -1.591 | Val NLL -3.235 | LR 2.00e-03
# Epoch 002 | Time 3.81s | Train NLL -0.698 | Val NLL -1.298 | LR 3.00e-03
# Epoch 003 | Time 3.73s | Train NLL -0.988 | Val NLL -1.882 | LR 4.00e-03
# Epoch 004 | Time 3.48s | Train NLL -1.205 | Val NLL -2.025 | LR 5.00e-03
# Epoch 005 | Time 3.43s | Train NLL -0.923 | Val NLL -2.516 | LR 5.00e-03
# Epoch 006 | Time 4.12s | Train NLL -1.552 | Val NLL -1.266 | LR 5.00e-03
# Epoch 007 | Time 3.49s | Train NLL -0.605 | Val NLL 1.483 | LR 5.00e-03
# Epoch 008 | Time 3.48s | Train NLL -1.550 | Val NLL -0.759 | LR 5.00e-03
# Epoch 009 | Time 3.49s | Train NLL -1.259 | Val NLL -0.028 | LR 5.00e-03
# Epoch 010 | Time 3.59s | Train NLL -1.207 | Val NLL -2.172 | LR 4.99e-03
# Epoch 011 | Time 3.50s | Train NLL -1.102 | Val NLL 1.265 | LR 4.99e-03
# Epoch 012 | Time 3.59s | Train NLL -2.089 | Val NLL -2.982 | LR 4.99e-03
# Epoch 013 | Time 3.48s | Train NLL -2.689 | Val NLL -4.252 | LR 4.99e-03
# Epoch 014 | Time 3.63s | Train NLL -2.785 | Val NLL -1.791 | LR 4.99e-03
# Epoch 015 | Time 3.58s | Train NLL -3.277 | Val NLL -2.489 | LR 4.98e-03
# Epoch 016 | Time 3.55s | Train NLL -3.201 | Val NLL -0.184 | LR 4.98e-03
# Epoch 017 | Time 3.59s | Train NLL -3.227 | Val NLL -4.408 | LR 4.98e-03
# Epoch 018 | Time 5.57s | Train NLL -3.768 | Val NLL -1.176 | LR 4.97e-03
# Epoch 019 | Time 5.93s | Train NLL -2.897 | Val NLL -2.633 | LR 4.97e-03
# Epoch 020 | Time 3.73s | Train NLL -3.047 | Val NLL 0.717 | LR 4.96e-03
# Epoch 021 | Time 3.65s | Train NLL -3.534 | Val NLL -4.270 | LR 4.96e-03
# Epoch 022 | Time 4.19s | Train NLL -2.721 | Val NLL -3.211 | LR 4.95e-03
# Epoch 023 | Time 4.04s | Train NLL -3.157 | Val NLL -1.986 | LR 4.95e-03
# Epoch 024 | Time 3.55s | Train NLL -3.734 | Val NLL -5.003 | LR 4.94e-03
# Epoch 025 | Time 4.26s | Train NLL -3.306 | Val NLL -4.089 | LR 4.94e-03
# Epoch 026 | Time 3.59s | Train NLL -2.627 | Val NLL -4.116 | LR 4.93e-03
# Epoch 027 | Time 3.53s | Train NLL -2.697 | Val NLL -1.080 | LR 4.93e-03
# Epoch 028 | Time 3.52s | Train NLL -3.486 | Val NLL -3.861 | LR 4.92e-03
# Epoch 029 | Time 3.74s | Train NLL -3.463 | Val NLL -4.989 | LR 4.91e-03
# Epoch 030 | Time 3.55s | Train NLL -4.626 | Val NLL -5.366 | LR 4.90e-03
# Epoch 031 | Time 3.63s | Train NLL -5.035 | Val NLL -4.726 | LR 4.90e-03
# Epoch 032 | Time 3.78s | Train NLL -3.317 | Val NLL -6.392 | LR 4.89e-03
# Epoch 033 | Time 4.38s | Train NLL -3.692 | Val NLL -3.205 | LR 4.88e-03
# Epoch 034 | Time 4.52s | Train NLL -3.980 | Val NLL -5.059 | LR 4.87e-03
# Epoch 035 | Time 4.29s | Train NLL -3.198 | Val NLL -5.202 | LR 4.86e-03
# Epoch 036 | Time 4.30s | Train NLL -4.042 | Val NLL -4.944 | LR 4.86e-03
# Epoch 037 | Time 4.39s | Train NLL -4.104 | Val NLL -5.108 | LR 4.85e-03
# Epoch 038 | Time 4.50s | Train NLL -5.038 | Val NLL -4.250 | LR 4.84e-03
# Epoch 039 | Time 4.50s | Train NLL -3.993 | Val NLL -4.072 | LR 4.83e-03
# Epoch 040 | Time 4.31s | Train NLL -3.722 | Val NLL 3.910 | LR 4.82e-03
# Epoch 041 | Time 4.51s | Train NLL -2.125 | Val NLL -6.075 | LR 4.81e-03
# Epoch 042 | Time 4.27s | Train NLL -3.389 | Val NLL -2.465 | LR 4.80e-03
# Epoch 043 | Time 4.28s | Train NLL -3.523 | Val NLL -4.780 | LR 4.79e-03
# Epoch 044 | Time 4.31s | Train NLL -4.514 | Val NLL -4.372 | LR 4.78e-03
# Epoch 045 | Time 4.81s | Train NLL -2.383 | Val NLL -6.287 | LR 4.77e-03
# Epoch 046 | Time 4.39s | Train NLL -2.753 | Val NLL -2.680 | LR 4.75e-03
# Epoch 047 | Time 4.36s | Train NLL -3.407 | Val NLL -3.019 | LR 4.74e-03
# Epoch 048 | Time 4.51s | Train NLL -3.455 | Val NLL -4.770 | LR 4.73e-03
# Epoch 049 | Time 4.55s | Train NLL -4.128 | Val NLL 1.613 | LR 4.72e-03
# Epoch 050 | Time 4.36s | Train NLL -1.367 | Val NLL -2.531 | LR 4.71e-03
# Epoch 051 | Time 4.16s | Train NLL -4.101 | Val NLL -4.783 | LR 4.69e-03
# Epoch 052 | Time 3.08s | Train NLL -4.226 | Val NLL -2.878 | LR 4.68e-03
# Epoch 053 | Time 3.45s | Train NLL -3.798 | Val NLL -4.627 | LR 4.67e-03
# Epoch 054 | Time 3.24s | Train NLL -3.929 | Val NLL -3.806 | LR 4.65e-03
# Epoch 055 | Time 4.10s | Train NLL -4.747 | Val NLL -4.027 | LR 4.64e-03
# Epoch 056 | Time 4.29s | Train NLL -4.379 | Val NLL -5.882 | LR 4.63e-03
# Epoch 057 | Time 4.42s | Train NLL -5.733 | Val NLL -6.068 | LR 4.61e-03
# Epoch 058 | Time 4.37s | Train NLL -5.967 | Val NLL -6.623 | LR 4.60e-03
# Epoch 059 | Time 4.42s | Train NLL -5.992 | Val NLL -6.836 | LR 4.58e-03
# Epoch 060 | Time 4.51s | Train NLL -6.284 | Val NLL -5.387 | LR 4.57e-03
# Epoch 061 | Time 4.49s | Train NLL -6.013 | Val NLL -6.649 | LR 4.55e-03
# Epoch 062 | Time 4.34s | Train NLL -6.511 | Val NLL -6.785 | LR 4.54e-03
# Epoch 063 | Time 4.33s | Train NLL -6.638 | Val NLL -6.266 | LR 4.52e-03
# Epoch 064 | Time 4.50s | Train NLL -6.699 | Val NLL -6.214 | LR 4.51e-03
# Epoch 065 | Time 4.33s | Train NLL -6.996 | Val NLL -7.468 | LR 4.49e-03
# Epoch 066 | Time 4.45s | Train NLL -6.985 | Val NLL -7.606 | LR 4.47e-03
# Epoch 067 | Time 4.53s | Train NLL -7.076 | Val NLL -7.452 | LR 4.46e-03
# Epoch 068 | Time 3.99s | Train NLL -4.616 | Val NLL -6.507 | LR 4.44e-03
# Epoch 069 | Time 3.08s | Train NLL -6.525 | Val NLL -4.611 | LR 4.42e-03
# Epoch 070 | Time 3.21s | Train NLL -6.712 | Val NLL -7.313 | LR 4.41e-03
# Epoch 071 | Time 4.23s | Train NLL -5.373 | Val NLL -6.146 | LR 4.39e-03
# Epoch 072 | Time 4.37s | Train NLL -6.718 | Val NLL -7.875 | LR 4.37e-03
# Epoch 073 | Time 4.45s | Train NLL -5.367 | Val NLL -7.736 | LR 4.35e-03
# Epoch 074 | Time 4.38s | Train NLL -6.430 | Val NLL -7.167 | LR 4.34e-03
# Epoch 075 | Time 4.47s | Train NLL -5.137 | Val NLL -6.326 | LR 4.32e-03
# Epoch 076 | Time 4.32s | Train NLL -4.530 | Val NLL -2.119 | LR 4.30e-03
# Epoch 077 | Time 4.39s | Train NLL -5.535 | Val NLL -3.948 | LR 4.28e-03
# Epoch 078 | Time 4.51s | Train NLL -3.913 | Val NLL -4.854 | LR 4.26e-03
# Epoch 079 | Time 4.37s | Train NLL -4.646 | Val NLL -3.220 | LR 4.24e-03
# Epoch 080 | Time 4.33s | Train NLL -4.890 | Val NLL -5.607 | LR 4.22e-03
# Epoch 081 | Time 4.34s | Train NLL -5.130 | Val NLL -2.986 | LR 4.21e-03
# Epoch 082 | Time 3.44s | Train NLL -5.451 | Val NLL -5.488 | LR 4.19e-03
# Epoch 083 | Time 3.13s | Train NLL -5.699 | Val NLL -5.590 | LR 4.17e-03
# Epoch 084 | Time 3.35s | Train NLL -6.237 | Val NLL -3.426 | LR 4.15e-03
# Epoch 085 | Time 3.88s | Train NLL -4.973 | Val NLL -5.312 | LR 4.13e-03
# Epoch 086 | Time 4.28s | Train NLL -5.221 | Val NLL -6.929 | LR 4.11e-03
# Epoch 087 | Time 4.42s | Train NLL -4.580 | Val NLL -5.845 | LR 4.09e-03
# Epoch 088 | Time 4.33s | Train NLL -6.913 | Val NLL -6.841 | LR 4.06e-03
# Epoch 089 | Time 4.41s | Train NLL -4.325 | Val NLL -4.969 | LR 4.04e-03
# Epoch 090 | Time 4.36s | Train NLL -5.390 | Val NLL -7.127 | LR 4.02e-03
# Epoch 091 | Time 4.33s | Train NLL -5.355 | Val NLL -6.927 | LR 4.00e-03
# Epoch 092 | Time 4.40s | Train NLL -5.525 | Val NLL -5.211 | LR 3.98e-03
# Epoch 093 | Time 4.45s | Train NLL -6.970 | Val NLL -7.772 | LR 3.96e-03
# Epoch 094 | Time 4.39s | Train NLL -6.018 | Val NLL -6.449 | LR 3.94e-03
# Epoch 095 | Time 4.44s | Train NLL -6.303 | Val NLL -3.875 | LR 3.92e-03
# Epoch 096 | Time 4.50s | Train NLL -6.330 | Val NLL -6.536 | LR 3.89e-03
# Epoch 097 | Time 3.13s | Train NLL -4.900 | Val NLL -7.312 | LR 3.87e-03
# Epoch 098 | Time 3.04s | Train NLL -6.760 | Val NLL -6.484 | LR 3.85e-03
# Epoch 099 | Time 3.36s | Train NLL -5.561 | Val NLL -6.279 | LR 3.83e-03
# Epoch 100 | Time 3.96s | Train NLL -6.469 | Val NLL -5.822 | LR 3.80e-03
# Epoch 101 | Time 4.23s | Train NLL -5.152 | Val NLL -6.648 | LR 3.78e-03
# Epoch 102 | Time 4.22s | Train NLL -5.945 | Val NLL -6.454 | LR 3.76e-03
# Epoch 103 | Time 4.39s | Train NLL -6.957 | Val NLL -8.144 | LR 3.73e-03
# Epoch 104 | Time 4.54s | Train NLL -6.853 | Val NLL -3.193 | LR 3.71e-03
# Epoch 105 | Time 4.32s | Train NLL -4.565 | Val NLL -6.857 | LR 3.69e-03
# Epoch 106 | Time 4.32s | Train NLL -5.601 | Val NLL -6.518 | LR 3.66e-03
# Epoch 107 | Time 4.47s | Train NLL -5.658 | Val NLL -6.066 | LR 3.64e-03
# Epoch 108 | Time 4.33s | Train NLL -5.994 | Val NLL -6.068 | LR 3.62e-03
# Epoch 109 | Time 4.31s | Train NLL -5.477 | Val NLL -5.868 | LR 3.59e-03
# Epoch 110 | Time 4.35s | Train NLL -5.359 | Val NLL -7.419 | LR 3.57e-03
# Epoch 111 | Time 4.20s | Train NLL -6.817 | Val NLL -7.155 | LR 3.55e-03
# Epoch 112 | Time 3.10s | Train NLL -3.709 | Val NLL -3.187 | LR 3.52e-03
# Epoch 113 | Time 3.01s | Train NLL -5.628 | Val NLL -7.112 | LR 3.50e-03
# Epoch 114 | Time 3.43s | Train NLL -5.985 | Val NLL -7.402 | LR 3.47e-03
# Epoch 115 | Time 4.51s | Train NLL -6.429 | Val NLL -5.393 | LR 3.45e-03
# Epoch 116 | Time 4.56s | Train NLL -4.089 | Val NLL -6.578 | LR 3.42e-03
# Epoch 117 | Time 4.40s | Train NLL -6.041 | Val NLL -7.524 | LR 3.40e-03
# Epoch 118 | Time 4.60s | Train NLL -6.684 | Val NLL -6.419 | LR 3.37e-03
# Epoch 119 | Time 4.65s | Train NLL -5.506 | Val NLL -3.700 | LR 3.35e-03
# Epoch 120 | Time 4.50s | Train NLL -5.110 | Val NLL -1.672 | LR 3.32e-03
# Epoch 121 | Time 4.43s | Train NLL -5.036 | Val NLL -6.695 | LR 3.30e-03
# Epoch 122 | Time 4.37s | Train NLL -7.038 | Val NLL -8.371 | LR 3.27e-03
# Epoch 123 | Time 4.55s | Train NLL -6.025 | Val NLL -8.320 | LR 3.25e-03
# Epoch 124 | Time 4.33s | Train NLL -5.635 | Val NLL -8.095 | LR 3.22e-03
# Epoch 125 | Time 4.33s | Train NLL -7.137 | Val NLL -8.299 | LR 3.20e-03
# Epoch 126 | Time 4.52s | Train NLL -6.517 | Val NLL -6.628 | LR 3.17e-03
# Epoch 127 | Time 4.43s | Train NLL -7.273 | Val NLL -8.332 | LR 3.14e-03
# Epoch 128 | Time 4.53s | Train NLL -6.207 | Val NLL -7.867 | LR 3.12e-03
# Epoch 129 | Time 4.63s | Train NLL -6.519 | Val NLL -7.315 | LR 3.09e-03
# Epoch 130 | Time 4.79s | Train NLL -7.088 | Val NLL -7.246 | LR 3.07e-03
# Epoch 131 | Time 4.43s | Train NLL -7.522 | Val NLL -8.545 | LR 3.04e-03
# Epoch 132 | Time 4.49s | Train NLL -6.949 | Val NLL -6.199 | LR 3.02e-03
# Epoch 133 | Time 4.63s | Train NLL -6.954 | Val NLL -8.101 | LR 2.99e-03
# Epoch 134 | Time 4.49s | Train NLL -6.177 | Val NLL -3.557 | LR 2.96e-03
# Epoch 135 | Time 3.21s | Train NLL -6.407 | Val NLL -8.352 | LR 2.94e-03
# Epoch 136 | Time 3.06s | Train NLL -5.439 | Val NLL 1.609 | LR 2.91e-03
# Epoch 137 | Time 3.18s | Train NLL -5.341 | Val NLL -8.245 | LR 2.88e-03
# Epoch 138 | Time 3.75s | Train NLL -6.443 | Val NLL -8.256 | LR 2.86e-03
# Epoch 139 | Time 4.54s | Train NLL -5.811 | Val NLL -7.851 | LR 2.83e-03
# Epoch 140 | Time 4.51s | Train NLL -7.344 | Val NLL -7.513 | LR 2.81e-03
# Epoch 141 | Time 4.48s | Train NLL -6.433 | Val NLL -6.032 | LR 2.78e-03
# Epoch 142 | Time 4.35s | Train NLL -7.353 | Val NLL -8.198 | LR 2.75e-03
# Epoch 143 | Time 4.37s | Train NLL -6.543 | Val NLL -7.273 | LR 2.73e-03
# Epoch 144 | Time 4.75s | Train NLL -7.101 | Val NLL -8.745 | LR 2.70e-03
# Epoch 145 | Time 4.50s | Train NLL -6.529 | Val NLL -6.400 | LR 2.67e-03
# Epoch 146 | Time 4.32s | Train NLL -6.460 | Val NLL -7.617 | LR 2.65e-03
# Epoch 147 | Time 4.33s | Train NLL -5.511 | Val NLL -6.123 | LR 2.62e-03
# Epoch 148 | Time 4.74s | Train NLL -7.429 | Val NLL -6.469 | LR 2.59e-03
# Epoch 149 | Time 4.33s | Train NLL -5.474 | Val NLL -3.345 | LR 2.57e-03
# Epoch 150 | Time 4.29s | Train NLL -5.229 | Val NLL -5.377 | LR 2.54e-03
# Epoch 151 | Time 4.42s | Train NLL -7.331 | Val NLL -8.273 | LR 2.51e-03
# Epoch 152 | Time 4.60s | Train NLL -7.733 | Val NLL -7.262 | LR 2.49e-03
# Epoch 153 | Time 5.23s | Train NLL -5.938 | Val NLL -4.781 | LR 2.46e-03
# Epoch 154 | Time 5.81s | Train NLL -7.222 | Val NLL -7.728 | LR 2.43e-03
# Epoch 155 | Time 4.59s | Train NLL -5.696 | Val NLL -7.960 | LR 2.41e-03
# Epoch 156 | Time 4.56s | Train NLL -7.553 | Val NLL -5.696 | LR 2.38e-03
# Epoch 157 | Time 4.33s | Train NLL -7.349 | Val NLL -5.222 | LR 2.35e-03
# Epoch 158 | Time 4.60s | Train NLL -7.465 | Val NLL -6.999 | LR 2.33e-03
# Epoch 159 | Time 4.32s | Train NLL -7.198 | Val NLL -6.086 | LR 2.30e-03
# Epoch 160 | Time 4.38s | Train NLL -6.977 | Val NLL -6.743 | LR 2.27e-03
# Epoch 161 | Time 4.41s | Train NLL -7.831 | Val NLL -8.512 | LR 2.25e-03
# Epoch 162 | Time 4.32s | Train NLL -6.977 | Val NLL -8.045 | LR 2.22e-03
# Epoch 163 | Time 4.32s | Train NLL -6.602 | Val NLL -7.983 | LR 2.19e-03
# Epoch 164 | Time 4.47s | Train NLL -7.722 | Val NLL -8.555 | LR 2.17e-03
# Epoch 165 | Time 4.37s | Train NLL -7.332 | Val NLL -3.643 | LR 2.14e-03
# Epoch 166 | Time 3.13s | Train NLL -7.957 | Val NLL -8.602 | LR 2.12e-03
# Epoch 167 | Time 3.19s | Train NLL -8.571 | Val NLL -9.449 | LR 2.09e-03
# Epoch 168 | Time 3.29s | Train NLL -5.458 | Val NLL -6.299 | LR 2.06e-03
# Epoch 169 | Time 3.99s | Train NLL -8.350 | Val NLL -9.363 | LR 2.04e-03
# Epoch 170 | Time 4.36s | Train NLL -6.637 | Val NLL -6.770 | LR 2.01e-03
# Epoch 171 | Time 4.44s | Train NLL -6.935 | Val NLL -5.358 | LR 1.98e-03
# Epoch 172 | Time 4.38s | Train NLL -8.169 | Val NLL -5.457 | LR 1.96e-03
# Epoch 173 | Time 4.63s | Train NLL -6.537 | Val NLL -9.015 | LR 1.93e-03
# Epoch 174 | Time 4.48s | Train NLL -6.997 | Val NLL -5.833 | LR 1.91e-03
# Epoch 175 | Time 4.69s | Train NLL -7.394 | Val NLL -8.931 | LR 1.88e-03
# Epoch 176 | Time 4.46s | Train NLL -8.410 | Val NLL -7.884 | LR 1.86e-03
# Epoch 177 | Time 4.44s | Train NLL -7.194 | Val NLL -7.934 | LR 1.83e-03
# Epoch 178 | Time 4.45s | Train NLL -8.713 | Val NLL -8.894 | LR 1.80e-03
# Epoch 179 | Time 4.58s | Train NLL -7.794 | Val NLL -6.807 | LR 1.78e-03
# Epoch 180 | Time 4.37s | Train NLL -6.119 | Val NLL -8.564 | LR 1.75e-03
# Epoch 181 | Time 4.40s | Train NLL -9.192 | Val NLL -7.929 | LR 1.73e-03
# Epoch 182 | Time 4.35s | Train NLL -7.032 | Val NLL -8.220 | LR 1.70e-03
# Epoch 183 | Time 4.51s | Train NLL -7.297 | Val NLL -8.616 | LR 1.68e-03
# Epoch 184 | Time 3.22s | Train NLL -8.739 | Val NLL -9.815 | LR 1.65e-03
# Epoch 185 | Time 3.16s | Train NLL -5.516 | Val NLL -5.685 | LR 1.63e-03
# Epoch 186 | Time 3.68s | Train NLL -7.462 | Val NLL -5.725 | LR 1.60e-03
# Epoch 187 | Time 4.36s | Train NLL -8.256 | Val NLL -9.077 | LR 1.58e-03
# Epoch 188 | Time 5.44s | Train NLL -6.142 | Val NLL -8.246 | LR 1.55e-03
# Epoch 189 | Time 6.03s | Train NLL -8.885 | Val NLL -4.384 | LR 1.53e-03
# Epoch 190 | Time 5.07s | Train NLL -5.173 | Val NLL -6.853 | LR 1.50e-03
# Epoch 191 | Time 4.58s | Train NLL -7.372 | Val NLL -7.968 | LR 1.48e-03
# Epoch 192 | Time 4.47s | Train NLL -7.316 | Val NLL -6.810 | LR 1.45e-03
# Epoch 193 | Time 4.36s | Train NLL -7.332 | Val NLL -8.303 | LR 1.43e-03
# Epoch 194 | Time 4.57s | Train NLL -8.001 | Val NLL -9.285 | LR 1.41e-03
# Epoch 195 | Time 4.62s | Train NLL -8.511 | Val NLL -9.195 | LR 1.38e-03
# Epoch 196 | Time 4.49s | Train NLL -9.170 | Val NLL -9.916 | LR 1.36e-03
# Epoch 197 | Time 4.65s | Train NLL -7.838 | Val NLL -8.386 | LR 1.34e-03
# Epoch 198 | Time 4.45s | Train NLL -9.637 | Val NLL -8.778 | LR 1.31e-03
# Epoch 199 | Time 4.36s | Train NLL -9.813 | Val NLL -9.899 | LR 1.29e-03
# Epoch 200 | Time 4.35s | Train NLL -7.138 | Val NLL -3.683 | LR 1.27e-03
# Epoch 201 | Time 4.65s | Train NLL -8.397 | Val NLL -9.927 | LR 1.24e-03
# Epoch 202 | Time 5.05s | Train NLL -8.974 | Val NLL -2.434 | LR 1.22e-03
# Epoch 203 | Time 4.47s | Train NLL -6.933 | Val NLL -9.363 | LR 1.20e-03
# Epoch 204 | Time 4.57s | Train NLL -8.881 | Val NLL -9.384 | LR 1.17e-03
# Epoch 205 | Time 4.43s | Train NLL -9.678 | Val NLL -9.313 | LR 1.15e-03
# Epoch 206 | Time 4.26s | Train NLL -8.150 | Val NLL -8.303 | LR 1.13e-03
# Epoch 207 | Time 4.46s | Train NLL -9.363 | Val NLL -9.061 | LR 1.11e-03
# Epoch 208 | Time 4.47s | Train NLL -7.567 | Val NLL -9.422 | LR 1.08e-03
# Epoch 209 | Time 4.31s | Train NLL -10.247 | Val NLL -10.424 | LR 1.06e-03
# Epoch 210 | Time 3.17s | Train NLL -7.323 | Val NLL -9.828 | LR 1.04e-03
# Epoch 211 | Time 3.17s | Train NLL -9.723 | Val NLL -7.526 | LR 1.02e-03
# Epoch 212 | Time 3.22s | Train NLL -7.545 | Val NLL -10.039 | LR 9.98e-04
# Epoch 213 | Time 3.87s | Train NLL -9.082 | Val NLL -9.341 | LR 9.77e-04
# Epoch 214 | Time 4.47s | Train NLL -10.072 | Val NLL -10.495 | LR 9.56e-04
# Epoch 215 | Time 4.47s | Train NLL -7.626 | Val NLL -7.897 | LR 9.35e-04
# Epoch 216 | Time 4.59s | Train NLL -9.277 | Val NLL -10.169 | LR 9.15e-04
# Epoch 217 | Time 4.72s | Train NLL -7.940 | Val NLL -9.882 | LR 8.94e-04
# Epoch 218 | Time 4.51s | Train NLL -9.898 | Val NLL -9.465 | LR 8.74e-04
# Epoch 219 | Time 4.55s | Train NLL -9.920 | Val NLL -9.840 | LR 8.54e-04
# Epoch 220 | Time 4.54s | Train NLL -10.067 | Val NLL -9.015 | LR 8.34e-04
# Epoch 221 | Time 4.43s | Train NLL -10.678 | Val NLL -10.834 | LR 8.14e-04
# Epoch 222 | Time 4.45s | Train NLL -10.598 | Val NLL -7.796 | LR 7.94e-04
# Epoch 223 | Time 4.57s | Train NLL -7.011 | Val NLL -5.838 | LR 7.75e-04
# Epoch 224 | Time 4.39s | Train NLL -9.833 | Val NLL -10.924 | LR 7.56e-04
# Epoch 225 | Time 4.44s | Train NLL -10.731 | Val NLL -6.451 | LR 7.37e-04
# Epoch 226 | Time 4.38s | Train NLL -7.530 | Val NLL -9.348 | LR 7.18e-04
# Epoch 227 | Time 4.51s | Train NLL -9.733 | Val NLL -7.816 | LR 7.00e-04
# Epoch 228 | Time 4.33s | Train NLL -10.518 | Val NLL -10.799 | LR 6.81e-04
# Epoch 229 | Time 3.31s | Train NLL -10.528 | Val NLL -4.903 | LR 6.63e-04
# Epoch 230 | Time 3.14s | Train NLL -9.895 | Val NLL -10.571 | LR 6.45e-04
# Epoch 231 | Time 3.22s | Train NLL -11.203 | Val NLL -8.506 | LR 6.27e-04
# Epoch 232 | Time 4.13s | Train NLL -7.325 | Val NLL -7.751 | LR 6.10e-04
# Epoch 233 | Time 4.66s | Train NLL -7.844 | Val NLL -9.179 | LR 5.93e-04
# Epoch 234 | Time 4.92s | Train NLL -10.403 | Val NLL -7.657 | LR 5.75e-04
# Epoch 235 | Time 4.66s | Train NLL -7.722 | Val NLL -9.798 | LR 5.59e-04
# Epoch 236 | Time 4.51s | Train NLL -11.083 | Val NLL -9.093 | LR 5.42e-04
# Epoch 237 | Time 4.40s | Train NLL -8.645 | Val NLL -9.730 | LR 5.25e-04
# Epoch 238 | Time 4.48s | Train NLL -11.167 | Val NLL -9.562 | LR 5.09e-04
# Epoch 239 | Time 4.46s | Train NLL -10.867 | Val NLL -11.187 | LR 4.93e-04
# Epoch 240 | Time 4.50s | Train NLL -10.740 | Val NLL -11.508 | LR 4.77e-04
# Epoch 241 | Time 4.47s | Train NLL -9.707 | Val NLL -11.266 | LR 4.62e-04
# Epoch 242 | Time 4.40s | Train NLL -10.580 | Val NLL -11.213 | LR 4.47e-04
# Epoch 243 | Time 4.54s | Train NLL -11.536 | Val NLL -11.325 | LR 4.32e-04
# Epoch 244 | Time 4.43s | Train NLL -11.861 | Val NLL -11.564 | LR 4.17e-04
# Epoch 245 | Time 4.72s | Train NLL -11.809 | Val NLL -11.941 | LR 4.02e-04
# Epoch 246 | Time 4.75s | Train NLL -8.845 | Val NLL -10.536 | LR 3.88e-04
# Epoch 247 | Time 4.59s | Train NLL -10.921 | Val NLL -10.061 | LR 3.74e-04
# Epoch 248 | Time 4.40s | Train NLL -10.973 | Val NLL -11.673 | LR 3.60e-04
# Epoch 249 | Time 4.54s | Train NLL -12.209 | Val NLL -10.709 | LR 3.46e-04
# Epoch 250 | Time 3.52s | Train NLL -8.229 | Val NLL -8.689 | LR 3.33e-04
# Epoch 251 | Time 3.15s | Train NLL -11.926 | Val NLL -11.869 | LR 3.20e-04
# Epoch 252 | Time 3.07s | Train NLL -11.663 | Val NLL -7.842 | LR 3.07e-04
# Epoch 253 | Time 3.79s | Train NLL -11.303 | Val NLL -11.937 | LR 2.94e-04
# Epoch 254 | Time 4.51s | Train NLL -12.374 | Val NLL -11.422 | LR 2.82e-04
# Epoch 255 | Time 4.46s | Train NLL -12.505 | Val NLL -12.093 | LR 2.69e-04
# Epoch 256 | Time 4.78s | Train NLL -12.663 | Val NLL -12.291 | LR 2.58e-04
# Epoch 257 | Time 4.64s | Train NLL -12.798 | Val NLL -12.403 | LR 2.46e-04
# Epoch 258 | Time 4.66s | Train NLL -12.848 | Val NLL -12.529 | LR 2.35e-04
# Epoch 259 | Time 4.50s | Train NLL -12.984 | Val NLL -12.461 | LR 2.23e-04
# Epoch 260 | Time 4.57s | Train NLL -10.514 | Val NLL -12.386 | LR 2.13e-04
# Epoch 261 | Time 4.70s | Train NLL -13.215 | Val NLL -13.041 | LR 2.02e-04
# Epoch 262 | Time 4.62s | Train NLL -13.364 | Val NLL -12.943 | LR 1.92e-04
# Epoch 263 | Time 4.45s | Train NLL -12.603 | Val NLL -11.821 | LR 1.81e-04
# Epoch 264 | Time 4.60s | Train NLL -12.720 | Val NLL -8.382 | LR 1.72e-04
# Epoch 265 | Time 4.49s | Train NLL -7.672 | Val NLL -7.816 | LR 1.62e-04
# Epoch 266 | Time 4.46s | Train NLL -9.231 | Val NLL -9.678 | LR 1.53e-04
# Epoch 267 | Time 4.20s | Train NLL -10.216 | Val NLL -9.891 | LR 1.44e-04
# Epoch 268 | Time 3.15s | Train NLL -11.178 | Val NLL -12.125 | LR 1.35e-04
# Epoch 269 | Time 3.09s | Train NLL -12.893 | Val NLL -12.873 | LR 1.27e-04
# Epoch 270 | Time 3.07s | Train NLL -13.134 | Val NLL -12.430 | LR 1.18e-04
# Epoch 271 | Time 4.35s | Train NLL -13.306 | Val NLL -12.711 | LR 1.10e-04
# Epoch 272 | Time 4.44s | Train NLL -13.558 | Val NLL -12.846 | LR 1.03e-04
# Epoch 273 | Time 4.46s | Train NLL -13.267 | Val NLL -11.838 | LR 9.52e-05
# Epoch 274 | Time 4.45s | Train NLL -13.724 | Val NLL -13.596 | LR 8.81e-05
# Epoch 275 | Time 4.68s | Train NLL -14.065 | Val NLL -13.305 | LR 8.12e-05
# Epoch 276 | Time 4.91s | Train NLL -14.146 | Val NLL -13.282 | LR 7.46e-05
# Epoch 277 | Time 4.72s | Train NLL -14.205 | Val NLL -14.034 | LR 6.83e-05
# Epoch 278 | Time 4.61s | Train NLL -14.477 | Val NLL -14.174 | LR 6.23e-05
# Epoch 279 | Time 4.78s | Train NLL -14.231 | Val NLL -13.473 | LR 5.65e-05
# Epoch 280 | Time 4.52s | Train NLL -14.512 | Val NLL -14.205 | LR 5.10e-05
# Epoch 281 | Time 4.54s | Train NLL -14.731 | Val NLL -14.320 | LR 4.58e-05
# Epoch 282 | Time 4.50s | Train NLL -14.748 | Val NLL -14.182 | LR 4.09e-05
# Epoch 283 | Time 4.55s | Train NLL -14.945 | Val NLL -14.451 | LR 3.62e-05
# Epoch 284 | Time 4.55s | Train NLL -14.991 | Val NLL -14.487 | LR 3.18e-05
# Epoch 285 | Time 4.56s | Train NLL -15.052 | Val NLL -14.573 | LR 2.77e-05
# Epoch 286 | Time 4.84s | Train NLL -15.109 | Val NLL -14.606 | LR 2.39e-05
# Epoch 287 | Time 4.69s | Train NLL -15.185 | Val NLL -14.680 | LR 2.04e-05
# Epoch 288 | Time 4.48s | Train NLL -15.225 | Val NLL -14.711 | LR 1.71e-05
# Epoch 289 | Time 4.28s | Train NLL -15.249 | Val NLL -14.732 | LR 1.42e-05
# Epoch 290 | Time 3.38s | Train NLL -15.274 | Val NLL -14.754 | LR 1.15e-05
# Epoch 291 | Time 3.56s | Train NLL -15.301 | Val NLL -14.775 | LR 9.07e-06
# Epoch 292 | Time 3.38s | Train NLL -15.315 | Val NLL -14.781 | LR 6.94e-06
# Epoch 293 | Time 4.52s | Train NLL -15.336 | Val NLL -14.782 | LR 5.10e-06
# Epoch 294 | Time 4.66s | Train NLL -15.347 | Val NLL -14.806 | LR 3.54e-06
# Epoch 295 | Time 4.68s | Train NLL -15.355 | Val NLL -14.812 | LR 2.27e-06
# Epoch 296 | Time 4.56s | Train NLL -15.361 | Val NLL -14.817 | LR 1.28e-06
# Epoch 297 | Time 4.55s | Train NLL -15.366 | Val NLL -14.820 | LR 5.67e-07
# Epoch 298 | Time 4.53s | Train NLL -15.367 | Val NLL -14.821 | LR 1.42e-07
# Epoch 299 | Time 4.71s | Train NLL -15.368 | Val NLL -14.820 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 1241302.75
# Average absolute difference in CASUALTIES: 0.02

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
