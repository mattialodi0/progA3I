# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wildfire'
RUN_PATH = Path(f"../runs/best_flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE'
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = 2   # DAMAGES, CASUALTIES

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=12,
    hidden_features=[128, 128],
    bins=8
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 306216 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 000 | Time 0.47s | Train NLL 3.211 | Val NLL 2.533 | LR 8.00e-04
# Epoch 001 | Time 0.32s | Train NLL 1.690 | Val NLL 1.452 | LR 1.10e-03
# Epoch 002 | Time 0.31s | Train NLL 1.732 | Val NLL 1.802 | LR 1.40e-03
# Epoch 003 | Time 0.33s | Train NLL 1.487 | Val NLL 0.740 | LR 1.70e-03
# Epoch 004 | Time 0.30s | Train NLL 1.233 | Val NLL 1.434 | LR 2.00e-03
# Epoch 005 | Time 0.32s | Train NLL 0.668 | Val NLL 1.931 | LR 2.30e-03
# Epoch 006 | Time 0.31s | Train NLL 0.639 | Val NLL 0.434 | LR 2.60e-03
# Epoch 007 | Time 0.32s | Train NLL -0.015 | Val NLL 1.260 | LR 2.90e-03
# Epoch 008 | Time 0.36s | Train NLL 0.358 | Val NLL 0.135 | LR 3.20e-03
# Epoch 009 | Time 0.34s | Train NLL -0.940 | Val NLL -0.661 | LR 3.50e-03
# Epoch 010 | Time 0.36s | Train NLL -0.013 | Val NLL -1.284 | LR 3.80e-03
# Epoch 011 | Time 0.33s | Train NLL 0.197 | Val NLL 0.106 | LR 4.10e-03
# Epoch 012 | Time 0.35s | Train NLL -0.253 | Val NLL -0.296 | LR 4.40e-03
# Epoch 013 | Time 0.34s | Train NLL -0.921 | Val NLL -1.017 | LR 4.70e-03
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 014 | Time 0.37s | Train NLL -1.175 | Val NLL -0.904 | LR 5.00e-03
# Epoch 015 | Time 0.34s | Train NLL -1.527 | Val NLL -1.165 | LR 5.00e-03
# Epoch 016 | Time 0.47s | Train NLL -1.079 | Val NLL -0.069 | LR 5.00e-03
# Epoch 017 | Time 0.32s | Train NLL -0.890 | Val NLL 0.363 | LR 5.00e-03
# Epoch 018 | Time 0.35s | Train NLL 0.338 | Val NLL -0.065 | LR 4.99e-03
# Epoch 019 | Time 0.32s | Train NLL -0.865 | Val NLL -0.545 | LR 4.99e-03
# Epoch 020 | Time 0.33s | Train NLL -1.537 | Val NLL -1.646 | LR 4.99e-03
# Epoch 021 | Time 0.33s | Train NLL -2.184 | Val NLL -2.076 | LR 4.98e-03
# Epoch 022 | Time 0.34s | Train NLL -1.295 | Val NLL -0.342 | LR 4.98e-03
# Epoch 023 | Time 0.35s | Train NLL -0.610 | Val NLL 0.292 | LR 4.97e-03
# Epoch 024 | Time 0.33s | Train NLL -0.431 | Val NLL -1.304 | LR 4.96e-03
# Epoch 025 | Time 0.32s | Train NLL -1.898 | Val NLL -1.649 | LR 4.96e-03
# Epoch 026 | Time 0.33s | Train NLL -2.144 | Val NLL -1.731 | LR 4.95e-03
# Epoch 027 | Time 0.30s | Train NLL -2.347 | Val NLL 0.385 | LR 4.94e-03
# Epoch 028 | Time 0.36s | Train NLL 0.299 | Val NLL 0.028 | LR 4.93e-03
# Epoch 029 | Time 0.41s | Train NLL 0.546 | Val NLL 2.157 | LR 4.92e-03
# Epoch 030 | Time 0.32s | Train NLL -0.454 | Val NLL -0.158 | LR 4.91e-03
# Epoch 031 | Time 0.30s | Train NLL -0.878 | Val NLL -1.517 | LR 4.90e-03
# Epoch 032 | Time 0.32s | Train NLL -1.440 | Val NLL -1.370 | LR 4.88e-03
# Epoch 033 | Time 0.35s | Train NLL -1.882 | Val NLL -1.193 | LR 4.87e-03
# Epoch 034 | Time 0.34s | Train NLL -2.299 | Val NLL -2.010 | LR 4.86e-03
# Epoch 035 | Time 0.32s | Train NLL -2.609 | Val NLL -0.848 | LR 4.84e-03
# Epoch 036 | Time 0.37s | Train NLL -1.250 | Val NLL 0.509 | LR 4.83e-03
# Epoch 037 | Time 0.34s | Train NLL -0.642 | Val NLL 0.697 | LR 4.81e-03
# Epoch 038 | Time 0.31s | Train NLL -0.300 | Val NLL -1.673 | LR 4.80e-03
# Epoch 039 | Time 0.30s | Train NLL -1.673 | Val NLL -2.017 | LR 4.78e-03
# Epoch 040 | Time 0.33s | Train NLL -2.482 | Val NLL -3.083 | LR 4.76e-03
# Epoch 041 | Time 0.36s | Train NLL -2.789 | Val NLL -0.269 | LR 4.74e-03
# Epoch 042 | Time 0.38s | Train NLL -1.007 | Val NLL 0.087 | LR 4.72e-03
# Epoch 043 | Time 0.36s | Train NLL -0.709 | Val NLL -1.264 | LR 4.70e-03
# Epoch 044 | Time 0.38s | Train NLL -1.997 | Val NLL -1.468 | LR 4.68e-03
# Epoch 045 | Time 0.43s | Train NLL -2.806 | Val NLL -2.338 | LR 4.66e-03
# Epoch 046 | Time 0.29s | Train NLL -3.125 | Val NLL -2.490 | LR 4.64e-03
# Epoch 047 | Time 0.31s | Train NLL -3.442 | Val NLL -2.760 | LR 4.62e-03
# Epoch 048 | Time 0.32s | Train NLL -3.564 | Val NLL -2.585 | LR 4.60e-03
# Epoch 049 | Time 0.30s | Train NLL -3.141 | Val NLL -2.510 | LR 4.57e-03
# Epoch 050 | Time 0.29s | Train NLL -3.789 | Val NLL -3.726 | LR 4.55e-03
# Epoch 051 | Time 0.33s | Train NLL -4.083 | Val NLL -4.266 | LR 4.52e-03
# Epoch 052 | Time 0.35s | Train NLL -3.796 | Val NLL -3.555 | LR 4.50e-03
# Epoch 053 | Time 0.31s | Train NLL -3.811 | Val NLL -2.965 | LR 4.47e-03
# Epoch 054 | Time 0.33s | Train NLL -1.123 | Val NLL -0.983 | LR 4.45e-03
# Epoch 055 | Time 0.33s | Train NLL -0.105 | Val NLL -2.833 | LR 4.42e-03
# Epoch 056 | Time 0.34s | Train NLL -1.616 | Val NLL -1.492 | LR 4.39e-03
# Epoch 057 | Time 0.32s | Train NLL -2.031 | Val NLL -1.248 | LR 4.36e-03
# Epoch 058 | Time 0.31s | Train NLL -1.421 | Val NLL -2.550 | LR 4.34e-03
# Epoch 059 | Time 0.34s | Train NLL -0.207 | Val NLL 0.138 | LR 4.31e-03
# Epoch 060 | Time 0.47s | Train NLL -1.591 | Val NLL -2.129 | LR 4.28e-03
# Epoch 061 | Time 0.40s | Train NLL -2.706 | Val NLL -2.242 | LR 4.25e-03
# Epoch 062 | Time 0.48s | Train NLL -3.407 | Val NLL -2.223 | LR 4.22e-03
# Epoch 063 | Time 0.41s | Train NLL -3.723 | Val NLL -2.433 | LR 4.18e-03
# Epoch 064 | Time 0.39s | Train NLL -4.154 | Val NLL -2.300 | LR 4.15e-03
# Epoch 065 | Time 0.38s | Train NLL -3.541 | Val NLL -4.507 | LR 4.12e-03
# Epoch 066 | Time 0.40s | Train NLL -4.559 | Val NLL -2.502 | LR 4.09e-03
# Epoch 067 | Time 0.40s | Train NLL -3.181 | Val NLL -1.248 | LR 4.06e-03
# Epoch 068 | Time 0.37s | Train NLL -2.163 | Val NLL -2.376 | LR 4.02e-03
# Epoch 069 | Time 0.36s | Train NLL -2.789 | Val NLL -4.060 | LR 3.99e-03
# Epoch 070 | Time 0.37s | Train NLL -2.468 | Val NLL -4.047 | LR 3.95e-03
# Epoch 071 | Time 0.34s | Train NLL -2.819 | Val NLL -1.584 | LR 3.92e-03
# Epoch 072 | Time 0.41s | Train NLL -2.928 | Val NLL -2.496 | LR 3.88e-03
# Epoch 073 | Time 0.48s | Train NLL -3.077 | Val NLL -3.013 | LR 3.85e-03
# Epoch 074 | Time 0.39s | Train NLL -3.729 | Val NLL -4.471 | LR 3.81e-03
# Epoch 075 | Time 0.35s | Train NLL -2.685 | Val NLL -1.271 | LR 3.78e-03
# Epoch 076 | Time 0.39s | Train NLL -1.928 | Val NLL 1.776 | LR 3.74e-03
# Epoch 077 | Time 0.40s | Train NLL -0.910 | Val NLL 0.061 | LR 3.70e-03
# Epoch 078 | Time 0.45s | Train NLL -0.159 | Val NLL -0.885 | LR 3.67e-03
# Epoch 079 | Time 0.44s | Train NLL -1.908 | Val NLL 0.760 | LR 3.63e-03
# Epoch 080 | Time 0.43s | Train NLL -1.072 | Val NLL -0.855 | LR 3.59e-03
# Epoch 081 | Time 0.34s | Train NLL -2.337 | Val NLL -2.161 | LR 3.55e-03
# Epoch 082 | Time 0.33s | Train NLL -2.642 | Val NLL -3.571 | LR 3.51e-03
# Epoch 083 | Time 0.38s | Train NLL -3.678 | Val NLL -3.821 | LR 3.47e-03
# Epoch 084 | Time 0.40s | Train NLL -3.567 | Val NLL -3.303 | LR 3.44e-03
# Epoch 085 | Time 0.38s | Train NLL -3.585 | Val NLL -3.482 | LR 3.40e-03
# Epoch 086 | Time 0.45s | Train NLL -4.007 | Val NLL -3.888 | LR 3.36e-03
# Epoch 087 | Time 0.38s | Train NLL -4.515 | Val NLL -4.003 | LR 3.32e-03
# Epoch 088 | Time 0.40s | Train NLL -4.704 | Val NLL -4.975 | LR 3.28e-03
# Epoch 089 | Time 0.41s | Train NLL -4.629 | Val NLL -3.817 | LR 3.24e-03
# Epoch 090 | Time 0.54s | Train NLL -3.861 | Val NLL -4.166 | LR 3.19e-03
# Epoch 091 | Time 0.47s | Train NLL -4.764 | Val NLL -3.235 | LR 3.15e-03
# Epoch 092 | Time 0.39s | Train NLL -4.123 | Val NLL -1.624 | LR 3.11e-03
# Epoch 093 | Time 0.48s | Train NLL -2.767 | Val NLL -1.942 | LR 3.07e-03
# Epoch 094 | Time 0.42s | Train NLL -2.034 | Val NLL -2.308 | LR 3.03e-03
# Epoch 095 | Time 0.41s | Train NLL -3.021 | Val NLL -2.842 | LR 2.99e-03
# Epoch 096 | Time 0.41s | Train NLL -3.709 | Val NLL -3.170 | LR 2.95e-03
# Epoch 097 | Time 0.45s | Train NLL -3.960 | Val NLL -4.515 | LR 2.91e-03
# Epoch 098 | Time 0.43s | Train NLL -4.707 | Val NLL -3.342 | LR 2.86e-03
# Epoch 099 | Time 0.41s | Train NLL -4.329 | Val NLL -4.402 | LR 2.82e-03
# Epoch 100 | Time 0.49s | Train NLL -4.882 | Val NLL -4.437 | LR 2.78e-03
# Epoch 101 | Time 0.35s | Train NLL -5.005 | Val NLL -3.914 | LR 2.74e-03
# Epoch 102 | Time 0.35s | Train NLL -4.649 | Val NLL -5.361 | LR 2.70e-03
# Epoch 103 | Time 0.35s | Train NLL -3.721 | Val NLL -2.740 | LR 2.65e-03
# Epoch 104 | Time 0.38s | Train NLL -4.218 | Val NLL -3.680 | LR 2.61e-03
# Epoch 105 | Time 0.44s | Train NLL -4.618 | Val NLL -3.528 | LR 2.57e-03
# Epoch 106 | Time 0.40s | Train NLL -3.952 | Val NLL -3.987 | LR 2.53e-03
# Epoch 107 | Time 0.39s | Train NLL -4.164 | Val NLL -3.188 | LR 2.48e-03
# Epoch 108 | Time 0.35s | Train NLL -3.802 | Val NLL -5.040 | LR 2.44e-03
# Epoch 109 | Time 0.35s | Train NLL -5.314 | Val NLL -4.677 | LR 2.40e-03
# Epoch 110 | Time 0.38s | Train NLL -5.438 | Val NLL -3.207 | LR 2.36e-03
# Epoch 111 | Time 0.40s | Train NLL -3.873 | Val NLL -3.290 | LR 2.31e-03
# Epoch 112 | Time 0.37s | Train NLL -3.820 | Val NLL -4.552 | LR 2.27e-03
# Epoch 113 | Time 0.33s | Train NLL -4.492 | Val NLL -4.335 | LR 2.23e-03
# Epoch 114 | Time 0.36s | Train NLL -4.871 | Val NLL -4.072 | LR 2.19e-03
# Epoch 115 | Time 0.33s | Train NLL -5.039 | Val NLL -4.423 | LR 2.15e-03
# Epoch 116 | Time 0.35s | Train NLL -5.244 | Val NLL -4.926 | LR 2.10e-03
# Epoch 117 | Time 0.37s | Train NLL -5.518 | Val NLL -4.620 | LR 2.06e-03
# Epoch 118 | Time 0.40s | Train NLL -5.700 | Val NLL -4.453 | LR 2.02e-03
# Epoch 119 | Time 0.46s | Train NLL -5.960 | Val NLL -4.778 | LR 1.98e-03
# Epoch 120 | Time 0.49s | Train NLL -5.951 | Val NLL -6.335 | LR 1.94e-03
# Epoch 121 | Time 0.45s | Train NLL -5.950 | Val NLL -3.678 | LR 1.90e-03
# Epoch 122 | Time 0.59s | Train NLL -3.772 | Val NLL -2.222 | LR 1.86e-03
# Epoch 123 | Time 0.43s | Train NLL -3.409 | Val NLL -2.107 | LR 1.82e-03
# Epoch 124 | Time 0.40s | Train NLL -4.101 | Val NLL -4.406 | LR 1.77e-03
# Epoch 125 | Time 0.77s | Train NLL -5.748 | Val NLL -5.424 | LR 1.73e-03
# Epoch 126 | Time 0.74s | Train NLL -5.934 | Val NLL -4.753 | LR 1.69e-03
# Epoch 127 | Time 1.73s | Train NLL -5.218 | Val NLL -3.974 | LR 1.65e-03
# Epoch 128 | Time 0.91s | Train NLL -5.327 | Val NLL -5.366 | LR 1.61e-03
# Epoch 129 | Time 0.90s | Train NLL -6.274 | Val NLL -4.550 | LR 1.57e-03
# Epoch 130 | Time 0.48s | Train NLL -5.335 | Val NLL -5.330 | LR 1.54e-03
# Epoch 131 | Time 0.41s | Train NLL -6.036 | Val NLL -5.604 | LR 1.50e-03
# Epoch 132 | Time 0.37s | Train NLL -5.878 | Val NLL -4.934 | LR 1.46e-03
# Epoch 133 | Time 0.39s | Train NLL -6.390 | Val NLL -6.152 | LR 1.42e-03
# Epoch 134 | Time 0.35s | Train NLL -6.492 | Val NLL -5.351 | LR 1.38e-03
# Epoch 135 | Time 0.40s | Train NLL -5.917 | Val NLL -3.938 | LR 1.34e-03
# Epoch 136 | Time 0.36s | Train NLL -5.204 | Val NLL -4.721 | LR 1.31e-03
# Epoch 137 | Time 0.38s | Train NLL -4.724 | Val NLL -6.420 | LR 1.27e-03
# Epoch 138 | Time 0.41s | Train NLL -4.666 | Val NLL -4.195 | LR 1.23e-03
# Epoch 139 | Time 0.38s | Train NLL -4.969 | Val NLL -3.727 | LR 1.20e-03
# Epoch 140 | Time 0.49s | Train NLL -5.063 | Val NLL -4.890 | LR 1.16e-03
# Epoch 141 | Time 0.44s | Train NLL -5.657 | Val NLL -4.809 | LR 1.13e-03
# Epoch 142 | Time 0.43s | Train NLL -5.703 | Val NLL -4.921 | LR 1.09e-03
# Epoch 143 | Time 0.46s | Train NLL -5.600 | Val NLL -4.950 | LR 1.06e-03
# Epoch 144 | Time 0.35s | Train NLL -5.923 | Val NLL -5.536 | LR 1.02e-03
# Epoch 145 | Time 0.35s | Train NLL -6.341 | Val NLL -6.323 | LR 9.88e-04
# Epoch 146 | Time 0.31s | Train NLL -6.948 | Val NLL -6.221 | LR 9.54e-04
# Epoch 147 | Time 0.35s | Train NLL -6.798 | Val NLL -6.524 | LR 9.21e-04
# Epoch 148 | Time 0.36s | Train NLL -6.736 | Val NLL -6.226 | LR 8.89e-04
# Epoch 149 | Time 0.33s | Train NLL -6.645 | Val NLL -5.348 | LR 8.57e-04
# Epoch 150 | Time 0.33s | Train NLL -6.829 | Val NLL -7.063 | LR 8.25e-04
# Epoch 151 | Time 0.32s | Train NLL -6.752 | Val NLL -6.742 | LR 7.94e-04
# Epoch 152 | Time 0.31s | Train NLL -7.051 | Val NLL -6.186 | LR 7.63e-04
# Epoch 153 | Time 0.36s | Train NLL -7.374 | Val NLL -7.336 | LR 7.33e-04
# Epoch 154 | Time 0.39s | Train NLL -7.385 | Val NLL -7.254 | LR 7.04e-04
# Epoch 155 | Time 0.35s | Train NLL -7.722 | Val NLL -6.724 | LR 6.75e-04
# Epoch 156 | Time 0.34s | Train NLL -7.496 | Val NLL -7.086 | LR 6.46e-04
# Epoch 157 | Time 0.34s | Train NLL -7.574 | Val NLL -6.797 | LR 6.18e-04
# Epoch 158 | Time 0.31s | Train NLL -7.690 | Val NLL -7.084 | LR 5.91e-04
# Epoch 159 | Time 0.30s | Train NLL -7.780 | Val NLL -7.531 | LR 5.64e-04
# Epoch 160 | Time 0.34s | Train NLL -7.948 | Val NLL -6.846 | LR 5.37e-04
# Epoch 161 | Time 0.37s | Train NLL -7.655 | Val NLL -7.510 | LR 5.12e-04
# Epoch 162 | Time 0.33s | Train NLL -7.895 | Val NLL -7.014 | LR 4.87e-04
# Epoch 163 | Time 0.31s | Train NLL -7.513 | Val NLL -6.751 | LR 4.62e-04
# Epoch 164 | Time 0.31s | Train NLL -7.178 | Val NLL -5.830 | LR 4.38e-04
# Epoch 165 | Time 0.30s | Train NLL -7.223 | Val NLL -5.909 | LR 4.14e-04
# Epoch 166 | Time 0.34s | Train NLL -6.879 | Val NLL -6.748 | LR 3.92e-04
# Epoch 167 | Time 0.35s | Train NLL -6.858 | Val NLL -7.326 | LR 3.69e-04
# Epoch 168 | Time 0.33s | Train NLL -7.459 | Val NLL -6.860 | LR 3.48e-04
# Epoch 169 | Time 0.34s | Train NLL -7.487 | Val NLL -6.167 | LR 3.27e-04
# Epoch 170 | Time 0.41s | Train NLL -7.417 | Val NLL -6.788 | LR 3.06e-04
# Epoch 171 | Time 0.34s | Train NLL -7.630 | Val NLL -7.145 | LR 2.87e-04
# Epoch 172 | Time 0.34s | Train NLL -7.338 | Val NLL -7.608 | LR 2.68e-04
# Epoch 173 | Time 0.35s | Train NLL -7.962 | Val NLL -7.449 | LR 2.49e-04
# Epoch 174 | Time 0.35s | Train NLL -7.933 | Val NLL -6.872 | LR 2.31e-04
# Epoch 175 | Time 0.33s | Train NLL -7.919 | Val NLL -6.977 | LR 2.14e-04
# Epoch 176 | Time 0.32s | Train NLL -7.747 | Val NLL -7.994 | LR 1.98e-04
# Epoch 177 | Time 0.33s | Train NLL -8.241 | Val NLL -8.119 | LR 1.82e-04
# Epoch 178 | Time 0.31s | Train NLL -8.428 | Val NLL -8.094 | LR 1.67e-04
# Epoch 179 | Time 0.32s | Train NLL -8.601 | Val NLL -8.055 | LR 1.53e-04
# Epoch 180 | Time 0.35s | Train NLL -8.696 | Val NLL -8.085 | LR 1.39e-04
# Epoch 181 | Time 0.35s | Train NLL -8.813 | Val NLL -8.095 | LR 1.26e-04
# Epoch 182 | Time 0.32s | Train NLL -8.616 | Val NLL -8.010 | LR 1.13e-04
# Epoch 183 | Time 0.32s | Train NLL -8.663 | Val NLL -8.138 | LR 1.02e-04
# Epoch 184 | Time 0.32s | Train NLL -8.723 | Val NLL -8.251 | LR 9.05e-05
# Epoch 185 | Time 0.58s | Train NLL -8.737 | Val NLL -8.235 | LR 8.02e-05
# Epoch 186 | Time 0.39s | Train NLL -8.836 | Val NLL -8.278 | LR 7.06e-05
# Epoch 187 | Time 0.37s | Train NLL -8.849 | Val NLL -8.316 | LR 6.16e-05
# Epoch 188 | Time 0.33s | Train NLL -8.946 | Val NLL -8.301 | LR 5.34e-05
# Epoch 189 | Time 0.33s | Train NLL -8.893 | Val NLL -8.330 | LR 4.59e-05
# Epoch 190 | Time 0.33s | Train NLL -8.983 | Val NLL -8.358 | LR 3.91e-05
# Epoch 191 | Time 0.34s | Train NLL -8.897 | Val NLL -8.366 | LR 3.30e-05
# Epoch 192 | Time 0.35s | Train NLL -9.028 | Val NLL -8.377 | LR 2.76e-05
# Epoch 193 | Time 0.32s | Train NLL -9.024 | Val NLL -8.405 | LR 2.29e-05
# Epoch 194 | Time 0.36s | Train NLL -9.019 | Val NLL -8.412 | LR 1.90e-05
# Epoch 195 | Time 0.35s | Train NLL -9.059 | Val NLL -8.404 | LR 1.58e-05
# Epoch 196 | Time 0.32s | Train NLL -9.005 | Val NLL -8.428 | LR 1.32e-05
# Epoch 197 | Time 0.33s | Train NLL -9.000 | Val NLL -8.435 | LR 1.14e-05
# Epoch 198 | Time 0.35s | Train NLL -9.120 | Val NLL -8.444 | LR 1.04e-05
# Epoch 199 | Time 0.39s | Train NLL -9.085 | Val NLL -8.451 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Run inference for the test set and plot results for damages and casualties
def run_inference_and_plot(flow, test_loader, y_scaler, target_cols):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            # Get the distribution and sample from it
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze(1)  # shape: [batch, 2]
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    # Inverse scale
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    # Plot for each target
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.scatter(y_true[:, 0], y_pred[:, 0], alpha=0.5)
    plt.xlabel(f"True {target_cols[0]}")
    plt.ylabel(f"Predicted {target_cols[0]}")
    plt.title(f"True vs Predicted: {target_cols[0]}")
    plt.plot([y_true[:, 0].min(), y_true[:, 0].max()], [y_true[:, 0].min(), y_true[:, 0].max()], 'r--')
    plt.grid()
    plt.subplot(1,2,2)
    plt.scatter(y_true[:, 1], y_pred[:, 1], alpha=0.5)
    plt.xlabel(f"True {target_cols[1]}")
    plt.ylabel(f"Predicted {target_cols[1]}")
    plt.title(f"True vs Predicted: {target_cols[1]}")
    plt.plot([y_true[:, 1].min(), y_true[:, 1].max()], [y_true[:, 1].min(), y_true[:, 1].max()], 'r--')
    plt.grid()
    plt.show()

run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS)

# %%
# compute average true/predicted damagesdifference
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            # Get the distribution and sample from it
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze(1)  # shape: [batch, 2]
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    # Inverse scale
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    # Compute average difference for damages
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 
compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 50132664.00
# Average absolute difference in CASUALTIES: 0.65
