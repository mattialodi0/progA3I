# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wildfire'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_test, Y_test)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
def compute_extreme_threshold(y, quantile=0.95):
    """
    Compute per-target threshold for extreme events automatically.
    y: [batch_size, num_targets]
    quantile: e.g., 0.95 for top 5% as extreme
    returns: threshold tensor [num_targets]
    """
    thresholds = torch.quantile(y, quantile, dim=0)
    return thresholds

history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

# Define separate lambdas for each target
lam_damage = 3.0       # heavier weight for extreme damages
lam_casualty = 0.5     # weight for extreme casualties
quantile_damage = 0.95
quantile_casualty = 0.95

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)

        # Forward pass
        dist = flow(x)
        log_prob = dist.log_prob(y)
        loss = -log_prob.mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        # Learning rate scheduling
        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)

    # Validation
    flow.eval()
    val_loss = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            val_loss += -flow(x).log_prob(y).mean().item()
    val_loss /= max(len(val_loader), 1)

    # Record history
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    # Save best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 0.54s | Train NLL 12.991 | Val NLL 9.737 | LR 1.00e-03
# Epoch 001 | Time 0.25s | Train NLL 8.610 | Val NLL 4.528 | LR 2.00e-03
# Epoch 002 | Time 0.24s | Train NLL 4.438 | Val NLL 2.551 | LR 3.00e-03
# Epoch 003 | Time 0.25s | Train NLL 2.340 | Val NLL 0.979 | LR 4.00e-03
# Epoch 004 | Time 0.24s | Train NLL 1.938 | Val NLL 0.524 | LR 5.00e-03
# Epoch 005 | Time 0.18s | Train NLL 1.446 | Val NLL 2.474 | LR 5.00e-03
# Epoch 006 | Time 0.23s | Train NLL 1.982 | Val NLL 0.078 | LR 5.00e-03
# Epoch 007 | Time 0.19s | Train NLL 1.016 | Val NLL 0.387 | LR 5.00e-03
# Epoch 008 | Time 0.23s | Train NLL 0.379 | Val NLL -1.069 | LR 4.99e-03
# Epoch 009 | Time 0.20s | Train NLL -0.496 | Val NLL -1.732 | LR 4.99e-03
# Epoch 010 | Time 0.20s | Train NLL -0.862 | Val NLL 0.673 | LR 4.99e-03
# Epoch 011 | Time 0.20s | Train NLL 1.843 | Val NLL 3.435 | LR 4.98e-03
# Epoch 012 | Time 0.20s | Train NLL 3.641 | Val NLL 1.808 | LR 4.98e-03
# Epoch 013 | Time 0.19s | Train NLL 1.778 | Val NLL 2.986 | LR 4.97e-03
# Epoch 014 | Time 0.20s | Train NLL 2.330 | Val NLL 0.530 | LR 4.97e-03
# Epoch 015 | Time 0.25s | Train NLL 1.007 | Val NLL -0.441 | LR 4.96e-03
# Epoch 016 | Time 0.21s | Train NLL -0.128 | Val NLL -1.393 | LR 4.95e-03
# Epoch 017 | Time 0.19s | Train NLL -0.925 | Val NLL -1.303 | LR 4.95e-03
# Epoch 018 | Time 0.20s | Train NLL -1.634 | Val NLL -0.235 | LR 4.94e-03
# Epoch 019 | Time 0.19s | Train NLL -0.792 | Val NLL -1.075 | LR 4.93e-03
# Epoch 020 | Time 0.22s | Train NLL -1.758 | Val NLL -3.155 | LR 4.92e-03
# Epoch 021 | Time 0.19s | Train NLL -0.466 | Val NLL 1.376 | LR 4.91e-03
# Epoch 022 | Time 0.18s | Train NLL 1.960 | Val NLL -0.157 | LR 4.90e-03
# Epoch 023 | Time 0.20s | Train NLL 0.255 | Val NLL 0.170 | LR 4.88e-03
# Epoch 024 | Time 0.21s | Train NLL 0.359 | Val NLL -0.513 | LR 4.87e-03
# Epoch 025 | Time 0.22s | Train NLL -0.133 | Val NLL -0.585 | LR 4.86e-03
# Epoch 026 | Time 0.24s | Train NLL -0.927 | Val NLL -1.842 | LR 4.84e-03
# Epoch 027 | Time 0.20s | Train NLL -2.254 | Val NLL -3.055 | LR 4.83e-03
# Epoch 028 | Time 0.18s | Train NLL -1.782 | Val NLL 0.401 | LR 4.82e-03
# Epoch 029 | Time 0.21s | Train NLL 2.111 | Val NLL 3.393 | LR 4.80e-03
# Epoch 030 | Time 0.22s | Train NLL 2.392 | Val NLL 1.144 | LR 4.78e-03
# Epoch 031 | Time 0.25s | Train NLL 2.855 | Val NLL 0.444 | LR 4.77e-03
# Epoch 032 | Time 0.19s | Train NLL -0.739 | Val NLL -1.152 | LR 4.75e-03
# Epoch 033 | Time 0.22s | Train NLL -1.212 | Val NLL -1.820 | LR 4.73e-03
# Epoch 034 | Time 0.18s | Train NLL -0.502 | Val NLL 0.763 | LR 4.71e-03
# Epoch 035 | Time 0.23s | Train NLL -0.183 | Val NLL -0.188 | LR 4.69e-03
# Epoch 036 | Time 0.22s | Train NLL -0.356 | Val NLL -0.425 | LR 4.68e-03
# Epoch 037 | Time 0.21s | Train NLL 0.118 | Val NLL -0.127 | LR 4.65e-03
# Epoch 038 | Time 0.22s | Train NLL -0.392 | Val NLL -1.454 | LR 4.63e-03
# Epoch 039 | Time 0.32s | Train NLL -1.352 | Val NLL -2.616 | LR 4.61e-03
# Epoch 040 | Time 0.27s | Train NLL -2.658 | Val NLL -0.190 | LR 4.59e-03
# Epoch 041 | Time 0.20s | Train NLL 1.824 | Val NLL 3.215 | LR 4.57e-03
# Epoch 042 | Time 0.21s | Train NLL 3.450 | Val NLL 3.777 | LR 4.55e-03
# Epoch 043 | Time 0.25s | Train NLL 4.321 | Val NLL 3.269 | LR 4.52e-03
# Epoch 044 | Time 0.24s | Train NLL 2.881 | Val NLL 0.540 | LR 4.50e-03
# Epoch 045 | Time 0.23s | Train NLL 0.157 | Val NLL 0.142 | LR 4.47e-03
# Epoch 046 | Time 0.21s | Train NLL -1.007 | Val NLL -2.768 | LR 4.45e-03
# Epoch 047 | Time 0.21s | Train NLL -0.258 | Val NLL 0.940 | LR 4.42e-03
# Epoch 048 | Time 0.30s | Train NLL 0.635 | Val NLL 0.546 | LR 4.40e-03
# Epoch 049 | Time 0.20s | Train NLL -0.083 | Val NLL -1.619 | LR 4.37e-03
# Epoch 050 | Time 0.20s | Train NLL -0.918 | Val NLL -2.369 | LR 4.34e-03
# Epoch 051 | Time 0.22s | Train NLL -2.112 | Val NLL -2.387 | LR 4.32e-03
# Epoch 052 | Time 0.32s | Train NLL -2.441 | Val NLL -1.103 | LR 4.29e-03
# Epoch 053 | Time 0.25s | Train NLL -2.013 | Val NLL -3.601 | LR 4.26e-03
# Epoch 054 | Time 0.30s | Train NLL -3.769 | Val NLL -3.017 | LR 4.23e-03
# Epoch 055 | Time 0.25s | Train NLL -1.830 | Val NLL -1.008 | LR 4.20e-03
# Epoch 056 | Time 0.25s | Train NLL -1.076 | Val NLL -2.358 | LR 4.17e-03
# Epoch 057 | Time 0.31s | Train NLL -1.143 | Val NLL -0.630 | LR 4.14e-03
# Epoch 058 | Time 0.30s | Train NLL -1.072 | Val NLL -2.392 | LR 4.11e-03
# Epoch 059 | Time 0.23s | Train NLL -1.716 | Val NLL -1.929 | LR 4.08e-03
# Epoch 060 | Time 0.31s | Train NLL -2.197 | Val NLL -2.796 | LR 4.05e-03
# Epoch 061 | Time 0.25s | Train NLL -2.840 | Val NLL -3.153 | LR 4.02e-03
# Epoch 062 | Time 0.30s | Train NLL -3.245 | Val NLL -3.752 | LR 3.99e-03
# Epoch 063 | Time 0.23s | Train NLL -3.569 | Val NLL -2.737 | LR 3.95e-03
# Epoch 064 | Time 0.26s | Train NLL -2.462 | Val NLL -0.154 | LR 3.92e-03
# Epoch 065 | Time 0.23s | Train NLL -0.208 | Val NLL 0.297 | LR 3.89e-03
# Epoch 066 | Time 0.27s | Train NLL -0.621 | Val NLL 0.440 | LR 3.85e-03
# Epoch 067 | Time 0.20s | Train NLL 0.421 | Val NLL -0.193 | LR 3.82e-03
# Epoch 068 | Time 0.26s | Train NLL -0.906 | Val NLL -1.843 | LR 3.78e-03
# Epoch 069 | Time 0.21s | Train NLL -1.091 | Val NLL -1.864 | LR 3.75e-03
# Epoch 070 | Time 0.24s | Train NLL -2.205 | Val NLL -2.088 | LR 3.71e-03
# Epoch 071 | Time 0.32s | Train NLL -2.364 | Val NLL -2.650 | LR 3.68e-03
# Epoch 072 | Time 0.27s | Train NLL -2.929 | Val NLL -2.735 | LR 3.64e-03
# Epoch 073 | Time 0.25s | Train NLL -2.608 | Val NLL -2.503 | LR 3.61e-03
# Epoch 074 | Time 0.26s | Train NLL -2.979 | Val NLL -4.171 | LR 3.57e-03
# Epoch 075 | Time 0.28s | Train NLL -3.380 | Val NLL -4.217 | LR 3.54e-03
# Epoch 076 | Time 0.27s | Train NLL -4.449 | Val NLL -4.368 | LR 3.50e-03
# Epoch 077 | Time 0.27s | Train NLL -4.038 | Val NLL -2.547 | LR 3.46e-03
# Epoch 078 | Time 0.27s | Train NLL -3.772 | Val NLL -2.277 | LR 3.42e-03
# Epoch 079 | Time 0.30s | Train NLL -1.824 | Val NLL -2.860 | LR 3.39e-03
# Epoch 080 | Time 0.30s | Train NLL -2.673 | Val NLL -3.911 | LR 3.35e-03
# Epoch 081 | Time 0.32s | Train NLL 0.331 | Val NLL 2.046 | LR 3.31e-03
# Epoch 082 | Time 0.30s | Train NLL 1.487 | Val NLL -1.192 | LR 3.27e-03
# Epoch 083 | Time 0.27s | Train NLL -1.361 | Val NLL -2.232 | LR 3.23e-03
# Epoch 084 | Time 0.24s | Train NLL -2.411 | Val NLL -2.953 | LR 3.20e-03
# Epoch 085 | Time 0.25s | Train NLL -2.993 | Val NLL -3.513 | LR 3.16e-03
# Epoch 086 | Time 0.27s | Train NLL -3.553 | Val NLL -4.285 | LR 3.12e-03
# Epoch 087 | Time 0.23s | Train NLL -3.927 | Val NLL -4.307 | LR 3.08e-03
# Epoch 088 | Time 0.27s | Train NLL -3.830 | Val NLL -4.540 | LR 3.04e-03
# Epoch 089 | Time 0.23s | Train NLL -3.778 | Val NLL -3.967 | LR 3.00e-03
# Epoch 090 | Time 0.25s | Train NLL -2.682 | Val NLL 0.588 | LR 2.96e-03
# Epoch 091 | Time 0.25s | Train NLL 1.746 | Val NLL -0.102 | LR 2.92e-03
# Epoch 092 | Time 0.23s | Train NLL 2.474 | Val NLL 4.297 | LR 2.88e-03
# Epoch 093 | Time 0.25s | Train NLL 4.972 | Val NLL 3.548 | LR 2.84e-03
# Epoch 094 | Time 0.28s | Train NLL 3.198 | Val NLL 1.152 | LR 2.80e-03
# Epoch 095 | Time 0.26s | Train NLL 0.042 | Val NLL -1.413 | LR 2.76e-03
# Epoch 096 | Time 0.26s | Train NLL -0.885 | Val NLL -1.184 | LR 2.72e-03
# Epoch 097 | Time 0.23s | Train NLL -1.324 | Val NLL -2.361 | LR 2.68e-03
# Epoch 098 | Time 0.21s | Train NLL -2.579 | Val NLL -2.982 | LR 2.64e-03
# Epoch 099 | Time 0.23s | Train NLL -3.290 | Val NLL -4.193 | LR 2.60e-03
# Epoch 100 | Time 0.27s | Train NLL -3.861 | Val NLL -4.197 | LR 2.56e-03
# Epoch 101 | Time 0.23s | Train NLL -2.376 | Val NLL -0.596 | LR 2.52e-03
# Epoch 102 | Time 0.26s | Train NLL 0.827 | Val NLL -0.758 | LR 2.48e-03
# Epoch 103 | Time 0.22s | Train NLL 0.750 | Val NLL -1.479 | LR 2.44e-03
# Epoch 104 | Time 0.21s | Train NLL -0.788 | Val NLL -0.882 | LR 2.40e-03
# Epoch 105 | Time 0.24s | Train NLL -1.208 | Val NLL -1.505 | LR 2.36e-03
# Epoch 106 | Time 0.23s | Train NLL -1.601 | Val NLL -2.054 | LR 2.32e-03
# Epoch 107 | Time 0.21s | Train NLL -2.343 | Val NLL -2.647 | LR 2.28e-03
# Epoch 108 | Time 0.20s | Train NLL -2.731 | Val NLL -3.216 | LR 2.24e-03
# Epoch 109 | Time 0.24s | Train NLL -3.673 | Val NLL -3.709 | LR 2.20e-03
# Epoch 110 | Time 0.24s | Train NLL -3.955 | Val NLL -2.799 | LR 2.16e-03
# Epoch 111 | Time 0.20s | Train NLL -3.523 | Val NLL -3.353 | LR 2.12e-03
# Epoch 112 | Time 0.20s | Train NLL -3.924 | Val NLL -2.199 | LR 2.08e-03
# Epoch 113 | Time 0.22s | Train NLL -2.213 | Val NLL 0.640 | LR 2.04e-03
# Epoch 114 | Time 0.21s | Train NLL 1.522 | Val NLL -0.223 | LR 2.00e-03
# Epoch 115 | Time 0.22s | Train NLL -0.802 | Val NLL -1.784 | LR 1.96e-03
# Epoch 116 | Time 0.20s | Train NLL -2.093 | Val NLL -3.026 | LR 1.92e-03
# Epoch 117 | Time 0.19s | Train NLL -3.237 | Val NLL -3.377 | LR 1.88e-03
# Epoch 118 | Time 0.20s | Train NLL -3.591 | Val NLL -3.821 | LR 1.84e-03
# Epoch 119 | Time 0.22s | Train NLL -2.805 | Val NLL -2.025 | LR 1.80e-03
# Epoch 120 | Time 0.24s | Train NLL -2.916 | Val NLL -4.979 | LR 1.77e-03
# Epoch 121 | Time 0.24s | Train NLL -4.973 | Val NLL -5.055 | LR 1.73e-03
# Epoch 122 | Time 0.26s | Train NLL -5.905 | Val NLL -5.227 | LR 1.69e-03
# Epoch 123 | Time 0.25s | Train NLL -4.381 | Val NLL -5.053 | LR 1.65e-03
# Epoch 124 | Time 0.30s | Train NLL -5.557 | Val NLL -4.247 | LR 1.61e-03
# Epoch 125 | Time 0.23s | Train NLL -4.005 | Val NLL -3.944 | LR 1.58e-03
# Epoch 126 | Time 0.22s | Train NLL -2.914 | Val NLL 0.093 | LR 1.54e-03
# Epoch 127 | Time 0.23s | Train NLL -0.582 | Val NLL -3.504 | LR 1.50e-03
# Epoch 128 | Time 0.25s | Train NLL -2.956 | Val NLL -2.452 | LR 1.46e-03
# Epoch 129 | Time 0.24s | Train NLL -2.775 | Val NLL -3.133 | LR 1.43e-03
# Epoch 130 | Time 0.22s | Train NLL -2.907 | Val NLL -3.811 | LR 1.39e-03
# Epoch 131 | Time 0.22s | Train NLL -4.079 | Val NLL -4.278 | LR 1.36e-03
# Epoch 132 | Time 0.21s | Train NLL -4.519 | Val NLL -4.961 | LR 1.32e-03
# Epoch 133 | Time 0.20s | Train NLL -4.957 | Val NLL -4.819 | LR 1.29e-03
# Epoch 134 | Time 0.22s | Train NLL -5.385 | Val NLL -5.106 | LR 1.25e-03
# Epoch 135 | Time 0.26s | Train NLL -5.193 | Val NLL -5.458 | LR 1.22e-03
# Epoch 136 | Time 0.21s | Train NLL -5.663 | Val NLL -5.301 | LR 1.18e-03
# Epoch 137 | Time 0.22s | Train NLL -5.886 | Val NLL -4.021 | LR 1.15e-03
# Epoch 138 | Time 0.22s | Train NLL -5.331 | Val NLL -4.380 | LR 1.11e-03
# Epoch 139 | Time 0.23s | Train NLL -4.640 | Val NLL -4.708 | LR 1.08e-03
# Epoch 140 | Time 0.27s | Train NLL -5.590 | Val NLL -4.665 | LR 1.05e-03
# Epoch 141 | Time 0.25s | Train NLL -5.283 | Val NLL -5.733 | LR 1.01e-03
# Epoch 142 | Time 0.21s | Train NLL -5.702 | Val NLL -5.654 | LR 9.82e-04
# Epoch 143 | Time 0.36s | Train NLL -6.471 | Val NLL -6.270 | LR 9.50e-04
# Epoch 144 | Time 0.20s | Train NLL -4.833 | Val NLL -5.712 | LR 9.19e-04
# Epoch 145 | Time 0.22s | Train NLL -4.702 | Val NLL -2.753 | LR 8.88e-04
# Epoch 146 | Time 0.22s | Train NLL -2.948 | Val NLL -4.278 | LR 8.57e-04
# Epoch 147 | Time 0.23s | Train NLL -5.660 | Val NLL -5.293 | LR 8.27e-04
# Epoch 148 | Time 0.23s | Train NLL -6.152 | Val NLL -4.984 | LR 7.97e-04
# Epoch 149 | Time 0.24s | Train NLL -5.177 | Val NLL -5.286 | LR 7.68e-04
# Epoch 150 | Time 0.25s | Train NLL -4.817 | Val NLL -2.461 | LR 7.39e-04
# Epoch 151 | Time 0.23s | Train NLL -0.848 | Val NLL -2.141 | LR 7.11e-04
# Epoch 152 | Time 0.22s | Train NLL -2.490 | Val NLL -3.543 | LR 6.83e-04
# Epoch 153 | Time 0.23s | Train NLL -2.044 | Val NLL -1.886 | LR 6.56e-04
# Epoch 154 | Time 0.20s | Train NLL -3.255 | Val NLL -2.993 | LR 6.29e-04
# Epoch 155 | Time 0.23s | Train NLL -3.093 | Val NLL -2.741 | LR 6.02e-04
# Epoch 156 | Time 0.22s | Train NLL -3.895 | Val NLL -4.064 | LR 5.76e-04
# Epoch 157 | Time 0.22s | Train NLL -4.024 | Val NLL -4.040 | LR 5.51e-04
# Epoch 158 | Time 0.21s | Train NLL -4.460 | Val NLL -4.506 | LR 5.26e-04
# Epoch 159 | Time 0.21s | Train NLL -5.463 | Val NLL -5.431 | LR 5.01e-04
# Epoch 160 | Time 0.20s | Train NLL -6.078 | Val NLL -5.672 | LR 4.77e-04
# Epoch 161 | Time 0.20s | Train NLL -6.340 | Val NLL -5.988 | LR 4.54e-04
# Epoch 162 | Time 0.29s | Train NLL -6.846 | Val NLL -6.614 | LR 4.31e-04
# Epoch 163 | Time 0.26s | Train NLL -6.914 | Val NLL -6.642 | LR 4.09e-04
# Epoch 164 | Time 0.30s | Train NLL -7.009 | Val NLL -6.708 | LR 3.87e-04
# Epoch 165 | Time 0.24s | Train NLL -7.001 | Val NLL -6.226 | LR 3.66e-04
# Epoch 166 | Time 0.23s | Train NLL -6.373 | Val NLL -6.582 | LR 3.45e-04
# Epoch 167 | Time 0.27s | Train NLL -7.371 | Val NLL -7.021 | LR 3.25e-04
# Epoch 168 | Time 0.20s | Train NLL -7.298 | Val NLL -6.718 | LR 3.05e-04
# Epoch 169 | Time 0.19s | Train NLL -7.187 | Val NLL -6.775 | LR 2.86e-04
# Epoch 170 | Time 0.21s | Train NLL -7.441 | Val NLL -7.175 | LR 2.68e-04
# Epoch 171 | Time 0.22s | Train NLL -7.770 | Val NLL -7.341 | LR 2.50e-04
# Epoch 172 | Time 0.25s | Train NLL -7.977 | Val NLL -7.383 | LR 2.33e-04
# Epoch 173 | Time 0.24s | Train NLL -8.189 | Val NLL -7.426 | LR 2.16e-04
# Epoch 174 | Time 0.26s | Train NLL -8.196 | Val NLL -7.553 | LR 2.00e-04
# Epoch 175 | Time 0.28s | Train NLL -8.134 | Val NLL -7.602 | LR 1.85e-04
# Epoch 176 | Time 0.26s | Train NLL -8.117 | Val NLL -7.668 | LR 1.70e-04
# Epoch 177 | Time 0.23s | Train NLL -8.360 | Val NLL -7.725 | LR 1.55e-04
# Epoch 178 | Time 0.24s | Train NLL -8.483 | Val NLL -7.773 | LR 1.42e-04
# Epoch 179 | Time 0.23s | Train NLL -8.440 | Val NLL -7.823 | LR 1.29e-04
# Epoch 180 | Time 0.23s | Train NLL -8.553 | Val NLL -7.863 | LR 1.16e-04
# Epoch 181 | Time 0.25s | Train NLL -8.660 | Val NLL -7.908 | LR 1.04e-04
# Epoch 182 | Time 0.24s | Train NLL -8.293 | Val NLL -7.943 | LR 9.32e-05
# Epoch 183 | Time 0.24s | Train NLL -8.579 | Val NLL -7.973 | LR 8.26e-05
# Epoch 184 | Time 0.24s | Train NLL -8.681 | Val NLL -7.993 | LR 7.26e-05
# Epoch 185 | Time 0.26s | Train NLL -8.721 | Val NLL -8.021 | LR 6.33e-05
# Epoch 186 | Time 0.24s | Train NLL -8.503 | Val NLL -8.049 | LR 5.46e-05
# Epoch 187 | Time 0.26s | Train NLL -8.503 | Val NLL -8.069 | LR 4.66e-05
# Epoch 188 | Time 0.26s | Train NLL -8.772 | Val NLL -8.085 | LR 3.92e-05
# Epoch 189 | Time 0.26s | Train NLL -8.769 | Val NLL -8.097 | LR 3.24e-05
# Epoch 190 | Time 0.24s | Train NLL -8.723 | Val NLL -8.110 | LR 2.62e-05
# Epoch 191 | Time 0.22s | Train NLL -8.857 | Val NLL -8.119 | LR 2.07e-05
# Epoch 192 | Time 0.23s | Train NLL -8.893 | Val NLL -8.126 | LR 1.59e-05
# Epoch 193 | Time 0.23s | Train NLL -8.794 | Val NLL -8.130 | LR 1.17e-05
# Epoch 194 | Time 0.26s | Train NLL -8.724 | Val NLL -8.136 | LR 8.11e-06
# Epoch 195 | Time 0.25s | Train NLL -8.877 | Val NLL -8.138 | LR 5.19e-06
# Epoch 196 | Time 0.24s | Train NLL -8.974 | Val NLL -8.140 | LR 2.92e-06
# Epoch 197 | Time 0.21s | Train NLL -8.860 | Val NLL -8.140 | LR 1.30e-06
# Epoch 198 | Time 0.25s | Train NLL -8.938 | Val NLL -8.141 | LR 3.24e-07
# Epoch 199 | Time 0.24s | Train NLL -8.774 | Val NLL -8.141 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 7361865.00
# Average absolute difference in CASUALTIES: 0.43

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
