# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Drought'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     Unnamed: 0  DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65          65      0.0           0             0.0       1.00      0.154204
# 72          72      0.0           0             0.0       0.88      0.353445
# 74          74      0.0           0             0.0       1.00      0.353445
# 76          76    100.0           0             0.0       1.75      0.353445
# 82          82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 24 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES"]#, "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE'
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = Y_train.shape[1]

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=12,
    hidden_features=[128, 128],
    bins=8
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 267540 parameters

# %% [markdown]
# ### Model training

# %%
class TrainingHistory:
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.lrs = []

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\david\Documents\GitHub\progA3I\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:1195: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   scheduler.step()
# Epoch 000 | Time 3.44s | Train NLL 0.162 | Val NLL -1.089 | LR 6.56e-04
# Epoch 001 | Time 3.21s | Train NLL -0.968 | Val NLL -1.173 | LR 8.11e-04
# Epoch 002 | Time 3.20s | Train NLL -1.161 | Val NLL -1.646 | LR 9.67e-04
# Epoch 003 | Time 3.09s | Train NLL -1.711 | Val NLL -1.467 | LR 1.12e-03
# Epoch 004 | Time 3.19s | Train NLL -1.702 | Val NLL -1.936 | LR 1.28e-03
# Epoch 005 | Time 3.27s | Train NLL -1.838 | Val NLL -1.691 | LR 1.43e-03
# Epoch 006 | Time 4.41s | Train NLL -1.717 | Val NLL -1.883 | LR 1.59e-03
# Epoch 007 | Time 4.02s | Train NLL -1.653 | Val NLL -1.727 | LR 1.74e-03
# Epoch 008 | Time 3.91s | Train NLL -1.009 | Val NLL -1.056 | LR 1.90e-03
# Epoch 009 | Time 3.82s | Train NLL -0.953 | Val NLL 0.069 | LR 2.06e-03
# Epoch 010 | Time 3.90s | Train NLL -1.448 | Val NLL -1.387 | LR 2.21e-03
# Epoch 011 | Time 3.49s | Train NLL -1.339 | Val NLL -1.731 | LR 2.37e-03
# Epoch 012 | Time 3.68s | Train NLL -0.258 | Val NLL -1.404 | LR 2.52e-03
# Epoch 013 | Time 3.41s | Train NLL -0.389 | Val NLL 1.074 | LR 2.68e-03
# Epoch 014 | Time 3.91s | Train NLL -0.858 | Val NLL -2.057 | LR 2.83e-03
# Epoch 015 | Time 4.07s | Train NLL -1.333 | Val NLL -0.570 | LR 2.99e-03
# Epoch 016 | Time 3.88s | Train NLL -0.677 | Val NLL -0.846 | LR 3.14e-03
# Epoch 017 | Time 3.94s | Train NLL -0.738 | Val NLL -1.824 | LR 3.30e-03
# Epoch 018 | Time 3.88s | Train NLL -1.360 | Val NLL -2.931 | LR 3.46e-03
# Epoch 019 | Time 4.08s | Train NLL -2.099 | Val NLL -1.721 | LR 3.61e-03
# Epoch 020 | Time 4.07s | Train NLL -1.342 | Val NLL -0.660 | LR 3.77e-03
# Epoch 021 | Time 3.68s | Train NLL -0.732 | Val NLL -1.941 | LR 3.92e-03
# Epoch 022 | Time 3.56s | Train NLL -0.946 | Val NLL 0.896 | LR 4.08e-03
# Epoch 023 | Time 3.57s | Train NLL -1.350 | Val NLL -0.773 | LR 4.23e-03
# Epoch 024 | Time 3.41s | Train NLL -0.856 | Val NLL -1.900 | LR 4.39e-03
# Epoch 025 | Time 3.57s | Train NLL -0.623 | Val NLL -2.325 | LR 4.54e-03
# Epoch 026 | Time 3.65s | Train NLL -0.639 | Val NLL -1.326 | LR 4.70e-03
# Epoch 027 | Time 3.37s | Train NLL -1.178 | Val NLL -2.461 | LR 4.86e-03
# Epoch 028 | Time 3.30s | Train NLL -0.908 | Val NLL 0.216 | LR 5.00e-03
# Epoch 029 | Time 3.33s | Train NLL -0.747 | Val NLL -0.868 | LR 5.00e-03
# Epoch 030 | Time 3.55s | Train NLL -1.460 | Val NLL -1.620 | LR 5.00e-03
# Epoch 031 | Time 3.61s | Train NLL 0.089 | Val NLL 2.139 | LR 5.00e-03
# Epoch 032 | Time 4.01s | Train NLL 0.941 | Val NLL -1.498 | LR 5.00e-03
# Epoch 033 | Time 3.68s | Train NLL -0.981 | Val NLL -0.670 | LR 5.00e-03
# Epoch 034 | Time 3.56s | Train NLL -0.395 | Val NLL 0.000 | LR 4.99e-03
# Epoch 035 | Time 3.74s | Train NLL -0.889 | Val NLL -1.901 | LR 4.99e-03
# Epoch 036 | Time 3.47s | Train NLL -0.060 | Val NLL -1.229 | LR 4.99e-03
# Epoch 037 | Time 3.68s | Train NLL -0.956 | Val NLL -0.812 | LR 4.99e-03
# Epoch 038 | Time 3.51s | Train NLL -0.796 | Val NLL -0.899 | LR 4.98e-03
# Epoch 039 | Time 4.03s | Train NLL -1.234 | Val NLL -0.095 | LR 4.98e-03
# Epoch 040 | Time 3.79s | Train NLL -1.530 | Val NLL -3.194 | LR 4.98e-03
# Epoch 041 | Time 4.02s | Train NLL -1.246 | Val NLL -2.046 | LR 4.97e-03
# Epoch 042 | Time 3.31s | Train NLL -1.280 | Val NLL 0.715 | LR 4.97e-03
# Epoch 043 | Time 3.56s | Train NLL -1.343 | Val NLL -1.457 | LR 4.96e-03
# Epoch 044 | Time 3.32s | Train NLL -0.634 | Val NLL 0.066 | LR 4.96e-03
# Epoch 045 | Time 3.32s | Train NLL -1.329 | Val NLL -0.730 | LR 4.95e-03
# Epoch 046 | Time 3.34s | Train NLL -2.191 | Val NLL -2.904 | LR 4.95e-03
# Epoch 047 | Time 3.42s | Train NLL -2.172 | Val NLL -2.564 | LR 4.94e-03
# Epoch 048 | Time 3.34s | Train NLL -2.509 | Val NLL -0.453 | LR 4.93e-03
# Epoch 049 | Time 3.32s | Train NLL -1.299 | Val NLL -0.243 | LR 4.93e-03
# Epoch 050 | Time 3.31s | Train NLL -1.882 | Val NLL -2.655 | LR 4.92e-03
# Epoch 051 | Time 3.33s | Train NLL -2.088 | Val NLL -2.219 | LR 4.91e-03
# Epoch 052 | Time 3.46s | Train NLL -1.915 | Val NLL -1.434 | LR 4.90e-03
# Epoch 053 | Time 3.42s | Train NLL -2.175 | Val NLL -0.139 | LR 4.90e-03
# Epoch 054 | Time 3.41s | Train NLL -1.366 | Val NLL -2.061 | LR 4.89e-03
# Epoch 055 | Time 3.47s | Train NLL -1.848 | Val NLL -2.020 | LR 4.88e-03
# Epoch 056 | Time 4.23s | Train NLL -2.203 | Val NLL -2.257 | LR 4.87e-03
# Epoch 057 | Time 3.97s | Train NLL -2.329 | Val NLL -3.520 | LR 4.86e-03
# Epoch 058 | Time 3.36s | Train NLL -1.961 | Val NLL -2.132 | LR 4.85e-03
# Epoch 059 | Time 3.16s | Train NLL -1.823 | Val NLL 2.182 | LR 4.84e-03
# Epoch 060 | Time 3.67s | Train NLL -1.622 | Val NLL -1.078 | LR 4.83e-03
# Epoch 061 | Time 4.07s | Train NLL -0.593 | Val NLL -1.654 | LR 4.82e-03
# Epoch 062 | Time 4.25s | Train NLL -1.108 | Val NLL -1.375 | LR 4.81e-03
# Epoch 063 | Time 3.98s | Train NLL -1.453 | Val NLL -2.460 | LR 4.80e-03
# Epoch 064 | Time 3.99s | Train NLL -2.279 | Val NLL -2.507 | LR 4.79e-03
# Epoch 065 | Time 3.71s | Train NLL -2.103 | Val NLL -3.181 | LR 4.77e-03
# Epoch 066 | Time 3.57s | Train NLL -1.812 | Val NLL -1.717 | LR 4.76e-03
# Epoch 067 | Time 3.49s | Train NLL -0.722 | Val NLL -1.562 | LR 4.75e-03
# Epoch 068 | Time 3.45s | Train NLL -0.965 | Val NLL -2.623 | LR 4.74e-03
# Epoch 069 | Time 3.43s | Train NLL -1.774 | Val NLL -2.993 | LR 4.72e-03
# Epoch 070 | Time 3.39s | Train NLL -2.100 | Val NLL 4.017 | LR 4.71e-03
# Epoch 071 | Time 3.44s | Train NLL 0.129 | Val NLL -1.872 | LR 4.70e-03
# Epoch 072 | Time 3.79s | Train NLL -0.757 | Val NLL -2.237 | LR 4.68e-03
# Epoch 073 | Time 3.64s | Train NLL -0.975 | Val NLL -2.081 | LR 4.67e-03
# Epoch 074 | Time 3.47s | Train NLL -2.301 | Val NLL -3.207 | LR 4.65e-03
# Epoch 075 | Time 3.53s | Train NLL -2.407 | Val NLL -2.756 | LR 4.64e-03
# Epoch 076 | Time 3.12s | Train NLL -2.418 | Val NLL -3.753 | LR 4.62e-03
# Epoch 077 | Time 3.61s | Train NLL -2.155 | Val NLL -1.386 | LR 4.61e-03
# Epoch 078 | Time 3.47s | Train NLL -2.336 | Val NLL -1.787 | LR 4.59e-03
# Epoch 079 | Time 3.21s | Train NLL -1.855 | Val NLL -2.065 | LR 4.58e-03
# Epoch 080 | Time 3.50s | Train NLL -2.763 | Val NLL -2.474 | LR 4.56e-03
# Epoch 081 | Time 3.29s | Train NLL -2.483 | Val NLL 1.728 | LR 4.54e-03
# Epoch 082 | Time 3.33s | Train NLL -1.944 | Val NLL -4.322 | LR 4.53e-03
# Epoch 083 | Time 3.41s | Train NLL -2.454 | Val NLL -2.570 | LR 4.51e-03
# Epoch 084 | Time 3.48s | Train NLL -2.774 | Val NLL -4.032 | LR 4.49e-03
# Epoch 085 | Time 3.43s | Train NLL -3.001 | Val NLL -2.660 | LR 4.47e-03
# Epoch 086 | Time 2.92s | Train NLL -1.928 | Val NLL -2.170 | LR 4.46e-03
# Epoch 087 | Time 3.08s | Train NLL -2.223 | Val NLL 0.235 | LR 4.44e-03
# Epoch 088 | Time 3.59s | Train NLL -1.812 | Val NLL -1.223 | LR 4.42e-03
# Epoch 089 | Time 3.59s | Train NLL -2.636 | Val NLL -2.771 | LR 4.40e-03
# Epoch 090 | Time 3.80s | Train NLL -1.445 | Val NLL -2.302 | LR 4.38e-03
# Epoch 091 | Time 3.69s | Train NLL -1.377 | Val NLL 1.045 | LR 4.36e-03
# Epoch 092 | Time 3.44s | Train NLL -2.017 | Val NLL -1.681 | LR 4.34e-03
# Epoch 093 | Time 3.45s | Train NLL -0.903 | Val NLL 0.457 | LR 4.32e-03
# Epoch 094 | Time 3.44s | Train NLL -1.166 | Val NLL -2.846 | LR 4.30e-03
# Epoch 095 | Time 3.49s | Train NLL -1.940 | Val NLL -2.344 | LR 4.28e-03
# Epoch 096 | Time 3.60s | Train NLL -2.042 | Val NLL -0.963 | LR 4.26e-03
# Epoch 097 | Time 3.11s | Train NLL -2.073 | Val NLL -2.359 | LR 4.24e-03
# Epoch 098 | Time 3.26s | Train NLL -2.288 | Val NLL -1.984 | LR 4.22e-03
# Epoch 099 | Time 3.08s | Train NLL -1.996 | Val NLL -3.203 | LR 4.20e-03
# Epoch 100 | Time 3.42s | Train NLL -3.047 | Val NLL -4.010 | LR 4.18e-03
# Epoch 101 | Time 3.43s | Train NLL -2.242 | Val NLL -3.000 | LR 4.16e-03
# Epoch 102 | Time 3.18s | Train NLL -2.709 | Val NLL -1.843 | LR 4.14e-03
# Epoch 103 | Time 3.07s | Train NLL -1.988 | Val NLL -1.974 | LR 4.11e-03
# Epoch 104 | Time 2.80s | Train NLL -2.411 | Val NLL -3.300 | LR 4.09e-03
# Epoch 105 | Time 2.74s | Train NLL -1.772 | Val NLL -1.152 | LR 4.07e-03
# Epoch 106 | Time 2.74s | Train NLL -2.761 | Val NLL -0.972 | LR 4.05e-03
# Epoch 107 | Time 2.88s | Train NLL -2.382 | Val NLL -2.533 | LR 4.02e-03
# Epoch 108 | Time 2.84s | Train NLL -1.971 | Val NLL -0.160 | LR 4.00e-03
# Epoch 109 | Time 2.93s | Train NLL 0.431 | Val NLL -1.839 | LR 3.98e-03
# Epoch 110 | Time 2.59s | Train NLL -1.109 | Val NLL -2.304 | LR 3.95e-03
# Epoch 111 | Time 2.80s | Train NLL -2.379 | Val NLL -2.413 | LR 3.93e-03
# Epoch 112 | Time 2.87s | Train NLL -2.745 | Val NLL -3.573 | LR 3.91e-03
# Epoch 113 | Time 2.80s | Train NLL -3.673 | Val NLL -4.614 | LR 3.88e-03
# Epoch 114 | Time 3.08s | Train NLL -2.943 | Val NLL -4.271 | LR 3.86e-03
# Epoch 115 | Time 2.85s | Train NLL -3.666 | Val NLL -4.292 | LR 3.83e-03
# Epoch 116 | Time 2.71s | Train NLL -3.850 | Val NLL -4.305 | LR 3.81e-03
# Epoch 117 | Time 2.73s | Train NLL -2.959 | Val NLL -3.789 | LR 3.78e-03
# Epoch 118 | Time 2.52s | Train NLL -1.985 | Val NLL -0.606 | LR 3.76e-03
# Epoch 119 | Time 3.06s | Train NLL -1.553 | Val NLL 0.452 | LR 3.73e-03
# Epoch 120 | Time 2.79s | Train NLL -1.413 | Val NLL -1.350 | LR 3.71e-03
# Epoch 121 | Time 2.81s | Train NLL -2.009 | Val NLL -0.442 | LR 3.68e-03
# Epoch 122 | Time 2.71s | Train NLL -2.382 | Val NLL 0.651 | LR 3.66e-03
# Epoch 123 | Time 2.88s | Train NLL -1.161 | Val NLL -2.248 | LR 3.63e-03
# Epoch 124 | Time 2.89s | Train NLL -1.898 | Val NLL -2.461 | LR 3.61e-03
# Epoch 125 | Time 2.87s | Train NLL -1.800 | Val NLL -2.220 | LR 3.58e-03
# Epoch 126 | Time 2.96s | Train NLL -3.208 | Val NLL -2.513 | LR 3.55e-03
# Epoch 127 | Time 2.99s | Train NLL -3.078 | Val NLL -3.856 | LR 3.53e-03
# Epoch 128 | Time 3.08s | Train NLL -3.214 | Val NLL -3.453 | LR 3.50e-03
# Epoch 129 | Time 2.97s | Train NLL -3.421 | Val NLL -4.265 | LR 3.48e-03
# Epoch 130 | Time 3.33s | Train NLL -2.176 | Val NLL 3.026 | LR 3.45e-03
# Epoch 131 | Time 2.94s | Train NLL -1.751 | Val NLL -1.937 | LR 3.42e-03
# Epoch 132 | Time 3.00s | Train NLL -3.134 | Val NLL -4.341 | LR 3.39e-03
# Epoch 133 | Time 2.55s | Train NLL -2.292 | Val NLL -3.777 | LR 3.37e-03
# Epoch 134 | Time 2.77s | Train NLL -2.886 | Val NLL -3.921 | LR 3.34e-03
# Epoch 135 | Time 3.15s | Train NLL -2.193 | Val NLL -2.881 | LR 3.31e-03
# Epoch 136 | Time 2.92s | Train NLL -1.197 | Val NLL -1.834 | LR 3.29e-03
# Epoch 137 | Time 2.64s | Train NLL -1.561 | Val NLL -2.671 | LR 3.26e-03
# Epoch 138 | Time 2.76s | Train NLL -3.052 | Val NLL -4.462 | LR 3.23e-03
# Epoch 139 | Time 2.76s | Train NLL -1.867 | Val NLL -2.849 | LR 3.20e-03
# Epoch 140 | Time 2.96s | Train NLL -2.629 | Val NLL -1.713 | LR 3.18e-03
# Epoch 141 | Time 3.00s | Train NLL -2.626 | Val NLL -3.725 | LR 3.15e-03
# Epoch 142 | Time 3.02s | Train NLL -3.616 | Val NLL -2.835 | LR 3.12e-03
# Epoch 143 | Time 3.37s | Train NLL -1.176 | Val NLL -1.683 | LR 3.09e-03
# Epoch 144 | Time 3.26s | Train NLL -2.771 | Val NLL -2.917 | LR 3.06e-03
# Epoch 145 | Time 3.09s | Train NLL -2.148 | Val NLL -0.970 | LR 3.03e-03
# Epoch 146 | Time 3.11s | Train NLL -1.902 | Val NLL -2.720 | LR 3.01e-03
# Epoch 147 | Time 3.49s | Train NLL -1.961 | Val NLL 0.258 | LR 2.98e-03
# Epoch 148 | Time 3.53s | Train NLL -1.557 | Val NLL -3.506 | LR 2.95e-03
# Epoch 149 | Time 3.32s | Train NLL -2.338 | Val NLL -0.464 | LR 2.92e-03
# Epoch 150 | Time 3.36s | Train NLL -1.128 | Val NLL -0.427 | LR 2.89e-03
# Epoch 151 | Time 3.82s | Train NLL -1.945 | Val NLL -2.377 | LR 2.86e-03
# Epoch 152 | Time 3.69s | Train NLL -2.990 | Val NLL -3.430 | LR 2.84e-03
# Epoch 153 | Time 3.45s | Train NLL -3.592 | Val NLL -4.129 | LR 2.81e-03
# Epoch 154 | Time 3.90s | Train NLL -2.790 | Val NLL -3.162 | LR 2.78e-03
# Epoch 155 | Time 3.82s | Train NLL -2.325 | Val NLL -2.350 | LR 2.75e-03
# Epoch 156 | Time 3.24s | Train NLL -2.498 | Val NLL -2.559 | LR 2.72e-03
# Epoch 157 | Time 3.04s | Train NLL -2.351 | Val NLL -3.306 | LR 2.69e-03
# Epoch 158 | Time 3.21s | Train NLL -3.834 | Val NLL -3.725 | LR 2.66e-03
# Epoch 159 | Time 3.09s | Train NLL -3.571 | Val NLL -3.157 | LR 2.63e-03
# Epoch 160 | Time 2.83s | Train NLL -2.427 | Val NLL -3.906 | LR 2.61e-03
# Epoch 161 | Time 2.79s | Train NLL -2.734 | Val NLL -3.272 | LR 2.58e-03
# Epoch 162 | Time 2.92s | Train NLL -3.261 | Val NLL -4.054 | LR 2.55e-03
# Epoch 163 | Time 3.02s | Train NLL -2.768 | Val NLL -3.465 | LR 2.52e-03
# Epoch 164 | Time 3.29s | Train NLL -3.086 | Val NLL -3.816 | LR 2.49e-03
# Epoch 165 | Time 3.19s | Train NLL -2.628 | Val NLL -3.458 | LR 2.46e-03
# Epoch 166 | Time 3.20s | Train NLL -3.495 | Val NLL -1.620 | LR 2.43e-03
# Epoch 167 | Time 3.22s | Train NLL -2.996 | Val NLL -3.422 | LR 2.40e-03
# Epoch 168 | Time 3.02s | Train NLL -3.433 | Val NLL -3.914 | LR 2.37e-03
# Epoch 169 | Time 3.29s | Train NLL -3.648 | Val NLL -2.876 | LR 2.35e-03
# Epoch 170 | Time 3.26s | Train NLL -3.553 | Val NLL -1.958 | LR 2.32e-03
# Epoch 171 | Time 3.39s | Train NLL -3.087 | Val NLL -3.103 | LR 2.29e-03
# Epoch 172 | Time 3.47s | Train NLL -2.518 | Val NLL -3.050 | LR 2.26e-03
# Epoch 173 | Time 3.27s | Train NLL -3.302 | Val NLL -3.421 | LR 2.23e-03
# Epoch 174 | Time 3.35s | Train NLL -3.363 | Val NLL -4.371 | LR 2.20e-03
# Epoch 175 | Time 3.23s | Train NLL -4.231 | Val NLL -3.863 | LR 2.17e-03
# Epoch 176 | Time 3.03s | Train NLL -3.787 | Val NLL -2.568 | LR 2.14e-03
# Epoch 177 | Time 3.32s | Train NLL -3.983 | Val NLL -5.057 | LR 2.12e-03
# Epoch 178 | Time 3.14s | Train NLL -4.926 | Val NLL -2.448 | LR 2.09e-03
# Epoch 179 | Time 3.12s | Train NLL -3.804 | Val NLL -4.793 | LR 2.06e-03
# Epoch 180 | Time 3.33s | Train NLL -3.662 | Val NLL -3.518 | LR 2.03e-03
# Epoch 181 | Time 3.31s | Train NLL -3.173 | Val NLL -3.022 | LR 2.00e-03
# Epoch 182 | Time 3.43s | Train NLL -1.087 | Val NLL -3.524 | LR 1.97e-03
# Epoch 183 | Time 3.05s | Train NLL -3.936 | Val NLL -4.410 | LR 1.94e-03
# Epoch 184 | Time 3.14s | Train NLL -3.852 | Val NLL -1.396 | LR 1.92e-03
# Epoch 185 | Time 2.94s | Train NLL -4.077 | Val NLL -4.799 | LR 1.89e-03
# Epoch 186 | Time 3.30s | Train NLL -3.017 | Val NLL -2.750 | LR 1.86e-03
# Epoch 187 | Time 2.77s | Train NLL -3.047 | Val NLL -4.028 | LR 1.83e-03
# Epoch 188 | Time 2.63s | Train NLL -1.007 | Val NLL -1.855 | LR 1.81e-03
# Epoch 189 | Time 2.53s | Train NLL -2.527 | Val NLL -4.916 | LR 1.78e-03
# Epoch 190 | Time 2.51s | Train NLL -3.969 | Val NLL -3.651 | LR 1.75e-03
# Epoch 191 | Time 2.50s | Train NLL -4.113 | Val NLL -5.365 | LR 1.72e-03
# Epoch 192 | Time 2.50s | Train NLL -4.003 | Val NLL -5.509 | LR 1.69e-03
# Epoch 193 | Time 2.26s | Train NLL -3.311 | Val NLL -2.558 | LR 1.67e-03
# Epoch 194 | Time 2.47s | Train NLL -3.730 | Val NLL 0.809 | LR 1.64e-03
# Epoch 195 | Time 2.62s | Train NLL -3.199 | Val NLL -4.198 | LR 1.61e-03
# Epoch 196 | Time 2.92s | Train NLL -3.843 | Val NLL -4.588 | LR 1.59e-03
# Epoch 197 | Time 2.91s | Train NLL -1.950 | Val NLL 1.448 | LR 1.56e-03
# Epoch 198 | Time 2.89s | Train NLL -2.012 | Val NLL -3.562 | LR 1.53e-03
# Epoch 199 | Time 2.95s | Train NLL -3.285 | Val NLL -3.192 | LR 1.51e-03
# Epoch 200 | Time 2.86s | Train NLL -4.093 | Val NLL -3.300 | LR 1.48e-03
# Epoch 201 | Time 2.67s | Train NLL -3.915 | Val NLL -5.268 | LR 1.45e-03
# Epoch 202 | Time 2.50s | Train NLL -3.093 | Val NLL -2.757 | LR 1.43e-03
# Epoch 203 | Time 2.39s | Train NLL -3.344 | Val NLL -0.994 | LR 1.40e-03
# Epoch 204 | Time 2.95s | Train NLL -4.055 | Val NLL -2.554 | LR 1.38e-03
# Epoch 205 | Time 2.83s | Train NLL -3.149 | Val NLL -2.829 | LR 1.35e-03
# Epoch 206 | Time 2.84s | Train NLL -3.436 | Val NLL -4.000 | LR 1.32e-03
# Epoch 207 | Time 3.27s | Train NLL -4.296 | Val NLL -3.350 | LR 1.30e-03
# Epoch 208 | Time 3.12s | Train NLL -2.953 | Val NLL -4.990 | LR 1.27e-03
# Epoch 209 | Time 3.29s | Train NLL -4.226 | Val NLL -4.757 | LR 1.25e-03
# Epoch 210 | Time 2.84s | Train NLL -3.603 | Val NLL -4.628 | LR 1.22e-03
# Epoch 211 | Time 2.77s | Train NLL -3.862 | Val NLL -3.397 | LR 1.20e-03
# Epoch 212 | Time 3.22s | Train NLL -4.092 | Val NLL -4.305 | LR 1.17e-03
# Epoch 213 | Time 2.98s | Train NLL -4.137 | Val NLL -3.832 | LR 1.15e-03
# Epoch 214 | Time 3.21s | Train NLL -4.278 | Val NLL -4.081 | LR 1.13e-03
# Epoch 215 | Time 3.22s | Train NLL -4.618 | Val NLL -5.134 | LR 1.10e-03
# Epoch 216 | Time 3.35s | Train NLL -5.236 | Val NLL -5.168 | LR 1.08e-03
# Epoch 217 | Time 3.44s | Train NLL -4.439 | Val NLL -1.939 | LR 1.05e-03
# Epoch 218 | Time 3.24s | Train NLL -4.074 | Val NLL -4.510 | LR 1.03e-03
# Epoch 219 | Time 3.19s | Train NLL -3.812 | Val NLL -5.444 | LR 1.01e-03
# Epoch 220 | Time 2.80s | Train NLL -4.087 | Val NLL -4.998 | LR 9.85e-04
# Epoch 221 | Time 2.77s | Train NLL -3.701 | Val NLL -2.934 | LR 9.62e-04
# Epoch 222 | Time 2.52s | Train NLL -4.681 | Val NLL -4.542 | LR 9.39e-04
# Epoch 223 | Time 3.26s | Train NLL -4.618 | Val NLL -5.926 | LR 9.17e-04
# Epoch 224 | Time 3.18s | Train NLL -4.922 | Val NLL -4.346 | LR 8.95e-04
# Epoch 225 | Time 2.95s | Train NLL -4.426 | Val NLL -2.533 | LR 8.73e-04
# Epoch 226 | Time 3.09s | Train NLL -3.926 | Val NLL -5.906 | LR 8.51e-04
# Epoch 227 | Time 3.42s | Train NLL -4.752 | Val NLL -4.629 | LR 8.29e-04
# Epoch 228 | Time 3.10s | Train NLL -5.400 | Val NLL -5.139 | LR 8.08e-04
# Epoch 229 | Time 4.23s | Train NLL -5.441 | Val NLL -5.987 | LR 7.87e-04
# Epoch 230 | Time 4.01s | Train NLL -5.552 | Val NLL -5.940 | LR 7.66e-04
# Epoch 231 | Time 3.93s | Train NLL -5.621 | Val NLL -5.251 | LR 7.46e-04
# Epoch 232 | Time 4.04s | Train NLL -4.579 | Val NLL -3.833 | LR 7.25e-04
# Epoch 233 | Time 4.04s | Train NLL -4.676 | Val NLL -4.735 | LR 7.05e-04
# Epoch 234 | Time 4.01s | Train NLL -4.664 | Val NLL -4.020 | LR 6.85e-04
# Epoch 235 | Time 4.33s | Train NLL -4.384 | Val NLL -3.966 | LR 6.65e-04
# Epoch 236 | Time 4.25s | Train NLL -4.537 | Val NLL -4.184 | LR 6.46e-04
# Epoch 237 | Time 4.17s | Train NLL -4.657 | Val NLL -3.974 | LR 6.27e-04
# Epoch 238 | Time 4.08s | Train NLL -4.715 | Val NLL -4.359 | LR 6.08e-04
# Epoch 239 | Time 3.94s | Train NLL -4.849 | Val NLL -4.444 | LR 5.89e-04
# Epoch 240 | Time 3.79s | Train NLL -4.886 | Val NLL -4.334 | LR 5.71e-04
# Epoch 241 | Time 3.59s | Train NLL -5.135 | Val NLL -5.850 | LR 5.53e-04
# Epoch 242 | Time 3.51s | Train NLL -5.085 | Val NLL -5.941 | LR 5.35e-04
# Epoch 243 | Time 3.42s | Train NLL -5.388 | Val NLL -4.891 | LR 5.17e-04
# Epoch 244 | Time 3.65s | Train NLL -5.315 | Val NLL -4.908 | LR 5.00e-04
# Epoch 245 | Time 3.76s | Train NLL -5.376 | Val NLL -4.553 | LR 4.83e-04
# Epoch 246 | Time 3.83s | Train NLL -5.137 | Val NLL -5.742 | LR 4.66e-04
# Epoch 247 | Time 3.43s | Train NLL -5.546 | Val NLL -6.134 | LR 4.50e-04
# Epoch 248 | Time 3.24s | Train NLL -5.341 | Val NLL -3.931 | LR 4.33e-04
# Epoch 249 | Time 3.32s | Train NLL -4.922 | Val NLL -4.131 | LR 4.17e-04
# Epoch 250 | Time 3.43s | Train NLL -4.522 | Val NLL -5.878 | LR 4.02e-04
# Epoch 251 | Time 3.63s | Train NLL -5.268 | Val NLL -5.643 | LR 3.86e-04
# Epoch 252 | Time 3.54s | Train NLL -5.797 | Val NLL -6.320 | LR 3.71e-04
# Epoch 253 | Time 3.49s | Train NLL -5.710 | Val NLL -5.172 | LR 3.56e-04
# Epoch 254 | Time 3.39s | Train NLL -5.899 | Val NLL -5.969 | LR 3.42e-04
# Epoch 255 | Time 3.33s | Train NLL -5.783 | Val NLL -5.806 | LR 3.27e-04
# Epoch 256 | Time 3.30s | Train NLL -5.786 | Val NLL -5.921 | LR 3.13e-04
# Epoch 257 | Time 3.38s | Train NLL -5.804 | Val NLL -5.844 | LR 3.00e-04
# Epoch 258 | Time 3.30s | Train NLL -5.871 | Val NLL -5.679 | LR 2.86e-04
# Epoch 259 | Time 3.32s | Train NLL -5.914 | Val NLL -6.003 | LR 2.73e-04
# Epoch 260 | Time 3.31s | Train NLL -5.976 | Val NLL -5.929 | LR 2.61e-04
# Epoch 261 | Time 3.34s | Train NLL -5.978 | Val NLL -5.772 | LR 2.48e-04
# Epoch 262 | Time 3.54s | Train NLL -6.045 | Val NLL -6.212 | LR 2.36e-04
# Epoch 263 | Time 3.52s | Train NLL -6.095 | Val NLL -6.165 | LR 2.24e-04
# Epoch 264 | Time 3.96s | Train NLL -6.141 | Val NLL -5.997 | LR 2.12e-04
# Epoch 265 | Time 3.83s | Train NLL -6.157 | Val NLL -6.176 | LR 2.01e-04
# Epoch 266 | Time 3.24s | Train NLL -6.230 | Val NLL -6.016 | LR 1.90e-04
# Epoch 267 | Time 3.02s | Train NLL -6.210 | Val NLL -5.386 | LR 1.80e-04
# Epoch 268 | Time 2.73s | Train NLL -5.914 | Val NLL -6.631 | LR 1.69e-04
# Epoch 269 | Time 3.09s | Train NLL -5.662 | Val NLL -4.347 | LR 1.59e-04
# Epoch 270 | Time 3.07s | Train NLL -6.037 | Val NLL -6.609 | LR 1.50e-04
# Epoch 271 | Time 3.05s | Train NLL -6.185 | Val NLL -5.826 | LR 1.40e-04
# Epoch 272 | Time 3.05s | Train NLL -6.153 | Val NLL -5.959 | LR 1.31e-04
# Epoch 273 | Time 3.23s | Train NLL -6.364 | Val NLL -6.785 | LR 1.22e-04
# Epoch 274 | Time 2.71s | Train NLL -6.439 | Val NLL -6.388 | LR 1.14e-04
# Epoch 275 | Time 3.13s | Train NLL -6.363 | Val NLL -6.717 | LR 1.06e-04
# Epoch 276 | Time 2.94s | Train NLL -6.428 | Val NLL -6.034 | LR 9.81e-05
# Epoch 277 | Time 2.88s | Train NLL -6.448 | Val NLL -5.796 | LR 9.07e-05
# Epoch 278 | Time 3.02s | Train NLL -6.115 | Val NLL -6.300 | LR 8.35e-05
# Epoch 279 | Time 2.83s | Train NLL -6.414 | Val NLL -6.094 | LR 7.67e-05
# Epoch 280 | Time 2.85s | Train NLL -6.461 | Val NLL -6.554 | LR 7.02e-05
# Epoch 281 | Time 2.92s | Train NLL -6.592 | Val NLL -6.579 | LR 6.41e-05
# Epoch 282 | Time 3.24s | Train NLL -6.521 | Val NLL -6.445 | LR 5.83e-05
# Epoch 283 | Time 3.24s | Train NLL -6.696 | Val NLL -6.387 | LR 5.28e-05
# Epoch 284 | Time 3.17s | Train NLL -6.664 | Val NLL -7.003 | LR 4.76e-05
# Epoch 285 | Time 3.34s | Train NLL -6.386 | Val NLL -6.282 | LR 4.28e-05
# Epoch 286 | Time 3.30s | Train NLL -6.500 | Val NLL -6.835 | LR 3.83e-05
# Epoch 287 | Time 2.94s | Train NLL -6.558 | Val NLL -6.993 | LR 3.41e-05
# Epoch 288 | Time 3.11s | Train NLL -6.707 | Val NLL -6.805 | LR 3.02e-05
# Epoch 289 | Time 3.11s | Train NLL -6.717 | Val NLL -6.695 | LR 2.67e-05
# Epoch 290 | Time 2.91s | Train NLL -6.637 | Val NLL -7.142 | LR 2.36e-05
# Epoch 291 | Time 3.19s | Train NLL -6.689 | Val NLL -6.948 | LR 2.07e-05
# Epoch 292 | Time 3.00s | Train NLL -6.782 | Val NLL -7.011 | LR 1.82e-05
# Epoch 293 | Time 2.99s | Train NLL -6.855 | Val NLL -6.938 | LR 1.60e-05
# Epoch 294 | Time 3.25s | Train NLL -6.779 | Val NLL -6.630 | LR 1.42e-05
# Epoch 295 | Time 3.15s | Train NLL -6.673 | Val NLL -6.625 | LR 1.27e-05
# Epoch 296 | Time 2.84s | Train NLL -6.745 | Val NLL -6.495 | LR 1.15e-05
# Epoch 297 | Time 2.94s | Train NLL -6.698 | Val NLL -7.024 | LR 1.07e-05
# Epoch 298 | Time 3.21s | Train NLL -6.553 | Val NLL -6.808 | LR 1.02e-05
# Epoch 299 | Time 3.01s | Train NLL -6.779 | Val NLL -7.168 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 plt.figure(figsize=(10,4))
#       3 plt.subplot(1,2,1)
# ----> 4 plt.plot(history.train_losses, label='Train Loss')
#       5 plt.plot(history.val_losses, label='Val Loss')
#       6 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 34878.12
