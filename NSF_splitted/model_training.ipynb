# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

from utils import TrainingHistory

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Flood'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# dequantization
# Y[:, 1] += np.random.uniform(0, 1, size=Y.shape[0])

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 200
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
X_DIM = X_train.shape[1]
Y_DIM = Y_train.shape[1]

flow = zuko.flows.NSF(
    features=Y_DIM,
    context=X_DIM,
    transforms=12,
    hidden_features=[128, 128],
    bins=8
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)

optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)

warmup = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=0.1,
    total_iters=WARMUP_STEPS
)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS * len(train_loader) - WARMUP_STEPS,
    eta_min=1e-5
)
scheduler = torch.optim.lr_scheduler.SequentialLR(
    optimizer,
    schedulers=[warmup, cosine],
    milestones=[WARMUP_STEPS]
)

scaler = torch.amp.GradScaler(device=device)

ema = torch.optim.swa_utils.AveragedModel(
    flow,
    avg_fn=lambda averaged, model, num_averaged: 0.999 * averaged + 0.001 * model
)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 306216 parameters

# %% [markdown]
# ### Model training

# %%
history = TrainingHistory()
best_val_loss = np.inf
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device.type):
            loss = -flow(x).log_prob(y).mean()

        scaler.scale(loss).backward()

        # gradient clipping
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(flow.parameters(), 5.0)

        scaler.step(optimizer)
        scaler.update()

        scheduler.step()

        ema.update_parameters(flow)

        train_loss += loss.item()
        global_step += 1

    train_loss /= len(train_loader)

    # ---------- Validation ----------
    flow.eval()
    val_loss = 0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= len(val_loader)

    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

    # Save EMA weights (better than raw model)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ema.module.state_dict(), RUN_PATH)
# Out:
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 000 | Time 6.44s | Train NLL -1.037 | Val NLL -1.198 | LR 7.28e-04
# Epoch 001 | Time 6.64s | Train NLL -2.241 | Val NLL -2.548 | LR 9.57e-04
# Epoch 002 | Time 6.28s | Train NLL -2.756 | Val NLL -0.674 | LR 1.19e-03
# Epoch 003 | Time 6.43s | Train NLL -2.608 | Val NLL -2.771 | LR 1.41e-03
# Epoch 004 | Time 6.00s | Train NLL -2.532 | Val NLL -0.975 | LR 1.64e-03
# Epoch 005 | Time 6.02s | Train NLL -2.141 | Val NLL -3.089 | LR 1.87e-03
# Epoch 006 | Time 5.68s | Train NLL -3.572 | Val NLL -3.712 | LR 2.10e-03
# Epoch 007 | Time 6.13s | Train NLL -3.617 | Val NLL -2.753 | LR 2.33e-03
# Epoch 008 | Time 5.88s | Train NLL -1.557 | Val NLL -1.692 | LR 2.56e-03
# Epoch 009 | Time 5.83s | Train NLL -3.076 | Val NLL -2.653 | LR 2.78e-03
# Epoch 010 | Time 5.62s | Train NLL -2.333 | Val NLL -3.427 | LR 3.01e-03
# Epoch 011 | Time 5.80s | Train NLL -2.334 | Val NLL -1.272 | LR 3.24e-03
# Epoch 012 | Time 5.60s | Train NLL -2.847 | Val NLL -4.701 | LR 3.47e-03
# Epoch 013 | Time 5.82s | Train NLL -2.567 | Val NLL -0.548 | LR 3.70e-03
# Epoch 014 | Time 5.70s | Train NLL -2.463 | Val NLL -5.370 | LR 3.93e-03
# Epoch 015 | Time 5.83s | Train NLL -3.350 | Val NLL -4.006 | LR 4.15e-03
# Epoch 016 | Time 5.84s | Train NLL -2.441 | Val NLL -3.401 | LR 4.38e-03
# Epoch 017 | Time 5.76s | Train NLL -2.362 | Val NLL -2.840 | LR 4.61e-03
# Epoch 018 | Time 5.62s | Train NLL -3.850 | Val NLL -0.678 | LR 4.84e-03
# c:\Users\matti\anaconda3\envs\ai311\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 019 | Time 5.75s | Train NLL -3.103 | Val NLL -2.429 | LR 5.00e-03
# Epoch 020 | Time 5.72s | Train NLL -2.222 | Val NLL -2.367 | LR 5.00e-03
# Epoch 021 | Time 5.77s | Train NLL -3.500 | Val NLL -2.047 | LR 5.00e-03
# Epoch 022 | Time 5.93s | Train NLL -3.453 | Val NLL -5.247 | LR 5.00e-03
# Epoch 023 | Time 5.80s | Train NLL -3.475 | Val NLL -3.224 | LR 4.99e-03
# Epoch 024 | Time 5.83s | Train NLL -3.188 | Val NLL -2.900 | LR 4.99e-03
# Epoch 025 | Time 5.72s | Train NLL -3.986 | Val NLL -1.569 | LR 4.99e-03
# Epoch 026 | Time 5.85s | Train NLL -2.451 | Val NLL -3.374 | LR 4.98e-03
# Epoch 027 | Time 6.07s | Train NLL -2.313 | Val NLL -5.666 | LR 4.97e-03
# Epoch 028 | Time 6.20s | Train NLL -3.262 | Val NLL -3.660 | LR 4.97e-03
# Epoch 029 | Time 5.96s | Train NLL -4.034 | Val NLL -2.858 | LR 4.96e-03
# Epoch 030 | Time 6.02s | Train NLL -3.274 | Val NLL -6.630 | LR 4.95e-03
# Epoch 031 | Time 6.13s | Train NLL -3.350 | Val NLL -3.938 | LR 4.94e-03
# Epoch 032 | Time 6.12s | Train NLL -3.635 | Val NLL -4.141 | LR 4.93e-03
# Epoch 033 | Time 6.63s | Train NLL -2.331 | Val NLL -3.744 | LR 4.92e-03
# Epoch 034 | Time 6.77s | Train NLL -3.998 | Val NLL -2.203 | LR 4.91e-03
# Epoch 035 | Time 6.70s | Train NLL -3.149 | Val NLL -5.962 | LR 4.90e-03
# Epoch 036 | Time 6.77s | Train NLL -3.745 | Val NLL -4.547 | LR 4.89e-03
# Epoch 037 | Time 6.22s | Train NLL -4.387 | Val NLL -4.391 | LR 4.87e-03
# Epoch 038 | Time 6.03s | Train NLL -2.524 | Val NLL -2.592 | LR 4.86e-03
# Epoch 039 | Time 5.95s | Train NLL -3.543 | Val NLL -3.669 | LR 4.85e-03
# Epoch 040 | Time 6.23s | Train NLL -4.247 | Val NLL -0.539 | LR 4.83e-03
# Epoch 041 | Time 6.04s | Train NLL -4.160 | Val NLL -0.667 | LR 4.81e-03
# Epoch 042 | Time 6.06s | Train NLL -3.004 | Val NLL -2.780 | LR 4.80e-03
# Epoch 043 | Time 6.19s | Train NLL -2.606 | Val NLL -3.400 | LR 4.78e-03
# Epoch 044 | Time 5.90s | Train NLL -3.347 | Val NLL -6.313 | LR 4.76e-03
# Epoch 045 | Time 6.05s | Train NLL -3.318 | Val NLL -2.124 | LR 4.74e-03
# Epoch 046 | Time 6.13s | Train NLL -3.391 | Val NLL -4.248 | LR 4.72e-03
# Epoch 047 | Time 5.98s | Train NLL -3.037 | Val NLL -4.797 | LR 4.70e-03
# Epoch 048 | Time 5.92s | Train NLL -3.331 | Val NLL -4.035 | LR 4.68e-03
# Epoch 049 | Time 5.93s | Train NLL -3.838 | Val NLL -3.814 | LR 4.66e-03
# Epoch 050 | Time 6.13s | Train NLL -3.962 | Val NLL -1.796 | LR 4.64e-03
# Epoch 051 | Time 6.88s | Train NLL -3.121 | Val NLL -3.756 | LR 4.62e-03
# Epoch 052 | Time 6.29s | Train NLL -4.693 | Val NLL -3.607 | LR 4.59e-03
# Epoch 053 | Time 6.37s | Train NLL -2.266 | Val NLL -3.562 | LR 4.57e-03
# Epoch 054 | Time 5.97s | Train NLL -4.346 | Val NLL -3.965 | LR 4.54e-03
# Epoch 055 | Time 6.10s | Train NLL -3.404 | Val NLL -5.413 | LR 4.52e-03
# Epoch 056 | Time 6.15s | Train NLL -3.705 | Val NLL -2.986 | LR 4.49e-03
# Epoch 057 | Time 6.13s | Train NLL -3.101 | Val NLL -0.942 | LR 4.46e-03
# Epoch 058 | Time 5.99s | Train NLL -3.383 | Val NLL -4.586 | LR 4.44e-03
# Epoch 059 | Time 6.11s | Train NLL -3.858 | Val NLL -5.028 | LR 4.41e-03
# Epoch 060 | Time 6.12s | Train NLL -4.261 | Val NLL -3.745 | LR 4.38e-03
# Epoch 061 | Time 6.18s | Train NLL -2.578 | Val NLL -2.420 | LR 4.35e-03
# Epoch 062 | Time 6.07s | Train NLL -3.077 | Val NLL -3.841 | LR 4.32e-03
# Epoch 063 | Time 6.18s | Train NLL -2.603 | Val NLL -0.375 | LR 4.29e-03
# Epoch 064 | Time 5.96s | Train NLL -2.720 | Val NLL -4.924 | LR 4.26e-03
# Epoch 065 | Time 6.02s | Train NLL -3.905 | Val NLL -5.176 | LR 4.23e-03
# Epoch 066 | Time 6.10s | Train NLL -3.778 | Val NLL -3.782 | LR 4.20e-03
# Epoch 067 | Time 6.16s | Train NLL -4.314 | Val NLL -4.972 | LR 4.17e-03
# Epoch 068 | Time 6.09s | Train NLL -2.300 | Val NLL -1.481 | LR 4.13e-03
# Epoch 069 | Time 5.96s | Train NLL -3.039 | Val NLL -5.354 | LR 4.10e-03
# Epoch 070 | Time 6.07s | Train NLL -4.264 | Val NLL -4.217 | LR 4.07e-03
# Epoch 071 | Time 6.04s | Train NLL -2.992 | Val NLL -1.935 | LR 4.03e-03
# Epoch 072 | Time 6.18s | Train NLL -3.838 | Val NLL -4.881 | LR 4.00e-03
# Epoch 073 | Time 5.94s | Train NLL -3.896 | Val NLL -4.863 | LR 3.96e-03
# Epoch 074 | Time 6.14s | Train NLL -3.876 | Val NLL -5.628 | LR 3.93e-03
# Epoch 075 | Time 6.21s | Train NLL -3.281 | Val NLL -3.193 | LR 3.89e-03
# Epoch 076 | Time 6.03s | Train NLL -3.421 | Val NLL -4.245 | LR 3.86e-03
# Epoch 077 | Time 6.25s | Train NLL -2.968 | Val NLL -0.614 | LR 3.82e-03
# Epoch 078 | Time 6.09s | Train NLL -3.478 | Val NLL -6.101 | LR 3.78e-03
# Epoch 079 | Time 5.88s | Train NLL -2.815 | Val NLL -4.233 | LR 3.75e-03
# Epoch 080 | Time 6.23s | Train NLL -3.929 | Val NLL -4.512 | LR 3.71e-03
# Epoch 081 | Time 6.18s | Train NLL -4.327 | Val NLL -6.842 | LR 3.67e-03
# Epoch 082 | Time 6.22s | Train NLL -3.979 | Val NLL -3.121 | LR 3.63e-03
# Epoch 083 | Time 6.02s | Train NLL -3.465 | Val NLL -2.498 | LR 3.59e-03
# Epoch 084 | Time 6.13s | Train NLL -3.364 | Val NLL -4.608 | LR 3.55e-03
# Epoch 085 | Time 6.24s | Train NLL -4.153 | Val NLL -4.824 | LR 3.51e-03
# Epoch 086 | Time 6.00s | Train NLL -5.042 | Val NLL -4.470 | LR 3.47e-03
# Epoch 087 | Time 6.10s | Train NLL -3.257 | Val NLL -5.099 | LR 3.43e-03
# Epoch 088 | Time 6.19s | Train NLL -4.169 | Val NLL -4.352 | LR 3.39e-03
# Epoch 089 | Time 6.17s | Train NLL -3.420 | Val NLL -4.854 | LR 3.35e-03
# Epoch 090 | Time 6.36s | Train NLL -5.678 | Val NLL -7.620 | LR 3.31e-03
# Epoch 091 | Time 6.27s | Train NLL -7.365 | Val NLL -5.825 | LR 3.27e-03
# Epoch 092 | Time 6.31s | Train NLL -4.573 | Val NLL -1.371 | LR 3.23e-03
# Epoch 093 | Time 6.36s | Train NLL -2.662 | Val NLL -4.480 | LR 3.19e-03
# Epoch 094 | Time 6.83s | Train NLL -4.117 | Val NLL -5.846 | LR 3.14e-03
# Epoch 095 | Time 6.60s | Train NLL -3.292 | Val NLL -3.508 | LR 3.10e-03
# Epoch 096 | Time 6.17s | Train NLL -4.220 | Val NLL -2.453 | LR 3.06e-03
# Epoch 097 | Time 6.22s | Train NLL -2.777 | Val NLL -5.291 | LR 3.02e-03
# Epoch 098 | Time 6.10s | Train NLL -3.739 | Val NLL -2.646 | LR 2.97e-03
# Epoch 099 | Time 6.14s | Train NLL -4.485 | Val NLL -3.688 | LR 2.93e-03
# Epoch 100 | Time 6.31s | Train NLL -4.965 | Val NLL -4.952 | LR 2.89e-03
# Epoch 101 | Time 5.89s | Train NLL -4.052 | Val NLL -6.215 | LR 2.85e-03
# Epoch 102 | Time 6.50s | Train NLL -4.154 | Val NLL -4.154 | LR 2.80e-03
# Epoch 103 | Time 6.15s | Train NLL -4.495 | Val NLL -4.553 | LR 2.76e-03
# Epoch 104 | Time 6.31s | Train NLL -3.832 | Val NLL -5.209 | LR 2.72e-03
# Epoch 105 | Time 6.04s | Train NLL -5.015 | Val NLL -4.403 | LR 2.67e-03
# Epoch 106 | Time 6.18s | Train NLL -3.776 | Val NLL -3.113 | LR 2.63e-03
# Epoch 107 | Time 6.03s | Train NLL -3.884 | Val NLL -4.851 | LR 2.59e-03
# Epoch 108 | Time 6.17s | Train NLL -4.171 | Val NLL -3.607 | LR 2.54e-03
# Epoch 109 | Time 6.03s | Train NLL -4.281 | Val NLL -5.483 | LR 2.50e-03
# Epoch 110 | Time 6.22s | Train NLL -3.907 | Val NLL -3.927 | LR 2.46e-03
# Epoch 111 | Time 6.38s | Train NLL -5.068 | Val NLL -6.543 | LR 2.41e-03
# Epoch 112 | Time 6.09s | Train NLL -6.113 | Val NLL -4.380 | LR 2.37e-03
# Epoch 113 | Time 6.22s | Train NLL -4.135 | Val NLL -6.133 | LR 2.32e-03
# Epoch 114 | Time 6.28s | Train NLL -4.754 | Val NLL -5.062 | LR 2.28e-03
# Epoch 115 | Time 6.10s | Train NLL -4.931 | Val NLL -5.133 | LR 2.24e-03
# Epoch 116 | Time 6.32s | Train NLL -4.631 | Val NLL -3.862 | LR 2.20e-03
# Epoch 117 | Time 6.06s | Train NLL -3.513 | Val NLL -4.107 | LR 2.15e-03
# Epoch 118 | Time 6.14s | Train NLL -4.254 | Val NLL -5.678 | LR 2.11e-03
# Epoch 119 | Time 6.07s | Train NLL -4.704 | Val NLL -5.629 | LR 2.07e-03
# Epoch 120 | Time 6.11s | Train NLL -4.794 | Val NLL -5.056 | LR 2.02e-03
# Epoch 121 | Time 6.12s | Train NLL -4.513 | Val NLL -5.741 | LR 1.98e-03
# Epoch 122 | Time 6.08s | Train NLL -5.428 | Val NLL -5.438 | LR 1.94e-03
# Epoch 123 | Time 6.17s | Train NLL -5.875 | Val NLL -4.637 | LR 1.90e-03
# Epoch 124 | Time 6.20s | Train NLL -4.907 | Val NLL -5.986 | LR 1.85e-03
# Epoch 125 | Time 6.12s | Train NLL -5.019 | Val NLL -2.336 | LR 1.81e-03
# Epoch 126 | Time 6.17s | Train NLL -4.581 | Val NLL -5.606 | LR 1.77e-03
# Epoch 127 | Time 6.14s | Train NLL -3.985 | Val NLL -5.903 | LR 1.73e-03
# Epoch 128 | Time 6.10s | Train NLL -5.520 | Val NLL -4.110 | LR 1.69e-03
# Epoch 129 | Time 6.18s | Train NLL -5.209 | Val NLL -3.803 | LR 1.65e-03
# Epoch 130 | Time 6.23s | Train NLL -4.925 | Val NLL -3.522 | LR 1.61e-03
# Epoch 131 | Time 6.31s | Train NLL -4.625 | Val NLL -6.137 | LR 1.57e-03
# Epoch 132 | Time 6.33s | Train NLL -4.974 | Val NLL -6.404 | LR 1.53e-03
# Epoch 133 | Time 6.31s | Train NLL -4.629 | Val NLL -3.101 | LR 1.49e-03
# Epoch 134 | Time 6.15s | Train NLL -4.294 | Val NLL -5.270 | LR 1.45e-03
# Epoch 135 | Time 6.21s | Train NLL -4.886 | Val NLL -6.234 | LR 1.41e-03
# Epoch 136 | Time 6.22s | Train NLL -4.915 | Val NLL -4.913 | LR 1.37e-03
# Epoch 137 | Time 5.90s | Train NLL -5.270 | Val NLL -3.564 | LR 1.33e-03
# Epoch 138 | Time 6.13s | Train NLL -5.882 | Val NLL -6.326 | LR 1.29e-03
# Epoch 139 | Time 5.87s | Train NLL -5.671 | Val NLL -6.545 | LR 1.25e-03
# Epoch 140 | Time 5.86s | Train NLL -6.211 | Val NLL -2.587 | LR 1.22e-03
# Epoch 141 | Time 5.94s | Train NLL -5.754 | Val NLL -5.988 | LR 1.18e-03
# Epoch 142 | Time 5.84s | Train NLL -6.250 | Val NLL -6.073 | LR 1.14e-03
# Epoch 143 | Time 5.77s | Train NLL -4.269 | Val NLL -3.490 | LR 1.11e-03
# Epoch 144 | Time 5.79s | Train NLL -5.461 | Val NLL -5.411 | LR 1.07e-03
# Epoch 145 | Time 5.82s | Train NLL -6.114 | Val NLL -5.560 | LR 1.04e-03
# Epoch 146 | Time 5.87s | Train NLL -6.399 | Val NLL -5.091 | LR 1.00e-03
# Epoch 147 | Time 5.92s | Train NLL -6.059 | Val NLL -5.983 | LR 9.66e-04
# Epoch 148 | Time 5.90s | Train NLL -6.251 | Val NLL -6.876 | LR 9.32e-04
# Epoch 149 | Time 5.83s | Train NLL -6.051 | Val NLL -5.490 | LR 8.99e-04
# Epoch 150 | Time 5.99s | Train NLL -6.563 | Val NLL -7.948 | LR 8.66e-04
# Epoch 151 | Time 6.38s | Train NLL -7.686 | Val NLL -8.075 | LR 8.33e-04
# Epoch 152 | Time 5.88s | Train NLL -7.295 | Val NLL -8.544 | LR 8.01e-04
# Epoch 153 | Time 6.25s | Train NLL -5.978 | Val NLL -6.028 | LR 7.69e-04
# Epoch 154 | Time 5.93s | Train NLL -6.224 | Val NLL -5.169 | LR 7.39e-04
# Epoch 155 | Time 6.11s | Train NLL -6.858 | Val NLL -7.653 | LR 7.08e-04
# Epoch 156 | Time 6.00s | Train NLL -6.385 | Val NLL -4.908 | LR 6.78e-04
# Epoch 157 | Time 5.97s | Train NLL -6.035 | Val NLL -6.371 | LR 6.49e-04
# Epoch 158 | Time 5.97s | Train NLL -6.231 | Val NLL -5.957 | LR 6.20e-04
# Epoch 159 | Time 6.11s | Train NLL -7.395 | Val NLL -6.044 | LR 5.92e-04
# Epoch 160 | Time 6.29s | Train NLL -7.227 | Val NLL -6.835 | LR 5.64e-04
# Epoch 161 | Time 6.16s | Train NLL -7.778 | Val NLL -8.582 | LR 5.37e-04
# Epoch 162 | Time 6.30s | Train NLL -7.144 | Val NLL -6.803 | LR 5.11e-04
# Epoch 163 | Time 6.31s | Train NLL -8.007 | Val NLL -8.086 | LR 4.85e-04
# Epoch 164 | Time 6.27s | Train NLL -8.119 | Val NLL -8.613 | LR 4.60e-04
# Epoch 165 | Time 6.22s | Train NLL -8.042 | Val NLL -8.435 | LR 4.35e-04
# Epoch 166 | Time 6.39s | Train NLL -8.994 | Val NLL -9.203 | LR 4.11e-04
# Epoch 167 | Time 6.28s | Train NLL -8.979 | Val NLL -8.959 | LR 3.88e-04
# Epoch 168 | Time 6.30s | Train NLL -8.589 | Val NLL -9.292 | LR 3.65e-04
# Epoch 169 | Time 6.39s | Train NLL -8.383 | Val NLL -9.771 | LR 3.43e-04
# Epoch 170 | Time 6.39s | Train NLL -8.589 | Val NLL -8.070 | LR 3.22e-04
# Epoch 171 | Time 6.30s | Train NLL -9.409 | Val NLL -9.390 | LR 3.01e-04
# Epoch 172 | Time 6.14s | Train NLL -9.381 | Val NLL -9.304 | LR 2.81e-04
# Epoch 173 | Time 6.21s | Train NLL -9.450 | Val NLL -8.165 | LR 2.62e-04
# Epoch 174 | Time 6.18s | Train NLL -9.571 | Val NLL -8.379 | LR 2.43e-04
# Epoch 175 | Time 6.37s | Train NLL -8.825 | Val NLL -10.093 | LR 2.25e-04
# Epoch 176 | Time 6.37s | Train NLL -9.497 | Val NLL -8.690 | LR 2.08e-04
# Epoch 177 | Time 6.19s | Train NLL -9.498 | Val NLL -10.307 | LR 1.91e-04
# Epoch 178 | Time 6.32s | Train NLL -10.154 | Val NLL -9.820 | LR 1.75e-04
# Epoch 179 | Time 6.51s | Train NLL -9.958 | Val NLL -10.655 | LR 1.60e-04
# Epoch 180 | Time 6.36s | Train NLL -9.732 | Val NLL -9.222 | LR 1.45e-04
# Epoch 181 | Time 6.26s | Train NLL -10.545 | Val NLL -10.382 | LR 1.32e-04
# Epoch 182 | Time 6.26s | Train NLL -10.622 | Val NLL -10.614 | LR 1.19e-04
# Epoch 183 | Time 6.16s | Train NLL -10.776 | Val NLL -10.990 | LR 1.06e-04
# Epoch 184 | Time 6.33s | Train NLL -10.859 | Val NLL -10.337 | LR 9.47e-05
# Epoch 185 | Time 6.25s | Train NLL -11.010 | Val NLL -11.578 | LR 8.39e-05
# Epoch 186 | Time 6.43s | Train NLL -11.379 | Val NLL -11.276 | LR 7.37e-05
# Epoch 187 | Time 6.15s | Train NLL -11.133 | Val NLL -11.550 | LR 6.43e-05
# Epoch 188 | Time 6.33s | Train NLL -11.535 | Val NLL -11.051 | LR 5.57e-05
# Epoch 189 | Time 6.49s | Train NLL -11.621 | Val NLL -11.900 | LR 4.78e-05
# Epoch 190 | Time 6.22s | Train NLL -11.798 | Val NLL -11.996 | LR 4.06e-05
# Epoch 191 | Time 6.48s | Train NLL -11.909 | Val NLL -11.980 | LR 3.42e-05
# Epoch 192 | Time 6.47s | Train NLL -12.064 | Val NLL -12.013 | LR 2.85e-05
# Epoch 193 | Time 6.43s | Train NLL -11.957 | Val NLL -11.733 | LR 2.36e-05
# Epoch 194 | Time 6.41s | Train NLL -11.891 | Val NLL -11.641 | LR 1.95e-05
# Epoch 195 | Time 6.54s | Train NLL -11.867 | Val NLL -11.506 | LR 1.61e-05
# Epoch 196 | Time 6.30s | Train NLL -11.993 | Val NLL -11.459 | LR 1.34e-05
# Epoch 197 | Time 6.23s | Train NLL -11.959 | Val NLL -11.521 | LR 1.15e-05
# Epoch 198 | Time 6.44s | Train NLL -12.063 | Val NLL -11.340 | LR 1.04e-05
# Epoch 199 | Time 6.43s | Train NLL -12.018 | Val NLL -11.589 | LR 1.00e-05

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
def run_inference_and_plot(flow, test_loader, y_scaler, target_cols):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample()
            # Ensure y_hat and y_batch are 2D
            if y_hat.ndim == 1:
                y_hat = y_hat.unsqueeze(1)
            if y_batch.ndim == 1:
                y_batch = y_batch.unsqueeze(1)
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    # Plot for the single target
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.scatter(y_true[:, 0], y_pred[:, 0], alpha=0.5)
    plt.xlabel(f"True {target_cols[0]}")
    plt.ylabel(f"Predicted {target_cols[0]}")
    plt.title(f"True vs Predicted: {target_cols[0]}")
    plt.plot([y_true[:, 0].min(), y_true[:, 0].max()], [y_true[:, 0].min(), y_true[:, 0].max()], 'r--')
    plt.grid()
    plt.subplot(1,2,2)
    plt.scatter(y_true[:, 1], y_pred[:, 1], alpha=0.5)
    plt.xlabel(f"True {target_cols[1]}")
    plt.ylabel(f"Predicted {target_cols[1]}")
    plt.title(f"True vs Predicted: {target_cols[1]}")
    plt.plot([y_true[:, 1].min(), y_true[:, 1].max()], [y_true[:, 1].min(), y_true[:, 1].max()], 'r--')
    plt.grid()
    plt.show()

run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 1195814.62
# Average absolute difference in CASUALTIES: 0.02

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
