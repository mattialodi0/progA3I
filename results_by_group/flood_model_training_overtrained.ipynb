# %% [markdown]
# # Flood model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Flood'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 500
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 3.56s | Train NLL 3.985 | Val NLL -1.506 | LR 1.00e-03
# Epoch 001 | Time 3.15s | Train NLL -1.822 | Val NLL -1.843 | LR 2.00e-03
# Epoch 002 | Time 3.15s | Train NLL -1.170 | Val NLL 0.123 | LR 3.00e-03
# Epoch 003 | Time 3.68s | Train NLL -0.619 | Val NLL -0.834 | LR 4.00e-03
# Epoch 004 | Time 3.46s | Train NLL -0.633 | Val NLL 1.327 | LR 5.00e-03
# Epoch 005 | Time 3.47s | Train NLL -0.545 | Val NLL -2.259 | LR 5.00e-03
# Epoch 006 | Time 3.51s | Train NLL -1.013 | Val NLL -0.910 | LR 5.00e-03
# Epoch 007 | Time 3.54s | Train NLL -0.609 | Val NLL -2.190 | LR 5.00e-03
# Epoch 008 | Time 3.38s | Train NLL -0.696 | Val NLL 0.131 | LR 5.00e-03
# Epoch 009 | Time 3.47s | Train NLL -1.054 | Val NLL -2.776 | LR 5.00e-03
# Epoch 010 | Time 5.38s | Train NLL -1.831 | Val NLL -2.306 | LR 5.00e-03
# Epoch 011 | Time 3.88s | Train NLL -0.931 | Val NLL 2.195 | LR 5.00e-03
# Epoch 012 | Time 3.70s | Train NLL -1.733 | Val NLL -2.330 | LR 5.00e-03
# Epoch 013 | Time 3.65s | Train NLL -1.094 | Val NLL -1.957 | LR 5.00e-03
# Epoch 014 | Time 3.86s | Train NLL -3.041 | Val NLL -2.822 | LR 4.99e-03
# Epoch 015 | Time 3.92s | Train NLL -2.168 | Val NLL -3.497 | LR 4.99e-03
# Epoch 016 | Time 3.65s | Train NLL -2.816 | Val NLL -4.332 | LR 4.99e-03
# Epoch 017 | Time 3.48s | Train NLL -2.833 | Val NLL 0.413 | LR 4.99e-03
# Epoch 018 | Time 3.97s | Train NLL -2.691 | Val NLL -4.451 | LR 4.99e-03
# Epoch 019 | Time 3.56s | Train NLL -4.262 | Val NLL -5.716 | LR 4.99e-03
# Epoch 020 | Time 3.60s | Train NLL -4.717 | Val NLL -4.732 | LR 4.99e-03
# Epoch 021 | Time 3.53s | Train NLL -4.464 | Val NLL -4.719 | LR 4.99e-03
# Epoch 022 | Time 3.53s | Train NLL -4.084 | Val NLL -5.702 | LR 4.98e-03
# Epoch 023 | Time 3.55s | Train NLL -3.236 | Val NLL -2.736 | LR 4.98e-03
# Epoch 024 | Time 3.48s | Train NLL -4.102 | Val NLL -4.869 | LR 4.98e-03
# Epoch 025 | Time 3.43s | Train NLL -4.081 | Val NLL -5.263 | LR 4.98e-03
# Epoch 026 | Time 3.55s | Train NLL -2.928 | Val NLL -3.912 | LR 4.98e-03
# Epoch 027 | Time 3.69s | Train NLL -4.113 | Val NLL -4.284 | LR 4.97e-03
# Epoch 028 | Time 3.44s | Train NLL -3.344 | Val NLL -0.775 | LR 4.97e-03
# Epoch 029 | Time 3.50s | Train NLL -3.699 | Val NLL -3.149 | LR 4.97e-03
# Epoch 030 | Time 3.49s | Train NLL -3.783 | Val NLL -4.729 | LR 4.97e-03
# Epoch 031 | Time 3.60s | Train NLL -2.872 | Val NLL -3.110 | LR 4.96e-03
# Epoch 032 | Time 3.43s | Train NLL -4.611 | Val NLL -5.075 | LR 4.96e-03
# Epoch 033 | Time 3.55s | Train NLL -3.807 | Val NLL -0.601 | LR 4.96e-03
# Epoch 034 | Time 3.55s | Train NLL -3.886 | Val NLL -5.379 | LR 4.95e-03
# Epoch 035 | Time 3.57s | Train NLL -5.239 | Val NLL -5.181 | LR 4.95e-03
# Epoch 036 | Time 3.82s | Train NLL -5.046 | Val NLL -4.331 | LR 4.95e-03
# Epoch 037 | Time 4.28s | Train NLL -4.976 | Val NLL -4.468 | LR 4.95e-03
# Epoch 038 | Time 4.35s | Train NLL -3.689 | Val NLL -1.003 | LR 4.94e-03
# Epoch 039 | Time 4.50s | Train NLL -4.090 | Val NLL -6.612 | LR 4.94e-03
# Epoch 040 | Time 4.32s | Train NLL -4.184 | Val NLL -5.175 | LR 4.94e-03
# Epoch 041 | Time 4.35s | Train NLL -4.037 | Val NLL -3.983 | LR 4.93e-03
# Epoch 042 | Time 4.38s | Train NLL -3.597 | Val NLL -2.272 | LR 4.93e-03
# Epoch 043 | Time 4.41s | Train NLL -4.377 | Val NLL -3.416 | LR 4.92e-03
# Epoch 044 | Time 4.32s | Train NLL -3.874 | Val NLL -4.601 | LR 4.92e-03
# Epoch 045 | Time 4.33s | Train NLL -3.580 | Val NLL -3.909 | LR 4.92e-03
# Epoch 046 | Time 4.42s | Train NLL -3.696 | Val NLL -1.839 | LR 4.91e-03
# Epoch 047 | Time 4.37s | Train NLL -3.329 | Val NLL -3.966 | LR 4.91e-03
# Epoch 048 | Time 3.30s | Train NLL -4.209 | Val NLL -3.968 | LR 4.90e-03
# Epoch 049 | Time 3.04s | Train NLL -3.421 | Val NLL -5.535 | LR 4.90e-03
# Epoch 050 | Time 3.11s | Train NLL -3.736 | Val NLL -2.719 | LR 4.89e-03
# Epoch 051 | Time 3.02s | Train NLL -3.679 | Val NLL -4.395 | LR 4.89e-03
# Epoch 052 | Time 4.03s | Train NLL -2.798 | Val NLL -1.658 | LR 4.88e-03
# Epoch 053 | Time 4.27s | Train NLL -3.744 | Val NLL -3.468 | LR 4.88e-03
# Epoch 054 | Time 4.46s | Train NLL -0.954 | Val NLL -5.310 | LR 4.88e-03
# Epoch 055 | Time 4.34s | Train NLL -4.758 | Val NLL -5.572 | LR 4.87e-03
# Epoch 056 | Time 4.23s | Train NLL -5.111 | Val NLL -6.122 | LR 4.87e-03
# Epoch 057 | Time 4.25s | Train NLL -3.709 | Val NLL -2.387 | LR 4.86e-03
# Epoch 058 | Time 4.37s | Train NLL -3.296 | Val NLL -3.601 | LR 4.85e-03
# Epoch 059 | Time 4.27s | Train NLL -3.665 | Val NLL -5.038 | LR 4.85e-03
# Epoch 060 | Time 4.30s | Train NLL -3.381 | Val NLL -2.810 | LR 4.84e-03
# Epoch 061 | Time 4.25s | Train NLL -1.553 | Val NLL -2.847 | LR 4.84e-03
# Epoch 062 | Time 4.45s | Train NLL -4.032 | Val NLL -4.236 | LR 4.83e-03
# Epoch 063 | Time 3.97s | Train NLL -4.885 | Val NLL -4.499 | LR 4.83e-03
# Epoch 064 | Time 3.04s | Train NLL -5.146 | Val NLL -4.547 | LR 4.82e-03
# Epoch 065 | Time 3.07s | Train NLL -2.985 | Val NLL -6.058 | LR 4.81e-03
# Epoch 066 | Time 3.12s | Train NLL -4.699 | Val NLL -5.356 | LR 4.81e-03
# Epoch 067 | Time 3.66s | Train NLL -4.966 | Val NLL -2.745 | LR 4.80e-03
# Epoch 068 | Time 4.41s | Train NLL -4.920 | Val NLL -5.325 | LR 4.80e-03
# Epoch 069 | Time 4.26s | Train NLL -5.512 | Val NLL -2.901 | LR 4.79e-03
# Epoch 070 | Time 4.40s | Train NLL -2.190 | Val NLL -3.079 | LR 4.78e-03
# Epoch 071 | Time 4.28s | Train NLL -1.627 | Val NLL -1.936 | LR 4.78e-03
# Epoch 072 | Time 4.34s | Train NLL -1.617 | Val NLL -0.865 | LR 4.77e-03
# Epoch 073 | Time 4.33s | Train NLL -1.831 | Val NLL -3.398 | LR 4.76e-03
# Epoch 074 | Time 4.47s | Train NLL -2.517 | Val NLL -3.181 | LR 4.76e-03
# Epoch 075 | Time 4.20s | Train NLL -1.532 | Val NLL -2.917 | LR 4.75e-03
# Epoch 076 | Time 4.27s | Train NLL -3.121 | Val NLL -3.633 | LR 4.74e-03
# Epoch 077 | Time 4.25s | Train NLL -2.591 | Val NLL -3.897 | LR 4.74e-03
# Epoch 078 | Time 4.38s | Train NLL -3.507 | Val NLL -5.348 | LR 4.73e-03
# Epoch 079 | Time 4.29s | Train NLL -3.972 | Val NLL -6.178 | LR 4.72e-03
# Epoch 080 | Time 4.22s | Train NLL -2.340 | Val NLL -4.280 | LR 4.71e-03
# Epoch 081 | Time 4.33s | Train NLL -4.306 | Val NLL -5.878 | LR 4.71e-03
# Epoch 082 | Time 3.37s | Train NLL -3.621 | Val NLL -2.402 | LR 4.70e-03
# Epoch 083 | Time 3.03s | Train NLL -4.041 | Val NLL -5.816 | LR 4.69e-03
# Epoch 084 | Time 3.05s | Train NLL -4.486 | Val NLL -3.570 | LR 4.68e-03
# Epoch 085 | Time 3.02s | Train NLL -4.123 | Val NLL -4.990 | LR 4.68e-03
# Epoch 086 | Time 4.25s | Train NLL -3.997 | Val NLL -2.608 | LR 4.67e-03
# Epoch 087 | Time 4.36s | Train NLL -4.273 | Val NLL -4.464 | LR 4.66e-03
# Epoch 088 | Time 4.34s | Train NLL -4.285 | Val NLL -6.281 | LR 4.65e-03
# Epoch 089 | Time 4.32s | Train NLL -3.242 | Val NLL -4.146 | LR 4.64e-03
# Epoch 090 | Time 4.42s | Train NLL -3.466 | Val NLL -4.803 | LR 4.64e-03
# Epoch 091 | Time 4.25s | Train NLL -3.395 | Val NLL -2.697 | LR 4.63e-03
# Epoch 092 | Time 4.34s | Train NLL -5.158 | Val NLL -2.032 | LR 4.62e-03
# Epoch 093 | Time 4.34s | Train NLL -3.768 | Val NLL -4.092 | LR 4.61e-03
# Epoch 094 | Time 4.49s | Train NLL -3.561 | Val NLL -5.705 | LR 4.60e-03
# Epoch 095 | Time 4.33s | Train NLL -4.878 | Val NLL -3.363 | LR 4.59e-03
# Epoch 096 | Time 4.30s | Train NLL -4.210 | Val NLL -6.542 | LR 4.59e-03
# Epoch 097 | Time 4.30s | Train NLL -1.928 | Val NLL -2.870 | LR 4.58e-03
# Epoch 098 | Time 4.42s | Train NLL -4.330 | Val NLL -4.854 | LR 4.57e-03
# Epoch 099 | Time 4.38s | Train NLL -4.418 | Val NLL -5.445 | LR 4.56e-03
# Epoch 100 | Time 4.27s | Train NLL -5.059 | Val NLL -5.625 | LR 4.55e-03
# Epoch 101 | Time 3.07s | Train NLL -3.899 | Val NLL -2.639 | LR 4.54e-03
# Epoch 102 | Time 3.14s | Train NLL -2.845 | Val NLL -3.272 | LR 4.53e-03
# Epoch 103 | Time 3.03s | Train NLL -4.245 | Val NLL -2.824 | LR 4.52e-03
# Epoch 104 | Time 3.87s | Train NLL -1.252 | Val NLL 0.285 | LR 4.51e-03
# Epoch 105 | Time 4.28s | Train NLL -1.408 | Val NLL -3.766 | LR 4.50e-03
# Epoch 106 | Time 4.42s | Train NLL -0.195 | Val NLL 1.289 | LR 4.49e-03
# Epoch 107 | Time 4.31s | Train NLL -0.010 | Val NLL -2.587 | LR 4.48e-03
# Epoch 108 | Time 4.26s | Train NLL -2.222 | Val NLL -0.684 | LR 4.47e-03
# Epoch 109 | Time 4.32s | Train NLL -3.068 | Val NLL -4.441 | LR 4.47e-03
# Epoch 110 | Time 4.43s | Train NLL -3.092 | Val NLL -4.393 | LR 4.46e-03
# Epoch 111 | Time 4.32s | Train NLL -4.502 | Val NLL -4.219 | LR 4.45e-03
# Epoch 112 | Time 4.45s | Train NLL -3.163 | Val NLL -4.831 | LR 4.44e-03
# Epoch 113 | Time 4.34s | Train NLL -4.119 | Val NLL -6.127 | LR 4.43e-03
# Epoch 114 | Time 4.41s | Train NLL -4.954 | Val NLL -4.347 | LR 4.42e-03
# Epoch 115 | Time 4.32s | Train NLL -5.796 | Val NLL -4.387 | LR 4.40e-03
# Epoch 116 | Time 4.32s | Train NLL -5.809 | Val NLL -2.686 | LR 4.39e-03
# Epoch 117 | Time 4.23s | Train NLL -1.161 | Val NLL -4.907 | LR 4.38e-03
# Epoch 118 | Time 4.45s | Train NLL -4.160 | Val NLL -5.058 | LR 4.37e-03
# Epoch 119 | Time 3.28s | Train NLL -5.071 | Val NLL -4.784 | LR 4.36e-03
# Epoch 120 | Time 3.02s | Train NLL -4.707 | Val NLL -4.783 | LR 4.35e-03
# Epoch 121 | Time 3.07s | Train NLL -3.739 | Val NLL -1.345 | LR 4.34e-03
# Epoch 122 | Time 3.60s | Train NLL -4.466 | Val NLL -2.058 | LR 4.33e-03
# Epoch 123 | Time 4.30s | Train NLL -5.151 | Val NLL -4.625 | LR 4.32e-03
# Epoch 124 | Time 4.32s | Train NLL -4.804 | Val NLL -6.826 | LR 4.31e-03
# Epoch 125 | Time 4.52s | Train NLL -6.148 | Val NLL -5.075 | LR 4.30e-03
# Epoch 126 | Time 4.32s | Train NLL -5.019 | Val NLL -6.146 | LR 4.29e-03
# Epoch 127 | Time 4.34s | Train NLL -5.253 | Val NLL -4.579 | LR 4.28e-03
# Epoch 128 | Time 4.33s | Train NLL -5.641 | Val NLL -5.197 | LR 4.26e-03
# Epoch 129 | Time 4.40s | Train NLL -3.144 | Val NLL -4.724 | LR 4.25e-03
# Epoch 130 | Time 4.35s | Train NLL -4.976 | Val NLL -5.863 | LR 4.24e-03
# Epoch 131 | Time 4.33s | Train NLL -5.316 | Val NLL -4.269 | LR 4.23e-03
# Epoch 132 | Time 4.32s | Train NLL -4.598 | Val NLL -5.997 | LR 4.22e-03
# Epoch 133 | Time 4.45s | Train NLL -6.399 | Val NLL -7.414 | LR 4.21e-03
# Epoch 134 | Time 4.35s | Train NLL -5.034 | Val NLL -6.480 | LR 4.20e-03
# Epoch 135 | Time 4.25s | Train NLL -4.842 | Val NLL -5.244 | LR 4.18e-03
# Epoch 136 | Time 4.30s | Train NLL -5.003 | Val NLL -5.117 | LR 4.17e-03
# Epoch 137 | Time 4.37s | Train NLL -4.510 | Val NLL -4.649 | LR 4.16e-03
# Epoch 138 | Time 3.23s | Train NLL -4.136 | Val NLL -6.034 | LR 4.15e-03
# Epoch 139 | Time 3.00s | Train NLL -4.699 | Val NLL -6.098 | LR 4.14e-03
# Epoch 140 | Time 3.10s | Train NLL -4.850 | Val NLL -3.977 | LR 4.13e-03
# Epoch 141 | Time 3.43s | Train NLL -5.076 | Val NLL -3.878 | LR 4.11e-03
# Epoch 142 | Time 4.23s | Train NLL -4.564 | Val NLL -5.373 | LR 4.10e-03
# Epoch 143 | Time 4.32s | Train NLL -4.941 | Val NLL -4.521 | LR 4.09e-03
# Epoch 144 | Time 4.38s | Train NLL -4.583 | Val NLL -3.909 | LR 4.08e-03
# Epoch 145 | Time 4.20s | Train NLL -3.358 | Val NLL -5.151 | LR 4.06e-03
# Epoch 146 | Time 4.26s | Train NLL -3.961 | Val NLL -5.455 | LR 4.05e-03
# Epoch 147 | Time 4.23s | Train NLL -3.283 | Val NLL -5.589 | LR 4.04e-03
# Epoch 148 | Time 4.42s | Train NLL -5.033 | Val NLL 3.191 | LR 4.03e-03
# Epoch 149 | Time 4.32s | Train NLL -1.379 | Val NLL -3.677 | LR 4.01e-03
# Epoch 150 | Time 4.35s | Train NLL -3.778 | Val NLL -3.474 | LR 4.00e-03
# Epoch 151 | Time 4.25s | Train NLL -3.632 | Val NLL -3.949 | LR 3.99e-03
# Epoch 152 | Time 4.42s | Train NLL -3.310 | Val NLL -5.232 | LR 3.98e-03
# Epoch 153 | Time 4.28s | Train NLL -3.888 | Val NLL -4.621 | LR 3.96e-03
# Epoch 154 | Time 4.27s | Train NLL -4.550 | Val NLL -4.636 | LR 3.95e-03
# Epoch 155 | Time 4.30s | Train NLL -4.194 | Val NLL -3.443 | LR 3.94e-03
# Epoch 156 | Time 4.43s | Train NLL -4.410 | Val NLL -2.712 | LR 3.92e-03
# Epoch 157 | Time 3.08s | Train NLL -4.662 | Val NLL -5.051 | LR 3.91e-03
# Epoch 158 | Time 3.03s | Train NLL -4.856 | Val NLL -5.232 | LR 3.90e-03
# Epoch 159 | Time 3.05s | Train NLL -5.588 | Val NLL -6.307 | LR 3.88e-03
# Epoch 160 | Time 3.30s | Train NLL -5.538 | Val NLL -5.123 | LR 3.87e-03
# Epoch 161 | Time 4.25s | Train NLL -4.550 | Val NLL -4.240 | LR 3.86e-03
# Epoch 162 | Time 4.28s | Train NLL -4.673 | Val NLL -4.060 | LR 3.84e-03
# Epoch 163 | Time 4.25s | Train NLL -4.589 | Val NLL -5.302 | LR 3.83e-03
# Epoch 164 | Time 5.08s | Train NLL -4.398 | Val NLL -2.678 | LR 3.82e-03
# Epoch 165 | Time 4.62s | Train NLL -4.507 | Val NLL -4.868 | LR 3.80e-03
# Epoch 166 | Time 4.48s | Train NLL -3.954 | Val NLL -5.273 | LR 3.79e-03
# Epoch 167 | Time 4.42s | Train NLL -4.476 | Val NLL -2.959 | LR 3.78e-03
# Epoch 168 | Time 4.36s | Train NLL -4.696 | Val NLL -5.736 | LR 3.76e-03
# Epoch 169 | Time 4.32s | Train NLL -5.365 | Val NLL -4.938 | LR 3.75e-03
# Epoch 170 | Time 4.30s | Train NLL -4.595 | Val NLL -1.406 | LR 3.74e-03
# Epoch 171 | Time 4.35s | Train NLL -3.252 | Val NLL -4.857 | LR 3.72e-03
# Epoch 172 | Time 4.37s | Train NLL -2.961 | Val NLL -1.953 | LR 3.71e-03
# Epoch 173 | Time 4.37s | Train NLL -4.324 | Val NLL -4.093 | LR 3.69e-03
# Epoch 174 | Time 4.27s | Train NLL -3.242 | Val NLL -4.787 | LR 3.68e-03
# Epoch 175 | Time 4.33s | Train NLL -4.061 | Val NLL -3.354 | LR 3.67e-03
# Epoch 176 | Time 4.31s | Train NLL -4.834 | Val NLL -5.438 | LR 3.65e-03
# Epoch 177 | Time 4.33s | Train NLL -4.784 | Val NLL -1.728 | LR 3.64e-03
# Epoch 178 | Time 4.34s | Train NLL -4.116 | Val NLL -5.783 | LR 3.62e-03
# Epoch 179 | Time 4.65s | Train NLL -5.065 | Val NLL -2.280 | LR 3.61e-03
# Epoch 180 | Time 4.45s | Train NLL -4.284 | Val NLL -4.805 | LR 3.60e-03
# Epoch 181 | Time 4.33s | Train NLL -4.244 | Val NLL 0.694 | LR 3.58e-03
# Epoch 182 | Time 4.28s | Train NLL -1.754 | Val NLL -1.728 | LR 3.57e-03
# Epoch 183 | Time 4.33s | Train NLL -3.489 | Val NLL -3.216 | LR 3.55e-03
# Epoch 184 | Time 3.73s | Train NLL -2.061 | Val NLL -3.388 | LR 3.54e-03
# Epoch 185 | Time 3.10s | Train NLL -4.034 | Val NLL -5.313 | LR 3.52e-03
# Epoch 186 | Time 3.13s | Train NLL -3.526 | Val NLL -4.198 | LR 3.51e-03
# Epoch 187 | Time 3.24s | Train NLL -3.901 | Val NLL -3.593 | LR 3.50e-03
# Epoch 188 | Time 4.45s | Train NLL -5.075 | Val NLL -6.857 | LR 3.48e-03
# Epoch 189 | Time 4.31s | Train NLL -5.166 | Val NLL -3.624 | LR 3.47e-03
# Epoch 190 | Time 4.27s | Train NLL -3.496 | Val NLL -0.766 | LR 3.45e-03
# Epoch 191 | Time 4.37s | Train NLL -4.011 | Val NLL -5.783 | LR 3.44e-03
# Epoch 192 | Time 4.90s | Train NLL -4.918 | Val NLL -6.115 | LR 3.42e-03
# Epoch 193 | Time 4.63s | Train NLL -5.029 | Val NLL -4.222 | LR 3.41e-03
# Epoch 194 | Time 4.45s | Train NLL -5.601 | Val NLL -5.755 | LR 3.39e-03
# Epoch 195 | Time 4.45s | Train NLL -4.535 | Val NLL -4.308 | LR 3.38e-03
# Epoch 196 | Time 4.52s | Train NLL -5.752 | Val NLL -4.854 | LR 3.36e-03
# Epoch 197 | Time 4.45s | Train NLL -5.574 | Val NLL -5.860 | LR 3.35e-03
# Epoch 198 | Time 4.38s | Train NLL -5.189 | Val NLL -3.826 | LR 3.33e-03
# Epoch 199 | Time 4.53s | Train NLL -4.207 | Val NLL -4.683 | LR 3.32e-03
# Epoch 200 | Time 4.58s | Train NLL -5.545 | Val NLL -6.245 | LR 3.30e-03
# Epoch 201 | Time 4.48s | Train NLL -5.177 | Val NLL -5.719 | LR 3.29e-03
# Epoch 202 | Time 4.35s | Train NLL -4.631 | Val NLL -6.555 | LR 3.27e-03
# Epoch 203 | Time 4.27s | Train NLL -4.747 | Val NLL -4.291 | LR 3.26e-03
# Epoch 204 | Time 4.37s | Train NLL -5.298 | Val NLL -4.793 | LR 3.24e-03
# Epoch 205 | Time 4.20s | Train NLL -4.752 | Val NLL -6.381 | LR 3.23e-03
# Epoch 206 | Time 4.37s | Train NLL -6.568 | Val NLL -7.418 | LR 3.21e-03
# Epoch 207 | Time 4.55s | Train NLL -3.817 | Val NLL -2.519 | LR 3.20e-03
# Epoch 208 | Time 4.32s | Train NLL -5.468 | Val NLL -6.086 | LR 3.18e-03
# Epoch 209 | Time 4.33s | Train NLL -6.049 | Val NLL -6.376 | LR 3.17e-03
# Epoch 210 | Time 4.27s | Train NLL -4.352 | Val NLL -5.992 | LR 3.15e-03
# Epoch 211 | Time 4.43s | Train NLL -5.090 | Val NLL -6.482 | LR 3.14e-03
# Epoch 212 | Time 4.38s | Train NLL -4.962 | Val NLL -7.086 | LR 3.12e-03
# Epoch 213 | Time 4.28s | Train NLL -5.663 | Val NLL -6.264 | LR 3.10e-03
# Epoch 214 | Time 4.32s | Train NLL -6.362 | Val NLL -1.826 | LR 3.09e-03
# Epoch 215 | Time 4.40s | Train NLL -5.898 | Val NLL -5.138 | LR 3.07e-03
# Epoch 216 | Time 4.27s | Train NLL -5.476 | Val NLL -5.948 | LR 3.06e-03
# Epoch 217 | Time 4.32s | Train NLL -5.033 | Val NLL -4.749 | LR 3.04e-03
# Epoch 218 | Time 4.24s | Train NLL -5.593 | Val NLL -6.110 | LR 3.03e-03
# Epoch 219 | Time 3.39s | Train NLL -5.605 | Val NLL -5.231 | LR 3.01e-03
# Epoch 220 | Time 3.02s | Train NLL -5.346 | Val NLL -5.088 | LR 3.00e-03
# Epoch 221 | Time 3.03s | Train NLL -5.977 | Val NLL -7.649 | LR 2.98e-03
# Epoch 222 | Time 3.50s | Train NLL -5.730 | Val NLL -5.676 | LR 2.97e-03
# Epoch 223 | Time 4.20s | Train NLL -6.059 | Val NLL -6.370 | LR 2.95e-03
# Epoch 224 | Time 4.30s | Train NLL -5.877 | Val NLL 2.687 | LR 2.93e-03
# Epoch 225 | Time 4.29s | Train NLL -3.864 | Val NLL -7.412 | LR 2.92e-03
# Epoch 226 | Time 4.40s | Train NLL -6.088 | Val NLL -6.252 | LR 2.90e-03
# Epoch 227 | Time 4.27s | Train NLL -6.294 | Val NLL -6.667 | LR 2.89e-03
# Epoch 228 | Time 4.33s | Train NLL -6.032 | Val NLL -6.662 | LR 2.87e-03
# Epoch 229 | Time 4.27s | Train NLL -5.293 | Val NLL -6.328 | LR 2.86e-03
# Epoch 230 | Time 4.42s | Train NLL -6.220 | Val NLL -4.845 | LR 2.84e-03
# Epoch 231 | Time 4.28s | Train NLL -6.421 | Val NLL -5.642 | LR 2.82e-03
# Epoch 232 | Time 4.31s | Train NLL -6.868 | Val NLL -7.403 | LR 2.81e-03
# Epoch 233 | Time 4.30s | Train NLL -6.375 | Val NLL -4.894 | LR 2.79e-03
# Epoch 234 | Time 4.42s | Train NLL -6.029 | Val NLL -6.531 | LR 2.78e-03
# Epoch 235 | Time 4.27s | Train NLL -7.117 | Val NLL -2.915 | LR 2.76e-03
# Epoch 236 | Time 4.30s | Train NLL -5.320 | Val NLL -6.826 | LR 2.75e-03
# Epoch 237 | Time 4.28s | Train NLL -5.936 | Val NLL -4.987 | LR 2.73e-03
# Epoch 238 | Time 4.43s | Train NLL -6.267 | Val NLL -6.659 | LR 2.71e-03
# Epoch 239 | Time 4.33s | Train NLL -5.803 | Val NLL -5.374 | LR 2.70e-03
# Epoch 240 | Time 4.22s | Train NLL -5.706 | Val NLL -5.127 | LR 2.68e-03
# Epoch 241 | Time 4.28s | Train NLL -6.611 | Val NLL -5.241 | LR 2.67e-03
# Epoch 242 | Time 4.38s | Train NLL -5.441 | Val NLL -4.414 | LR 2.65e-03
# Epoch 243 | Time 3.31s | Train NLL -6.513 | Val NLL -5.675 | LR 2.63e-03
# Epoch 244 | Time 3.08s | Train NLL -4.752 | Val NLL -2.368 | LR 2.62e-03
# Epoch 245 | Time 3.03s | Train NLL -4.458 | Val NLL -5.330 | LR 2.60e-03
# Epoch 246 | Time 3.55s | Train NLL -4.833 | Val NLL -6.048 | LR 2.59e-03
# Epoch 247 | Time 4.23s | Train NLL -6.182 | Val NLL -5.420 | LR 2.57e-03
# Epoch 248 | Time 4.27s | Train NLL -5.900 | Val NLL -7.216 | LR 2.56e-03
# Epoch 249 | Time 4.28s | Train NLL -5.855 | Val NLL -3.453 | LR 2.54e-03
# Epoch 250 | Time 4.43s | Train NLL -5.738 | Val NLL -4.970 | LR 2.52e-03
# Epoch 251 | Time 4.29s | Train NLL -6.024 | Val NLL -6.833 | LR 2.51e-03
# Epoch 252 | Time 4.30s | Train NLL -5.775 | Val NLL -6.489 | LR 2.49e-03
# Epoch 253 | Time 4.30s | Train NLL -6.623 | Val NLL -6.743 | LR 2.48e-03
# Epoch 254 | Time 4.33s | Train NLL -6.346 | Val NLL -4.648 | LR 2.46e-03
# Epoch 255 | Time 4.24s | Train NLL -4.668 | Val NLL 4.720 | LR 2.44e-03
# Epoch 256 | Time 4.26s | Train NLL -4.345 | Val NLL -6.780 | LR 2.43e-03
# Epoch 257 | Time 4.37s | Train NLL -5.815 | Val NLL -6.305 | LR 2.41e-03
# Epoch 258 | Time 4.45s | Train NLL -4.843 | Val NLL -5.857 | LR 2.40e-03
# Epoch 259 | Time 4.37s | Train NLL -5.213 | Val NLL -6.581 | LR 2.38e-03
# Epoch 260 | Time 4.30s | Train NLL -6.603 | Val NLL -4.647 | LR 2.37e-03
# Epoch 261 | Time 4.38s | Train NLL -5.882 | Val NLL -6.634 | LR 2.35e-03
# Epoch 262 | Time 4.42s | Train NLL -6.360 | Val NLL -6.091 | LR 2.33e-03
# Epoch 263 | Time 4.37s | Train NLL -5.155 | Val NLL -7.896 | LR 2.32e-03
# Epoch 264 | Time 4.35s | Train NLL -6.614 | Val NLL -7.298 | LR 2.30e-03
# Epoch 265 | Time 4.42s | Train NLL -5.467 | Val NLL -6.836 | LR 2.29e-03
# Epoch 266 | Time 3.15s | Train NLL -6.116 | Val NLL -6.095 | LR 2.27e-03
# Epoch 267 | Time 3.05s | Train NLL -5.710 | Val NLL -4.596 | LR 2.25e-03
# Epoch 268 | Time 3.07s | Train NLL -6.272 | Val NLL -3.711 | LR 2.24e-03
# Epoch 269 | Time 3.17s | Train NLL -5.068 | Val NLL -6.853 | LR 2.22e-03
# Epoch 270 | Time 4.27s | Train NLL -6.549 | Val NLL -6.580 | LR 2.21e-03
# Epoch 271 | Time 4.35s | Train NLL -5.793 | Val NLL -6.362 | LR 2.19e-03
# Epoch 272 | Time 4.37s | Train NLL -5.291 | Val NLL -5.844 | LR 2.18e-03
# Epoch 273 | Time 4.43s | Train NLL -5.760 | Val NLL -5.730 | LR 2.16e-03
# Epoch 274 | Time 4.30s | Train NLL -5.988 | Val NLL -6.218 | LR 2.14e-03
# Epoch 275 | Time 4.30s | Train NLL -5.758 | Val NLL -5.849 | LR 2.13e-03
# Epoch 276 | Time 4.27s | Train NLL -5.951 | Val NLL -3.985 | LR 2.11e-03
# Epoch 277 | Time 4.40s | Train NLL -5.994 | Val NLL -5.795 | LR 2.10e-03
# Epoch 278 | Time 4.27s | Train NLL -6.734 | Val NLL -5.824 | LR 2.08e-03
# Epoch 279 | Time 4.28s | Train NLL -6.483 | Val NLL -7.621 | LR 2.07e-03
# Epoch 280 | Time 4.33s | Train NLL -7.566 | Val NLL -8.555 | LR 2.05e-03
# Epoch 281 | Time 4.58s | Train NLL -5.158 | Val NLL -1.928 | LR 2.03e-03
# Epoch 282 | Time 4.28s | Train NLL -6.002 | Val NLL -7.596 | LR 2.02e-03
# Epoch 283 | Time 4.33s | Train NLL -6.282 | Val NLL -6.877 | LR 2.00e-03
# Epoch 284 | Time 4.47s | Train NLL -7.067 | Val NLL -7.223 | LR 1.99e-03
# Epoch 285 | Time 4.35s | Train NLL -7.266 | Val NLL -4.325 | LR 1.97e-03
# Epoch 286 | Time 4.27s | Train NLL -5.710 | Val NLL -4.763 | LR 1.96e-03
# Epoch 287 | Time 3.40s | Train NLL -6.665 | Val NLL -6.774 | LR 1.94e-03
# Epoch 288 | Time 3.15s | Train NLL -6.989 | Val NLL -8.035 | LR 1.93e-03
# Epoch 289 | Time 3.03s | Train NLL -6.996 | Val NLL -6.057 | LR 1.91e-03
# Epoch 290 | Time 3.48s | Train NLL -7.140 | Val NLL -2.563 | LR 1.90e-03
# Epoch 291 | Time 4.30s | Train NLL -6.338 | Val NLL -7.083 | LR 1.88e-03
# Epoch 292 | Time 4.48s | Train NLL -7.407 | Val NLL -8.420 | LR 1.86e-03
# Epoch 293 | Time 4.25s | Train NLL -6.127 | Val NLL -8.243 | LR 1.85e-03
# Epoch 294 | Time 4.33s | Train NLL -7.041 | Val NLL -7.475 | LR 1.83e-03
# Epoch 295 | Time 4.29s | Train NLL -6.867 | Val NLL -3.504 | LR 1.82e-03
# Epoch 296 | Time 4.45s | Train NLL -7.095 | Val NLL -6.005 | LR 1.80e-03
# Epoch 297 | Time 4.23s | Train NLL -7.262 | Val NLL -7.355 | LR 1.79e-03
# Epoch 298 | Time 4.18s | Train NLL -5.816 | Val NLL -7.541 | LR 1.77e-03
# Epoch 299 | Time 4.28s | Train NLL -6.925 | Val NLL -8.421 | LR 1.76e-03
# Epoch 300 | Time 4.45s | Train NLL -7.631 | Val NLL -8.165 | LR 1.74e-03
# Epoch 301 | Time 4.37s | Train NLL -7.689 | Val NLL -6.725 | LR 1.73e-03
# Epoch 302 | Time 4.38s | Train NLL -7.650 | Val NLL -9.194 | LR 1.71e-03
# Epoch 303 | Time 4.50s | Train NLL -7.598 | Val NLL -4.404 | LR 1.70e-03
# Epoch 304 | Time 4.37s | Train NLL -6.981 | Val NLL -8.470 | LR 1.68e-03
# Epoch 305 | Time 4.20s | Train NLL -7.856 | Val NLL -8.730 | LR 1.67e-03
# Epoch 306 | Time 3.07s | Train NLL -7.872 | Val NLL -7.787 | LR 1.65e-03
# Epoch 307 | Time 3.10s | Train NLL -6.999 | Val NLL -5.675 | LR 1.64e-03
# Epoch 308 | Time 3.02s | Train NLL -7.770 | Val NLL -8.238 | LR 1.62e-03
# Epoch 309 | Time 4.03s | Train NLL -7.705 | Val NLL -3.181 | LR 1.61e-03
# Epoch 310 | Time 4.28s | Train NLL -7.455 | Val NLL -6.910 | LR 1.59e-03
# Epoch 311 | Time 4.47s | Train NLL -6.978 | Val NLL -8.304 | LR 1.58e-03
# Epoch 312 | Time 4.34s | Train NLL -8.407 | Val NLL -9.166 | LR 1.56e-03
# Epoch 313 | Time 4.26s | Train NLL -6.761 | Val NLL -7.220 | LR 1.55e-03
# Epoch 314 | Time 4.35s | Train NLL -6.291 | Val NLL -4.345 | LR 1.53e-03
# Epoch 315 | Time 4.47s | Train NLL -7.105 | Val NLL -7.108 | LR 1.52e-03
# Epoch 316 | Time 4.32s | Train NLL -8.275 | Val NLL -8.917 | LR 1.50e-03
# Epoch 317 | Time 4.35s | Train NLL -8.192 | Val NLL -3.596 | LR 1.49e-03
# Epoch 318 | Time 4.33s | Train NLL -6.256 | Val NLL 1.271 | LR 1.48e-03
# Epoch 319 | Time 4.37s | Train NLL -5.932 | Val NLL -7.963 | LR 1.46e-03
# Epoch 320 | Time 4.32s | Train NLL -7.840 | Val NLL -8.215 | LR 1.45e-03
# Epoch 321 | Time 4.34s | Train NLL -8.385 | Val NLL -7.654 | LR 1.43e-03
# Epoch 322 | Time 4.28s | Train NLL -9.271 | Val NLL -9.393 | LR 1.42e-03
# Epoch 323 | Time 4.60s | Train NLL -8.724 | Val NLL -9.506 | LR 1.40e-03
# Epoch 324 | Time 4.36s | Train NLL -9.319 | Val NLL -7.987 | LR 1.39e-03
# Epoch 325 | Time 4.43s | Train NLL -8.364 | Val NLL -9.860 | LR 1.38e-03
# Epoch 326 | Time 4.47s | Train NLL -6.653 | Val NLL -6.179 | LR 1.36e-03
# Epoch 327 | Time 3.27s | Train NLL -7.372 | Val NLL -7.242 | LR 1.35e-03
# Epoch 328 | Time 3.04s | Train NLL -6.823 | Val NLL -7.356 | LR 1.33e-03
# Epoch 329 | Time 3.13s | Train NLL -8.031 | Val NLL -8.559 | LR 1.32e-03
# Epoch 330 | Time 3.58s | Train NLL -8.611 | Val NLL -9.556 | LR 1.31e-03
# Epoch 331 | Time 4.23s | Train NLL -8.151 | Val NLL -9.221 | LR 1.29e-03
# Epoch 332 | Time 4.30s | Train NLL -7.682 | Val NLL -9.077 | LR 1.28e-03
# Epoch 333 | Time 4.50s | Train NLL -8.553 | Val NLL -9.947 | LR 1.26e-03
# Epoch 334 | Time 4.32s | Train NLL -8.912 | Val NLL -5.571 | LR 1.25e-03
# Epoch 335 | Time 4.32s | Train NLL -6.099 | Val NLL -2.413 | LR 1.24e-03
# Epoch 336 | Time 4.30s | Train NLL -7.640 | Val NLL -9.741 | LR 1.22e-03
# Epoch 337 | Time 4.40s | Train NLL -7.034 | Val NLL -8.527 | LR 1.21e-03
# Epoch 338 | Time 4.27s | Train NLL -8.582 | Val NLL -9.105 | LR 1.20e-03
# Epoch 339 | Time 4.30s | Train NLL -8.029 | Val NLL -8.438 | LR 1.18e-03
# Epoch 340 | Time 4.43s | Train NLL -8.372 | Val NLL -7.694 | LR 1.17e-03
# Epoch 341 | Time 4.32s | Train NLL -7.933 | Val NLL -9.588 | LR 1.16e-03
# Epoch 342 | Time 4.30s | Train NLL -8.492 | Val NLL -7.155 | LR 1.14e-03
# Epoch 343 | Time 4.25s | Train NLL -7.717 | Val NLL -8.396 | LR 1.13e-03
# Epoch 344 | Time 4.18s | Train NLL -8.855 | Val NLL -9.590 | LR 1.12e-03
# Epoch 345 | Time 4.30s | Train NLL -9.200 | Val NLL -9.758 | LR 1.10e-03
# Epoch 346 | Time 4.23s | Train NLL -7.196 | Val NLL -7.435 | LR 1.09e-03
# Epoch 347 | Time 4.32s | Train NLL -8.449 | Val NLL -9.282 | LR 1.08e-03
# Epoch 348 | Time 3.47s | Train NLL -9.750 | Val NLL -9.395 | LR 1.06e-03
# Epoch 349 | Time 3.22s | Train NLL -8.388 | Val NLL -9.018 | LR 1.05e-03
# Epoch 350 | Time 3.10s | Train NLL -9.472 | Val NLL -9.251 | LR 1.04e-03
# Epoch 351 | Time 3.35s | Train NLL -7.175 | Val NLL -4.944 | LR 1.02e-03
# Epoch 352 | Time 4.30s | Train NLL -6.522 | Val NLL -7.760 | LR 1.01e-03
# Epoch 353 | Time 4.48s | Train NLL -7.969 | Val NLL -4.488 | LR 9.99e-04
# Epoch 354 | Time 4.28s | Train NLL -9.024 | Val NLL -10.042 | LR 9.86e-04
# Epoch 355 | Time 4.43s | Train NLL -9.148 | Val NLL -10.337 | LR 9.73e-04
# Epoch 356 | Time 4.55s | Train NLL -9.599 | Val NLL -9.190 | LR 9.61e-04
# Epoch 357 | Time 4.27s | Train NLL -10.068 | Val NLL -10.115 | LR 9.48e-04
# Epoch 358 | Time 4.40s | Train NLL -9.538 | Val NLL -10.095 | LR 9.36e-04
# Epoch 359 | Time 4.31s | Train NLL -8.331 | Val NLL -5.651 | LR 9.24e-04
# Epoch 360 | Time 4.49s | Train NLL -8.394 | Val NLL -8.856 | LR 9.11e-04
# Epoch 361 | Time 4.33s | Train NLL -9.183 | Val NLL -8.383 | LR 8.99e-04
# Epoch 362 | Time 4.25s | Train NLL -9.299 | Val NLL -6.020 | LR 8.87e-04
# Epoch 363 | Time 4.25s | Train NLL -8.328 | Val NLL -6.963 | LR 8.75e-04
# Epoch 364 | Time 4.47s | Train NLL -9.208 | Val NLL -9.263 | LR 8.63e-04
# Epoch 365 | Time 4.30s | Train NLL -8.700 | Val NLL -10.034 | LR 8.51e-04
# Epoch 366 | Time 4.33s | Train NLL -9.385 | Val NLL -9.979 | LR 8.39e-04
# Epoch 367 | Time 4.33s | Train NLL -10.170 | Val NLL -10.681 | LR 8.27e-04
# Epoch 368 | Time 4.50s | Train NLL -9.333 | Val NLL -9.643 | LR 8.15e-04
# Epoch 369 | Time 4.30s | Train NLL -8.999 | Val NLL -9.965 | LR 8.04e-04
# Epoch 370 | Time 3.08s | Train NLL -10.062 | Val NLL -10.544 | LR 7.92e-04
# Epoch 371 | Time 3.14s | Train NLL -9.861 | Val NLL -9.886 | LR 7.81e-04
# Epoch 372 | Time 3.03s | Train NLL -9.452 | Val NLL -10.622 | LR 7.69e-04
# Epoch 373 | Time 3.77s | Train NLL -9.819 | Val NLL -9.875 | LR 7.58e-04
# Epoch 374 | Time 4.27s | Train NLL -8.855 | Val NLL -9.733 | LR 7.46e-04
# Epoch 375 | Time 4.47s | Train NLL -10.144 | Val NLL -10.415 | LR 7.35e-04
# Epoch 376 | Time 4.28s | Train NLL -8.359 | Val NLL -9.305 | LR 7.24e-04
# Epoch 377 | Time 4.36s | Train NLL -10.612 | Val NLL -10.714 | LR 7.13e-04
# Epoch 378 | Time 4.52s | Train NLL -10.018 | Val NLL -8.653 | LR 7.02e-04
# Epoch 379 | Time 4.44s | Train NLL -9.666 | Val NLL -10.929 | LR 6.91e-04
# Epoch 380 | Time 4.33s | Train NLL -10.459 | Val NLL -9.904 | LR 6.80e-04
# Epoch 381 | Time 4.43s | Train NLL -7.759 | Val NLL -2.900 | LR 6.69e-04
# Epoch 382 | Time 4.30s | Train NLL -6.660 | Val NLL -8.162 | LR 6.58e-04
# Epoch 383 | Time 4.33s | Train NLL -7.849 | Val NLL -8.391 | LR 6.47e-04
# Epoch 384 | Time 4.27s | Train NLL -9.773 | Val NLL -9.982 | LR 6.37e-04
# Epoch 385 | Time 4.41s | Train NLL -10.095 | Val NLL -9.755 | LR 6.26e-04
# Epoch 386 | Time 4.28s | Train NLL -10.729 | Val NLL -9.493 | LR 6.16e-04
# Epoch 387 | Time 4.28s | Train NLL -10.375 | Val NLL -10.055 | LR 6.05e-04
# Epoch 388 | Time 4.33s | Train NLL -10.838 | Val NLL -8.917 | LR 5.95e-04
# Epoch 389 | Time 4.43s | Train NLL -10.210 | Val NLL -10.769 | LR 5.85e-04
# Epoch 390 | Time 3.03s | Train NLL -11.070 | Val NLL -10.822 | LR 5.75e-04
# Epoch 391 | Time 3.05s | Train NLL -11.178 | Val NLL -10.901 | LR 5.65e-04
# Epoch 392 | Time 3.15s | Train NLL -11.261 | Val NLL -10.975 | LR 5.55e-04
# Epoch 393 | Time 3.30s | Train NLL -10.400 | Val NLL -11.140 | LR 5.45e-04
# Epoch 394 | Time 4.38s | Train NLL -11.365 | Val NLL -11.114 | LR 5.35e-04
# Epoch 395 | Time 4.33s | Train NLL -11.541 | Val NLL -11.376 | LR 5.25e-04
# Epoch 396 | Time 4.58s | Train NLL -10.056 | Val NLL -4.795 | LR 5.15e-04
# Epoch 397 | Time 4.40s | Train NLL -7.009 | Val NLL -9.660 | LR 5.06e-04
# Epoch 398 | Time 4.35s | Train NLL -10.328 | Val NLL -11.426 | LR 4.96e-04
# Epoch 399 | Time 4.47s | Train NLL -11.005 | Val NLL -11.362 | LR 4.87e-04
# Epoch 400 | Time 4.33s | Train NLL -9.779 | Val NLL -9.207 | LR 4.77e-04
# Epoch 401 | Time 4.30s | Train NLL -10.066 | Val NLL -11.021 | LR 4.68e-04
# Epoch 402 | Time 4.42s | Train NLL -11.257 | Val NLL -10.420 | LR 4.59e-04
# Epoch 403 | Time 4.40s | Train NLL -10.250 | Val NLL -11.024 | LR 4.50e-04
# Epoch 404 | Time 4.30s | Train NLL -11.314 | Val NLL -9.524 | LR 4.41e-04
# Epoch 405 | Time 4.28s | Train NLL -9.957 | Val NLL -10.610 | LR 4.32e-04
# Epoch 406 | Time 4.35s | Train NLL -10.822 | Val NLL -10.048 | LR 4.23e-04
# Epoch 407 | Time 4.39s | Train NLL -10.862 | Val NLL -1.513 | LR 4.14e-04
# Epoch 408 | Time 4.31s | Train NLL -4.565 | Val NLL -8.370 | LR 4.05e-04
# Epoch 409 | Time 4.29s | Train NLL -9.408 | Val NLL -9.385 | LR 3.97e-04
# Epoch 410 | Time 4.33s | Train NLL -11.135 | Val NLL -11.197 | LR 3.88e-04
# Epoch 411 | Time 3.23s | Train NLL -11.747 | Val NLL -11.605 | LR 3.80e-04
# Epoch 412 | Time 3.10s | Train NLL -11.883 | Val NLL -11.166 | LR 3.72e-04
# Epoch 413 | Time 3.05s | Train NLL -10.459 | Val NLL -10.842 | LR 3.63e-04
# Epoch 414 | Time 3.79s | Train NLL -11.403 | Val NLL -11.550 | LR 3.55e-04
# Epoch 415 | Time 4.40s | Train NLL -11.686 | Val NLL -11.931 | LR 3.47e-04
# Epoch 416 | Time 4.40s | Train NLL -11.782 | Val NLL -10.996 | LR 3.39e-04
# Epoch 417 | Time 4.30s | Train NLL -12.058 | Val NLL -12.044 | LR 3.31e-04
# Epoch 418 | Time 4.50s | Train NLL -12.219 | Val NLL -11.760 | LR 3.23e-04
# Epoch 419 | Time 4.32s | Train NLL -12.236 | Val NLL -11.862 | LR 3.15e-04
# Epoch 420 | Time 4.38s | Train NLL -12.322 | Val NLL -11.804 | LR 3.08e-04
# Epoch 421 | Time 4.39s | Train NLL -12.140 | Val NLL -12.412 | LR 3.00e-04
# Epoch 422 | Time 4.48s | Train NLL -11.677 | Val NLL -12.213 | LR 2.93e-04
# Epoch 423 | Time 4.40s | Train NLL -12.559 | Val NLL -12.447 | LR 2.85e-04
# Epoch 424 | Time 4.42s | Train NLL -11.677 | Val NLL -5.324 | LR 2.78e-04
# Epoch 425 | Time 4.35s | Train NLL -10.836 | Val NLL -12.371 | LR 2.71e-04
# Epoch 426 | Time 4.70s | Train NLL -12.495 | Val NLL -9.811 | LR 2.64e-04
# Epoch 427 | Time 4.40s | Train NLL -11.691 | Val NLL -12.444 | LR 2.57e-04
# Epoch 428 | Time 4.37s | Train NLL -12.877 | Val NLL -12.275 | LR 2.50e-04
# Epoch 429 | Time 4.37s | Train NLL -12.367 | Val NLL -12.389 | LR 2.43e-04
# Epoch 430 | Time 4.43s | Train NLL -11.319 | Val NLL -7.184 | LR 2.36e-04
# Epoch 431 | Time 4.37s | Train NLL -11.074 | Val NLL -12.529 | LR 2.29e-04
# Epoch 432 | Time 4.25s | Train NLL -12.948 | Val NLL -12.574 | LR 2.23e-04
# Epoch 433 | Time 3.28s | Train NLL -12.711 | Val NLL -12.677 | LR 2.16e-04
# Epoch 434 | Time 3.05s | Train NLL -11.919 | Val NLL -11.029 | LR 2.10e-04
# Epoch 435 | Time 3.09s | Train NLL -12.556 | Val NLL -12.557 | LR 2.03e-04
# Epoch 436 | Time 4.08s | Train NLL -12.862 | Val NLL -12.249 | LR 1.97e-04
# Epoch 437 | Time 4.46s | Train NLL -12.890 | Val NLL -13.093 | LR 1.91e-04
# Epoch 438 | Time 4.42s | Train NLL -12.956 | Val NLL -12.411 | LR 1.85e-04
# Epoch 439 | Time 4.39s | Train NLL -12.973 | Val NLL -11.957 | LR 1.79e-04
# Epoch 440 | Time 4.33s | Train NLL -13.322 | Val NLL -13.011 | LR 1.73e-04
# Epoch 441 | Time 4.43s | Train NLL -13.271 | Val NLL -12.967 | LR 1.67e-04
# Epoch 442 | Time 4.33s | Train NLL -13.330 | Val NLL -13.008 | LR 1.62e-04
# Epoch 443 | Time 4.35s | Train NLL -13.387 | Val NLL -13.204 | LR 1.56e-04
# Epoch 444 | Time 4.38s | Train NLL -13.329 | Val NLL -13.172 | LR 1.51e-04
# Epoch 445 | Time 4.47s | Train NLL -13.557 | Val NLL -13.272 | LR 1.45e-04
# Epoch 446 | Time 4.40s | Train NLL -13.583 | Val NLL -12.990 | LR 1.40e-04
# Epoch 447 | Time 4.37s | Train NLL -13.565 | Val NLL -13.598 | LR 1.35e-04
# Epoch 448 | Time 4.47s | Train NLL -12.593 | Val NLL -11.994 | LR 1.30e-04
# Epoch 449 | Time 4.62s | Train NLL -13.342 | Val NLL -13.712 | LR 1.25e-04
# Epoch 450 | Time 4.41s | Train NLL -13.470 | Val NLL -13.269 | LR 1.20e-04
# Epoch 451 | Time 4.40s | Train NLL -13.704 | Val NLL -13.274 | LR 1.15e-04
# Epoch 452 | Time 4.49s | Train NLL -13.875 | Val NLL -13.809 | LR 1.10e-04
# Epoch 453 | Time 4.51s | Train NLL -14.189 | Val NLL -13.904 | LR 1.06e-04
# Epoch 454 | Time 4.40s | Train NLL -13.984 | Val NLL -12.966 | LR 1.01e-04
# Epoch 455 | Time 4.34s | Train NLL -9.192 | Val NLL -8.774 | LR 9.68e-05
# Epoch 456 | Time 4.32s | Train NLL -9.596 | Val NLL -9.727 | LR 9.25e-05
# Epoch 457 | Time 4.41s | Train NLL -10.173 | Val NLL -10.345 | LR 8.83e-05
# Epoch 458 | Time 3.08s | Train NLL -10.612 | Val NLL -10.798 | LR 8.42e-05
# Epoch 459 | Time 3.12s | Train NLL -11.419 | Val NLL -11.480 | LR 8.01e-05
# Epoch 460 | Time 3.17s | Train NLL -12.283 | Val NLL -12.489 | LR 7.62e-05
# Epoch 461 | Time 4.03s | Train NLL -13.110 | Val NLL -13.177 | LR 7.24e-05
# Epoch 462 | Time 4.32s | Train NLL -3.245 | Val NLL 1.510 | LR 6.86e-05
# Epoch 463 | Time 4.38s | Train NLL -0.682 | Val NLL -2.760 | LR 6.50e-05
# Epoch 464 | Time 4.33s | Train NLL -4.377 | Val NLL -5.382 | LR 6.14e-05
# Epoch 465 | Time 4.50s | Train NLL -6.513 | Val NLL -6.917 | LR 5.80e-05
# Epoch 466 | Time 4.38s | Train NLL -7.763 | Val NLL -8.154 | LR 5.46e-05
# Epoch 467 | Time 4.35s | Train NLL -9.906 | Val NLL -11.877 | LR 5.14e-05
# Epoch 468 | Time 4.35s | Train NLL -7.808 | Val NLL -7.649 | LR 4.82e-05
# Epoch 469 | Time 4.49s | Train NLL -8.886 | Val NLL -9.322 | LR 4.52e-05
# Epoch 470 | Time 4.32s | Train NLL -10.203 | Val NLL -10.413 | LR 4.22e-05
# Epoch 471 | Time 4.27s | Train NLL -11.102 | Val NLL -11.181 | LR 3.94e-05
# Epoch 472 | Time 4.35s | Train NLL -11.784 | Val NLL -11.752 | LR 3.66e-05
# Epoch 473 | Time 4.40s | Train NLL -12.330 | Val NLL -12.239 | LR 3.40e-05
# Epoch 474 | Time 4.30s | Train NLL -12.768 | Val NLL -12.678 | LR 3.14e-05
# Epoch 475 | Time 4.25s | Train NLL -13.151 | Val NLL -12.805 | LR 2.89e-05
# Epoch 476 | Time 4.22s | Train NLL -13.446 | Val NLL -13.284 | LR 2.66e-05
# Epoch 477 | Time 4.40s | Train NLL -13.712 | Val NLL -13.438 | LR 2.43e-05
# Epoch 478 | Time 4.37s | Train NLL -13.911 | Val NLL -13.638 | LR 2.22e-05
# Epoch 479 | Time 4.22s | Train NLL -13.769 | Val NLL -13.760 | LR 2.01e-05
# Epoch 480 | Time 4.30s | Train NLL -14.204 | Val NLL -13.931 | LR 1.82e-05
# Epoch 481 | Time 3.68s | Train NLL -14.291 | Val NLL -13.953 | LR 1.63e-05
# Epoch 482 | Time 3.14s | Train NLL -14.382 | Val NLL -14.045 | LR 1.45e-05
# Epoch 483 | Time 3.05s | Train NLL -14.445 | Val NLL -14.105 | LR 1.29e-05
# Epoch 484 | Time 3.53s | Train NLL -14.544 | Val NLL -14.222 | LR 1.13e-05
# Epoch 485 | Time 4.45s | Train NLL -14.602 | Val NLL -14.300 | LR 9.86e-06
# Epoch 486 | Time 4.35s | Train NLL -14.652 | Val NLL -14.286 | LR 8.50e-06
# Epoch 487 | Time 4.35s | Train NLL -14.685 | Val NLL -14.319 | LR 7.25e-06
# Epoch 488 | Time 4.52s | Train NLL -14.704 | Val NLL -14.347 | LR 6.09e-06
# Epoch 489 | Time 4.37s | Train NLL -14.754 | Val NLL -14.430 | LR 5.03e-06
# Epoch 490 | Time 4.38s | Train NLL -14.783 | Val NLL -14.456 | LR 4.08e-06
# Epoch 491 | Time 4.35s | Train NLL -14.804 | Val NLL -14.464 | LR 3.22e-06
# Epoch 492 | Time 4.48s | Train NLL -14.817 | Val NLL -14.481 | LR 2.47e-06
# Epoch 493 | Time 4.37s | Train NLL -14.830 | Val NLL -14.491 | LR 1.81e-06
# Epoch 494 | Time 4.34s | Train NLL -14.839 | Val NLL -14.494 | LR 1.26e-06
# Epoch 495 | Time 4.50s | Train NLL -14.846 | Val NLL -14.503 | LR 8.06e-07
# Epoch 496 | Time 4.56s | Train NLL -14.849 | Val NLL -14.506 | LR 4.53e-07
# Epoch 497 | Time 4.40s | Train NLL -14.853 | Val NLL -14.508 | LR 2.01e-07
# Epoch 498 | Time 4.36s | Train NLL -14.855 | Val NLL -14.507 | LR 5.03e-08
# Epoch 499 | Time 4.43s | Train NLL -14.855 | Val NLL -14.509 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 11497387.00
# Average absolute difference in CASUALTIES: 0.02

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
