# %% [markdown]
# # Storm model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Storm'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 5.94s | Train NLL 0.428 | Val NLL -2.487 | LR 1.00e-03
# Epoch 001 | Time 3.47s | Train NLL -2.116 | Val NLL -3.695 | LR 2.00e-03
# Epoch 002 | Time 3.70s | Train NLL -1.933 | Val NLL 0.676 | LR 3.00e-03
# Epoch 003 | Time 3.80s | Train NLL -1.741 | Val NLL -2.617 | LR 4.00e-03
# Epoch 004 | Time 3.90s | Train NLL -1.721 | Val NLL -2.447 | LR 5.00e-03
# Epoch 005 | Time 3.88s | Train NLL -1.602 | Val NLL -3.160 | LR 5.00e-03
# Epoch 006 | Time 3.73s | Train NLL -2.084 | Val NLL -2.767 | LR 5.00e-03
# Epoch 007 | Time 3.68s | Train NLL -2.258 | Val NLL -1.328 | LR 5.00e-03
# Epoch 008 | Time 3.78s | Train NLL -1.784 | Val NLL -4.892 | LR 5.00e-03
# Epoch 009 | Time 3.75s | Train NLL -2.239 | Val NLL -2.525 | LR 5.00e-03
# Epoch 010 | Time 3.82s | Train NLL -2.939 | Val NLL -5.047 | LR 4.99e-03
# Epoch 011 | Time 4.00s | Train NLL -3.121 | Val NLL -3.670 | LR 4.99e-03
# Epoch 012 | Time 3.88s | Train NLL -3.021 | Val NLL -5.172 | LR 4.99e-03
# Epoch 013 | Time 4.27s | Train NLL -2.387 | Val NLL -3.921 | LR 4.99e-03
# Epoch 014 | Time 4.46s | Train NLL -4.152 | Val NLL -3.432 | LR 4.99e-03
# Epoch 015 | Time 3.89s | Train NLL -3.306 | Val NLL -3.354 | LR 4.98e-03
# Epoch 016 | Time 3.97s | Train NLL -4.600 | Val NLL -5.443 | LR 4.98e-03
# Epoch 017 | Time 4.02s | Train NLL -3.719 | Val NLL -5.383 | LR 4.98e-03
# Epoch 018 | Time 4.25s | Train NLL -3.725 | Val NLL -5.625 | LR 4.97e-03
# Epoch 019 | Time 8.64s | Train NLL -4.476 | Val NLL -1.064 | LR 4.97e-03
# Epoch 020 | Time 5.06s | Train NLL -3.237 | Val NLL -4.619 | LR 4.96e-03
# Epoch 021 | Time 4.25s | Train NLL -3.438 | Val NLL -1.781 | LR 4.96e-03
# Epoch 022 | Time 3.85s | Train NLL -3.538 | Val NLL -6.093 | LR 4.95e-03
# Epoch 023 | Time 4.57s | Train NLL -4.903 | Val NLL -5.456 | LR 4.95e-03
# Epoch 024 | Time 4.42s | Train NLL -3.577 | Val NLL -6.599 | LR 4.94e-03
# Epoch 025 | Time 4.46s | Train NLL -4.547 | Val NLL -4.367 | LR 4.94e-03
# Epoch 026 | Time 3.64s | Train NLL -4.307 | Val NLL -6.560 | LR 4.93e-03
# Epoch 027 | Time 3.58s | Train NLL -4.692 | Val NLL -4.412 | LR 4.93e-03
# Epoch 028 | Time 3.67s | Train NLL -2.749 | Val NLL -3.509 | LR 4.92e-03
# Epoch 029 | Time 3.40s | Train NLL -4.076 | Val NLL -4.607 | LR 4.91e-03
# Epoch 030 | Time 3.48s | Train NLL -5.100 | Val NLL -7.203 | LR 4.90e-03
# Epoch 031 | Time 3.60s | Train NLL -4.896 | Val NLL -5.695 | LR 4.90e-03
# Epoch 032 | Time 3.54s | Train NLL -4.315 | Val NLL -5.477 | LR 4.89e-03
# Epoch 033 | Time 3.35s | Train NLL -4.406 | Val NLL -3.765 | LR 4.88e-03
# Epoch 034 | Time 3.48s | Train NLL -1.741 | Val NLL -1.658 | LR 4.87e-03
# Epoch 035 | Time 3.42s | Train NLL -3.356 | Val NLL -4.983 | LR 4.86e-03
# Epoch 036 | Time 3.42s | Train NLL -3.298 | Val NLL -6.151 | LR 4.86e-03
# Epoch 037 | Time 3.39s | Train NLL -3.174 | Val NLL -1.245 | LR 4.85e-03
# Epoch 038 | Time 3.50s | Train NLL -2.965 | Val NLL -1.867 | LR 4.84e-03
# Epoch 039 | Time 3.46s | Train NLL -4.439 | Val NLL -4.893 | LR 4.83e-03
# Epoch 040 | Time 3.54s | Train NLL -6.150 | Val NLL -7.329 | LR 4.82e-03
# Epoch 041 | Time 3.67s | Train NLL -4.327 | Val NLL -5.386 | LR 4.81e-03
# Epoch 042 | Time 3.44s | Train NLL -5.000 | Val NLL -6.349 | LR 4.80e-03
# Epoch 043 | Time 3.85s | Train NLL -4.197 | Val NLL -3.473 | LR 4.79e-03
# Epoch 044 | Time 3.38s | Train NLL -5.067 | Val NLL -5.762 | LR 4.78e-03
# Epoch 045 | Time 3.40s | Train NLL -6.048 | Val NLL -6.091 | LR 4.77e-03
# Epoch 046 | Time 3.54s | Train NLL -5.315 | Val NLL -7.138 | LR 4.75e-03
# Epoch 047 | Time 4.52s | Train NLL -4.289 | Val NLL -0.950 | LR 4.74e-03
# Epoch 048 | Time 4.50s | Train NLL -3.062 | Val NLL -3.236 | LR 4.73e-03
# Epoch 049 | Time 4.50s | Train NLL -4.901 | Val NLL -6.926 | LR 4.72e-03
# Epoch 050 | Time 4.53s | Train NLL -4.972 | Val NLL -4.948 | LR 4.71e-03
# Epoch 051 | Time 4.53s | Train NLL -5.426 | Val NLL -6.680 | LR 4.69e-03
# Epoch 052 | Time 3.29s | Train NLL -5.475 | Val NLL -5.039 | LR 4.68e-03
# Epoch 053 | Time 3.49s | Train NLL -4.812 | Val NLL -4.910 | LR 4.67e-03
# Epoch 054 | Time 4.43s | Train NLL -4.832 | Val NLL -6.263 | LR 4.65e-03
# Epoch 055 | Time 4.47s | Train NLL -5.221 | Val NLL -3.521 | LR 4.64e-03
# Epoch 056 | Time 4.44s | Train NLL -4.026 | Val NLL -4.217 | LR 4.63e-03
# Epoch 057 | Time 4.09s | Train NLL -4.820 | Val NLL -1.170 | LR 4.61e-03
# Epoch 058 | Time 3.05s | Train NLL -4.277 | Val NLL -1.757 | LR 4.60e-03
# Epoch 059 | Time 4.18s | Train NLL -3.441 | Val NLL -2.714 | LR 4.58e-03
# Epoch 060 | Time 4.42s | Train NLL -4.379 | Val NLL -1.638 | LR 4.57e-03
# Epoch 061 | Time 4.42s | Train NLL -3.728 | Val NLL -4.366 | LR 4.55e-03
# Epoch 062 | Time 4.36s | Train NLL -4.376 | Val NLL -4.105 | LR 4.54e-03
# Epoch 063 | Time 3.06s | Train NLL -5.905 | Val NLL -5.766 | LR 4.52e-03
# Epoch 064 | Time 3.86s | Train NLL -5.453 | Val NLL -5.415 | LR 4.51e-03
# Epoch 065 | Time 4.98s | Train NLL -2.766 | Val NLL -5.696 | LR 4.49e-03
# Epoch 066 | Time 5.75s | Train NLL -1.180 | Val NLL -1.151 | LR 4.47e-03
# Epoch 067 | Time 5.00s | Train NLL -2.664 | Val NLL -4.336 | LR 4.46e-03
# Epoch 068 | Time 5.48s | Train NLL -3.387 | Val NLL -0.797 | LR 4.44e-03
# Epoch 069 | Time 3.84s | Train NLL -3.466 | Val NLL -5.216 | LR 4.42e-03
# Epoch 070 | Time 6.88s | Train NLL -4.551 | Val NLL -1.534 | LR 4.41e-03
# Epoch 071 | Time 5.15s | Train NLL -4.090 | Val NLL -1.919 | LR 4.39e-03
# Epoch 072 | Time 4.87s | Train NLL -4.531 | Val NLL -1.101 | LR 4.37e-03
# Epoch 073 | Time 6.32s | Train NLL -5.814 | Val NLL -6.506 | LR 4.35e-03
# Epoch 074 | Time 6.11s | Train NLL -2.348 | Val NLL -3.588 | LR 4.34e-03
# Epoch 075 | Time 5.97s | Train NLL -0.981 | Val NLL -3.111 | LR 4.32e-03
# Epoch 076 | Time 5.84s | Train NLL -4.223 | Val NLL -4.015 | LR 4.30e-03
# Epoch 077 | Time 7.94s | Train NLL -5.297 | Val NLL -7.276 | LR 4.28e-03
# Epoch 078 | Time 5.94s | Train NLL -3.537 | Val NLL -5.951 | LR 4.26e-03
# Epoch 079 | Time 5.34s | Train NLL -4.293 | Val NLL -1.702 | LR 4.24e-03
# Epoch 080 | Time 5.24s | Train NLL -4.722 | Val NLL -5.749 | LR 4.22e-03
# Epoch 081 | Time 3.73s | Train NLL -4.280 | Val NLL -2.919 | LR 4.21e-03
# Epoch 082 | Time 3.71s | Train NLL -4.712 | Val NLL -6.228 | LR 4.19e-03
# Epoch 083 | Time 3.81s | Train NLL -5.291 | Val NLL -5.425 | LR 4.17e-03
# Epoch 084 | Time 4.44s | Train NLL -6.079 | Val NLL -6.314 | LR 4.15e-03
# Epoch 085 | Time 5.14s | Train NLL -5.813 | Val NLL -3.947 | LR 4.13e-03
# Epoch 086 | Time 5.18s | Train NLL -4.565 | Val NLL -3.822 | LR 4.11e-03
# Epoch 087 | Time 5.18s | Train NLL -4.460 | Val NLL -4.487 | LR 4.09e-03
# Epoch 088 | Time 5.19s | Train NLL -5.336 | Val NLL -6.484 | LR 4.06e-03
# Epoch 089 | Time 5.31s | Train NLL -5.695 | Val NLL -6.120 | LR 4.04e-03
# Epoch 090 | Time 5.26s | Train NLL -6.431 | Val NLL -7.702 | LR 4.02e-03
# Epoch 091 | Time 3.99s | Train NLL -4.490 | Val NLL -6.813 | LR 4.00e-03
# Epoch 092 | Time 3.82s | Train NLL -5.977 | Val NLL -6.535 | LR 3.98e-03
# Epoch 093 | Time 3.63s | Train NLL -5.743 | Val NLL -7.530 | LR 3.96e-03
# Epoch 094 | Time 4.49s | Train NLL -4.547 | Val NLL -2.993 | LR 3.94e-03
# Epoch 095 | Time 5.15s | Train NLL -5.109 | Val NLL -6.474 | LR 3.92e-03
# Epoch 096 | Time 5.15s | Train NLL -6.168 | Val NLL -6.685 | LR 3.89e-03
# Epoch 097 | Time 5.28s | Train NLL -5.987 | Val NLL -5.957 | LR 3.87e-03
# Epoch 098 | Time 5.37s | Train NLL -6.112 | Val NLL -7.067 | LR 3.85e-03
# Epoch 099 | Time 5.18s | Train NLL -4.942 | Val NLL -4.648 | LR 3.83e-03
# Epoch 100 | Time 5.16s | Train NLL -6.035 | Val NLL -0.810 | LR 3.80e-03
# Epoch 101 | Time 4.78s | Train NLL -5.456 | Val NLL -6.377 | LR 3.78e-03
# Epoch 102 | Time 3.79s | Train NLL -6.508 | Val NLL -5.264 | LR 3.76e-03
# Epoch 103 | Time 3.62s | Train NLL -5.219 | Val NLL -4.074 | LR 3.73e-03
# Epoch 104 | Time 3.88s | Train NLL -5.773 | Val NLL -4.841 | LR 3.71e-03
# Epoch 105 | Time 5.18s | Train NLL -6.059 | Val NLL -7.580 | LR 3.69e-03
# Epoch 106 | Time 5.15s | Train NLL -6.853 | Val NLL -6.554 | LR 3.66e-03
# Epoch 107 | Time 5.21s | Train NLL -5.397 | Val NLL -7.785 | LR 3.64e-03
# Epoch 108 | Time 5.26s | Train NLL -6.009 | Val NLL -6.537 | LR 3.62e-03
# Epoch 109 | Time 5.17s | Train NLL -6.475 | Val NLL -6.852 | LR 3.59e-03
# Epoch 110 | Time 5.15s | Train NLL -2.783 | Val NLL -2.540 | LR 3.57e-03
# Epoch 111 | Time 5.16s | Train NLL -5.121 | Val NLL -5.106 | LR 3.55e-03
# Epoch 112 | Time 4.32s | Train NLL -6.250 | Val NLL -7.677 | LR 3.52e-03
# Epoch 113 | Time 3.67s | Train NLL -5.945 | Val NLL -7.060 | LR 3.50e-03
# Epoch 114 | Time 3.76s | Train NLL -6.866 | Val NLL -6.827 | LR 3.47e-03
# Epoch 115 | Time 3.92s | Train NLL -6.908 | Val NLL -7.434 | LR 3.45e-03
# Epoch 116 | Time 5.17s | Train NLL -6.494 | Val NLL -8.083 | LR 3.42e-03
# Epoch 117 | Time 5.16s | Train NLL -5.953 | Val NLL -6.573 | LR 3.40e-03
# Epoch 118 | Time 5.22s | Train NLL -5.239 | Val NLL -3.252 | LR 3.37e-03
# Epoch 119 | Time 5.16s | Train NLL -6.555 | Val NLL -7.256 | LR 3.35e-03
# Epoch 120 | Time 5.14s | Train NLL -7.015 | Val NLL -7.530 | LR 3.32e-03
# Epoch 121 | Time 5.20s | Train NLL -6.428 | Val NLL -6.957 | LR 3.30e-03
# Epoch 122 | Time 5.20s | Train NLL -7.366 | Val NLL -8.038 | LR 3.27e-03
# Epoch 123 | Time 3.70s | Train NLL -7.789 | Val NLL -7.618 | LR 3.25e-03
# Epoch 124 | Time 3.73s | Train NLL -7.423 | Val NLL -5.862 | LR 3.22e-03
# Epoch 125 | Time 3.64s | Train NLL -7.939 | Val NLL -8.228 | LR 3.20e-03
# Epoch 126 | Time 4.76s | Train NLL -5.360 | Val NLL -6.251 | LR 3.17e-03
# Epoch 127 | Time 5.14s | Train NLL -6.111 | Val NLL -2.829 | LR 3.14e-03
# Epoch 128 | Time 5.20s | Train NLL -7.523 | Val NLL -8.175 | LR 3.12e-03
# Epoch 129 | Time 6.02s | Train NLL -7.584 | Val NLL -8.428 | LR 3.09e-03
# Epoch 130 | Time 5.66s | Train NLL -7.062 | Val NLL -3.875 | LR 3.07e-03
# Epoch 131 | Time 5.60s | Train NLL -7.761 | Val NLL -9.296 | LR 3.04e-03
# Epoch 132 | Time 5.52s | Train NLL -8.481 | Val NLL -8.290 | LR 3.02e-03
# Epoch 133 | Time 5.16s | Train NLL -6.316 | Val NLL -6.680 | LR 2.99e-03
# Epoch 134 | Time 5.51s | Train NLL -5.885 | Val NLL -6.236 | LR 2.96e-03
# Epoch 135 | Time 5.18s | Train NLL -7.330 | Val NLL -4.723 | LR 2.94e-03
# Epoch 136 | Time 5.22s | Train NLL -6.680 | Val NLL -9.120 | LR 2.91e-03
# Epoch 137 | Time 4.93s | Train NLL -7.504 | Val NLL -6.908 | LR 2.88e-03
# Epoch 138 | Time 3.66s | Train NLL -7.655 | Val NLL -6.696 | LR 2.86e-03
# Epoch 139 | Time 3.62s | Train NLL -6.943 | Val NLL -9.206 | LR 2.83e-03
# Epoch 140 | Time 4.42s | Train NLL -8.536 | Val NLL -9.416 | LR 2.81e-03
# Epoch 141 | Time 5.37s | Train NLL -6.405 | Val NLL -5.616 | LR 2.78e-03
# Epoch 142 | Time 5.26s | Train NLL -8.395 | Val NLL -9.647 | LR 2.75e-03
# Epoch 143 | Time 5.17s | Train NLL -6.963 | Val NLL -7.907 | LR 2.73e-03
# Epoch 144 | Time 5.34s | Train NLL -6.906 | Val NLL -8.864 | LR 2.70e-03
# Epoch 145 | Time 5.28s | Train NLL -7.353 | Val NLL -3.205 | LR 2.67e-03
# Epoch 146 | Time 5.35s | Train NLL -7.132 | Val NLL -6.783 | LR 2.65e-03
# Epoch 147 | Time 5.22s | Train NLL -7.566 | Val NLL -9.332 | LR 2.62e-03
# Epoch 148 | Time 5.25s | Train NLL -6.479 | Val NLL -7.757 | LR 2.59e-03
# Epoch 149 | Time 4.56s | Train NLL -8.019 | Val NLL -8.409 | LR 2.57e-03
# Epoch 150 | Time 3.85s | Train NLL -7.628 | Val NLL -5.812 | LR 2.54e-03
# Epoch 151 | Time 3.83s | Train NLL -7.034 | Val NLL -9.430 | LR 2.51e-03
# Epoch 152 | Time 4.47s | Train NLL -8.272 | Val NLL -9.216 | LR 2.49e-03
# Epoch 153 | Time 5.26s | Train NLL -8.662 | Val NLL -9.643 | LR 2.46e-03
# Epoch 154 | Time 5.31s | Train NLL -6.553 | Val NLL -8.924 | LR 2.43e-03
# Epoch 155 | Time 5.21s | Train NLL -7.468 | Val NLL -9.426 | LR 2.41e-03
# Epoch 156 | Time 5.21s | Train NLL -6.727 | Val NLL -7.189 | LR 2.38e-03
# Epoch 157 | Time 5.36s | Train NLL -8.004 | Val NLL -8.609 | LR 2.35e-03
# Epoch 158 | Time 5.18s | Train NLL -7.178 | Val NLL -6.922 | LR 2.33e-03
# Epoch 159 | Time 5.21s | Train NLL -8.206 | Val NLL -9.074 | LR 2.30e-03
# Epoch 160 | Time 5.20s | Train NLL -8.621 | Val NLL -9.516 | LR 2.27e-03
# Epoch 161 | Time 3.90s | Train NLL -8.795 | Val NLL -7.000 | LR 2.25e-03
# Epoch 162 | Time 3.69s | Train NLL -8.360 | Val NLL -9.495 | LR 2.22e-03
# Epoch 163 | Time 3.79s | Train NLL -8.241 | Val NLL -9.116 | LR 2.19e-03
# Epoch 164 | Time 4.87s | Train NLL -7.135 | Val NLL -8.813 | LR 2.17e-03
# Epoch 165 | Time 5.09s | Train NLL -7.294 | Val NLL -3.561 | LR 2.14e-03
# Epoch 166 | Time 5.18s | Train NLL -7.287 | Val NLL -9.054 | LR 2.12e-03
# Epoch 167 | Time 5.02s | Train NLL -7.907 | Val NLL -9.982 | LR 2.09e-03
# Epoch 168 | Time 5.75s | Train NLL -7.420 | Val NLL -9.841 | LR 2.06e-03
# Epoch 169 | Time 5.19s | Train NLL -7.646 | Val NLL -9.189 | LR 2.04e-03
# Epoch 170 | Time 5.12s | Train NLL -8.360 | Val NLL -8.810 | LR 2.01e-03
# Epoch 171 | Time 5.17s | Train NLL -9.371 | Val NLL -10.134 | LR 1.98e-03
# Epoch 172 | Time 5.27s | Train NLL -8.780 | Val NLL -4.936 | LR 1.96e-03
# Epoch 173 | Time 5.13s | Train NLL -8.224 | Val NLL -9.285 | LR 1.93e-03
# Epoch 174 | Time 4.71s | Train NLL -8.546 | Val NLL -8.566 | LR 1.91e-03
# Epoch 175 | Time 3.72s | Train NLL -8.077 | Val NLL -10.221 | LR 1.88e-03
# Epoch 176 | Time 3.63s | Train NLL -7.968 | Val NLL -8.923 | LR 1.86e-03
# Epoch 177 | Time 4.36s | Train NLL -9.732 | Val NLL -10.335 | LR 1.83e-03
# Epoch 178 | Time 5.18s | Train NLL -9.312 | Val NLL -10.258 | LR 1.80e-03
# Epoch 179 | Time 5.16s | Train NLL -8.035 | Val NLL -9.149 | LR 1.78e-03
# Epoch 180 | Time 5.15s | Train NLL -9.816 | Val NLL -10.774 | LR 1.75e-03
# Epoch 181 | Time 5.30s | Train NLL -8.502 | Val NLL -10.293 | LR 1.73e-03
# Epoch 182 | Time 5.11s | Train NLL -6.781 | Val NLL -9.172 | LR 1.70e-03
# Epoch 183 | Time 5.25s | Train NLL -9.518 | Val NLL -6.772 | LR 1.68e-03
# Epoch 184 | Time 5.14s | Train NLL -8.911 | Val NLL -10.090 | LR 1.65e-03
# Epoch 185 | Time 5.07s | Train NLL -8.222 | Val NLL -9.175 | LR 1.63e-03
# Epoch 186 | Time 3.62s | Train NLL -8.683 | Val NLL -9.821 | LR 1.60e-03
# Epoch 187 | Time 3.60s | Train NLL -9.445 | Val NLL -10.321 | LR 1.58e-03
# Epoch 188 | Time 3.73s | Train NLL -9.077 | Val NLL -10.094 | LR 1.55e-03
# Epoch 189 | Time 5.23s | Train NLL -7.890 | Val NLL -8.204 | LR 1.53e-03
# Epoch 190 | Time 5.19s | Train NLL -9.444 | Val NLL -9.703 | LR 1.50e-03
# Epoch 191 | Time 5.11s | Train NLL -8.704 | Val NLL -7.091 | LR 1.48e-03
# Epoch 192 | Time 5.27s | Train NLL -9.759 | Val NLL -10.827 | LR 1.45e-03
# Epoch 193 | Time 5.08s | Train NLL -8.020 | Val NLL -10.260 | LR 1.43e-03
# Epoch 194 | Time 5.08s | Train NLL -9.098 | Val NLL -9.125 | LR 1.41e-03
# Epoch 195 | Time 5.11s | Train NLL -9.603 | Val NLL -10.659 | LR 1.38e-03
# Epoch 196 | Time 5.12s | Train NLL -10.420 | Val NLL -10.565 | LR 1.36e-03
# Epoch 197 | Time 3.76s | Train NLL -8.322 | Val NLL -9.701 | LR 1.34e-03
# Epoch 198 | Time 3.72s | Train NLL -10.626 | Val NLL -9.982 | LR 1.31e-03
# Epoch 199 | Time 3.60s | Train NLL -8.905 | Val NLL -9.081 | LR 1.29e-03
# Epoch 200 | Time 5.09s | Train NLL -10.579 | Val NLL -10.574 | LR 1.27e-03
# Epoch 201 | Time 5.08s | Train NLL -9.498 | Val NLL -10.636 | LR 1.24e-03
# Epoch 202 | Time 5.12s | Train NLL -10.155 | Val NLL -10.314 | LR 1.22e-03
# Epoch 203 | Time 5.09s | Train NLL -9.885 | Val NLL -9.756 | LR 1.20e-03
# Epoch 204 | Time 5.34s | Train NLL -10.925 | Val NLL -10.996 | LR 1.17e-03
# Epoch 205 | Time 5.55s | Train NLL -10.959 | Val NLL -11.317 | LR 1.15e-03
# Epoch 206 | Time 5.14s | Train NLL -8.913 | Val NLL -10.943 | LR 1.13e-03
# Epoch 207 | Time 5.28s | Train NLL -11.034 | Val NLL -11.327 | LR 1.11e-03
# Epoch 208 | Time 5.10s | Train NLL -10.364 | Val NLL -5.424 | LR 1.08e-03
# Epoch 209 | Time 5.27s | Train NLL -10.464 | Val NLL -11.397 | LR 1.06e-03
# Epoch 210 | Time 3.79s | Train NLL -11.273 | Val NLL -10.677 | LR 1.04e-03
# Epoch 211 | Time 3.63s | Train NLL -9.809 | Val NLL -10.890 | LR 1.02e-03
# Epoch 212 | Time 3.92s | Train NLL -11.428 | Val NLL -10.616 | LR 9.98e-04
# Epoch 213 | Time 5.27s | Train NLL -11.289 | Val NLL -11.721 | LR 9.77e-04
# Epoch 214 | Time 5.19s | Train NLL -9.855 | Val NLL -11.319 | LR 9.56e-04
# Epoch 215 | Time 5.22s | Train NLL -10.703 | Val NLL -10.473 | LR 9.35e-04
# Epoch 216 | Time 5.27s | Train NLL -11.355 | Val NLL -6.513 | LR 9.15e-04
# Epoch 217 | Time 4.97s | Train NLL -10.355 | Val NLL -10.900 | LR 8.94e-04
# Epoch 218 | Time 5.02s | Train NLL -11.370 | Val NLL -11.791 | LR 8.74e-04
# Epoch 219 | Time 4.95s | Train NLL -11.253 | Val NLL -10.521 | LR 8.54e-04
# Epoch 220 | Time 5.01s | Train NLL -11.424 | Val NLL -11.885 | LR 8.34e-04
# Epoch 221 | Time 4.97s | Train NLL -11.245 | Val NLL -11.376 | LR 8.14e-04
# Epoch 222 | Time 4.06s | Train NLL -11.146 | Val NLL -11.787 | LR 7.94e-04
# Epoch 223 | Time 3.44s | Train NLL -11.999 | Val NLL -11.759 | LR 7.75e-04
# Epoch 224 | Time 3.43s | Train NLL -10.277 | Val NLL -11.512 | LR 7.56e-04
# Epoch 225 | Time 4.15s | Train NLL -12.037 | Val NLL -11.934 | LR 7.37e-04
# Epoch 226 | Time 5.12s | Train NLL -11.995 | Val NLL -12.178 | LR 7.18e-04
# Epoch 227 | Time 4.94s | Train NLL -9.983 | Val NLL -9.168 | LR 7.00e-04
# Epoch 228 | Time 4.94s | Train NLL -11.593 | Val NLL -12.194 | LR 6.81e-04
# Epoch 229 | Time 5.11s | Train NLL -12.225 | Val NLL -10.126 | LR 6.63e-04
# Epoch 230 | Time 4.95s | Train NLL -10.761 | Val NLL -12.520 | LR 6.45e-04
# Epoch 231 | Time 4.89s | Train NLL -12.444 | Val NLL -12.379 | LR 6.27e-04
# Epoch 232 | Time 4.58s | Train NLL -11.862 | Val NLL -12.210 | LR 6.10e-04
# Epoch 233 | Time 3.38s | Train NLL -12.452 | Val NLL -11.237 | LR 5.93e-04
# Epoch 234 | Time 3.48s | Train NLL -11.827 | Val NLL -12.754 | LR 5.75e-04
# Epoch 235 | Time 4.42s | Train NLL -12.654 | Val NLL -12.891 | LR 5.59e-04
# Epoch 236 | Time 5.05s | Train NLL -10.311 | Val NLL -12.308 | LR 5.42e-04
# Epoch 237 | Time 4.99s | Train NLL -9.910 | Val NLL -11.690 | LR 5.25e-04
# Epoch 238 | Time 4.90s | Train NLL -12.481 | Val NLL -11.910 | LR 5.09e-04
# Epoch 239 | Time 4.95s | Train NLL -9.124 | Val NLL -11.979 | LR 4.93e-04
# Epoch 240 | Time 4.93s | Train NLL -12.657 | Val NLL -7.478 | LR 4.77e-04
# Epoch 241 | Time 4.92s | Train NLL -8.103 | Val NLL -10.567 | LR 4.62e-04
# Epoch 242 | Time 3.57s | Train NLL -11.432 | Val NLL -12.125 | LR 4.47e-04
# Epoch 243 | Time 3.46s | Train NLL -12.047 | Val NLL -12.849 | LR 4.32e-04
# Epoch 244 | Time 3.40s | Train NLL -12.061 | Val NLL -12.838 | LR 4.17e-04
# Epoch 245 | Time 4.97s | Train NLL -12.092 | Val NLL -12.908 | LR 4.02e-04
# Epoch 246 | Time 4.90s | Train NLL -12.341 | Val NLL -12.366 | LR 3.88e-04
# Epoch 247 | Time 4.97s | Train NLL -12.336 | Val NLL -11.619 | LR 3.74e-04
# Epoch 248 | Time 5.02s | Train NLL -12.377 | Val NLL -10.711 | LR 3.60e-04
# Epoch 249 | Time 4.93s | Train NLL -12.621 | Val NLL -13.329 | LR 3.46e-04
# Epoch 250 | Time 4.92s | Train NLL -12.725 | Val NLL -12.989 | LR 3.33e-04
# Epoch 251 | Time 4.92s | Train NLL -12.733 | Val NLL -13.099 | LR 3.20e-04
# Epoch 252 | Time 3.50s | Train NLL -12.918 | Val NLL -13.612 | LR 3.07e-04
# Epoch 253 | Time 3.42s | Train NLL -13.191 | Val NLL -13.035 | LR 2.94e-04
# Epoch 254 | Time 3.56s | Train NLL -13.130 | Val NLL -13.754 | LR 2.82e-04
# Epoch 255 | Time 4.28s | Train NLL -13.212 | Val NLL -13.261 | LR 2.69e-04
# Epoch 256 | Time 5.04s | Train NLL -12.987 | Val NLL -11.764 | LR 2.58e-04
# Epoch 257 | Time 4.98s | Train NLL -11.673 | Val NLL -11.219 | LR 2.46e-04
# Epoch 258 | Time 5.00s | Train NLL -13.543 | Val NLL -13.635 | LR 2.35e-04
# Epoch 259 | Time 5.05s | Train NLL -12.369 | Val NLL -12.619 | LR 2.23e-04
# Epoch 260 | Time 4.92s | Train NLL -13.664 | Val NLL -13.420 | LR 2.13e-04
# Epoch 261 | Time 5.00s | Train NLL -13.685 | Val NLL -12.601 | LR 2.02e-04
# Epoch 262 | Time 4.97s | Train NLL -13.694 | Val NLL -14.066 | LR 1.92e-04
# Epoch 263 | Time 3.95s | Train NLL -13.129 | Val NLL -13.359 | LR 1.81e-04
# Epoch 264 | Time 3.45s | Train NLL -14.090 | Val NLL -13.924 | LR 1.72e-04
# Epoch 265 | Time 3.43s | Train NLL -12.917 | Val NLL -14.092 | LR 1.62e-04
# Epoch 266 | Time 4.59s | Train NLL -14.354 | Val NLL -14.425 | LR 1.53e-04
# Epoch 267 | Time 4.91s | Train NLL -14.128 | Val NLL -13.684 | LR 1.44e-04
# Epoch 268 | Time 4.89s | Train NLL -13.523 | Val NLL -12.853 | LR 1.35e-04
# Epoch 269 | Time 5.18s | Train NLL -14.294 | Val NLL -14.534 | LR 1.27e-04
# Epoch 270 | Time 4.94s | Train NLL -14.175 | Val NLL -13.328 | LR 1.18e-04
# Epoch 271 | Time 4.98s | Train NLL -14.401 | Val NLL -15.017 | LR 1.10e-04
# Epoch 272 | Time 5.03s | Train NLL -14.384 | Val NLL -14.800 | LR 1.03e-04
# Epoch 273 | Time 4.77s | Train NLL -14.598 | Val NLL -14.660 | LR 9.52e-05
# Epoch 274 | Time 3.48s | Train NLL -14.881 | Val NLL -14.360 | LR 8.81e-05
# Epoch 275 | Time 3.43s | Train NLL -15.081 | Val NLL -15.142 | LR 8.12e-05
# Epoch 276 | Time 3.49s | Train NLL -12.991 | Val NLL -14.778 | LR 7.46e-05
# Epoch 277 | Time 5.03s | Train NLL -14.800 | Val NLL -13.962 | LR 6.83e-05
# Epoch 278 | Time 5.01s | Train NLL -14.865 | Val NLL -14.888 | LR 6.23e-05
# Epoch 279 | Time 5.38s | Train NLL -15.472 | Val NLL -15.434 | LR 5.65e-05
# Epoch 280 | Time 5.17s | Train NLL -15.368 | Val NLL -13.904 | LR 5.10e-05
# Epoch 281 | Time 5.26s | Train NLL -15.354 | Val NLL -15.617 | LR 4.58e-05
# Epoch 282 | Time 5.19s | Train NLL -15.802 | Val NLL -15.668 | LR 4.09e-05
# Epoch 283 | Time 5.14s | Train NLL -15.765 | Val NLL -15.727 | LR 3.62e-05
# Epoch 284 | Time 5.24s | Train NLL -15.892 | Val NLL -15.871 | LR 3.18e-05
# Epoch 285 | Time 5.14s | Train NLL -16.058 | Val NLL -15.926 | LR 2.77e-05
# Epoch 286 | Time 5.24s | Train NLL -16.107 | Val NLL -16.015 | LR 2.39e-05
# Epoch 287 | Time 3.75s | Train NLL -16.164 | Val NLL -16.089 | LR 2.04e-05
# Epoch 288 | Time 3.55s | Train NLL -16.200 | Val NLL -15.990 | LR 1.71e-05
# Epoch 289 | Time 3.68s | Train NLL -16.271 | Val NLL -16.143 | LR 1.42e-05
# Epoch 290 | Time 5.12s | Train NLL -16.326 | Val NLL -16.199 | LR 1.15e-05
# Epoch 291 | Time 5.30s | Train NLL -16.359 | Val NLL -16.232 | LR 9.07e-06
# Epoch 292 | Time 5.19s | Train NLL -16.398 | Val NLL -16.251 | LR 6.94e-06
# Epoch 293 | Time 5.11s | Train NLL -16.414 | Val NLL -16.275 | LR 5.10e-06
# Epoch 294 | Time 5.32s | Train NLL -16.431 | Val NLL -16.290 | LR 3.54e-06
# Epoch 295 | Time 5.43s | Train NLL -16.444 | Val NLL -16.296 | LR 2.27e-06
# Epoch 296 | Time 5.19s | Train NLL -16.431 | Val NLL -16.299 | LR 1.28e-06
# Epoch 297 | Time 5.14s | Train NLL -16.445 | Val NLL -16.306 | LR 5.67e-07
# Epoch 298 | Time 5.21s | Train NLL -16.446 | Val NLL -16.307 | LR 1.42e-07
# Epoch 299 | Time 5.11s | Train NLL -16.455 | Val NLL -16.307 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 909318.31
# Average absolute difference in CASUALTIES: 0.10

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
