# %% [markdown]
# # Wind model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wind'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 11.47s | Train NLL -1.101 | Val NLL -2.580 | LR 1.00e-03
# Epoch 001 | Time 12.02s | Train NLL -2.481 | Val NLL -2.587 | LR 2.00e-03
# Epoch 002 | Time 10.93s | Train NLL -2.302 | Val NLL -3.003 | LR 3.00e-03
# Epoch 003 | Time 10.53s | Train NLL -2.520 | Val NLL -2.680 | LR 4.00e-03
# Epoch 004 | Time 10.30s | Train NLL -2.103 | Val NLL -2.309 | LR 5.00e-03
# Epoch 005 | Time 10.39s | Train NLL -1.840 | Val NLL -2.962 | LR 5.00e-03
# Epoch 006 | Time 10.23s | Train NLL -2.559 | Val NLL -3.706 | LR 5.00e-03
# Epoch 007 | Time 10.58s | Train NLL -1.643 | Val NLL -2.353 | LR 5.00e-03
# Epoch 008 | Time 10.41s | Train NLL -1.809 | Val NLL -1.862 | LR 5.00e-03
# Epoch 009 | Time 10.93s | Train NLL -2.376 | Val NLL 0.310 | LR 5.00e-03
# Epoch 010 | Time 10.68s | Train NLL -1.574 | Val NLL -3.050 | LR 4.99e-03
# Epoch 011 | Time 10.43s | Train NLL -3.326 | Val NLL -4.959 | LR 4.99e-03
# Epoch 012 | Time 10.58s | Train NLL -3.782 | Val NLL -2.084 | LR 4.99e-03
# Epoch 013 | Time 10.17s | Train NLL -2.969 | Val NLL -5.429 | LR 4.99e-03
# Epoch 014 | Time 10.45s | Train NLL -2.996 | Val NLL -5.233 | LR 4.99e-03
# Epoch 015 | Time 10.20s | Train NLL -3.625 | Val NLL 0.047 | LR 4.98e-03
# Epoch 016 | Time 10.40s | Train NLL -4.346 | Val NLL -3.474 | LR 4.98e-03
# Epoch 017 | Time 10.27s | Train NLL -4.440 | Val NLL -4.447 | LR 4.98e-03
# Epoch 018 | Time 10.55s | Train NLL -3.983 | Val NLL -4.839 | LR 4.97e-03
# Epoch 019 | Time 10.40s | Train NLL -4.183 | Val NLL -3.328 | LR 4.97e-03
# Epoch 020 | Time 10.53s | Train NLL -4.347 | Val NLL -6.105 | LR 4.96e-03
# Epoch 021 | Time 10.57s | Train NLL -4.079 | Val NLL -5.195 | LR 4.96e-03
# Epoch 022 | Time 10.47s | Train NLL -4.544 | Val NLL -2.499 | LR 4.95e-03
# Epoch 023 | Time 10.63s | Train NLL -3.597 | Val NLL -5.850 | LR 4.95e-03
# Epoch 024 | Time 10.43s | Train NLL -4.041 | Val NLL -5.356 | LR 4.94e-03
# Epoch 025 | Time 10.37s | Train NLL -4.023 | Val NLL -2.549 | LR 4.94e-03
# Epoch 026 | Time 10.32s | Train NLL -4.383 | Val NLL -3.154 | LR 4.93e-03
# Epoch 027 | Time 10.43s | Train NLL -4.680 | Val NLL -6.600 | LR 4.93e-03
# Epoch 028 | Time 10.95s | Train NLL -5.301 | Val NLL -4.121 | LR 4.92e-03
# Epoch 029 | Time 10.23s | Train NLL -4.869 | Val NLL -5.742 | LR 4.91e-03
# Epoch 030 | Time 10.53s | Train NLL -3.999 | Val NLL -3.601 | LR 4.90e-03
# Epoch 031 | Time 10.50s | Train NLL -4.227 | Val NLL -5.413 | LR 4.90e-03
# Epoch 032 | Time 11.87s | Train NLL -4.717 | Val NLL -3.326 | LR 4.89e-03
# Epoch 033 | Time 13.27s | Train NLL -4.564 | Val NLL -3.615 | LR 4.88e-03
# Epoch 034 | Time 13.18s | Train NLL -4.979 | Val NLL -3.741 | LR 4.87e-03
# Epoch 035 | Time 9.45s | Train NLL -4.692 | Val NLL -2.237 | LR 4.86e-03
# Epoch 036 | Time 11.60s | Train NLL -5.137 | Val NLL -6.358 | LR 4.86e-03
# Epoch 037 | Time 13.47s | Train NLL -3.920 | Val NLL -1.929 | LR 4.85e-03
# Epoch 038 | Time 12.67s | Train NLL -4.487 | Val NLL -6.435 | LR 4.84e-03
# Epoch 039 | Time 9.48s | Train NLL -3.832 | Val NLL -2.822 | LR 4.83e-03
# Epoch 040 | Time 12.92s | Train NLL -4.884 | Val NLL -5.922 | LR 4.82e-03
# Epoch 041 | Time 12.43s | Train NLL -5.112 | Val NLL -5.302 | LR 4.81e-03
# Epoch 042 | Time 9.85s | Train NLL -5.786 | Val NLL -7.120 | LR 4.80e-03
# Epoch 043 | Time 13.35s | Train NLL -4.894 | Val NLL -5.018 | LR 4.79e-03
# Epoch 044 | Time 13.10s | Train NLL -4.748 | Val NLL -5.730 | LR 4.78e-03
# Epoch 045 | Time 9.13s | Train NLL -4.941 | Val NLL -5.386 | LR 4.77e-03
# Epoch 046 | Time 12.60s | Train NLL -4.753 | Val NLL -4.043 | LR 4.75e-03
# Epoch 047 | Time 13.03s | Train NLL -4.795 | Val NLL -6.085 | LR 4.74e-03
# Epoch 048 | Time 11.28s | Train NLL -4.214 | Val NLL -5.771 | LR 4.73e-03
# Epoch 049 | Time 10.39s | Train NLL -4.326 | Val NLL -7.274 | LR 4.72e-03
# Epoch 050 | Time 13.11s | Train NLL -5.152 | Val NLL -4.936 | LR 4.71e-03
# Epoch 051 | Time 12.70s | Train NLL -4.989 | Val NLL -4.266 | LR 4.69e-03
# Epoch 052 | Time 9.85s | Train NLL -4.525 | Val NLL -2.653 | LR 4.68e-03
# Epoch 053 | Time 13.31s | Train NLL -4.895 | Val NLL -5.028 | LR 4.67e-03
# Epoch 054 | Time 13.29s | Train NLL -5.512 | Val NLL -3.240 | LR 4.65e-03
# Epoch 055 | Time 9.10s | Train NLL -5.441 | Val NLL -3.846 | LR 4.64e-03
# Epoch 056 | Time 12.64s | Train NLL -5.017 | Val NLL -6.545 | LR 4.63e-03
# Epoch 057 | Time 13.21s | Train NLL -6.019 | Val NLL -7.081 | LR 4.61e-03
# Epoch 058 | Time 12.30s | Train NLL -5.922 | Val NLL -6.658 | LR 4.60e-03
# Epoch 059 | Time 9.39s | Train NLL -5.136 | Val NLL -7.103 | LR 4.58e-03
# Epoch 060 | Time 13.18s | Train NLL -4.669 | Val NLL -1.684 | LR 4.57e-03
# Epoch 061 | Time 13.40s | Train NLL -5.692 | Val NLL -5.300 | LR 4.55e-03
# Epoch 062 | Time 9.43s | Train NLL -6.128 | Val NLL -5.783 | LR 4.54e-03
# Epoch 063 | Time 12.27s | Train NLL -5.921 | Val NLL -6.780 | LR 4.52e-03
# Epoch 064 | Time 13.27s | Train NLL -6.245 | Val NLL -6.866 | LR 4.51e-03
# Epoch 065 | Time 11.10s | Train NLL -5.262 | Val NLL -4.369 | LR 4.49e-03
# Epoch 066 | Time 11.72s | Train NLL -5.377 | Val NLL -5.779 | LR 4.47e-03
# Epoch 067 | Time 13.42s | Train NLL -5.431 | Val NLL -4.457 | LR 4.46e-03
# Epoch 068 | Time 11.17s | Train NLL -5.536 | Val NLL -7.515 | LR 4.44e-03
# Epoch 069 | Time 10.77s | Train NLL -7.091 | Val NLL -7.566 | LR 4.42e-03
# Epoch 070 | Time 13.37s | Train NLL -6.176 | Val NLL -7.805 | LR 4.41e-03
# Epoch 071 | Time 12.33s | Train NLL -5.967 | Val NLL -8.111 | LR 4.39e-03
# Epoch 072 | Time 9.62s | Train NLL -6.143 | Val NLL -7.098 | LR 4.37e-03
# Epoch 073 | Time 13.05s | Train NLL -6.374 | Val NLL -6.631 | LR 4.35e-03
# Epoch 074 | Time 13.33s | Train NLL -5.696 | Val NLL -7.403 | LR 4.34e-03
# Epoch 075 | Time 9.82s | Train NLL -5.964 | Val NLL -6.404 | LR 4.32e-03
# Epoch 076 | Time 11.32s | Train NLL -6.410 | Val NLL -6.538 | LR 4.30e-03
# Epoch 077 | Time 13.48s | Train NLL -6.909 | Val NLL -4.279 | LR 4.28e-03
# Epoch 078 | Time 13.33s | Train NLL -6.224 | Val NLL -6.915 | LR 4.26e-03
# Epoch 079 | Time 11.64s | Train NLL -7.170 | Val NLL -7.954 | LR 4.24e-03
# Epoch 080 | Time 9.58s | Train NLL -6.815 | Val NLL -7.516 | LR 4.22e-03
# Epoch 081 | Time 13.02s | Train NLL -6.065 | Val NLL -6.972 | LR 4.21e-03
# Epoch 082 | Time 13.15s | Train NLL -6.669 | Val NLL -6.938 | LR 4.19e-03
# Epoch 083 | Time 11.52s | Train NLL -6.418 | Val NLL -7.776 | LR 4.17e-03
# Epoch 084 | Time 10.58s | Train NLL -6.536 | Val NLL -7.392 | LR 4.15e-03
# Epoch 085 | Time 12.95s | Train NLL -6.599 | Val NLL -7.674 | LR 4.13e-03
# Epoch 086 | Time 11.69s | Train NLL -4.901 | Val NLL -6.345 | LR 4.11e-03
# Epoch 087 | Time 10.19s | Train NLL -6.311 | Val NLL -7.576 | LR 4.09e-03
# Epoch 088 | Time 12.88s | Train NLL -6.609 | Val NLL -6.804 | LR 4.06e-03
# Epoch 089 | Time 13.12s | Train NLL -6.186 | Val NLL -5.116 | LR 4.04e-03
# Epoch 090 | Time 9.33s | Train NLL -6.192 | Val NLL -5.382 | LR 4.02e-03
# Epoch 091 | Time 11.73s | Train NLL -6.666 | Val NLL -7.673 | LR 4.00e-03
# Epoch 092 | Time 12.90s | Train NLL -5.522 | Val NLL -6.524 | LR 3.98e-03
# Epoch 093 | Time 12.38s | Train NLL -6.379 | Val NLL -7.092 | LR 3.96e-03
# Epoch 094 | Time 9.07s | Train NLL -6.461 | Val NLL -7.021 | LR 3.94e-03
# Epoch 095 | Time 12.71s | Train NLL -5.819 | Val NLL -6.181 | LR 3.92e-03
# Epoch 096 | Time 13.21s | Train NLL -5.303 | Val NLL -5.723 | LR 3.89e-03
# Epoch 097 | Time 10.85s | Train NLL -5.524 | Val NLL -7.113 | LR 3.87e-03
# Epoch 098 | Time 10.50s | Train NLL -4.984 | Val NLL -5.025 | LR 3.85e-03
# Epoch 099 | Time 13.17s | Train NLL -4.460 | Val NLL -5.635 | LR 3.83e-03
# Epoch 100 | Time 13.00s | Train NLL -5.321 | Val NLL -2.628 | LR 3.80e-03
# Epoch 101 | Time 10.02s | Train NLL -6.264 | Val NLL -7.138 | LR 3.78e-03
# Epoch 102 | Time 11.20s | Train NLL -6.045 | Val NLL -6.329 | LR 3.76e-03
# Epoch 103 | Time 13.17s | Train NLL -6.282 | Val NLL -7.104 | LR 3.73e-03
# Epoch 104 | Time 12.40s | Train NLL -6.749 | Val NLL -7.754 | LR 3.71e-03
# Epoch 105 | Time 9.68s | Train NLL -4.457 | Val NLL -5.499 | LR 3.69e-03
# Epoch 106 | Time 12.95s | Train NLL -5.397 | Val NLL -5.832 | LR 3.66e-03
# Epoch 107 | Time 13.16s | Train NLL -6.338 | Val NLL -7.786 | LR 3.64e-03
# Epoch 108 | Time 12.22s | Train NLL -6.127 | Val NLL -7.870 | LR 3.62e-03
# Epoch 109 | Time 9.98s | Train NLL -6.352 | Val NLL -4.947 | LR 3.59e-03
# Epoch 110 | Time 13.24s | Train NLL -5.498 | Val NLL -3.556 | LR 3.57e-03
# Epoch 111 | Time 13.08s | Train NLL -5.688 | Val NLL -1.291 | LR 3.55e-03
# Epoch 112 | Time 8.99s | Train NLL -5.555 | Val NLL -3.804 | LR 3.52e-03
# Epoch 113 | Time 12.87s | Train NLL -5.982 | Val NLL -6.866 | LR 3.50e-03
# Epoch 114 | Time 12.90s | Train NLL -7.014 | Val NLL -6.442 | LR 3.47e-03
# Epoch 115 | Time 11.32s | Train NLL -6.314 | Val NLL -7.842 | LR 3.45e-03
# Epoch 116 | Time 10.10s | Train NLL -7.080 | Val NLL -7.801 | LR 3.42e-03
# Epoch 117 | Time 12.82s | Train NLL -6.582 | Val NLL -8.135 | LR 3.40e-03
# Epoch 118 | Time 12.98s | Train NLL -6.272 | Val NLL -6.967 | LR 3.37e-03
# Epoch 119 | Time 10.20s | Train NLL -7.322 | Val NLL -8.879 | LR 3.35e-03
# Epoch 120 | Time 11.39s | Train NLL -7.070 | Val NLL -4.826 | LR 3.32e-03
# Epoch 121 | Time 13.01s | Train NLL -7.352 | Val NLL -8.088 | LR 3.30e-03
# Epoch 122 | Time 12.52s | Train NLL -5.612 | Val NLL -6.883 | LR 3.27e-03
# Epoch 123 | Time 9.12s | Train NLL -6.059 | Val NLL -8.248 | LR 3.25e-03
# Epoch 124 | Time 12.32s | Train NLL -6.556 | Val NLL 12.530 | LR 3.22e-03
# Epoch 125 | Time 12.88s | Train NLL -3.250 | Val NLL -5.493 | LR 3.20e-03
# Epoch 126 | Time 12.52s | Train NLL -6.839 | Val NLL -6.391 | LR 3.17e-03
# Epoch 127 | Time 9.54s | Train NLL -6.052 | Val NLL -7.845 | LR 3.14e-03
# Epoch 128 | Time 13.17s | Train NLL -6.735 | Val NLL -7.584 | LR 3.12e-03
# Epoch 129 | Time 12.98s | Train NLL -6.839 | Val NLL -8.008 | LR 3.09e-03
# Epoch 130 | Time 10.52s | Train NLL -7.090 | Val NLL -7.326 | LR 3.07e-03
# Epoch 131 | Time 11.53s | Train NLL -6.447 | Val NLL -2.834 | LR 3.04e-03
# Epoch 132 | Time 12.93s | Train NLL -6.475 | Val NLL -6.877 | LR 3.02e-03
# Epoch 133 | Time 12.83s | Train NLL -7.197 | Val NLL -8.281 | LR 2.99e-03
# Epoch 134 | Time 9.38s | Train NLL -7.024 | Val NLL -7.265 | LR 2.96e-03
# Epoch 135 | Time 12.25s | Train NLL -7.126 | Val NLL -6.597 | LR 2.94e-03
# Epoch 136 | Time 13.15s | Train NLL -7.728 | Val NLL -8.119 | LR 2.91e-03
# Epoch 137 | Time 12.35s | Train NLL -7.071 | Val NLL -6.544 | LR 2.88e-03
# Epoch 138 | Time 10.08s | Train NLL -7.586 | Val NLL -7.849 | LR 2.86e-03
# Epoch 139 | Time 12.95s | Train NLL -7.437 | Val NLL -7.490 | LR 2.83e-03
# Epoch 140 | Time 12.12s | Train NLL -7.093 | Val NLL -5.839 | LR 2.81e-03
# Epoch 141 | Time 9.92s | Train NLL -7.080 | Val NLL -7.448 | LR 2.78e-03
# Epoch 142 | Time 13.00s | Train NLL -6.832 | Val NLL -7.394 | LR 2.75e-03
# Epoch 143 | Time 13.07s | Train NLL -7.763 | Val NLL -7.705 | LR 2.73e-03
# Epoch 144 | Time 10.30s | Train NLL -7.796 | Val NLL -6.557 | LR 2.70e-03
# Epoch 145 | Time 11.12s | Train NLL -8.124 | Val NLL -3.945 | LR 2.67e-03
# Epoch 146 | Time 13.14s | Train NLL -7.368 | Val NLL -7.089 | LR 2.65e-03
# Epoch 147 | Time 12.71s | Train NLL -7.822 | Val NLL -8.242 | LR 2.62e-03
# Epoch 148 | Time 9.39s | Train NLL -7.778 | Val NLL -7.385 | LR 2.59e-03
# Epoch 149 | Time 13.01s | Train NLL -7.390 | Val NLL -8.105 | LR 2.57e-03
# Epoch 150 | Time 13.02s | Train NLL -7.409 | Val NLL -6.609 | LR 2.54e-03
# Epoch 151 | Time 10.38s | Train NLL -7.629 | Val NLL -8.325 | LR 2.51e-03
# Epoch 152 | Time 11.03s | Train NLL -7.809 | Val NLL -9.068 | LR 2.49e-03
# Epoch 153 | Time 13.32s | Train NLL -6.214 | Val NLL -4.700 | LR 2.46e-03
# Epoch 154 | Time 12.95s | Train NLL -7.354 | Val NLL -7.716 | LR 2.43e-03
# Epoch 155 | Time 9.09s | Train NLL -7.602 | Val NLL -7.549 | LR 2.41e-03
# Epoch 156 | Time 12.32s | Train NLL -7.771 | Val NLL -6.807 | LR 2.38e-03
# Epoch 157 | Time 13.10s | Train NLL -8.096 | Val NLL -9.039 | LR 2.35e-03
# Epoch 158 | Time 12.80s | Train NLL -7.748 | Val NLL -9.162 | LR 2.33e-03
# Epoch 159 | Time 9.18s | Train NLL -8.112 | Val NLL -6.952 | LR 2.30e-03
# Epoch 160 | Time 12.90s | Train NLL -8.038 | Val NLL -5.424 | LR 2.27e-03
# Epoch 161 | Time 12.97s | Train NLL -7.015 | Val NLL -8.468 | LR 2.25e-03
# Epoch 162 | Time 12.03s | Train NLL -6.832 | Val NLL -7.330 | LR 2.22e-03
# Epoch 163 | Time 10.10s | Train NLL -7.550 | Val NLL -6.990 | LR 2.19e-03
# Epoch 164 | Time 12.89s | Train NLL -7.377 | Val NLL -8.132 | LR 2.17e-03
# Epoch 165 | Time 13.12s | Train NLL -7.921 | Val NLL -9.591 | LR 2.14e-03
# Epoch 166 | Time 11.47s | Train NLL -7.768 | Val NLL -8.648 | LR 2.12e-03
# Epoch 167 | Time 10.61s | Train NLL -8.285 | Val NLL -1.202 | LR 2.09e-03
# Epoch 168 | Time 13.19s | Train NLL -7.704 | Val NLL -7.809 | LR 2.06e-03
# Epoch 169 | Time 12.79s | Train NLL -8.375 | Val NLL -6.349 | LR 2.04e-03
# Epoch 170 | Time 9.71s | Train NLL -8.494 | Val NLL -7.438 | LR 2.01e-03
# Epoch 171 | Time 11.89s | Train NLL -7.261 | Val NLL -5.118 | LR 1.98e-03
# Epoch 172 | Time 12.74s | Train NLL -8.260 | Val NLL -9.169 | LR 1.96e-03
# Epoch 173 | Time 13.02s | Train NLL -8.335 | Val NLL -9.459 | LR 1.93e-03
# Epoch 174 | Time 9.15s | Train NLL -8.503 | Val NLL -9.417 | LR 1.91e-03
# Epoch 175 | Time 12.48s | Train NLL -8.228 | Val NLL -7.390 | LR 1.88e-03
# Epoch 176 | Time 12.93s | Train NLL -8.479 | Val NLL -8.824 | LR 1.86e-03
# Epoch 177 | Time 13.13s | Train NLL -8.526 | Val NLL -7.288 | LR 1.83e-03
# Epoch 178 | Time 9.22s | Train NLL -7.073 | Val NLL -8.502 | LR 1.80e-03
# Epoch 179 | Time 12.50s | Train NLL -8.672 | Val NLL -9.680 | LR 1.78e-03
# Epoch 180 | Time 13.12s | Train NLL -7.695 | Val NLL -9.059 | LR 1.75e-03
# Epoch 181 | Time 12.63s | Train NLL -6.431 | Val NLL -4.150 | LR 1.73e-03
# Epoch 182 | Time 9.38s | Train NLL -3.630 | Val NLL -4.224 | LR 1.70e-03
# Epoch 183 | Time 12.89s | Train NLL -4.906 | Val NLL -5.149 | LR 1.68e-03
# Epoch 184 | Time 13.31s | Train NLL -4.705 | Val NLL -5.780 | LR 1.65e-03
# Epoch 185 | Time 11.75s | Train NLL -5.191 | Val NLL -5.094 | LR 1.63e-03
# Epoch 186 | Time 9.55s | Train NLL -6.290 | Val NLL -7.156 | LR 1.60e-03
# Epoch 187 | Time 13.02s | Train NLL -6.184 | Val NLL -7.214 | LR 1.58e-03
# Epoch 188 | Time 13.13s | Train NLL -7.112 | Val NLL -8.024 | LR 1.55e-03
# Epoch 189 | Time 11.35s | Train NLL -7.263 | Val NLL -7.166 | LR 1.53e-03
# Epoch 190 | Time 11.57s | Train NLL -7.590 | Val NLL -5.661 | LR 1.50e-03
# Epoch 191 | Time 13.03s | Train NLL -7.357 | Val NLL -8.682 | LR 1.48e-03
# Epoch 192 | Time 13.22s | Train NLL -7.517 | Val NLL -7.028 | LR 1.45e-03
# Epoch 193 | Time 10.68s | Train NLL -7.189 | Val NLL -5.432 | LR 1.43e-03
# Epoch 194 | Time 11.44s | Train NLL -7.036 | Val NLL -7.957 | LR 1.41e-03
# Epoch 195 | Time 13.16s | Train NLL -7.388 | Val NLL -6.857 | LR 1.38e-03
# Epoch 196 | Time 13.07s | Train NLL -7.600 | Val NLL -8.971 | LR 1.36e-03
# Epoch 197 | Time 9.33s | Train NLL -7.476 | Val NLL -6.320 | LR 1.34e-03
# Epoch 198 | Time 12.22s | Train NLL -7.809 | Val NLL -8.235 | LR 1.31e-03
# Epoch 199 | Time 13.28s | Train NLL -7.400 | Val NLL -7.428 | LR 1.29e-03
# Epoch 200 | Time 12.99s | Train NLL -7.683 | Val NLL -9.295 | LR 1.27e-03
# Epoch 201 | Time 9.36s | Train NLL -7.331 | Val NLL -8.006 | LR 1.24e-03
# Epoch 202 | Time 13.12s | Train NLL -8.362 | Val NLL -7.619 | LR 1.22e-03
# Epoch 203 | Time 13.20s | Train NLL -7.853 | Val NLL -7.149 | LR 1.20e-03
# Epoch 204 | Time 11.80s | Train NLL -8.028 | Val NLL -6.412 | LR 1.17e-03
# Epoch 205 | Time 10.35s | Train NLL -8.707 | Val NLL -4.694 | LR 1.15e-03
# Epoch 206 | Time 13.05s | Train NLL -7.780 | Val NLL -8.626 | LR 1.13e-03
# Epoch 207 | Time 12.90s | Train NLL -8.787 | Val NLL -9.883 | LR 1.11e-03
# Epoch 208 | Time 11.97s | Train NLL -8.429 | Val NLL -8.703 | LR 1.08e-03
# Epoch 209 | Time 10.28s | Train NLL -8.518 | Val NLL -8.626 | LR 1.06e-03
# Epoch 210 | Time 13.15s | Train NLL -8.744 | Val NLL -9.555 | LR 1.04e-03
# Epoch 211 | Time 13.15s | Train NLL -8.693 | Val NLL -7.935 | LR 1.02e-03
# Epoch 212 | Time 11.25s | Train NLL -8.021 | Val NLL -8.078 | LR 9.98e-04
# Epoch 213 | Time 10.72s | Train NLL -8.047 | Val NLL -8.388 | LR 9.77e-04
# Epoch 214 | Time 13.13s | Train NLL -8.880 | Val NLL -8.354 | LR 9.56e-04
# Epoch 215 | Time 13.00s | Train NLL -8.718 | Val NLL -9.514 | LR 9.35e-04
# Epoch 216 | Time 9.75s | Train NLL -8.242 | Val NLL -8.962 | LR 9.15e-04
# Epoch 217 | Time 11.55s | Train NLL -8.713 | Val NLL -7.460 | LR 8.94e-04
# Epoch 218 | Time 13.13s | Train NLL -9.029 | Val NLL -8.901 | LR 8.74e-04
# Epoch 219 | Time 13.05s | Train NLL -8.319 | Val NLL -8.054 | LR 8.54e-04
# Epoch 220 | Time 9.03s | Train NLL -8.760 | Val NLL -10.296 | LR 8.34e-04
# Epoch 221 | Time 12.52s | Train NLL -8.711 | Val NLL -9.048 | LR 8.14e-04
# Epoch 222 | Time 12.88s | Train NLL -8.434 | Val NLL -8.945 | LR 7.94e-04
# Epoch 223 | Time 12.38s | Train NLL -9.648 | Val NLL -4.948 | LR 7.75e-04
# Epoch 224 | Time 9.68s | Train NLL -8.923 | Val NLL -9.690 | LR 7.56e-04
# Epoch 225 | Time 13.10s | Train NLL -8.959 | Val NLL -6.616 | LR 7.37e-04
# Epoch 226 | Time 12.80s | Train NLL -9.722 | Val NLL -9.683 | LR 7.18e-04
# Epoch 227 | Time 10.53s | Train NLL -9.962 | Val NLL -9.318 | LR 7.00e-04
# Epoch 228 | Time 11.27s | Train NLL -9.470 | Val NLL -10.960 | LR 6.81e-04
# Epoch 229 | Time 13.53s | Train NLL -10.341 | Val NLL -10.857 | LR 6.63e-04
# Epoch 230 | Time 12.92s | Train NLL -10.366 | Val NLL -10.591 | LR 6.45e-04
# Epoch 231 | Time 11.00s | Train NLL -10.732 | Val NLL -9.230 | LR 6.27e-04
# Epoch 232 | Time 11.18s | Train NLL -10.194 | Val NLL -10.699 | LR 6.10e-04
# Epoch 233 | Time 13.13s | Train NLL -10.871 | Val NLL -8.787 | LR 5.93e-04
# Epoch 234 | Time 12.55s | Train NLL -10.688 | Val NLL -11.203 | LR 5.75e-04
# Epoch 235 | Time 9.72s | Train NLL -10.947 | Val NLL -11.341 | LR 5.59e-04
# Epoch 236 | Time 13.08s | Train NLL -11.182 | Val NLL -11.583 | LR 5.42e-04
# Epoch 237 | Time 13.25s | Train NLL -11.006 | Val NLL -11.021 | LR 5.25e-04
# Epoch 238 | Time 11.45s | Train NLL -10.762 | Val NLL -9.979 | LR 5.09e-04
# Epoch 239 | Time 11.22s | Train NLL -11.366 | Val NLL -10.924 | LR 4.93e-04
# Epoch 240 | Time 12.90s | Train NLL -11.026 | Val NLL -11.645 | LR 4.77e-04
# Epoch 241 | Time 13.23s | Train NLL -11.093 | Val NLL -10.713 | LR 4.62e-04
# Epoch 242 | Time 10.30s | Train NLL -10.557 | Val NLL -11.178 | LR 4.47e-04
# Epoch 243 | Time 12.28s | Train NLL -9.919 | Val NLL -0.587 | LR 4.32e-04
# Epoch 244 | Time 12.90s | Train NLL -9.123 | Val NLL -10.910 | LR 4.17e-04
# Epoch 245 | Time 12.37s | Train NLL -9.984 | Val NLL -6.592 | LR 4.02e-04
# Epoch 246 | Time 9.10s | Train NLL -10.841 | Val NLL -11.103 | LR 3.88e-04
# Epoch 247 | Time 12.27s | Train NLL -11.148 | Val NLL -10.831 | LR 3.74e-04
# Epoch 248 | Time 13.01s | Train NLL -10.033 | Val NLL -9.786 | LR 3.60e-04
# Epoch 249 | Time 13.11s | Train NLL -11.523 | Val NLL -11.764 | LR 3.46e-04
# Epoch 250 | Time 9.40s | Train NLL -11.858 | Val NLL -12.093 | LR 3.33e-04
# Epoch 251 | Time 12.45s | Train NLL -11.678 | Val NLL -12.344 | LR 3.20e-04
# Epoch 252 | Time 13.05s | Train NLL -11.166 | Val NLL -11.934 | LR 3.07e-04
# Epoch 253 | Time 13.09s | Train NLL -10.491 | Val NLL -11.802 | LR 2.94e-04
# Epoch 254 | Time 10.42s | Train NLL -10.896 | Val NLL -12.261 | LR 2.82e-04
# Epoch 255 | Time 11.90s | Train NLL -10.844 | Val NLL -12.066 | LR 2.69e-04
# Epoch 256 | Time 13.18s | Train NLL -11.921 | Val NLL -7.173 | LR 2.58e-04
# Epoch 257 | Time 12.95s | Train NLL -10.856 | Val NLL -12.482 | LR 2.46e-04
# Epoch 258 | Time 9.20s | Train NLL -12.344 | Val NLL -12.261 | LR 2.35e-04
# Epoch 259 | Time 12.73s | Train NLL -12.425 | Val NLL -10.703 | LR 2.23e-04
# Epoch 260 | Time 13.11s | Train NLL -12.459 | Val NLL -12.057 | LR 2.13e-04
# Epoch 261 | Time 12.50s | Train NLL -12.813 | Val NLL -13.302 | LR 2.02e-04
# Epoch 262 | Time 10.56s | Train NLL -11.681 | Val NLL -13.204 | LR 1.92e-04
# Epoch 263 | Time 13.12s | Train NLL -12.810 | Val NLL -12.680 | LR 1.81e-04
# Epoch 264 | Time 12.98s | Train NLL -11.266 | Val NLL -13.356 | LR 1.72e-04
# Epoch 265 | Time 10.48s | Train NLL -12.393 | Val NLL -13.084 | LR 1.62e-04
# Epoch 266 | Time 11.36s | Train NLL -11.272 | Val NLL -13.130 | LR 1.53e-04
# Epoch 267 | Time 12.90s | Train NLL -11.389 | Val NLL -12.446 | LR 1.44e-04
# Epoch 268 | Time 13.00s | Train NLL -13.044 | Val NLL -12.908 | LR 1.35e-04
# Epoch 269 | Time 9.70s | Train NLL -13.441 | Val NLL -13.220 | LR 1.27e-04
# Epoch 270 | Time 12.86s | Train NLL -13.509 | Val NLL -12.969 | LR 1.18e-04
# Epoch 271 | Time 12.95s | Train NLL -13.679 | Val NLL -14.054 | LR 1.10e-04
# Epoch 272 | Time 10.79s | Train NLL -12.563 | Val NLL -13.633 | LR 1.03e-04
# Epoch 273 | Time 11.15s | Train NLL -13.738 | Val NLL -14.005 | LR 9.52e-05
# Epoch 274 | Time 13.08s | Train NLL -13.552 | Val NLL -13.485 | LR 8.81e-05
# Epoch 275 | Time 13.23s | Train NLL -14.184 | Val NLL -14.305 | LR 8.12e-05
# Epoch 276 | Time 9.28s | Train NLL -13.645 | Val NLL -14.363 | LR 7.46e-05
# Epoch 277 | Time 12.65s | Train NLL -14.156 | Val NLL -13.869 | LR 6.83e-05
# Epoch 278 | Time 12.93s | Train NLL -12.076 | Val NLL -14.065 | LR 6.23e-05
# Epoch 279 | Time 13.07s | Train NLL -14.529 | Val NLL -14.337 | LR 5.65e-05
# Epoch 280 | Time 9.03s | Train NLL -14.749 | Val NLL -14.287 | LR 5.10e-05
# Epoch 281 | Time 13.35s | Train NLL -14.792 | Val NLL -14.684 | LR 4.58e-05
# Epoch 282 | Time 13.15s | Train NLL -14.897 | Val NLL -14.683 | LR 4.09e-05
# Epoch 283 | Time 10.48s | Train NLL -13.765 | Val NLL -13.864 | LR 3.62e-05
# Epoch 284 | Time 11.50s | Train NLL -13.867 | Val NLL -14.596 | LR 3.18e-05
# Epoch 285 | Time 13.06s | Train NLL -15.288 | Val NLL -14.748 | LR 2.77e-05
# Epoch 286 | Time 13.28s | Train NLL -15.380 | Val NLL -15.173 | LR 2.39e-05
# Epoch 287 | Time 9.28s | Train NLL -15.455 | Val NLL -15.150 | LR 2.04e-05
# Epoch 288 | Time 12.30s | Train NLL -15.567 | Val NLL -15.292 | LR 1.71e-05
# Epoch 289 | Time 13.27s | Train NLL -15.657 | Val NLL -14.880 | LR 1.42e-05
# Epoch 290 | Time 12.74s | Train NLL -15.679 | Val NLL -15.460 | LR 1.15e-05
# Epoch 291 | Time 9.92s | Train NLL -15.780 | Val NLL -15.492 | LR 9.07e-06
# Epoch 292 | Time 12.97s | Train NLL -15.841 | Val NLL -15.395 | LR 6.94e-06
# Epoch 293 | Time 12.35s | Train NLL -15.871 | Val NLL -15.566 | LR 5.10e-06
# Epoch 294 | Time 9.95s | Train NLL -15.907 | Val NLL -15.574 | LR 3.54e-06
# Epoch 295 | Time 13.28s | Train NLL -15.926 | Val NLL -15.599 | LR 2.27e-06
# Epoch 296 | Time 13.17s | Train NLL -15.937 | Val NLL -15.607 | LR 1.28e-06
# Epoch 297 | Time 10.88s | Train NLL -15.935 | Val NLL -15.612 | LR 5.67e-07
# Epoch 298 | Time 11.44s | Train NLL -15.953 | Val NLL -15.614 | LR 1.42e-07
# Epoch 299 | Time 13.26s | Train NLL -15.956 | Val NLL -15.615 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 15351099.00
# Average absolute difference in CASUALTIES: 0.01

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
