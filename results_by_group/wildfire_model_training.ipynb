# %% [markdown]
# # Wildfire model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Wildfire'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 0.89s | Train NLL 8.772 | Val NLL 7.423 | LR 1.00e-03
# Epoch 001 | Time 0.48s | Train NLL 4.719 | Val NLL 2.782 | LR 2.00e-03
# Epoch 002 | Time 0.36s | Train NLL 2.759 | Val NLL 2.260 | LR 3.00e-03
# Epoch 003 | Time 0.35s | Train NLL 1.436 | Val NLL 0.862 | LR 4.00e-03
# Epoch 004 | Time 0.52s | Train NLL 1.080 | Val NLL 0.758 | LR 5.00e-03
# Epoch 005 | Time 0.27s | Train NLL 0.304 | Val NLL 0.755 | LR 5.00e-03
# Epoch 006 | Time 0.23s | Train NLL 0.491 | Val NLL 1.026 | LR 5.00e-03
# Epoch 007 | Time 0.27s | Train NLL 0.011 | Val NLL -0.121 | LR 5.00e-03
# Epoch 008 | Time 0.24s | Train NLL -0.631 | Val NLL -0.919 | LR 5.00e-03
# Epoch 009 | Time 0.24s | Train NLL -1.421 | Val NLL -1.688 | LR 5.00e-03
# Epoch 010 | Time 0.23s | Train NLL 0.707 | Val NLL 0.031 | LR 4.99e-03
# Epoch 011 | Time 0.25s | Train NLL -0.614 | Val NLL -0.189 | LR 4.99e-03
# Epoch 012 | Time 0.25s | Train NLL -0.234 | Val NLL -0.102 | LR 4.99e-03
# Epoch 013 | Time 0.23s | Train NLL -0.704 | Val NLL -0.830 | LR 4.99e-03
# Epoch 014 | Time 0.27s | Train NLL -1.425 | Val NLL -1.374 | LR 4.99e-03
# Epoch 015 | Time 0.26s | Train NLL -0.631 | Val NLL -0.351 | LR 4.98e-03
# Epoch 016 | Time 0.21s | Train NLL -0.897 | Val NLL 1.200 | LR 4.98e-03
# Epoch 017 | Time 0.19s | Train NLL 0.231 | Val NLL -0.577 | LR 4.98e-03
# Epoch 018 | Time 0.19s | Train NLL -0.906 | Val NLL 0.154 | LR 4.97e-03
# Epoch 019 | Time 0.19s | Train NLL -0.383 | Val NLL -0.773 | LR 4.97e-03
# Epoch 020 | Time 0.23s | Train NLL -1.170 | Val NLL -1.289 | LR 4.96e-03
# Epoch 021 | Time 0.34s | Train NLL -1.677 | Val NLL -1.813 | LR 4.96e-03
# Epoch 022 | Time 0.24s | Train NLL -2.449 | Val NLL -2.442 | LR 4.95e-03
# Epoch 023 | Time 0.25s | Train NLL -1.453 | Val NLL -2.758 | LR 4.95e-03
# Epoch 024 | Time 0.18s | Train NLL 0.779 | Val NLL 1.173 | LR 4.94e-03
# Epoch 025 | Time 0.30s | Train NLL 0.961 | Val NLL 1.594 | LR 4.94e-03
# Epoch 026 | Time 0.26s | Train NLL 1.059 | Val NLL 0.578 | LR 4.93e-03
# Epoch 027 | Time 0.21s | Train NLL -0.032 | Val NLL -0.692 | LR 4.93e-03
# Epoch 028 | Time 0.23s | Train NLL -1.401 | Val NLL -1.937 | LR 4.92e-03
# Epoch 029 | Time 0.17s | Train NLL -2.540 | Val NLL 0.957 | LR 4.91e-03
# Epoch 030 | Time 0.19s | Train NLL 0.413 | Val NLL -0.686 | LR 4.90e-03
# Epoch 031 | Time 0.17s | Train NLL -1.239 | Val NLL -0.771 | LR 4.90e-03
# Epoch 032 | Time 0.22s | Train NLL -1.665 | Val NLL -2.435 | LR 4.89e-03
# Epoch 033 | Time 0.19s | Train NLL -2.746 | Val NLL -2.330 | LR 4.88e-03
# Epoch 034 | Time 0.20s | Train NLL -2.768 | Val NLL 1.429 | LR 4.87e-03
# Epoch 035 | Time 0.19s | Train NLL -0.275 | Val NLL -2.204 | LR 4.86e-03
# Epoch 036 | Time 0.19s | Train NLL -0.317 | Val NLL 0.027 | LR 4.86e-03
# Epoch 037 | Time 0.20s | Train NLL -0.378 | Val NLL -0.514 | LR 4.85e-03
# Epoch 038 | Time 0.30s | Train NLL -1.444 | Val NLL -0.458 | LR 4.84e-03
# Epoch 039 | Time 0.23s | Train NLL -1.389 | Val NLL -2.363 | LR 4.83e-03
# Epoch 040 | Time 0.19s | Train NLL -1.539 | Val NLL -1.594 | LR 4.82e-03
# Epoch 041 | Time 0.19s | Train NLL -2.197 | Val NLL -0.857 | LR 4.81e-03
# Epoch 042 | Time 0.20s | Train NLL -1.122 | Val NLL -1.191 | LR 4.80e-03
# Epoch 043 | Time 0.24s | Train NLL -2.234 | Val NLL -2.877 | LR 4.79e-03
# Epoch 044 | Time 0.21s | Train NLL -2.551 | Val NLL -1.212 | LR 4.78e-03
# Epoch 045 | Time 0.26s | Train NLL -1.949 | Val NLL -1.676 | LR 4.77e-03
# Epoch 046 | Time 0.27s | Train NLL -1.510 | Val NLL -0.325 | LR 4.75e-03
# Epoch 047 | Time 0.34s | Train NLL 3.546 | Val NLL 4.964 | LR 4.74e-03
# Epoch 048 | Time 0.29s | Train NLL 3.624 | Val NLL 3.020 | LR 4.73e-03
# Epoch 049 | Time 0.33s | Train NLL 2.565 | Val NLL 2.079 | LR 4.72e-03
# Epoch 050 | Time 0.33s | Train NLL 1.257 | Val NLL 0.563 | LR 4.71e-03
# Epoch 051 | Time 0.24s | Train NLL -0.610 | Val NLL -1.470 | LR 4.69e-03
# Epoch 052 | Time 0.19s | Train NLL -1.200 | Val NLL -2.014 | LR 4.68e-03
# Epoch 053 | Time 0.21s | Train NLL -0.998 | Val NLL -0.916 | LR 4.67e-03
# Epoch 054 | Time 0.23s | Train NLL -1.797 | Val NLL -0.078 | LR 4.65e-03
# Epoch 055 | Time 0.27s | Train NLL -1.484 | Val NLL 0.763 | LR 4.64e-03
# Epoch 056 | Time 0.33s | Train NLL 1.736 | Val NLL 3.337 | LR 4.63e-03
# Epoch 057 | Time 0.30s | Train NLL 2.202 | Val NLL 0.465 | LR 4.61e-03
# Epoch 058 | Time 0.32s | Train NLL -0.154 | Val NLL -0.420 | LR 4.60e-03
# Epoch 059 | Time 0.28s | Train NLL -0.964 | Val NLL -0.502 | LR 4.58e-03
# Epoch 060 | Time 0.25s | Train NLL -1.312 | Val NLL -1.854 | LR 4.57e-03
# Epoch 061 | Time 0.24s | Train NLL -2.213 | Val NLL 1.227 | LR 4.55e-03
# Epoch 062 | Time 0.21s | Train NLL -0.060 | Val NLL -1.221 | LR 4.54e-03
# Epoch 063 | Time 0.22s | Train NLL -0.491 | Val NLL -0.717 | LR 4.52e-03
# Epoch 064 | Time 0.22s | Train NLL -1.004 | Val NLL -2.059 | LR 4.51e-03
# Epoch 065 | Time 0.22s | Train NLL -1.481 | Val NLL -2.254 | LR 4.49e-03
# Epoch 066 | Time 0.25s | Train NLL 0.448 | Val NLL 1.740 | LR 4.47e-03
# Epoch 067 | Time 0.25s | Train NLL 1.544 | Val NLL 1.931 | LR 4.46e-03
# Epoch 068 | Time 0.26s | Train NLL 0.557 | Val NLL 0.173 | LR 4.44e-03
# Epoch 069 | Time 0.20s | Train NLL 0.288 | Val NLL 0.217 | LR 4.42e-03
# Epoch 070 | Time 0.36s | Train NLL -1.119 | Val NLL 0.915 | LR 4.41e-03
# Epoch 071 | Time 0.30s | Train NLL -0.392 | Val NLL 0.591 | LR 4.39e-03
# Epoch 072 | Time 0.30s | Train NLL 0.773 | Val NLL 1.507 | LR 4.37e-03
# Epoch 073 | Time 0.35s | Train NLL 0.414 | Val NLL -0.622 | LR 4.35e-03
# Epoch 074 | Time 0.29s | Train NLL -1.104 | Val NLL -0.876 | LR 4.34e-03
# Epoch 075 | Time 0.27s | Train NLL -1.820 | Val NLL -2.912 | LR 4.32e-03
# Epoch 076 | Time 0.27s | Train NLL -3.297 | Val NLL -2.553 | LR 4.30e-03
# Epoch 077 | Time 0.26s | Train NLL -3.276 | Val NLL -1.411 | LR 4.28e-03
# Epoch 078 | Time 0.28s | Train NLL -1.140 | Val NLL -2.157 | LR 4.26e-03
# Epoch 079 | Time 0.29s | Train NLL -2.536 | Val NLL -2.532 | LR 4.24e-03
# Epoch 080 | Time 0.37s | Train NLL -2.864 | Val NLL -3.209 | LR 4.22e-03
# Epoch 081 | Time 0.32s | Train NLL -3.744 | Val NLL -3.616 | LR 4.21e-03
# Epoch 082 | Time 0.28s | Train NLL -3.302 | Val NLL -2.121 | LR 4.19e-03
# Epoch 083 | Time 0.28s | Train NLL -3.222 | Val NLL -2.505 | LR 4.17e-03
# Epoch 084 | Time 0.27s | Train NLL -2.354 | Val NLL 0.222 | LR 4.15e-03
# Epoch 085 | Time 0.42s | Train NLL -0.186 | Val NLL -0.154 | LR 4.13e-03
# Epoch 086 | Time 0.25s | Train NLL -0.938 | Val NLL -1.699 | LR 4.11e-03
# Epoch 087 | Time 0.24s | Train NLL -2.358 | Val NLL -2.444 | LR 4.09e-03
# Epoch 088 | Time 0.22s | Train NLL -2.578 | Val NLL -1.670 | LR 4.06e-03
# Epoch 089 | Time 0.21s | Train NLL -2.499 | Val NLL -2.621 | LR 4.04e-03
# Epoch 090 | Time 0.20s | Train NLL -3.181 | Val NLL -1.960 | LR 4.02e-03
# Epoch 091 | Time 0.20s | Train NLL -2.474 | Val NLL -3.159 | LR 4.00e-03
# Epoch 092 | Time 0.22s | Train NLL -3.230 | Val NLL -3.454 | LR 3.98e-03
# Epoch 093 | Time 0.23s | Train NLL -2.726 | Val NLL -1.286 | LR 3.96e-03
# Epoch 094 | Time 0.22s | Train NLL -2.062 | Val NLL -2.075 | LR 3.94e-03
# Epoch 095 | Time 0.26s | Train NLL -3.345 | Val NLL -3.911 | LR 3.92e-03
# Epoch 096 | Time 0.24s | Train NLL -3.090 | Val NLL -2.929 | LR 3.89e-03
# Epoch 097 | Time 0.24s | Train NLL -3.486 | Val NLL -3.633 | LR 3.87e-03
# Epoch 098 | Time 0.25s | Train NLL -3.731 | Val NLL -3.753 | LR 3.85e-03
# Epoch 099 | Time 0.27s | Train NLL -4.061 | Val NLL -4.226 | LR 3.83e-03
# Epoch 100 | Time 0.29s | Train NLL -3.917 | Val NLL -4.577 | LR 3.80e-03
# Epoch 101 | Time 0.23s | Train NLL -2.697 | Val NLL 0.550 | LR 3.78e-03
# Epoch 102 | Time 0.24s | Train NLL -1.539 | Val NLL -1.477 | LR 3.76e-03
# Epoch 103 | Time 0.24s | Train NLL -0.809 | Val NLL -0.602 | LR 3.73e-03
# Epoch 104 | Time 0.26s | Train NLL -0.606 | Val NLL -1.094 | LR 3.71e-03
# Epoch 105 | Time 0.24s | Train NLL -1.799 | Val NLL -2.190 | LR 3.69e-03
# Epoch 106 | Time 0.22s | Train NLL -2.747 | Val NLL -1.705 | LR 3.66e-03
# Epoch 107 | Time 0.23s | Train NLL -2.160 | Val NLL -2.048 | LR 3.64e-03
# Epoch 108 | Time 0.23s | Train NLL -3.439 | Val NLL -2.191 | LR 3.62e-03
# Epoch 109 | Time 0.23s | Train NLL -3.471 | Val NLL -2.667 | LR 3.59e-03
# Epoch 110 | Time 0.23s | Train NLL -2.883 | Val NLL -2.831 | LR 3.57e-03
# Epoch 111 | Time 0.25s | Train NLL -3.792 | Val NLL -4.218 | LR 3.55e-03
# Epoch 112 | Time 0.23s | Train NLL -2.244 | Val NLL -0.861 | LR 3.52e-03
# Epoch 113 | Time 0.26s | Train NLL -0.466 | Val NLL -0.147 | LR 3.50e-03
# Epoch 114 | Time 0.24s | Train NLL -0.157 | Val NLL -0.862 | LR 3.47e-03
# Epoch 115 | Time 0.23s | Train NLL -1.324 | Val NLL -1.268 | LR 3.45e-03
# Epoch 116 | Time 0.24s | Train NLL -2.057 | Val NLL -2.287 | LR 3.42e-03
# Epoch 117 | Time 0.22s | Train NLL -3.135 | Val NLL -3.462 | LR 3.40e-03
# Epoch 118 | Time 0.22s | Train NLL -4.266 | Val NLL -4.388 | LR 3.37e-03
# Epoch 119 | Time 0.22s | Train NLL -5.242 | Val NLL -1.268 | LR 3.35e-03
# Epoch 120 | Time 0.22s | Train NLL -2.525 | Val NLL -2.460 | LR 3.32e-03
# Epoch 121 | Time 0.24s | Train NLL -0.912 | Val NLL -0.861 | LR 3.30e-03
# Epoch 122 | Time 0.24s | Train NLL -0.440 | Val NLL -0.739 | LR 3.27e-03
# Epoch 123 | Time 0.26s | Train NLL -2.132 | Val NLL -1.991 | LR 3.25e-03
# Epoch 124 | Time 0.24s | Train NLL -2.670 | Val NLL -2.899 | LR 3.22e-03
# Epoch 125 | Time 0.23s | Train NLL -3.671 | Val NLL -3.914 | LR 3.20e-03
# Epoch 126 | Time 0.23s | Train NLL -4.172 | Val NLL -2.698 | LR 3.17e-03
# Epoch 127 | Time 0.23s | Train NLL -2.721 | Val NLL -2.474 | LR 3.14e-03
# Epoch 128 | Time 0.24s | Train NLL -3.474 | Val NLL -3.513 | LR 3.12e-03
# Epoch 129 | Time 0.24s | Train NLL -3.111 | Val NLL -3.706 | LR 3.09e-03
# Epoch 130 | Time 0.25s | Train NLL -3.596 | Val NLL -2.014 | LR 3.07e-03
# Epoch 131 | Time 0.25s | Train NLL -2.807 | Val NLL -3.495 | LR 3.04e-03
# Epoch 132 | Time 0.27s | Train NLL -2.163 | Val NLL -1.511 | LR 3.02e-03
# Epoch 133 | Time 0.27s | Train NLL -2.510 | Val NLL -2.457 | LR 2.99e-03
# Epoch 134 | Time 0.27s | Train NLL -3.298 | Val NLL -3.307 | LR 2.96e-03
# Epoch 135 | Time 0.25s | Train NLL -3.571 | Val NLL -4.129 | LR 2.94e-03
# Epoch 136 | Time 0.25s | Train NLL -4.356 | Val NLL -1.540 | LR 2.91e-03
# Epoch 137 | Time 0.25s | Train NLL -2.249 | Val NLL -2.524 | LR 2.88e-03
# Epoch 138 | Time 0.30s | Train NLL -3.039 | Val NLL -2.657 | LR 2.86e-03
# Epoch 139 | Time 0.24s | Train NLL -3.845 | Val NLL -3.701 | LR 2.83e-03
# Epoch 140 | Time 0.24s | Train NLL -3.760 | Val NLL -1.489 | LR 2.81e-03
# Epoch 141 | Time 0.24s | Train NLL -2.744 | Val NLL -2.177 | LR 2.78e-03
# Epoch 142 | Time 0.24s | Train NLL -2.334 | Val NLL -1.125 | LR 2.75e-03
# Epoch 143 | Time 0.23s | Train NLL -1.851 | Val NLL -1.723 | LR 2.73e-03
# Epoch 144 | Time 0.23s | Train NLL -2.273 | Val NLL -2.974 | LR 2.70e-03
# Epoch 145 | Time 0.23s | Train NLL -2.947 | Val NLL -1.191 | LR 2.67e-03
# Epoch 146 | Time 0.22s | Train NLL -2.426 | Val NLL -3.237 | LR 2.65e-03
# Epoch 147 | Time 0.22s | Train NLL -3.152 | Val NLL -3.960 | LR 2.62e-03
# Epoch 148 | Time 0.23s | Train NLL -2.690 | Val NLL -1.314 | LR 2.59e-03
# Epoch 149 | Time 0.21s | Train NLL -2.355 | Val NLL -2.433 | LR 2.57e-03
# Epoch 150 | Time 0.23s | Train NLL -3.432 | Val NLL -3.993 | LR 2.54e-03
# Epoch 151 | Time 0.22s | Train NLL -4.054 | Val NLL -4.319 | LR 2.51e-03
# Epoch 152 | Time 0.22s | Train NLL -4.530 | Val NLL -3.811 | LR 2.49e-03
# Epoch 153 | Time 0.24s | Train NLL -4.381 | Val NLL -3.537 | LR 2.46e-03
# Epoch 154 | Time 0.22s | Train NLL -4.267 | Val NLL -2.146 | LR 2.43e-03
# Epoch 155 | Time 0.22s | Train NLL -0.950 | Val NLL 0.188 | LR 2.41e-03
# Epoch 156 | Time 0.22s | Train NLL -0.708 | Val NLL -0.538 | LR 2.38e-03
# Epoch 157 | Time 0.22s | Train NLL -1.993 | Val NLL -2.204 | LR 2.35e-03
# Epoch 158 | Time 0.22s | Train NLL -3.053 | Val NLL -2.912 | LR 2.33e-03
# Epoch 159 | Time 0.26s | Train NLL -3.871 | Val NLL -4.635 | LR 2.30e-03
# Epoch 160 | Time 0.24s | Train NLL -4.491 | Val NLL -2.268 | LR 2.27e-03
# Epoch 161 | Time 0.24s | Train NLL -1.133 | Val NLL -1.617 | LR 2.25e-03
# Epoch 162 | Time 0.23s | Train NLL -2.583 | Val NLL -3.501 | LR 2.22e-03
# Epoch 163 | Time 0.25s | Train NLL -4.120 | Val NLL -4.342 | LR 2.19e-03
# Epoch 164 | Time 0.25s | Train NLL -3.324 | Val NLL -2.177 | LR 2.17e-03
# Epoch 165 | Time 0.24s | Train NLL -2.957 | Val NLL -2.421 | LR 2.14e-03
# Epoch 166 | Time 0.23s | Train NLL -3.324 | Val NLL -3.234 | LR 2.12e-03
# Epoch 167 | Time 0.23s | Train NLL -3.987 | Val NLL -4.082 | LR 2.09e-03
# Epoch 168 | Time 0.24s | Train NLL -4.504 | Val NLL -4.834 | LR 2.06e-03
# Epoch 169 | Time 0.26s | Train NLL -5.044 | Val NLL -5.043 | LR 2.04e-03
# Epoch 170 | Time 0.38s | Train NLL -5.344 | Val NLL -5.165 | LR 2.01e-03
# Epoch 171 | Time 0.25s | Train NLL -5.468 | Val NLL -5.621 | LR 1.98e-03
# Epoch 172 | Time 0.24s | Train NLL -5.749 | Val NLL -5.860 | LR 1.96e-03
# Epoch 173 | Time 0.23s | Train NLL -3.588 | Val NLL -2.285 | LR 1.93e-03
# Epoch 174 | Time 0.23s | Train NLL -2.522 | Val NLL -2.581 | LR 1.91e-03
# Epoch 175 | Time 0.21s | Train NLL -3.320 | Val NLL -4.567 | LR 1.88e-03
# Epoch 176 | Time 0.22s | Train NLL -3.459 | Val NLL -3.376 | LR 1.86e-03
# Epoch 177 | Time 0.22s | Train NLL -2.413 | Val NLL -2.008 | LR 1.83e-03
# Epoch 178 | Time 0.25s | Train NLL -2.342 | Val NLL -2.146 | LR 1.80e-03
# Epoch 179 | Time 0.22s | Train NLL -2.612 | Val NLL -2.721 | LR 1.78e-03
# Epoch 180 | Time 0.22s | Train NLL -3.279 | Val NLL -3.158 | LR 1.75e-03
# Epoch 181 | Time 0.24s | Train NLL -3.739 | Val NLL -3.865 | LR 1.73e-03
# Epoch 182 | Time 0.23s | Train NLL -4.365 | Val NLL -4.576 | LR 1.70e-03
# Epoch 183 | Time 0.21s | Train NLL -5.139 | Val NLL -4.834 | LR 1.68e-03
# Epoch 184 | Time 0.23s | Train NLL -4.599 | Val NLL -1.827 | LR 1.65e-03
# Epoch 185 | Time 0.22s | Train NLL -2.174 | Val NLL -2.867 | LR 1.63e-03
# Epoch 186 | Time 0.22s | Train NLL -4.527 | Val NLL -2.296 | LR 1.60e-03
# Epoch 187 | Time 0.22s | Train NLL -4.193 | Val NLL -5.679 | LR 1.58e-03
# Epoch 188 | Time 0.23s | Train NLL -5.797 | Val NLL -4.094 | LR 1.55e-03
# Epoch 189 | Time 0.21s | Train NLL -3.351 | Val NLL -2.679 | LR 1.53e-03
# Epoch 190 | Time 0.23s | Train NLL -3.783 | Val NLL -4.070 | LR 1.50e-03
# Epoch 191 | Time 0.23s | Train NLL -4.796 | Val NLL -4.066 | LR 1.48e-03
# Epoch 192 | Time 0.21s | Train NLL -5.186 | Val NLL -5.613 | LR 1.45e-03
# Epoch 193 | Time 0.22s | Train NLL -5.372 | Val NLL -5.041 | LR 1.43e-03
# Epoch 194 | Time 0.22s | Train NLL -5.174 | Val NLL -4.419 | LR 1.41e-03
# Epoch 195 | Time 0.23s | Train NLL -5.403 | Val NLL -5.146 | LR 1.38e-03
# Epoch 196 | Time 0.23s | Train NLL -5.440 | Val NLL -4.224 | LR 1.36e-03
# Epoch 197 | Time 0.25s | Train NLL -5.421 | Val NLL -5.036 | LR 1.34e-03
# Epoch 198 | Time 0.24s | Train NLL -4.623 | Val NLL -3.239 | LR 1.31e-03
# Epoch 199 | Time 0.22s | Train NLL -4.586 | Val NLL -4.419 | LR 1.29e-03
# Epoch 200 | Time 0.23s | Train NLL -5.851 | Val NLL -1.790 | LR 1.27e-03
# Epoch 201 | Time 0.22s | Train NLL -2.309 | Val NLL -2.218 | LR 1.24e-03
# Epoch 202 | Time 0.22s | Train NLL -1.407 | Val NLL -0.741 | LR 1.22e-03
# Epoch 203 | Time 0.22s | Train NLL -1.969 | Val NLL -2.476 | LR 1.20e-03
# Epoch 204 | Time 0.21s | Train NLL -2.807 | Val NLL -2.668 | LR 1.17e-03
# Epoch 205 | Time 0.22s | Train NLL -3.438 | Val NLL -3.508 | LR 1.15e-03
# Epoch 206 | Time 0.22s | Train NLL -3.765 | Val NLL -3.586 | LR 1.13e-03
# Epoch 207 | Time 0.26s | Train NLL -4.064 | Val NLL -3.880 | LR 1.11e-03
# Epoch 208 | Time 0.23s | Train NLL -4.349 | Val NLL -4.252 | LR 1.08e-03
# Epoch 209 | Time 0.22s | Train NLL -4.730 | Val NLL -4.569 | LR 1.06e-03
# Epoch 210 | Time 0.21s | Train NLL -4.953 | Val NLL -4.841 | LR 1.04e-03
# Epoch 211 | Time 0.21s | Train NLL -5.353 | Val NLL -5.141 | LR 1.02e-03
# Epoch 212 | Time 0.22s | Train NLL -5.489 | Val NLL -5.042 | LR 9.98e-04
# Epoch 213 | Time 0.22s | Train NLL -4.948 | Val NLL -3.550 | LR 9.77e-04
# Epoch 214 | Time 0.22s | Train NLL -4.129 | Val NLL -5.340 | LR 9.56e-04
# Epoch 215 | Time 0.23s | Train NLL -4.014 | Val NLL -3.135 | LR 9.35e-04
# Epoch 216 | Time 0.22s | Train NLL -4.073 | Val NLL -2.002 | LR 9.15e-04
# Epoch 217 | Time 0.25s | Train NLL -1.893 | Val NLL -1.436 | LR 8.94e-04
# Epoch 218 | Time 0.23s | Train NLL -2.123 | Val NLL -2.555 | LR 8.74e-04
# Epoch 219 | Time 0.23s | Train NLL -3.219 | Val NLL -3.734 | LR 8.54e-04
# Epoch 220 | Time 0.22s | Train NLL -5.033 | Val NLL -4.680 | LR 8.34e-04
# Epoch 221 | Time 0.21s | Train NLL -5.331 | Val NLL -5.220 | LR 8.14e-04
# Epoch 222 | Time 0.23s | Train NLL -5.477 | Val NLL -5.356 | LR 7.94e-04
# Epoch 223 | Time 0.21s | Train NLL -5.752 | Val NLL -5.455 | LR 7.75e-04
# Epoch 224 | Time 0.25s | Train NLL -6.013 | Val NLL -6.104 | LR 7.56e-04
# Epoch 225 | Time 0.22s | Train NLL -5.967 | Val NLL -5.553 | LR 7.37e-04
# Epoch 226 | Time 0.24s | Train NLL -6.073 | Val NLL -6.403 | LR 7.18e-04
# Epoch 227 | Time 0.23s | Train NLL -5.315 | Val NLL -4.737 | LR 7.00e-04
# Epoch 228 | Time 0.22s | Train NLL -5.977 | Val NLL -5.065 | LR 6.81e-04
# Epoch 229 | Time 0.21s | Train NLL -5.459 | Val NLL -4.957 | LR 6.63e-04
# Epoch 230 | Time 0.23s | Train NLL -5.317 | Val NLL -5.160 | LR 6.45e-04
# Epoch 231 | Time 0.23s | Train NLL -5.671 | Val NLL -5.654 | LR 6.27e-04
# Epoch 232 | Time 0.23s | Train NLL -6.131 | Val NLL -6.051 | LR 6.10e-04
# Epoch 233 | Time 0.22s | Train NLL -5.435 | Val NLL -1.847 | LR 5.93e-04
# Epoch 234 | Time 0.22s | Train NLL -2.096 | Val NLL -2.962 | LR 5.75e-04
# Epoch 235 | Time 0.22s | Train NLL -3.416 | Val NLL -1.354 | LR 5.59e-04
# Epoch 236 | Time 0.22s | Train NLL -2.138 | Val NLL -2.871 | LR 5.42e-04
# Epoch 237 | Time 0.26s | Train NLL -3.264 | Val NLL -3.665 | LR 5.25e-04
# Epoch 238 | Time 0.21s | Train NLL -4.082 | Val NLL -4.248 | LR 5.09e-04
# Epoch 239 | Time 0.22s | Train NLL -4.978 | Val NLL -4.888 | LR 4.93e-04
# Epoch 240 | Time 0.21s | Train NLL -5.623 | Val NLL -5.388 | LR 4.77e-04
# Epoch 241 | Time 0.21s | Train NLL -5.995 | Val NLL -5.942 | LR 4.62e-04
# Epoch 242 | Time 0.21s | Train NLL -6.440 | Val NLL -6.147 | LR 4.47e-04
# Epoch 243 | Time 0.21s | Train NLL -6.637 | Val NLL -6.332 | LR 4.32e-04
# Epoch 244 | Time 0.25s | Train NLL -6.927 | Val NLL -6.679 | LR 4.17e-04
# Epoch 245 | Time 0.23s | Train NLL -7.162 | Val NLL -6.902 | LR 4.02e-04
# Epoch 246 | Time 0.25s | Train NLL -7.434 | Val NLL -7.216 | LR 3.88e-04
# Epoch 247 | Time 0.26s | Train NLL -7.708 | Val NLL -7.283 | LR 3.74e-04
# Epoch 248 | Time 0.25s | Train NLL -7.606 | Val NLL -7.412 | LR 3.60e-04
# Epoch 249 | Time 0.25s | Train NLL -7.713 | Val NLL -7.845 | LR 3.46e-04
# Epoch 250 | Time 0.22s | Train NLL -8.058 | Val NLL -7.408 | LR 3.33e-04
# Epoch 251 | Time 0.25s | Train NLL -8.435 | Val NLL -8.351 | LR 3.20e-04
# Epoch 252 | Time 0.22s | Train NLL -8.591 | Val NLL -7.327 | LR 3.07e-04
# Epoch 253 | Time 0.25s | Train NLL -7.651 | Val NLL -5.717 | LR 2.94e-04
# Epoch 254 | Time 0.23s | Train NLL -7.346 | Val NLL -7.133 | LR 2.82e-04
# Epoch 255 | Time 0.35s | Train NLL -7.114 | Val NLL -6.630 | LR 2.69e-04
# Epoch 256 | Time 0.21s | Train NLL -7.299 | Val NLL -5.644 | LR 2.58e-04
# Epoch 257 | Time 0.21s | Train NLL -5.905 | Val NLL -5.802 | LR 2.46e-04
# Epoch 258 | Time 0.21s | Train NLL -6.107 | Val NLL -5.887 | LR 2.35e-04
# Epoch 259 | Time 0.21s | Train NLL -6.546 | Val NLL -6.156 | LR 2.23e-04
# Epoch 260 | Time 0.22s | Train NLL -6.762 | Val NLL -6.653 | LR 2.13e-04
# Epoch 261 | Time 0.22s | Train NLL -7.133 | Val NLL -6.877 | LR 2.02e-04
# Epoch 262 | Time 0.21s | Train NLL -7.461 | Val NLL -7.057 | LR 1.92e-04
# Epoch 263 | Time 0.22s | Train NLL -7.693 | Val NLL -7.287 | LR 1.81e-04
# Epoch 264 | Time 0.22s | Train NLL -7.852 | Val NLL -7.485 | LR 1.72e-04
# Epoch 265 | Time 0.23s | Train NLL -8.024 | Val NLL -7.609 | LR 1.62e-04
# Epoch 266 | Time 0.23s | Train NLL -8.160 | Val NLL -7.728 | LR 1.53e-04
# Epoch 267 | Time 0.22s | Train NLL -8.300 | Val NLL -7.842 | LR 1.44e-04
# Epoch 268 | Time 0.23s | Train NLL -8.378 | Val NLL -7.926 | LR 1.35e-04
# Epoch 269 | Time 0.22s | Train NLL -8.348 | Val NLL -8.022 | LR 1.27e-04
# Epoch 270 | Time 0.21s | Train NLL -8.612 | Val NLL -8.098 | LR 1.18e-04
# Epoch 271 | Time 0.22s | Train NLL -8.588 | Val NLL -8.175 | LR 1.10e-04
# Epoch 272 | Time 0.21s | Train NLL -8.661 | Val NLL -8.247 | LR 1.03e-04
# Epoch 273 | Time 0.21s | Train NLL -8.731 | Val NLL -8.306 | LR 9.52e-05
# Epoch 274 | Time 0.24s | Train NLL -8.840 | Val NLL -8.361 | LR 8.81e-05
# Epoch 275 | Time 0.25s | Train NLL -8.932 | Val NLL -8.430 | LR 8.12e-05
# Epoch 276 | Time 0.26s | Train NLL -8.910 | Val NLL -8.479 | LR 7.46e-05
# Epoch 277 | Time 0.25s | Train NLL -8.998 | Val NLL -8.527 | LR 6.83e-05
# Epoch 278 | Time 0.23s | Train NLL -9.075 | Val NLL -8.571 | LR 6.23e-05
# Epoch 279 | Time 0.25s | Train NLL -9.003 | Val NLL -8.611 | LR 5.65e-05
# Epoch 280 | Time 0.25s | Train NLL -9.065 | Val NLL -8.644 | LR 5.10e-05
# Epoch 281 | Time 0.23s | Train NLL -9.145 | Val NLL -8.678 | LR 4.58e-05
# Epoch 282 | Time 0.23s | Train NLL -9.163 | Val NLL -8.705 | LR 4.09e-05
# Epoch 283 | Time 0.24s | Train NLL -9.274 | Val NLL -8.722 | LR 3.62e-05
# Epoch 284 | Time 0.26s | Train NLL -9.160 | Val NLL -8.746 | LR 3.18e-05
# Epoch 285 | Time 0.25s | Train NLL -9.319 | Val NLL -8.768 | LR 2.77e-05
# Epoch 286 | Time 0.24s | Train NLL -9.170 | Val NLL -8.793 | LR 2.39e-05
# Epoch 287 | Time 0.23s | Train NLL -9.316 | Val NLL -8.812 | LR 2.04e-05
# Epoch 288 | Time 0.24s | Train NLL -9.250 | Val NLL -8.821 | LR 1.71e-05
# Epoch 289 | Time 0.25s | Train NLL -9.317 | Val NLL -8.836 | LR 1.42e-05
# Epoch 290 | Time 0.23s | Train NLL -9.334 | Val NLL -8.844 | LR 1.15e-05
# Epoch 291 | Time 0.23s | Train NLL -9.323 | Val NLL -8.851 | LR 9.07e-06
# Epoch 292 | Time 0.24s | Train NLL -9.426 | Val NLL -8.857 | LR 6.94e-06
# Epoch 293 | Time 0.24s | Train NLL -9.371 | Val NLL -8.861 | LR 5.10e-06
# Epoch 294 | Time 0.25s | Train NLL -9.344 | Val NLL -8.864 | LR 3.54e-06
# Epoch 295 | Time 0.26s | Train NLL -9.326 | Val NLL -8.866 | LR 2.27e-06
# Epoch 296 | Time 0.24s | Train NLL -9.307 | Val NLL -8.867 | LR 1.28e-06
# Epoch 297 | Time 0.26s | Train NLL -9.321 | Val NLL -8.867 | LR 5.67e-07
# Epoch 298 | Time 0.25s | Train NLL -9.268 | Val NLL -8.868 | LR 1.42e-07
# Epoch 299 | Time 0.25s | Train NLL -9.379 | Val NLL -8.868 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 50365444.00
# Average absolute difference in CASUALTIES: 0.59

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
