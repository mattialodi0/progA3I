# %% [markdown]
# # Freeze model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Freeze'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 3.51s | Train NLL 4.119 | Val NLL -0.045 | LR 1.00e-03
# Epoch 001 | Time 3.14s | Train NLL -1.270 | Val NLL -2.896 | LR 2.00e-03
# Epoch 002 | Time 3.09s | Train NLL -1.688 | Val NLL -3.488 | LR 3.00e-03
# Epoch 003 | Time 2.95s | Train NLL -1.216 | Val NLL 0.682 | LR 4.00e-03
# Epoch 004 | Time 2.94s | Train NLL -0.197 | Val NLL -2.146 | LR 5.00e-03
# Epoch 005 | Time 2.81s | Train NLL -0.825 | Val NLL 1.138 | LR 5.00e-03
# Epoch 006 | Time 2.98s | Train NLL -1.493 | Val NLL -4.542 | LR 5.00e-03
# Epoch 007 | Time 2.93s | Train NLL -1.243 | Val NLL -1.504 | LR 5.00e-03
# Epoch 008 | Time 3.14s | Train NLL -2.436 | Val NLL -1.619 | LR 5.00e-03
# Epoch 009 | Time 2.80s | Train NLL -3.171 | Val NLL -4.952 | LR 5.00e-03
# Epoch 010 | Time 2.98s | Train NLL -0.781 | Val NLL 1.190 | LR 4.99e-03
# Epoch 011 | Time 2.95s | Train NLL -1.219 | Val NLL -3.961 | LR 4.99e-03
# Epoch 012 | Time 3.11s | Train NLL -3.521 | Val NLL 0.526 | LR 4.99e-03
# Epoch 013 | Time 3.16s | Train NLL 0.630 | Val NLL 5.659 | LR 4.99e-03
# Epoch 014 | Time 2.96s | Train NLL -0.070 | Val NLL -3.020 | LR 4.99e-03
# Epoch 015 | Time 3.01s | Train NLL -2.284 | Val NLL -3.477 | LR 4.98e-03
# Epoch 016 | Time 2.89s | Train NLL -3.010 | Val NLL -3.587 | LR 4.98e-03
# Epoch 017 | Time 3.10s | Train NLL -3.100 | Val NLL -2.360 | LR 4.98e-03
# Epoch 018 | Time 3.03s | Train NLL -3.964 | Val NLL -6.399 | LR 4.97e-03
# Epoch 019 | Time 2.97s | Train NLL -4.378 | Val NLL -3.252 | LR 4.97e-03
# Epoch 020 | Time 2.99s | Train NLL -3.073 | Val NLL -6.227 | LR 4.96e-03
# Epoch 021 | Time 6.18s | Train NLL -1.886 | Val NLL -2.814 | LR 4.96e-03
# Epoch 022 | Time 3.07s | Train NLL -3.113 | Val NLL -3.731 | LR 4.95e-03
# Epoch 023 | Time 2.66s | Train NLL -3.567 | Val NLL -2.865 | LR 4.95e-03
# Epoch 024 | Time 2.72s | Train NLL -3.537 | Val NLL -5.012 | LR 4.94e-03
# Epoch 025 | Time 2.58s | Train NLL -4.047 | Val NLL -0.648 | LR 4.94e-03
# Epoch 026 | Time 2.77s | Train NLL -3.901 | Val NLL -6.151 | LR 4.93e-03
# Epoch 027 | Time 2.89s | Train NLL -3.385 | Val NLL -4.344 | LR 4.93e-03
# Epoch 028 | Time 2.88s | Train NLL -4.455 | Val NLL -1.405 | LR 4.92e-03
# Epoch 029 | Time 4.10s | Train NLL -3.880 | Val NLL -5.338 | LR 4.91e-03
# Epoch 030 | Time 8.44s | Train NLL -3.628 | Val NLL -5.302 | LR 4.90e-03
# Epoch 031 | Time 6.56s | Train NLL -4.515 | Val NLL -7.069 | LR 4.90e-03
# Epoch 032 | Time 7.37s | Train NLL -5.195 | Val NLL -5.083 | LR 4.89e-03
# Epoch 033 | Time 7.51s | Train NLL -4.777 | Val NLL -4.955 | LR 4.88e-03
# Epoch 034 | Time 6.87s | Train NLL -3.243 | Val NLL -0.806 | LR 4.87e-03
# Epoch 035 | Time 6.89s | Train NLL -4.265 | Val NLL -4.276 | LR 4.86e-03
# Epoch 036 | Time 4.15s | Train NLL -5.157 | Val NLL -3.806 | LR 4.86e-03
# Epoch 037 | Time 5.10s | Train NLL -4.956 | Val NLL -2.074 | LR 4.85e-03
# Epoch 038 | Time 4.08s | Train NLL -3.978 | Val NLL -5.916 | LR 4.84e-03
# Epoch 039 | Time 2.32s | Train NLL -4.090 | Val NLL -5.387 | LR 4.83e-03
# Epoch 040 | Time 2.64s | Train NLL -3.799 | Val NLL -0.526 | LR 4.82e-03
# Epoch 041 | Time 3.17s | Train NLL -0.953 | Val NLL -3.244 | LR 4.81e-03
# Epoch 042 | Time 3.07s | Train NLL -3.290 | Val NLL -3.337 | LR 4.80e-03
# Epoch 043 | Time 3.06s | Train NLL -3.381 | Val NLL -3.266 | LR 4.79e-03
# Epoch 044 | Time 3.05s | Train NLL -2.158 | Val NLL -5.031 | LR 4.78e-03
# Epoch 045 | Time 3.18s | Train NLL -3.526 | Val NLL -3.947 | LR 4.77e-03
# Epoch 046 | Time 3.08s | Train NLL -3.501 | Val NLL -2.300 | LR 4.75e-03
# Epoch 047 | Time 3.62s | Train NLL -2.485 | Val NLL -3.041 | LR 4.74e-03
# Epoch 048 | Time 3.27s | Train NLL -4.342 | Val NLL -2.761 | LR 4.73e-03
# Epoch 049 | Time 3.59s | Train NLL -3.280 | Val NLL -3.539 | LR 4.72e-03
# Epoch 050 | Time 3.76s | Train NLL -4.778 | Val NLL -5.032 | LR 4.71e-03
# Epoch 051 | Time 3.52s | Train NLL -4.211 | Val NLL -2.372 | LR 4.69e-03
# Epoch 052 | Time 3.39s | Train NLL -3.891 | Val NLL -6.258 | LR 4.68e-03
# Epoch 053 | Time 3.52s | Train NLL -4.480 | Val NLL -5.411 | LR 4.67e-03
# Epoch 054 | Time 3.98s | Train NLL -4.190 | Val NLL -6.576 | LR 4.65e-03
# Epoch 055 | Time 3.14s | Train NLL -2.802 | Val NLL -5.312 | LR 4.64e-03
# Epoch 056 | Time 3.09s | Train NLL -4.606 | Val NLL -0.478 | LR 4.63e-03
# Epoch 057 | Time 3.09s | Train NLL -3.838 | Val NLL -3.672 | LR 4.61e-03
# Epoch 058 | Time 3.23s | Train NLL -4.327 | Val NLL -4.264 | LR 4.60e-03
# Epoch 059 | Time 3.59s | Train NLL -4.231 | Val NLL -2.839 | LR 4.58e-03
# Epoch 060 | Time 3.73s | Train NLL -2.754 | Val NLL -4.513 | LR 4.57e-03
# Epoch 061 | Time 6.26s | Train NLL -4.535 | Val NLL -2.150 | LR 4.55e-03
# Epoch 062 | Time 3.87s | Train NLL -3.966 | Val NLL -5.472 | LR 4.54e-03
# Epoch 063 | Time 5.14s | Train NLL -3.072 | Val NLL -3.705 | LR 4.52e-03
# Epoch 064 | Time 5.73s | Train NLL -3.950 | Val NLL -7.175 | LR 4.51e-03
# Epoch 065 | Time 4.52s | Train NLL -5.475 | Val NLL -1.825 | LR 4.49e-03
# Epoch 066 | Time 3.70s | Train NLL -2.823 | Val NLL -3.062 | LR 4.47e-03
# Epoch 067 | Time 6.02s | Train NLL -3.866 | Val NLL -5.927 | LR 4.46e-03
# Epoch 068 | Time 4.00s | Train NLL -5.860 | Val NLL -6.778 | LR 4.44e-03
# Epoch 069 | Time 4.44s | Train NLL -6.248 | Val NLL -2.960 | LR 4.42e-03
# Epoch 070 | Time 4.01s | Train NLL -3.571 | Val NLL -6.796 | LR 4.41e-03
# Epoch 071 | Time 3.70s | Train NLL -6.491 | Val NLL -3.352 | LR 4.39e-03
# Epoch 072 | Time 4.48s | Train NLL -2.069 | Val NLL -2.615 | LR 4.37e-03
# Epoch 073 | Time 5.15s | Train NLL -4.215 | Val NLL -4.628 | LR 4.35e-03
# Epoch 074 | Time 4.08s | Train NLL -5.292 | Val NLL -7.607 | LR 4.34e-03
# Epoch 075 | Time 3.48s | Train NLL -6.012 | Val NLL -4.187 | LR 4.32e-03
# Epoch 076 | Time 3.98s | Train NLL -5.280 | Val NLL -4.537 | LR 4.30e-03
# Epoch 077 | Time 4.00s | Train NLL -6.211 | Val NLL -6.500 | LR 4.28e-03
# Epoch 078 | Time 4.28s | Train NLL -6.297 | Val NLL -6.314 | LR 4.26e-03
# Epoch 079 | Time 3.94s | Train NLL -4.630 | Val NLL -4.940 | LR 4.24e-03
# Epoch 080 | Time 3.74s | Train NLL -5.193 | Val NLL -4.801 | LR 4.22e-03
# Epoch 081 | Time 3.83s | Train NLL -4.986 | Val NLL -6.976 | LR 4.21e-03
# Epoch 082 | Time 3.78s | Train NLL -5.575 | Val NLL -4.014 | LR 4.19e-03
# Epoch 083 | Time 3.64s | Train NLL -5.473 | Val NLL -5.000 | LR 4.17e-03
# Epoch 084 | Time 3.68s | Train NLL -4.691 | Val NLL 0.773 | LR 4.15e-03
# Epoch 085 | Time 3.79s | Train NLL -2.587 | Val NLL -2.324 | LR 4.13e-03
# Epoch 086 | Time 3.74s | Train NLL -4.907 | Val NLL -7.008 | LR 4.11e-03
# Epoch 087 | Time 4.09s | Train NLL -5.247 | Val NLL -0.661 | LR 4.09e-03
# Epoch 088 | Time 3.76s | Train NLL -5.647 | Val NLL -8.043 | LR 4.06e-03
# Epoch 089 | Time 3.69s | Train NLL -5.571 | Val NLL -4.991 | LR 4.04e-03
# Epoch 090 | Time 3.60s | Train NLL -6.129 | Val NLL -4.661 | LR 4.02e-03
# Epoch 091 | Time 3.83s | Train NLL -4.912 | Val NLL -1.687 | LR 4.00e-03
# Epoch 092 | Time 4.63s | Train NLL -5.558 | Val NLL -3.851 | LR 3.98e-03
# Epoch 093 | Time 3.91s | Train NLL -5.579 | Val NLL -2.929 | LR 3.96e-03
# Epoch 094 | Time 3.53s | Train NLL -4.864 | Val NLL -6.025 | LR 3.94e-03
# Epoch 095 | Time 3.64s | Train NLL -6.432 | Val NLL -7.303 | LR 3.92e-03
# Epoch 096 | Time 3.60s | Train NLL -5.770 | Val NLL -3.378 | LR 3.89e-03
# Epoch 097 | Time 3.67s | Train NLL -5.534 | Val NLL -5.928 | LR 3.87e-03
# Epoch 098 | Time 3.53s | Train NLL -4.736 | Val NLL -1.093 | LR 3.85e-03
# Epoch 099 | Time 3.78s | Train NLL -5.379 | Val NLL -6.371 | LR 3.83e-03
# Epoch 100 | Time 3.26s | Train NLL -6.929 | Val NLL -7.914 | LR 3.80e-03
# Epoch 101 | Time 3.38s | Train NLL -6.408 | Val NLL -6.445 | LR 3.78e-03
# Epoch 102 | Time 3.65s | Train NLL -6.143 | Val NLL -4.759 | LR 3.76e-03
# Epoch 103 | Time 3.57s | Train NLL -6.253 | Val NLL -6.255 | LR 3.73e-03
# Epoch 104 | Time 3.58s | Train NLL -6.664 | Val NLL -7.301 | LR 3.71e-03
# Epoch 105 | Time 3.27s | Train NLL -5.046 | Val NLL -5.445 | LR 3.69e-03
# Epoch 106 | Time 3.90s | Train NLL -6.694 | Val NLL -6.740 | LR 3.66e-03
# Epoch 107 | Time 3.46s | Train NLL -6.740 | Val NLL -8.804 | LR 3.64e-03
# Epoch 108 | Time 3.29s | Train NLL -4.630 | Val NLL -1.812 | LR 3.62e-03
# Epoch 109 | Time 3.45s | Train NLL -2.924 | Val NLL -6.586 | LR 3.59e-03
# Epoch 110 | Time 4.62s | Train NLL -7.250 | Val NLL -7.213 | LR 3.57e-03
# Epoch 111 | Time 3.69s | Train NLL -6.084 | Val NLL -8.024 | LR 3.55e-03
# Epoch 112 | Time 3.65s | Train NLL -8.346 | Val NLL -9.094 | LR 3.52e-03
# Epoch 113 | Time 3.71s | Train NLL -8.186 | Val NLL -8.818 | LR 3.50e-03
# Epoch 114 | Time 3.66s | Train NLL -8.538 | Val NLL -9.207 | LR 3.47e-03
# Epoch 115 | Time 3.78s | Train NLL -7.926 | Val NLL -2.761 | LR 3.45e-03
# Epoch 116 | Time 3.63s | Train NLL -6.593 | Val NLL -8.030 | LR 3.42e-03
# Epoch 117 | Time 3.57s | Train NLL -7.778 | Val NLL -8.967 | LR 3.40e-03
# Epoch 118 | Time 3.52s | Train NLL -6.927 | Val NLL -7.796 | LR 3.37e-03
# Epoch 119 | Time 3.72s | Train NLL -6.238 | Val NLL -6.020 | LR 3.35e-03
# Epoch 120 | Time 3.66s | Train NLL -6.244 | Val NLL -7.085 | LR 3.32e-03
# Epoch 121 | Time 3.68s | Train NLL -7.341 | Val NLL -9.210 | LR 3.30e-03
# Epoch 122 | Time 3.55s | Train NLL -7.150 | Val NLL -5.794 | LR 3.27e-03
# Epoch 123 | Time 3.60s | Train NLL -7.149 | Val NLL -8.732 | LR 3.25e-03
# Epoch 124 | Time 3.76s | Train NLL -5.647 | Val NLL -5.356 | LR 3.22e-03
# Epoch 125 | Time 3.69s | Train NLL -7.036 | Val NLL -5.469 | LR 3.20e-03
# Epoch 126 | Time 3.59s | Train NLL -7.306 | Val NLL -8.830 | LR 3.17e-03
# Epoch 127 | Time 3.58s | Train NLL -6.664 | Val NLL -7.026 | LR 3.14e-03
# Epoch 128 | Time 2.54s | Train NLL -7.650 | Val NLL -8.607 | LR 3.12e-03
# Epoch 129 | Time 2.62s | Train NLL -6.592 | Val NLL -7.465 | LR 3.09e-03
# Epoch 130 | Time 2.47s | Train NLL -7.185 | Val NLL -6.249 | LR 3.07e-03
# Epoch 131 | Time 2.54s | Train NLL -7.978 | Val NLL -4.384 | LR 3.04e-03
# Epoch 132 | Time 3.41s | Train NLL -6.768 | Val NLL -6.323 | LR 3.02e-03
# Epoch 133 | Time 3.72s | Train NLL -7.025 | Val NLL -2.196 | LR 2.99e-03
# Epoch 134 | Time 3.59s | Train NLL -6.066 | Val NLL -3.786 | LR 2.96e-03
# Epoch 135 | Time 3.63s | Train NLL -6.062 | Val NLL -8.228 | LR 2.94e-03
# Epoch 136 | Time 3.57s | Train NLL -6.362 | Val NLL -5.093 | LR 2.91e-03
# Epoch 137 | Time 3.72s | Train NLL -5.998 | Val NLL -4.076 | LR 2.88e-03
# Epoch 138 | Time 3.66s | Train NLL -6.277 | Val NLL -4.136 | LR 2.86e-03
# Epoch 139 | Time 3.67s | Train NLL -7.366 | Val NLL -8.167 | LR 2.83e-03
# Epoch 140 | Time 3.71s | Train NLL -5.304 | Val NLL -8.125 | LR 2.81e-03
# Epoch 141 | Time 3.56s | Train NLL -6.484 | Val NLL -7.369 | LR 2.78e-03
# Epoch 142 | Time 3.66s | Train NLL -6.228 | Val NLL -2.834 | LR 2.75e-03
# Epoch 143 | Time 3.63s | Train NLL -7.145 | Val NLL -8.704 | LR 2.73e-03
# Epoch 144 | Time 3.61s | Train NLL -8.784 | Val NLL -6.761 | LR 2.70e-03
# Epoch 145 | Time 3.51s | Train NLL -7.535 | Val NLL -9.138 | LR 2.67e-03
# Epoch 146 | Time 3.56s | Train NLL -9.221 | Val NLL -9.544 | LR 2.65e-03
# Epoch 147 | Time 3.67s | Train NLL -8.373 | Val NLL -9.410 | LR 2.62e-03
# Epoch 148 | Time 3.59s | Train NLL -8.468 | Val NLL -8.816 | LR 2.59e-03
# Epoch 149 | Time 3.60s | Train NLL -8.845 | Val NLL -10.265 | LR 2.57e-03
# Epoch 150 | Time 3.68s | Train NLL -8.117 | Val NLL -9.923 | LR 2.54e-03
# Epoch 151 | Time 3.68s | Train NLL -7.730 | Val NLL -6.987 | LR 2.51e-03
# Epoch 152 | Time 3.44s | Train NLL -8.353 | Val NLL -9.495 | LR 2.49e-03
# Epoch 153 | Time 2.50s | Train NLL -7.088 | Val NLL -4.624 | LR 2.46e-03
# Epoch 154 | Time 2.50s | Train NLL -4.622 | Val NLL -6.205 | LR 2.43e-03
# Epoch 155 | Time 2.52s | Train NLL -7.513 | Val NLL -2.322 | LR 2.41e-03
# Epoch 156 | Time 2.58s | Train NLL -3.811 | Val NLL -6.803 | LR 2.38e-03
# Epoch 157 | Time 3.41s | Train NLL -6.348 | Val NLL -9.165 | LR 2.35e-03
# Epoch 158 | Time 3.52s | Train NLL -6.283 | Val NLL -5.191 | LR 2.33e-03
# Epoch 159 | Time 3.58s | Train NLL -7.610 | Val NLL -3.235 | LR 2.30e-03
# Epoch 160 | Time 3.76s | Train NLL -7.882 | Val NLL -6.984 | LR 2.27e-03
# Epoch 161 | Time 3.66s | Train NLL -8.509 | Val NLL -8.477 | LR 2.25e-03
# Epoch 162 | Time 3.60s | Train NLL -9.317 | Val NLL -10.426 | LR 2.22e-03
# Epoch 163 | Time 3.60s | Train NLL -8.515 | Val NLL -8.279 | LR 2.19e-03
# Epoch 164 | Time 3.57s | Train NLL -9.097 | Val NLL -10.135 | LR 2.17e-03
# Epoch 165 | Time 3.67s | Train NLL -8.495 | Val NLL -7.989 | LR 2.14e-03
# Epoch 166 | Time 3.61s | Train NLL -8.674 | Val NLL -10.280 | LR 2.12e-03
# Epoch 167 | Time 3.63s | Train NLL -8.494 | Val NLL -9.363 | LR 2.09e-03
# Epoch 168 | Time 3.70s | Train NLL -9.084 | Val NLL -9.640 | LR 2.06e-03
# Epoch 169 | Time 3.79s | Train NLL -8.926 | Val NLL -7.473 | LR 2.04e-03
# Epoch 170 | Time 3.67s | Train NLL -9.562 | Val NLL -10.143 | LR 2.01e-03
# Epoch 171 | Time 3.68s | Train NLL -9.638 | Val NLL -3.559 | LR 1.98e-03
# Epoch 172 | Time 3.61s | Train NLL -7.380 | Val NLL -9.226 | LR 1.96e-03
# Epoch 173 | Time 3.64s | Train NLL -7.483 | Val NLL -8.211 | LR 1.93e-03
# Epoch 174 | Time 3.72s | Train NLL -6.742 | Val NLL -8.360 | LR 1.91e-03
# Epoch 175 | Time 3.63s | Train NLL -8.392 | Val NLL -10.483 | LR 1.88e-03
# Epoch 176 | Time 2.66s | Train NLL -7.294 | Val NLL -6.388 | LR 1.86e-03
# Epoch 177 | Time 2.53s | Train NLL -9.617 | Val NLL -10.893 | LR 1.83e-03
# Epoch 178 | Time 2.62s | Train NLL -10.082 | Val NLL -5.943 | LR 1.80e-03
# Epoch 179 | Time 2.54s | Train NLL -7.779 | Val NLL -9.797 | LR 1.78e-03
# Epoch 180 | Time 3.32s | Train NLL -10.207 | Val NLL -6.679 | LR 1.75e-03
# Epoch 181 | Time 3.60s | Train NLL -7.242 | Val NLL -9.602 | LR 1.73e-03
# Epoch 182 | Time 3.95s | Train NLL -9.676 | Val NLL -5.120 | LR 1.70e-03
# Epoch 183 | Time 3.81s | Train NLL -8.891 | Val NLL -8.949 | LR 1.68e-03
# Epoch 184 | Time 3.65s | Train NLL -9.824 | Val NLL -9.680 | LR 1.65e-03
# Epoch 185 | Time 5.15s | Train NLL -9.695 | Val NLL -11.125 | LR 1.63e-03
# Epoch 186 | Time 4.62s | Train NLL -8.885 | Val NLL -8.089 | LR 1.60e-03
# Epoch 187 | Time 4.11s | Train NLL -9.926 | Val NLL -7.427 | LR 1.58e-03
# Epoch 188 | Time 3.73s | Train NLL -9.632 | Val NLL -9.996 | LR 1.55e-03
# Epoch 189 | Time 3.70s | Train NLL -10.318 | Val NLL -8.850 | LR 1.53e-03
# Epoch 190 | Time 3.68s | Train NLL -10.126 | Val NLL -10.091 | LR 1.50e-03
# Epoch 191 | Time 3.71s | Train NLL -9.955 | Val NLL -10.727 | LR 1.48e-03
# Epoch 192 | Time 3.79s | Train NLL -11.095 | Val NLL -10.573 | LR 1.45e-03
# Epoch 193 | Time 3.65s | Train NLL -8.954 | Val NLL -10.630 | LR 1.43e-03
# Epoch 194 | Time 3.72s | Train NLL -9.977 | Val NLL -10.751 | LR 1.41e-03
# Epoch 195 | Time 3.68s | Train NLL -11.002 | Val NLL -10.503 | LR 1.38e-03
# Epoch 196 | Time 3.58s | Train NLL -9.871 | Val NLL -10.696 | LR 1.36e-03
# Epoch 197 | Time 3.75s | Train NLL -11.010 | Val NLL -11.102 | LR 1.34e-03
# Epoch 198 | Time 3.60s | Train NLL -9.710 | Val NLL -10.426 | LR 1.31e-03
# Epoch 199 | Time 3.65s | Train NLL -10.661 | Val NLL -11.691 | LR 1.29e-03
# Epoch 200 | Time 3.68s | Train NLL -10.056 | Val NLL -8.995 | LR 1.27e-03
# Epoch 201 | Time 3.70s | Train NLL -9.940 | Val NLL -9.691 | LR 1.24e-03
# Epoch 202 | Time 3.27s | Train NLL -10.629 | Val NLL -8.685 | LR 1.22e-03
# Epoch 203 | Time 2.52s | Train NLL -10.897 | Val NLL -11.223 | LR 1.20e-03
# Epoch 204 | Time 2.67s | Train NLL -10.209 | Val NLL -11.979 | LR 1.17e-03
# Epoch 205 | Time 2.54s | Train NLL -9.707 | Val NLL -10.375 | LR 1.15e-03
# Epoch 206 | Time 2.97s | Train NLL -11.417 | Val NLL -10.983 | LR 1.13e-03
# Epoch 207 | Time 3.54s | Train NLL -9.287 | Val NLL -10.280 | LR 1.11e-03
# Epoch 208 | Time 3.64s | Train NLL -11.508 | Val NLL -11.053 | LR 1.08e-03
# Epoch 209 | Time 3.60s | Train NLL -11.254 | Val NLL -9.549 | LR 1.06e-03
# Epoch 210 | Time 3.59s | Train NLL -10.852 | Val NLL -11.796 | LR 1.04e-03
# Epoch 211 | Time 3.78s | Train NLL -12.000 | Val NLL -12.252 | LR 1.02e-03
# Epoch 212 | Time 3.67s | Train NLL -10.854 | Val NLL -11.825 | LR 9.98e-04
# Epoch 213 | Time 3.67s | Train NLL -11.418 | Val NLL -12.246 | LR 9.77e-04
# Epoch 214 | Time 3.68s | Train NLL -12.220 | Val NLL -11.301 | LR 9.56e-04
# Epoch 215 | Time 3.75s | Train NLL -9.420 | Val NLL -11.362 | LR 9.35e-04
# Epoch 216 | Time 3.62s | Train NLL -11.275 | Val NLL -12.032 | LR 9.15e-04
# Epoch 217 | Time 3.62s | Train NLL -12.313 | Val NLL -11.903 | LR 8.94e-04
# Epoch 218 | Time 3.65s | Train NLL -9.779 | Val NLL -10.987 | LR 8.74e-04
# Epoch 219 | Time 3.65s | Train NLL -11.421 | Val NLL -8.676 | LR 8.54e-04
# Epoch 220 | Time 3.74s | Train NLL -10.894 | Val NLL -12.075 | LR 8.34e-04
# Epoch 221 | Time 3.55s | Train NLL -11.903 | Val NLL -7.092 | LR 8.14e-04
# Epoch 222 | Time 3.00s | Train NLL -9.227 | Val NLL -9.557 | LR 7.94e-04
# Epoch 223 | Time 2.47s | Train NLL -10.271 | Val NLL -11.231 | LR 7.75e-04
# Epoch 224 | Time 2.52s | Train NLL -11.930 | Val NLL -12.615 | LR 7.56e-04
# Epoch 225 | Time 2.64s | Train NLL -11.647 | Val NLL -12.443 | LR 7.37e-04
# Epoch 226 | Time 2.92s | Train NLL -11.503 | Val NLL -11.861 | LR 7.18e-04
# Epoch 227 | Time 3.58s | Train NLL -12.084 | Val NLL -6.906 | LR 7.00e-04
# Epoch 228 | Time 3.67s | Train NLL -10.145 | Val NLL -12.119 | LR 6.81e-04
# Epoch 229 | Time 3.68s | Train NLL -10.921 | Val NLL -10.862 | LR 6.63e-04
# Epoch 230 | Time 3.77s | Train NLL -11.941 | Val NLL -12.878 | LR 6.45e-04
# Epoch 231 | Time 3.60s | Train NLL -12.040 | Val NLL -3.272 | LR 6.27e-04
# Epoch 232 | Time 3.61s | Train NLL -3.816 | Val NLL -6.260 | LR 6.10e-04
# Epoch 233 | Time 3.68s | Train NLL -11.298 | Val NLL -13.006 | LR 5.93e-04
# Epoch 234 | Time 3.67s | Train NLL -12.994 | Val NLL -13.126 | LR 5.75e-04
# Epoch 235 | Time 3.79s | Train NLL -13.214 | Val NLL -13.451 | LR 5.59e-04
# Epoch 236 | Time 4.01s | Train NLL -13.276 | Val NLL -13.092 | LR 5.42e-04
# Epoch 237 | Time 3.78s | Train NLL -13.282 | Val NLL -13.502 | LR 5.25e-04
# Epoch 238 | Time 3.81s | Train NLL -8.792 | Val NLL -13.281 | LR 5.09e-04
# Epoch 239 | Time 3.81s | Train NLL -9.120 | Val NLL -12.263 | LR 4.93e-04
# Epoch 240 | Time 3.69s | Train NLL -10.593 | Val NLL -13.016 | LR 4.77e-04
# Epoch 241 | Time 3.69s | Train NLL -12.574 | Val NLL -13.785 | LR 4.62e-04
# Epoch 242 | Time 3.62s | Train NLL -11.887 | Val NLL -12.349 | LR 4.47e-04
# Epoch 243 | Time 3.31s | Train NLL -13.269 | Val NLL -14.022 | LR 4.32e-04
# Epoch 244 | Time 2.65s | Train NLL -13.943 | Val NLL -10.940 | LR 4.17e-04
# Epoch 245 | Time 2.81s | Train NLL -11.300 | Val NLL -13.900 | LR 4.02e-04
# Epoch 246 | Time 2.64s | Train NLL -13.911 | Val NLL -14.250 | LR 3.88e-04
# Epoch 247 | Time 3.10s | Train NLL -14.051 | Val NLL -13.734 | LR 3.74e-04
# Epoch 248 | Time 3.76s | Train NLL -13.920 | Val NLL -11.876 | LR 3.60e-04
# Epoch 249 | Time 3.62s | Train NLL -13.755 | Val NLL -12.495 | LR 3.46e-04
# Epoch 250 | Time 3.63s | Train NLL -13.391 | Val NLL -10.790 | LR 3.33e-04
# Epoch 251 | Time 3.69s | Train NLL -11.381 | Val NLL -12.927 | LR 3.20e-04
# Epoch 252 | Time 3.79s | Train NLL -13.731 | Val NLL -13.923 | LR 3.07e-04
# Epoch 253 | Time 3.61s | Train NLL -13.883 | Val NLL -13.976 | LR 2.94e-04
# Epoch 254 | Time 3.62s | Train NLL -13.989 | Val NLL -13.890 | LR 2.82e-04
# Epoch 255 | Time 3.69s | Train NLL -14.041 | Val NLL -14.116 | LR 2.69e-04
# Epoch 256 | Time 3.67s | Train NLL -14.148 | Val NLL -14.180 | LR 2.58e-04
# Epoch 257 | Time 3.81s | Train NLL -14.252 | Val NLL -14.226 | LR 2.46e-04
# Epoch 258 | Time 3.67s | Train NLL -14.345 | Val NLL -14.351 | LR 2.35e-04
# Epoch 259 | Time 3.68s | Train NLL -14.383 | Val NLL -14.477 | LR 2.23e-04
# Epoch 260 | Time 3.72s | Train NLL -14.513 | Val NLL -14.556 | LR 2.13e-04
# Epoch 261 | Time 3.77s | Train NLL -14.841 | Val NLL -15.205 | LR 2.02e-04
# Epoch 262 | Time 3.76s | Train NLL -15.230 | Val NLL -15.388 | LR 1.92e-04
# Epoch 263 | Time 3.74s | Train NLL -15.406 | Val NLL -15.547 | LR 1.81e-04
# Epoch 264 | Time 3.68s | Train NLL -15.398 | Val NLL -15.149 | LR 1.72e-04
# Epoch 265 | Time 3.64s | Train NLL -15.382 | Val NLL -15.493 | LR 1.62e-04
# Epoch 266 | Time 2.50s | Train NLL -15.514 | Val NLL -15.521 | LR 1.53e-04
# Epoch 267 | Time 2.56s | Train NLL -15.626 | Val NLL -15.850 | LR 1.44e-04
# Epoch 268 | Time 2.53s | Train NLL -15.685 | Val NLL -15.761 | LR 1.35e-04
# Epoch 269 | Time 2.83s | Train NLL -15.791 | Val NLL -15.966 | LR 1.27e-04
# Epoch 270 | Time 3.70s | Train NLL -15.923 | Val NLL -15.852 | LR 1.18e-04
# Epoch 271 | Time 3.68s | Train NLL -15.976 | Val NLL -16.101 | LR 1.10e-04
# Epoch 272 | Time 3.72s | Train NLL -16.057 | Val NLL -16.203 | LR 1.03e-04
# Epoch 273 | Time 3.62s | Train NLL -16.151 | Val NLL -16.170 | LR 9.52e-05
# Epoch 274 | Time 3.86s | Train NLL -16.254 | Val NLL -16.346 | LR 8.81e-05
# Epoch 275 | Time 3.71s | Train NLL -16.317 | Val NLL -16.446 | LR 8.12e-05
# Epoch 276 | Time 3.73s | Train NLL -16.384 | Val NLL -16.527 | LR 7.46e-05
# Epoch 277 | Time 3.70s | Train NLL -16.475 | Val NLL -16.579 | LR 6.83e-05
# Epoch 278 | Time 3.79s | Train NLL -16.540 | Val NLL -16.614 | LR 6.23e-05
# Epoch 279 | Time 3.81s | Train NLL -16.612 | Val NLL -16.594 | LR 5.65e-05
# Epoch 280 | Time 3.77s | Train NLL -16.637 | Val NLL -16.704 | LR 5.10e-05
# Epoch 281 | Time 3.69s | Train NLL -16.703 | Val NLL -16.766 | LR 4.58e-05
# Epoch 282 | Time 3.72s | Train NLL -16.751 | Val NLL -16.797 | LR 4.09e-05
# Epoch 283 | Time 3.68s | Train NLL -16.774 | Val NLL -16.834 | LR 3.62e-05
# Epoch 284 | Time 2.55s | Train NLL -16.815 | Val NLL -16.869 | LR 3.18e-05
# Epoch 285 | Time 2.66s | Train NLL -16.854 | Val NLL -16.886 | LR 2.77e-05
# Epoch 286 | Time 2.53s | Train NLL -16.885 | Val NLL -16.919 | LR 2.39e-05
# Epoch 287 | Time 2.53s | Train NLL -16.907 | Val NLL -16.941 | LR 2.04e-05
# Epoch 288 | Time 3.56s | Train NLL -16.931 | Val NLL -16.956 | LR 1.71e-05
# Epoch 289 | Time 3.77s | Train NLL -16.946 | Val NLL -16.974 | LR 1.42e-05
# Epoch 290 | Time 3.74s | Train NLL -16.961 | Val NLL -16.987 | LR 1.15e-05
# Epoch 291 | Time 3.74s | Train NLL -16.972 | Val NLL -16.999 | LR 9.07e-06
# Epoch 292 | Time 3.81s | Train NLL -16.981 | Val NLL -17.009 | LR 6.94e-06
# Epoch 293 | Time 3.71s | Train NLL -16.989 | Val NLL -17.015 | LR 5.10e-06
# Epoch 294 | Time 3.86s | Train NLL -16.998 | Val NLL -17.020 | LR 3.54e-06
# Epoch 295 | Time 3.77s | Train NLL -17.003 | Val NLL -17.023 | LR 2.27e-06
# Epoch 296 | Time 3.73s | Train NLL -17.004 | Val NLL -17.025 | LR 1.28e-06
# Epoch 297 | Time 3.80s | Train NLL -17.008 | Val NLL -17.026 | LR 5.67e-07
# Epoch 298 | Time 3.69s | Train NLL -17.006 | Val NLL -17.027 | LR 1.42e-07
# Epoch 299 | Time 3.84s | Train NLL -17.004 | Val NLL -17.027 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 40060.65
# Average absolute difference in CASUALTIES: 0.04

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
