# %% [markdown]
# # Hail model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Hail'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'HAIL_SIZE',
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 6.01s | Train NLL 3.990 | Val NLL -2.248 | LR 1.00e-03
# Epoch 001 | Time 5.38s | Train NLL -1.942 | Val NLL -3.522 | LR 2.00e-03
# Epoch 002 | Time 4.86s | Train NLL -2.587 | Val NLL -3.682 | LR 3.00e-03
# Epoch 003 | Time 4.52s | Train NLL -1.941 | Val NLL -2.022 | LR 4.00e-03
# Epoch 004 | Time 4.42s | Train NLL -1.687 | Val NLL -2.369 | LR 5.00e-03
# Epoch 005 | Time 5.67s | Train NLL -2.318 | Val NLL -1.958 | LR 5.00e-03
# Epoch 006 | Time 4.50s | Train NLL -1.709 | Val NLL -1.246 | LR 5.00e-03
# Epoch 007 | Time 4.45s | Train NLL -2.241 | Val NLL -1.125 | LR 5.00e-03
# Epoch 008 | Time 4.27s | Train NLL -2.729 | Val NLL 0.995 | LR 5.00e-03
# Epoch 009 | Time 4.16s | Train NLL -2.841 | Val NLL -0.404 | LR 5.00e-03
# Epoch 010 | Time 4.15s | Train NLL -2.116 | Val NLL -3.077 | LR 4.99e-03
# Epoch 011 | Time 4.44s | Train NLL -3.314 | Val NLL -4.660 | LR 4.99e-03
# Epoch 012 | Time 4.35s | Train NLL -1.858 | Val NLL -4.427 | LR 4.99e-03
# Epoch 013 | Time 4.44s | Train NLL -2.971 | Val NLL -3.392 | LR 4.99e-03
# Epoch 014 | Time 4.39s | Train NLL -2.572 | Val NLL -4.470 | LR 4.99e-03
# Epoch 015 | Time 4.32s | Train NLL -3.150 | Val NLL -5.098 | LR 4.98e-03
# Epoch 016 | Time 4.42s | Train NLL -2.954 | Val NLL 2.590 | LR 4.98e-03
# Epoch 017 | Time 4.38s | Train NLL -1.584 | Val NLL -3.688 | LR 4.98e-03
# Epoch 018 | Time 4.32s | Train NLL -2.934 | Val NLL -1.851 | LR 4.97e-03
# Epoch 019 | Time 4.48s | Train NLL -2.654 | Val NLL -0.404 | LR 4.97e-03
# Epoch 020 | Time 4.70s | Train NLL -2.858 | Val NLL -1.920 | LR 4.96e-03
# Epoch 021 | Time 4.79s | Train NLL -4.344 | Val NLL -3.234 | LR 4.96e-03
# Epoch 022 | Time 4.33s | Train NLL -3.653 | Val NLL -5.534 | LR 4.95e-03
# Epoch 023 | Time 4.34s | Train NLL -4.741 | Val NLL -3.613 | LR 4.95e-03
# Epoch 024 | Time 4.30s | Train NLL -4.759 | Val NLL 1.236 | LR 4.94e-03
# Epoch 025 | Time 4.68s | Train NLL -4.353 | Val NLL -5.636 | LR 4.94e-03
# Epoch 026 | Time 4.47s | Train NLL -4.012 | Val NLL -3.877 | LR 4.93e-03
# Epoch 027 | Time 4.45s | Train NLL -4.235 | Val NLL -5.296 | LR 4.93e-03
# Epoch 028 | Time 4.40s | Train NLL -5.800 | Val NLL -1.932 | LR 4.92e-03
# Epoch 029 | Time 5.01s | Train NLL -5.209 | Val NLL -3.536 | LR 4.91e-03
# Epoch 030 | Time 4.47s | Train NLL -5.309 | Val NLL -5.050 | LR 4.90e-03
# Epoch 031 | Time 4.36s | Train NLL -4.556 | Val NLL -3.896 | LR 4.90e-03
# Epoch 032 | Time 4.51s | Train NLL -4.559 | Val NLL -5.881 | LR 4.89e-03
# Epoch 033 | Time 4.31s | Train NLL -4.445 | Val NLL -6.311 | LR 4.88e-03
# Epoch 034 | Time 4.59s | Train NLL -5.119 | Val NLL -4.247 | LR 4.87e-03
# Epoch 035 | Time 4.71s | Train NLL -5.288 | Val NLL -4.124 | LR 4.86e-03
# Epoch 036 | Time 4.50s | Train NLL -3.726 | Val NLL -2.597 | LR 4.86e-03
# Epoch 037 | Time 4.45s | Train NLL -4.809 | Val NLL -5.451 | LR 4.85e-03
# Epoch 038 | Time 4.47s | Train NLL -4.995 | Val NLL -6.400 | LR 4.84e-03
# Epoch 039 | Time 4.71s | Train NLL -5.228 | Val NLL -4.912 | LR 4.83e-03
# Epoch 040 | Time 4.51s | Train NLL -5.041 | Val NLL -7.237 | LR 4.82e-03
# Epoch 041 | Time 4.74s | Train NLL -5.811 | Val NLL -5.858 | LR 4.81e-03
# Epoch 042 | Time 5.53s | Train NLL -4.498 | Val NLL -6.627 | LR 4.80e-03
# Epoch 043 | Time 5.58s | Train NLL -4.791 | Val NLL -2.956 | LR 4.79e-03
# Epoch 044 | Time 4.48s | Train NLL -3.651 | Val NLL -6.209 | LR 4.78e-03
# Epoch 045 | Time 4.59s | Train NLL -5.039 | Val NLL -5.664 | LR 4.77e-03
# Epoch 046 | Time 4.39s | Train NLL -5.551 | Val NLL -3.781 | LR 4.75e-03
# Epoch 047 | Time 4.36s | Train NLL -5.837 | Val NLL -6.284 | LR 4.74e-03
# Epoch 048 | Time 4.58s | Train NLL -4.374 | Val NLL 0.605 | LR 4.73e-03
# Epoch 049 | Time 4.43s | Train NLL -1.102 | Val NLL 0.865 | LR 4.72e-03
# Epoch 050 | Time 5.14s | Train NLL -2.581 | Val NLL -1.430 | LR 4.71e-03
# Epoch 051 | Time 6.69s | Train NLL 0.677 | Val NLL -3.727 | LR 4.69e-03
# Epoch 052 | Time 4.20s | Train NLL -0.710 | Val NLL -1.284 | LR 4.68e-03
# Epoch 053 | Time 5.65s | Train NLL -2.468 | Val NLL -3.444 | LR 4.67e-03
# Epoch 054 | Time 8.02s | Train NLL -3.186 | Val NLL -3.239 | LR 4.65e-03
# Epoch 055 | Time 5.38s | Train NLL -3.017 | Val NLL -1.335 | LR 4.64e-03
# Epoch 056 | Time 5.01s | Train NLL -1.840 | Val NLL -4.113 | LR 4.63e-03
# Epoch 057 | Time 4.38s | Train NLL -3.661 | Val NLL -4.912 | LR 4.61e-03
# Epoch 058 | Time 4.48s | Train NLL -2.700 | Val NLL -0.161 | LR 4.60e-03
# Epoch 059 | Time 4.36s | Train NLL -3.228 | Val NLL -6.682 | LR 4.58e-03
# Epoch 060 | Time 4.58s | Train NLL -4.350 | Val NLL -2.341 | LR 4.57e-03
# Epoch 061 | Time 4.30s | Train NLL -3.674 | Val NLL -4.673 | LR 4.55e-03
# Epoch 062 | Time 4.33s | Train NLL -4.200 | Val NLL -6.313 | LR 4.54e-03
# Epoch 063 | Time 4.55s | Train NLL -4.612 | Val NLL -3.205 | LR 4.52e-03
# Epoch 064 | Time 4.49s | Train NLL -4.747 | Val NLL -3.786 | LR 4.51e-03
# Epoch 065 | Time 4.34s | Train NLL -5.656 | Val NLL -7.996 | LR 4.49e-03
# Epoch 066 | Time 4.34s | Train NLL -5.370 | Val NLL -4.892 | LR 4.47e-03
# Epoch 067 | Time 4.38s | Train NLL -5.488 | Val NLL -2.244 | LR 4.46e-03
# Epoch 068 | Time 4.56s | Train NLL -4.887 | Val NLL 2.258 | LR 4.44e-03
# Epoch 069 | Time 4.52s | Train NLL -2.101 | Val NLL 1.171 | LR 4.42e-03
# Epoch 070 | Time 4.38s | Train NLL -4.707 | Val NLL -7.755 | LR 4.41e-03
# Epoch 071 | Time 4.29s | Train NLL -6.066 | Val NLL -6.509 | LR 4.39e-03
# Epoch 072 | Time 4.61s | Train NLL -4.813 | Val NLL -3.050 | LR 4.37e-03
# Epoch 073 | Time 4.45s | Train NLL -4.928 | Val NLL -3.548 | LR 4.35e-03
# Epoch 074 | Time 4.38s | Train NLL -5.944 | Val NLL -4.937 | LR 4.34e-03
# Epoch 075 | Time 4.35s | Train NLL -4.972 | Val NLL -5.200 | LR 4.32e-03
# Epoch 076 | Time 4.37s | Train NLL -4.638 | Val NLL -6.211 | LR 4.30e-03
# Epoch 077 | Time 4.45s | Train NLL -6.071 | Val NLL -6.809 | LR 4.28e-03
# Epoch 078 | Time 4.34s | Train NLL -6.131 | Val NLL -7.269 | LR 4.26e-03
# Epoch 079 | Time 4.37s | Train NLL -5.053 | Val NLL -5.764 | LR 4.24e-03
# Epoch 080 | Time 4.22s | Train NLL -5.688 | Val NLL -3.848 | LR 4.22e-03
# Epoch 081 | Time 4.31s | Train NLL -5.183 | Val NLL -5.769 | LR 4.21e-03
# Epoch 082 | Time 4.47s | Train NLL -3.101 | Val NLL -3.603 | LR 4.19e-03
# Epoch 083 | Time 4.35s | Train NLL -4.903 | Val NLL -4.597 | LR 4.17e-03
# Epoch 084 | Time 4.29s | Train NLL -6.083 | Val NLL -6.681 | LR 4.15e-03
# Epoch 085 | Time 4.54s | Train NLL -4.129 | Val NLL -5.611 | LR 4.13e-03
# Epoch 086 | Time 4.58s | Train NLL -6.760 | Val NLL -4.933 | LR 4.11e-03
# Epoch 087 | Time 4.28s | Train NLL -6.967 | Val NLL -7.674 | LR 4.09e-03
# Epoch 088 | Time 4.28s | Train NLL -6.209 | Val NLL -0.885 | LR 4.06e-03
# Epoch 089 | Time 4.23s | Train NLL -5.363 | Val NLL -7.209 | LR 4.04e-03
# Epoch 090 | Time 4.43s | Train NLL -6.189 | Val NLL -7.271 | LR 4.02e-03
# Epoch 091 | Time 4.33s | Train NLL -6.452 | Val NLL -7.036 | LR 4.00e-03
# Epoch 092 | Time 4.30s | Train NLL -6.147 | Val NLL -1.799 | LR 3.98e-03
# Epoch 093 | Time 4.32s | Train NLL -6.129 | Val NLL -2.299 | LR 3.96e-03
# Epoch 094 | Time 4.93s | Train NLL -5.394 | Val NLL -7.323 | LR 3.94e-03
# Epoch 095 | Time 4.36s | Train NLL -6.459 | Val NLL -7.454 | LR 3.92e-03
# Epoch 096 | Time 4.39s | Train NLL -5.724 | Val NLL -5.523 | LR 3.89e-03
# Epoch 097 | Time 4.35s | Train NLL -5.470 | Val NLL -6.816 | LR 3.87e-03
# Epoch 098 | Time 4.58s | Train NLL -5.573 | Val NLL -5.559 | LR 3.85e-03
# Epoch 099 | Time 4.38s | Train NLL -6.793 | Val NLL -1.541 | LR 3.83e-03
# Epoch 100 | Time 4.33s | Train NLL -4.291 | Val NLL -6.890 | LR 3.80e-03
# Epoch 101 | Time 4.33s | Train NLL -5.145 | Val NLL -1.821 | LR 3.78e-03
# Epoch 102 | Time 4.44s | Train NLL -5.044 | Val NLL -3.346 | LR 3.76e-03
# Epoch 103 | Time 4.26s | Train NLL -3.879 | Val NLL -2.708 | LR 3.73e-03
# Epoch 104 | Time 5.45s | Train NLL -2.503 | Val NLL -2.222 | LR 3.71e-03
# Epoch 105 | Time 4.26s | Train NLL -6.495 | Val NLL -5.438 | LR 3.69e-03
# Epoch 106 | Time 4.51s | Train NLL -5.558 | Val NLL -4.591 | LR 3.66e-03
# Epoch 107 | Time 4.27s | Train NLL -6.399 | Val NLL -6.480 | LR 3.64e-03
# Epoch 108 | Time 4.27s | Train NLL -6.763 | Val NLL -5.581 | LR 3.62e-03
# Epoch 109 | Time 4.29s | Train NLL -6.517 | Val NLL -7.164 | LR 3.59e-03
# Epoch 110 | Time 4.75s | Train NLL -5.944 | Val NLL -5.892 | LR 3.57e-03
# Epoch 111 | Time 4.63s | Train NLL -5.364 | Val NLL -5.363 | LR 3.55e-03
# Epoch 112 | Time 4.35s | Train NLL -6.270 | Val NLL -3.950 | LR 3.52e-03
# Epoch 113 | Time 5.45s | Train NLL -5.843 | Val NLL -6.323 | LR 3.50e-03
# Epoch 114 | Time 5.28s | Train NLL -6.041 | Val NLL -7.030 | LR 3.47e-03
# Epoch 115 | Time 4.69s | Train NLL -5.976 | Val NLL -5.844 | LR 3.45e-03
# Epoch 116 | Time 4.43s | Train NLL -6.189 | Val NLL -7.154 | LR 3.42e-03
# Epoch 117 | Time 4.61s | Train NLL -4.515 | Val NLL -4.590 | LR 3.40e-03
# Epoch 118 | Time 4.49s | Train NLL -6.777 | Val NLL -7.530 | LR 3.37e-03
# Epoch 119 | Time 4.38s | Train NLL -5.888 | Val NLL -7.058 | LR 3.35e-03
# Epoch 120 | Time 4.37s | Train NLL -6.500 | Val NLL -7.369 | LR 3.32e-03
# Epoch 121 | Time 4.39s | Train NLL -6.599 | Val NLL -7.811 | LR 3.30e-03
# Epoch 122 | Time 4.59s | Train NLL -6.328 | Val NLL -6.125 | LR 3.27e-03
# Epoch 123 | Time 4.32s | Train NLL -6.965 | Val NLL -6.054 | LR 3.25e-03
# Epoch 124 | Time 4.33s | Train NLL -5.507 | Val NLL -3.857 | LR 3.22e-03
# Epoch 125 | Time 4.20s | Train NLL -6.616 | Val NLL -6.633 | LR 3.20e-03
# Epoch 126 | Time 4.41s | Train NLL -4.959 | Val NLL -7.744 | LR 3.17e-03
# Epoch 127 | Time 4.30s | Train NLL -7.198 | Val NLL -8.045 | LR 3.14e-03
# Epoch 128 | Time 4.34s | Train NLL -6.271 | Val NLL -6.695 | LR 3.12e-03
# Epoch 129 | Time 4.33s | Train NLL -6.633 | Val NLL -5.181 | LR 3.09e-03
# Epoch 130 | Time 4.48s | Train NLL -3.125 | Val NLL -5.919 | LR 3.07e-03
# Epoch 131 | Time 4.40s | Train NLL -6.088 | Val NLL -8.464 | LR 3.04e-03
# Epoch 132 | Time 4.33s | Train NLL -6.988 | Val NLL -8.427 | LR 3.02e-03
# Epoch 133 | Time 4.36s | Train NLL -7.473 | Val NLL -9.408 | LR 2.99e-03
# Epoch 134 | Time 4.30s | Train NLL -6.844 | Val NLL -8.164 | LR 2.96e-03
# Epoch 135 | Time 4.42s | Train NLL -6.608 | Val NLL -7.345 | LR 2.94e-03
# Epoch 136 | Time 4.65s | Train NLL -5.530 | Val NLL -6.375 | LR 2.91e-03
# Epoch 137 | Time 5.34s | Train NLL -6.446 | Val NLL -7.454 | LR 2.88e-03
# Epoch 138 | Time 5.33s | Train NLL -5.810 | Val NLL -7.713 | LR 2.86e-03
# Epoch 139 | Time 5.57s | Train NLL -7.133 | Val NLL -7.798 | LR 2.83e-03
# Epoch 140 | Time 5.25s | Train NLL -6.798 | Val NLL -7.016 | LR 2.81e-03
# Epoch 141 | Time 5.28s | Train NLL -7.136 | Val NLL -5.994 | LR 2.78e-03
# Epoch 142 | Time 5.52s | Train NLL -7.015 | Val NLL -8.560 | LR 2.75e-03
# Epoch 143 | Time 5.51s | Train NLL -5.287 | Val NLL -8.593 | LR 2.73e-03
# Epoch 144 | Time 5.06s | Train NLL -8.673 | Val NLL -7.332 | LR 2.70e-03
# Epoch 145 | Time 5.27s | Train NLL -7.318 | Val NLL -6.367 | LR 2.67e-03
# Epoch 146 | Time 5.05s | Train NLL -7.793 | Val NLL -3.745 | LR 2.65e-03
# Epoch 147 | Time 5.25s | Train NLL -5.441 | Val NLL -8.431 | LR 2.62e-03
# Epoch 148 | Time 5.05s | Train NLL -7.285 | Val NLL -8.149 | LR 2.59e-03
# Epoch 149 | Time 3.83s | Train NLL -8.260 | Val NLL -6.805 | LR 2.57e-03
# Epoch 150 | Time 3.52s | Train NLL -7.358 | Val NLL -1.879 | LR 2.54e-03
# Epoch 151 | Time 3.66s | Train NLL -5.964 | Val NLL -5.115 | LR 2.51e-03
# Epoch 152 | Time 4.83s | Train NLL -7.406 | Val NLL -8.619 | LR 2.49e-03
# Epoch 153 | Time 5.12s | Train NLL -5.262 | Val NLL -7.624 | LR 2.46e-03
# Epoch 154 | Time 5.08s | Train NLL -8.629 | Val NLL -9.672 | LR 2.43e-03
# Epoch 155 | Time 5.35s | Train NLL -8.802 | Val NLL -6.606 | LR 2.41e-03
# Epoch 156 | Time 5.49s | Train NLL -7.660 | Val NLL -6.310 | LR 2.38e-03
# Epoch 157 | Time 5.25s | Train NLL -8.766 | Val NLL -9.161 | LR 2.35e-03
# Epoch 158 | Time 5.48s | Train NLL -7.984 | Val NLL -8.809 | LR 2.33e-03
# Epoch 159 | Time 5.45s | Train NLL -9.505 | Val NLL -9.760 | LR 2.30e-03
# Epoch 160 | Time 4.99s | Train NLL -7.113 | Val NLL -8.587 | LR 2.27e-03
# Epoch 161 | Time 3.81s | Train NLL -7.556 | Val NLL -3.867 | LR 2.25e-03
# Epoch 162 | Time 3.81s | Train NLL -8.461 | Val NLL -9.503 | LR 2.22e-03
# Epoch 163 | Time 4.16s | Train NLL -6.438 | Val NLL -7.364 | LR 2.19e-03
# Epoch 164 | Time 5.62s | Train NLL -7.613 | Val NLL -5.149 | LR 2.17e-03
# Epoch 165 | Time 5.49s | Train NLL -8.857 | Val NLL -8.705 | LR 2.14e-03
# Epoch 166 | Time 5.29s | Train NLL -8.205 | Val NLL -8.498 | LR 2.12e-03
# Epoch 167 | Time 5.43s | Train NLL -8.219 | Val NLL -5.118 | LR 2.09e-03
# Epoch 168 | Time 5.63s | Train NLL -7.291 | Val NLL -5.620 | LR 2.06e-03
# Epoch 169 | Time 5.39s | Train NLL -7.441 | Val NLL -8.531 | LR 2.04e-03
# Epoch 170 | Time 5.50s | Train NLL -8.373 | Val NLL -9.808 | LR 2.01e-03
# Epoch 171 | Time 5.45s | Train NLL -7.198 | Val NLL -5.726 | LR 1.98e-03
# Epoch 172 | Time 5.29s | Train NLL -7.465 | Val NLL -2.210 | LR 1.96e-03
# Epoch 173 | Time 3.80s | Train NLL -6.687 | Val NLL -7.002 | LR 1.93e-03
# Epoch 174 | Time 3.84s | Train NLL -8.317 | Val NLL -3.991 | LR 1.91e-03
# Epoch 175 | Time 4.54s | Train NLL -8.206 | Val NLL -10.671 | LR 1.88e-03
# Epoch 176 | Time 5.48s | Train NLL -8.122 | Val NLL -0.985 | LR 1.86e-03
# Epoch 177 | Time 5.24s | Train NLL -7.639 | Val NLL -9.426 | LR 1.83e-03
# Epoch 178 | Time 5.35s | Train NLL -7.654 | Val NLL -10.764 | LR 1.80e-03
# Epoch 179 | Time 5.37s | Train NLL -8.243 | Val NLL -9.808 | LR 1.78e-03
# Epoch 180 | Time 5.58s | Train NLL -6.486 | Val NLL -8.576 | LR 1.75e-03
# Epoch 181 | Time 5.46s | Train NLL -7.253 | Val NLL -8.219 | LR 1.73e-03
# Epoch 182 | Time 5.37s | Train NLL -6.527 | Val NLL -7.408 | LR 1.70e-03
# Epoch 183 | Time 5.29s | Train NLL -7.474 | Val NLL -8.378 | LR 1.68e-03
# Epoch 184 | Time 5.50s | Train NLL -8.042 | Val NLL -6.538 | LR 1.65e-03
# Epoch 185 | Time 3.91s | Train NLL -8.304 | Val NLL -10.138 | LR 1.63e-03
# Epoch 186 | Time 3.74s | Train NLL -9.298 | Val NLL -10.233 | LR 1.60e-03
# Epoch 187 | Time 4.05s | Train NLL -8.382 | Val NLL -9.345 | LR 1.58e-03
# Epoch 188 | Time 5.50s | Train NLL -10.006 | Val NLL -5.502 | LR 1.55e-03
# Epoch 189 | Time 5.33s | Train NLL -9.581 | Val NLL -8.663 | LR 1.53e-03
# Epoch 190 | Time 5.30s | Train NLL -10.394 | Val NLL -10.172 | LR 1.50e-03
# Epoch 191 | Time 5.29s | Train NLL -8.078 | Val NLL -9.885 | LR 1.48e-03
# Epoch 192 | Time 5.52s | Train NLL -10.638 | Val NLL -7.886 | LR 1.45e-03
# Epoch 193 | Time 5.37s | Train NLL -8.516 | Val NLL -11.142 | LR 1.43e-03
# Epoch 194 | Time 5.31s | Train NLL -8.401 | Val NLL -10.354 | LR 1.41e-03
# Epoch 195 | Time 5.20s | Train NLL -8.601 | Val NLL -6.534 | LR 1.38e-03
# Epoch 196 | Time 4.00s | Train NLL -8.917 | Val NLL -8.532 | LR 1.36e-03
# Epoch 197 | Time 3.92s | Train NLL -7.576 | Val NLL -4.947 | LR 1.34e-03
# Epoch 198 | Time 4.47s | Train NLL -7.600 | Val NLL -7.313 | LR 1.31e-03
# Epoch 199 | Time 5.41s | Train NLL -9.946 | Val NLL -10.580 | LR 1.29e-03
# Epoch 200 | Time 5.55s | Train NLL -10.777 | Val NLL -11.128 | LR 1.27e-03
# Epoch 201 | Time 5.82s | Train NLL -6.839 | Val NLL -7.487 | LR 1.24e-03
# Epoch 202 | Time 5.47s | Train NLL -9.240 | Val NLL -10.283 | LR 1.22e-03
# Epoch 203 | Time 5.43s | Train NLL -10.859 | Val NLL -11.105 | LR 1.20e-03
# Epoch 204 | Time 5.39s | Train NLL -9.487 | Val NLL -9.396 | LR 1.17e-03
# Epoch 205 | Time 5.52s | Train NLL -8.981 | Val NLL -10.831 | LR 1.15e-03
# Epoch 206 | Time 5.31s | Train NLL -8.623 | Val NLL -10.137 | LR 1.13e-03
# Epoch 207 | Time 5.34s | Train NLL -10.631 | Val NLL -9.857 | LR 1.11e-03
# Epoch 208 | Time 5.33s | Train NLL -6.846 | Val NLL -7.286 | LR 1.08e-03
# Epoch 209 | Time 4.02s | Train NLL -8.442 | Val NLL -9.746 | LR 1.06e-03
# Epoch 210 | Time 3.78s | Train NLL -8.586 | Val NLL -9.987 | LR 1.04e-03
# Epoch 211 | Time 4.10s | Train NLL -9.264 | Val NLL -4.560 | LR 1.02e-03
# Epoch 212 | Time 5.29s | Train NLL -8.684 | Val NLL -9.912 | LR 9.98e-04
# Epoch 213 | Time 5.49s | Train NLL -8.674 | Val NLL -8.341 | LR 9.77e-04
# Epoch 214 | Time 5.41s | Train NLL -9.753 | Val NLL -9.663 | LR 9.56e-04
# Epoch 215 | Time 5.42s | Train NLL -7.953 | Val NLL -5.227 | LR 9.35e-04
# Epoch 216 | Time 5.58s | Train NLL -8.767 | Val NLL -8.296 | LR 9.15e-04
# Epoch 217 | Time 5.76s | Train NLL -9.168 | Val NLL -7.782 | LR 8.94e-04
# Epoch 218 | Time 5.43s | Train NLL -9.283 | Val NLL -11.251 | LR 8.74e-04
# Epoch 219 | Time 5.37s | Train NLL -5.609 | Val NLL -5.610 | LR 8.54e-04
# Epoch 220 | Time 5.32s | Train NLL -10.226 | Val NLL -9.844 | LR 8.34e-04
# Epoch 221 | Time 5.45s | Train NLL -10.392 | Val NLL -10.776 | LR 8.14e-04
# Epoch 222 | Time 5.21s | Train NLL -10.627 | Val NLL -12.438 | LR 7.94e-04
# Epoch 223 | Time 3.75s | Train NLL -10.315 | Val NLL -10.481 | LR 7.75e-04
# Epoch 224 | Time 3.89s | Train NLL -10.959 | Val NLL -11.752 | LR 7.56e-04
# Epoch 225 | Time 4.26s | Train NLL -10.584 | Val NLL -11.215 | LR 7.37e-04
# Epoch 226 | Time 5.50s | Train NLL -11.141 | Val NLL -12.681 | LR 7.18e-04
# Epoch 227 | Time 5.43s | Train NLL -11.432 | Val NLL -12.177 | LR 7.00e-04
# Epoch 228 | Time 5.38s | Train NLL -11.422 | Val NLL -11.313 | LR 6.81e-04
# Epoch 229 | Time 5.43s | Train NLL -12.454 | Val NLL -12.136 | LR 6.63e-04
# Epoch 230 | Time 5.63s | Train NLL -12.769 | Val NLL -13.352 | LR 6.45e-04
# Epoch 231 | Time 5.41s | Train NLL -11.620 | Val NLL -11.197 | LR 6.27e-04
# Epoch 232 | Time 5.36s | Train NLL -12.716 | Val NLL -12.529 | LR 6.10e-04
# Epoch 233 | Time 5.42s | Train NLL -12.740 | Val NLL -11.828 | LR 5.93e-04
# Epoch 234 | Time 5.73s | Train NLL -13.102 | Val NLL -13.148 | LR 5.75e-04
# Epoch 235 | Time 4.05s | Train NLL -13.278 | Val NLL -12.417 | LR 5.59e-04
# Epoch 236 | Time 3.76s | Train NLL -12.457 | Val NLL -13.457 | LR 5.42e-04
# Epoch 237 | Time 4.83s | Train NLL -12.189 | Val NLL -12.655 | LR 5.25e-04
# Epoch 238 | Time 5.47s | Train NLL -13.446 | Val NLL -11.300 | LR 5.09e-04
# Epoch 239 | Time 5.44s | Train NLL -11.885 | Val NLL -9.722 | LR 4.93e-04
# Epoch 240 | Time 5.36s | Train NLL -11.603 | Val NLL -12.801 | LR 4.77e-04
# Epoch 241 | Time 5.53s | Train NLL -13.573 | Val NLL -13.867 | LR 4.62e-04
# Epoch 242 | Time 5.53s | Train NLL -11.940 | Val NLL -12.030 | LR 4.47e-04
# Epoch 243 | Time 5.51s | Train NLL -12.608 | Val NLL -11.640 | LR 4.32e-04
# Epoch 244 | Time 5.34s | Train NLL -13.418 | Val NLL -12.118 | LR 4.17e-04
# Epoch 245 | Time 5.27s | Train NLL -11.715 | Val NLL -12.776 | LR 4.02e-04
# Epoch 246 | Time 5.35s | Train NLL -13.742 | Val NLL -13.243 | LR 3.88e-04
# Epoch 247 | Time 5.55s | Train NLL -13.980 | Val NLL -13.423 | LR 3.74e-04
# Epoch 248 | Time 5.27s | Train NLL -14.103 | Val NLL -13.778 | LR 3.60e-04
# Epoch 249 | Time 3.92s | Train NLL -14.235 | Val NLL -13.877 | LR 3.46e-04
# Epoch 250 | Time 3.94s | Train NLL -14.335 | Val NLL -13.827 | LR 3.33e-04
# Epoch 251 | Time 3.89s | Train NLL -14.449 | Val NLL -14.092 | LR 3.20e-04
# Epoch 252 | Time 5.27s | Train NLL -14.571 | Val NLL -14.542 | LR 3.07e-04
# Epoch 253 | Time 5.40s | Train NLL -14.683 | Val NLL -14.480 | LR 2.94e-04
# Epoch 254 | Time 5.53s | Train NLL -14.770 | Val NLL -14.877 | LR 2.82e-04
# Epoch 255 | Time 5.61s | Train NLL -13.371 | Val NLL -13.867 | LR 2.69e-04
# Epoch 256 | Time 5.48s | Train NLL -14.831 | Val NLL -15.089 | LR 2.58e-04
# Epoch 257 | Time 5.35s | Train NLL -12.774 | Val NLL -13.115 | LR 2.46e-04
# Epoch 258 | Time 5.33s | Train NLL -14.768 | Val NLL -15.078 | LR 2.35e-04
# Epoch 259 | Time 5.50s | Train NLL -15.293 | Val NLL -15.032 | LR 2.23e-04
# Epoch 260 | Time 5.29s | Train NLL -15.284 | Val NLL -14.776 | LR 2.13e-04
# Epoch 261 | Time 5.09s | Train NLL -15.380 | Val NLL -15.361 | LR 2.02e-04
# Epoch 262 | Time 3.84s | Train NLL -15.516 | Val NLL -15.024 | LR 1.92e-04
# Epoch 263 | Time 3.91s | Train NLL -15.629 | Val NLL -15.392 | LR 1.81e-04
# Epoch 264 | Time 4.82s | Train NLL -15.729 | Val NLL -15.571 | LR 1.72e-04
# Epoch 265 | Time 5.52s | Train NLL -15.858 | Val NLL -15.430 | LR 1.62e-04
# Epoch 266 | Time 5.52s | Train NLL -14.775 | Val NLL -15.371 | LR 1.53e-04
# Epoch 267 | Time 5.51s | Train NLL -15.860 | Val NLL -15.962 | LR 1.44e-04
# Epoch 268 | Time 5.69s | Train NLL -16.339 | Val NLL -15.734 | LR 1.35e-04
# Epoch 269 | Time 5.48s | Train NLL -16.017 | Val NLL -16.134 | LR 1.27e-04
# Epoch 270 | Time 5.50s | Train NLL -16.465 | Val NLL -15.591 | LR 1.18e-04
# Epoch 271 | Time 5.57s | Train NLL -16.515 | Val NLL -16.614 | LR 1.10e-04
# Epoch 272 | Time 5.46s | Train NLL -16.244 | Val NLL -15.473 | LR 1.03e-04
# Epoch 273 | Time 5.66s | Train NLL -16.542 | Val NLL -16.584 | LR 9.52e-05
# Epoch 274 | Time 3.89s | Train NLL -16.706 | Val NLL -10.016 | LR 8.81e-05
# Epoch 275 | Time 3.90s | Train NLL -16.337 | Val NLL -16.782 | LR 8.12e-05
# Epoch 276 | Time 4.22s | Train NLL -17.243 | Val NLL -16.495 | LR 7.46e-05
# Epoch 277 | Time 5.60s | Train NLL -17.355 | Val NLL -17.154 | LR 6.83e-05
# Epoch 278 | Time 5.68s | Train NLL -16.475 | Val NLL -17.209 | LR 6.23e-05
# Epoch 279 | Time 5.45s | Train NLL -17.620 | Val NLL -17.658 | LR 5.65e-05
# Epoch 280 | Time 5.49s | Train NLL -17.739 | Val NLL -17.477 | LR 5.10e-05
# Epoch 281 | Time 5.40s | Train NLL -17.803 | Val NLL -17.894 | LR 4.58e-05
# Epoch 282 | Time 5.40s | Train NLL -17.878 | Val NLL -17.917 | LR 4.09e-05
# Epoch 283 | Time 5.62s | Train NLL -18.218 | Val NLL -18.006 | LR 3.62e-05
# Epoch 284 | Time 5.39s | Train NLL -18.273 | Val NLL -18.176 | LR 3.18e-05
# Epoch 285 | Time 5.42s | Train NLL -18.340 | Val NLL -18.203 | LR 2.77e-05
# Epoch 286 | Time 4.82s | Train NLL -18.531 | Val NLL -18.290 | LR 2.39e-05
# Epoch 287 | Time 4.02s | Train NLL -18.594 | Val NLL -18.394 | LR 2.04e-05
# Epoch 288 | Time 3.90s | Train NLL -18.501 | Val NLL -18.305 | LR 1.71e-05
# Epoch 289 | Time 4.46s | Train NLL -18.638 | Val NLL -18.411 | LR 1.42e-05
# Epoch 290 | Time 5.48s | Train NLL -18.795 | Val NLL -18.484 | LR 1.15e-05
# Epoch 291 | Time 5.59s | Train NLL -18.811 | Val NLL -18.514 | LR 9.07e-06
# Epoch 292 | Time 5.47s | Train NLL -18.857 | Val NLL -18.554 | LR 6.94e-06
# Epoch 293 | Time 5.34s | Train NLL -18.891 | Val NLL -18.545 | LR 5.10e-06
# Epoch 294 | Time 5.47s | Train NLL -18.912 | Val NLL -18.585 | LR 3.54e-06
# Epoch 295 | Time 5.56s | Train NLL -18.924 | Val NLL -18.605 | LR 2.27e-06
# Epoch 296 | Time 5.56s | Train NLL -18.929 | Val NLL -18.600 | LR 1.28e-06
# Epoch 297 | Time 5.51s | Train NLL -18.937 | Val NLL -18.612 | LR 5.67e-07
# Epoch 298 | Time 5.53s | Train NLL -18.951 | Val NLL -18.614 | LR 1.42e-07
# Epoch 299 | Time 4.21s | Train NLL -18.949 | Val NLL -18.614 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 65381.61
# Average absolute difference in CASUALTIES: 0.00

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
