# %% [markdown]
# # Heat model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Heat'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 500
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 3.25s | Train NLL 6.507 | Val NLL 2.403 | LR 1.00e-03
# Epoch 001 | Time 1.10s | Train NLL 0.396 | Val NLL 0.455 | LR 2.00e-03
# Epoch 002 | Time 1.15s | Train NLL 0.704 | Val NLL -0.937 | LR 3.00e-03
# Epoch 003 | Time 1.33s | Train NLL 1.426 | Val NLL -0.722 | LR 4.00e-03
# Epoch 004 | Time 1.87s | Train NLL 0.367 | Val NLL 0.307 | LR 5.00e-03
# Epoch 005 | Time 2.05s | Train NLL -1.605 | Val NLL 1.293 | LR 5.00e-03
# Epoch 006 | Time 1.31s | Train NLL -0.346 | Val NLL -1.285 | LR 5.00e-03
# Epoch 007 | Time 1.12s | Train NLL -1.191 | Val NLL 0.822 | LR 5.00e-03
# Epoch 008 | Time 1.09s | Train NLL 0.278 | Val NLL 1.178 | LR 5.00e-03
# Epoch 009 | Time 1.30s | Train NLL -0.746 | Val NLL -1.951 | LR 5.00e-03
# Epoch 010 | Time 1.03s | Train NLL -1.289 | Val NLL 0.050 | LR 5.00e-03
# Epoch 011 | Time 1.09s | Train NLL -1.267 | Val NLL -1.485 | LR 5.00e-03
# Epoch 012 | Time 1.15s | Train NLL -0.915 | Val NLL -1.855 | LR 5.00e-03
# Epoch 013 | Time 1.23s | Train NLL -2.448 | Val NLL -3.037 | LR 5.00e-03
# Epoch 014 | Time 1.17s | Train NLL -3.335 | Val NLL 0.542 | LR 4.99e-03
# Epoch 015 | Time 1.12s | Train NLL -0.618 | Val NLL -1.881 | LR 4.99e-03
# Epoch 016 | Time 1.12s | Train NLL -2.638 | Val NLL -2.243 | LR 4.99e-03
# Epoch 017 | Time 1.17s | Train NLL -0.613 | Val NLL 0.907 | LR 4.99e-03
# Epoch 018 | Time 1.12s | Train NLL -2.682 | Val NLL -2.630 | LR 4.99e-03
# Epoch 019 | Time 1.08s | Train NLL -1.852 | Val NLL -0.799 | LR 4.99e-03
# Epoch 020 | Time 1.18s | Train NLL -1.491 | Val NLL -0.669 | LR 4.99e-03
# Epoch 021 | Time 1.27s | Train NLL -2.801 | Val NLL -4.675 | LR 4.99e-03
# Epoch 022 | Time 1.10s | Train NLL -3.616 | Val NLL -4.603 | LR 4.98e-03
# Epoch 023 | Time 1.18s | Train NLL -3.425 | Val NLL -3.081 | LR 4.98e-03
# Epoch 024 | Time 1.08s | Train NLL -2.423 | Val NLL -4.187 | LR 4.98e-03
# Epoch 025 | Time 1.32s | Train NLL -2.125 | Val NLL -4.634 | LR 4.98e-03
# Epoch 026 | Time 1.38s | Train NLL -2.784 | Val NLL -3.565 | LR 4.98e-03
# Epoch 027 | Time 1.32s | Train NLL -4.491 | Val NLL -2.369 | LR 4.97e-03
# Epoch 028 | Time 1.32s | Train NLL -3.182 | Val NLL -1.019 | LR 4.97e-03
# Epoch 029 | Time 1.30s | Train NLL -3.473 | Val NLL -4.025 | LR 4.97e-03
# Epoch 030 | Time 1.33s | Train NLL -5.340 | Val NLL -5.860 | LR 4.97e-03
# Epoch 031 | Time 1.34s | Train NLL -0.041 | Val NLL -1.943 | LR 4.96e-03
# Epoch 032 | Time 1.29s | Train NLL -3.526 | Val NLL -5.350 | LR 4.96e-03
# Epoch 033 | Time 1.65s | Train NLL -2.783 | Val NLL -1.522 | LR 4.96e-03
# Epoch 034 | Time 1.36s | Train NLL -3.982 | Val NLL -5.110 | LR 4.95e-03
# Epoch 035 | Time 1.30s | Train NLL -3.921 | Val NLL -4.446 | LR 4.95e-03
# Epoch 036 | Time 1.28s | Train NLL -4.668 | Val NLL -3.968 | LR 4.95e-03
# Epoch 037 | Time 1.38s | Train NLL -3.734 | Val NLL -1.382 | LR 4.95e-03
# Epoch 038 | Time 1.47s | Train NLL -3.160 | Val NLL -3.428 | LR 4.94e-03
# Epoch 039 | Time 1.36s | Train NLL -4.410 | Val NLL -1.052 | LR 4.94e-03
# Epoch 040 | Time 1.39s | Train NLL -2.951 | Val NLL -3.612 | LR 4.94e-03
# Epoch 041 | Time 1.75s | Train NLL -4.619 | Val NLL -6.169 | LR 4.93e-03
# Epoch 042 | Time 1.75s | Train NLL -4.372 | Val NLL -4.634 | LR 4.93e-03
# Epoch 043 | Time 1.93s | Train NLL -4.320 | Val NLL -2.278 | LR 4.92e-03
# Epoch 044 | Time 1.65s | Train NLL -3.995 | Val NLL -2.371 | LR 4.92e-03
# Epoch 045 | Time 1.85s | Train NLL -4.615 | Val NLL -0.891 | LR 4.92e-03
# Epoch 046 | Time 1.42s | Train NLL -2.997 | Val NLL -5.493 | LR 4.91e-03
# Epoch 047 | Time 1.27s | Train NLL -4.878 | Val NLL -2.825 | LR 4.91e-03
# Epoch 048 | Time 1.29s | Train NLL -4.890 | Val NLL -5.406 | LR 4.90e-03
# Epoch 049 | Time 1.26s | Train NLL -3.261 | Val NLL 0.897 | LR 4.90e-03
# Epoch 050 | Time 1.32s | Train NLL -2.455 | Val NLL -3.521 | LR 4.89e-03
# Epoch 051 | Time 1.45s | Train NLL -2.524 | Val NLL -2.993 | LR 4.89e-03
# Epoch 052 | Time 1.40s | Train NLL -3.039 | Val NLL -1.137 | LR 4.88e-03
# Epoch 053 | Time 1.35s | Train NLL -3.067 | Val NLL -2.744 | LR 4.88e-03
# Epoch 054 | Time 1.35s | Train NLL 1.632 | Val NLL 4.069 | LR 4.88e-03
# Epoch 055 | Time 1.37s | Train NLL -1.469 | Val NLL -3.973 | LR 4.87e-03
# Epoch 056 | Time 1.34s | Train NLL -5.025 | Val NLL -3.270 | LR 4.87e-03
# Epoch 057 | Time 1.28s | Train NLL -4.287 | Val NLL -2.478 | LR 4.86e-03
# Epoch 058 | Time 1.36s | Train NLL -5.037 | Val NLL -6.525 | LR 4.85e-03
# Epoch 059 | Time 1.38s | Train NLL -6.086 | Val NLL -2.161 | LR 4.85e-03
# Epoch 060 | Time 1.30s | Train NLL -4.864 | Val NLL -5.046 | LR 4.84e-03
# Epoch 061 | Time 1.33s | Train NLL -5.080 | Val NLL -6.440 | LR 4.84e-03
# Epoch 062 | Time 1.40s | Train NLL -4.032 | Val NLL -3.703 | LR 4.83e-03
# Epoch 063 | Time 1.34s | Train NLL -5.212 | Val NLL 0.674 | LR 4.83e-03
# Epoch 064 | Time 1.48s | Train NLL -1.330 | Val NLL -3.014 | LR 4.82e-03
# Epoch 065 | Time 1.35s | Train NLL -3.766 | Val NLL -4.484 | LR 4.81e-03
# Epoch 066 | Time 1.38s | Train NLL -5.828 | Val NLL -7.182 | LR 4.81e-03
# Epoch 067 | Time 1.38s | Train NLL -3.245 | Val NLL -0.278 | LR 4.80e-03
# Epoch 068 | Time 1.52s | Train NLL -3.334 | Val NLL -4.973 | LR 4.80e-03
# Epoch 069 | Time 1.48s | Train NLL -4.862 | Val NLL -4.713 | LR 4.79e-03
# Epoch 070 | Time 1.45s | Train NLL -5.938 | Val NLL -5.837 | LR 4.78e-03
# Epoch 071 | Time 1.33s | Train NLL -5.724 | Val NLL -4.945 | LR 4.78e-03
# Epoch 072 | Time 1.39s | Train NLL -2.179 | Val NLL -2.054 | LR 4.77e-03
# Epoch 073 | Time 1.31s | Train NLL -2.386 | Val NLL -4.623 | LR 4.76e-03
# Epoch 074 | Time 1.33s | Train NLL -5.383 | Val NLL -6.401 | LR 4.76e-03
# Epoch 075 | Time 1.37s | Train NLL -6.267 | Val NLL -5.963 | LR 4.75e-03
# Epoch 076 | Time 1.40s | Train NLL -5.338 | Val NLL -4.436 | LR 4.74e-03
# Epoch 077 | Time 1.50s | Train NLL -5.778 | Val NLL -6.660 | LR 4.74e-03
# Epoch 078 | Time 1.34s | Train NLL -6.967 | Val NLL -1.221 | LR 4.73e-03
# Epoch 079 | Time 1.33s | Train NLL -4.251 | Val NLL -4.259 | LR 4.72e-03
# Epoch 080 | Time 1.43s | Train NLL -5.613 | Val NLL -6.154 | LR 4.71e-03
# Epoch 081 | Time 1.44s | Train NLL -3.001 | Val NLL -2.783 | LR 4.71e-03
# Epoch 082 | Time 1.53s | Train NLL -3.840 | Val NLL -4.642 | LR 4.70e-03
# Epoch 083 | Time 1.47s | Train NLL -5.196 | Val NLL -5.634 | LR 4.69e-03
# Epoch 084 | Time 1.48s | Train NLL -4.343 | Val NLL -5.299 | LR 4.68e-03
# Epoch 085 | Time 1.50s | Train NLL -6.490 | Val NLL -2.452 | LR 4.68e-03
# Epoch 086 | Time 1.52s | Train NLL -2.425 | Val NLL -0.248 | LR 4.67e-03
# Epoch 087 | Time 1.40s | Train NLL -4.166 | Val NLL -4.735 | LR 4.66e-03
# Epoch 088 | Time 1.53s | Train NLL -4.324 | Val NLL -4.949 | LR 4.65e-03
# Epoch 089 | Time 1.53s | Train NLL -5.982 | Val NLL -4.790 | LR 4.64e-03
# Epoch 090 | Time 1.53s | Train NLL -5.295 | Val NLL -5.815 | LR 4.64e-03
# Epoch 091 | Time 1.38s | Train NLL -5.805 | Val NLL -1.686 | LR 4.63e-03
# Epoch 092 | Time 1.40s | Train NLL -4.169 | Val NLL -4.948 | LR 4.62e-03
# Epoch 093 | Time 1.38s | Train NLL -6.309 | Val NLL -6.871 | LR 4.61e-03
# Epoch 094 | Time 1.46s | Train NLL -5.813 | Val NLL -4.293 | LR 4.60e-03
# Epoch 095 | Time 1.35s | Train NLL -5.511 | Val NLL -6.201 | LR 4.59e-03
# Epoch 096 | Time 1.37s | Train NLL -6.860 | Val NLL -6.174 | LR 4.59e-03
# Epoch 097 | Time 1.33s | Train NLL -6.043 | Val NLL -2.929 | LR 4.58e-03
# Epoch 098 | Time 1.29s | Train NLL -4.668 | Val NLL -5.228 | LR 4.57e-03
# Epoch 099 | Time 1.32s | Train NLL -6.824 | Val NLL -6.877 | LR 4.56e-03
# Epoch 100 | Time 1.35s | Train NLL -6.910 | Val NLL -7.043 | LR 4.55e-03
# Epoch 101 | Time 1.27s | Train NLL -4.460 | Val NLL -5.594 | LR 4.54e-03
# Epoch 102 | Time 1.28s | Train NLL -6.649 | Val NLL -7.007 | LR 4.53e-03
# Epoch 103 | Time 1.42s | Train NLL -7.673 | Val NLL -5.717 | LR 4.52e-03
# Epoch 104 | Time 1.33s | Train NLL -2.014 | Val NLL 1.982 | LR 4.51e-03
# Epoch 105 | Time 1.36s | Train NLL -2.571 | Val NLL -4.363 | LR 4.50e-03
# Epoch 106 | Time 1.33s | Train NLL -5.686 | Val NLL -6.162 | LR 4.49e-03
# Epoch 107 | Time 1.27s | Train NLL -7.110 | Val NLL -4.874 | LR 4.48e-03
# Epoch 108 | Time 1.28s | Train NLL -4.565 | Val NLL -6.485 | LR 4.47e-03
# Epoch 109 | Time 1.26s | Train NLL -6.225 | Val NLL -6.676 | LR 4.47e-03
# Epoch 110 | Time 1.33s | Train NLL -5.771 | Val NLL -1.735 | LR 4.46e-03
# Epoch 111 | Time 1.34s | Train NLL -1.369 | Val NLL -0.902 | LR 4.45e-03
# Epoch 112 | Time 1.45s | Train NLL -4.097 | Val NLL -5.541 | LR 4.44e-03
# Epoch 113 | Time 1.37s | Train NLL -5.803 | Val NLL -1.762 | LR 4.43e-03
# Epoch 114 | Time 1.32s | Train NLL -5.250 | Val NLL -6.052 | LR 4.42e-03
# Epoch 115 | Time 1.54s | Train NLL -7.201 | Val NLL -5.622 | LR 4.40e-03
# Epoch 116 | Time 1.35s | Train NLL -7.801 | Val NLL -4.421 | LR 4.39e-03
# Epoch 117 | Time 1.35s | Train NLL -5.451 | Val NLL -6.912 | LR 4.38e-03
# Epoch 118 | Time 1.36s | Train NLL -5.593 | Val NLL -3.119 | LR 4.37e-03
# Epoch 119 | Time 1.48s | Train NLL -5.357 | Val NLL -5.774 | LR 4.36e-03
# Epoch 120 | Time 1.47s | Train NLL -6.984 | Val NLL -7.439 | LR 4.35e-03
# Epoch 121 | Time 1.46s | Train NLL -5.211 | Val NLL -4.850 | LR 4.34e-03
# Epoch 122 | Time 1.52s | Train NLL -5.572 | Val NLL -6.297 | LR 4.33e-03
# Epoch 123 | Time 1.70s | Train NLL -5.607 | Val NLL -2.859 | LR 4.32e-03
# Epoch 124 | Time 1.38s | Train NLL -2.703 | Val NLL -2.448 | LR 4.31e-03
# Epoch 125 | Time 1.40s | Train NLL -5.042 | Val NLL -6.461 | LR 4.30e-03
# Epoch 126 | Time 1.47s | Train NLL -6.952 | Val NLL -7.601 | LR 4.29e-03
# Epoch 127 | Time 1.46s | Train NLL -7.404 | Val NLL -5.597 | LR 4.28e-03
# Epoch 128 | Time 1.63s | Train NLL -6.652 | Val NLL -5.775 | LR 4.26e-03
# Epoch 129 | Time 1.37s | Train NLL -6.547 | Val NLL -6.972 | LR 4.25e-03
# Epoch 130 | Time 1.45s | Train NLL -6.886 | Val NLL -7.130 | LR 4.24e-03
# Epoch 131 | Time 1.47s | Train NLL -6.759 | Val NLL -6.382 | LR 4.23e-03
# Epoch 132 | Time 1.37s | Train NLL -5.319 | Val NLL -3.912 | LR 4.22e-03
# Epoch 133 | Time 1.50s | Train NLL -5.292 | Val NLL -6.477 | LR 4.21e-03
# Epoch 134 | Time 1.53s | Train NLL -6.809 | Val NLL -3.672 | LR 4.20e-03
# Epoch 135 | Time 1.33s | Train NLL -5.643 | Val NLL -5.984 | LR 4.18e-03
# Epoch 136 | Time 1.38s | Train NLL -6.705 | Val NLL -6.831 | LR 4.17e-03
# Epoch 137 | Time 1.48s | Train NLL -3.317 | Val NLL -4.123 | LR 4.16e-03
# Epoch 138 | Time 1.42s | Train NLL -5.156 | Val NLL -4.279 | LR 4.15e-03
# Epoch 139 | Time 1.55s | Train NLL -6.077 | Val NLL -7.002 | LR 4.14e-03
# Epoch 140 | Time 1.53s | Train NLL -5.498 | Val NLL -6.180 | LR 4.13e-03
# Epoch 141 | Time 1.50s | Train NLL -1.793 | Val NLL -4.671 | LR 4.11e-03
# Epoch 142 | Time 1.52s | Train NLL -4.828 | Val NLL -6.364 | LR 4.10e-03
# Epoch 143 | Time 1.42s | Train NLL -7.479 | Val NLL -6.254 | LR 4.09e-03
# Epoch 144 | Time 1.52s | Train NLL -6.958 | Val NLL -7.044 | LR 4.08e-03
# Epoch 145 | Time 1.50s | Train NLL -7.288 | Val NLL -7.986 | LR 4.06e-03
# Epoch 146 | Time 1.43s | Train NLL -5.025 | Val NLL -4.585 | LR 4.05e-03
# Epoch 147 | Time 1.70s | Train NLL -5.477 | Val NLL -2.796 | LR 4.04e-03
# Epoch 148 | Time 1.70s | Train NLL -2.812 | Val NLL -4.237 | LR 4.03e-03
# Epoch 149 | Time 1.62s | Train NLL -5.115 | Val NLL -4.978 | LR 4.01e-03
# Epoch 150 | Time 1.97s | Train NLL -5.451 | Val NLL -6.388 | LR 4.00e-03
# Epoch 151 | Time 2.25s | Train NLL -6.752 | Val NLL -5.565 | LR 3.99e-03
# Epoch 152 | Time 1.72s | Train NLL -5.856 | Val NLL -1.563 | LR 3.98e-03
# Epoch 153 | Time 1.93s | Train NLL -3.868 | Val NLL 0.567 | LR 3.96e-03
# Epoch 154 | Time 2.30s | Train NLL -2.436 | Val NLL 0.225 | LR 3.95e-03
# Epoch 155 | Time 1.88s | Train NLL -4.574 | Val NLL -4.306 | LR 3.94e-03
# Epoch 156 | Time 1.65s | Train NLL -6.448 | Val NLL -6.933 | LR 3.92e-03
# Epoch 157 | Time 1.51s | Train NLL -7.130 | Val NLL -1.207 | LR 3.91e-03
# Epoch 158 | Time 1.55s | Train NLL -3.859 | Val NLL -6.496 | LR 3.90e-03
# Epoch 159 | Time 1.69s | Train NLL -7.872 | Val NLL -6.638 | LR 3.88e-03
# Epoch 160 | Time 1.50s | Train NLL 0.261 | Val NLL 3.245 | LR 3.87e-03
# Epoch 161 | Time 1.63s | Train NLL -2.250 | Val NLL -4.539 | LR 3.86e-03
# Epoch 162 | Time 1.66s | Train NLL -6.728 | Val NLL -7.220 | LR 3.84e-03
# Epoch 163 | Time 1.65s | Train NLL -4.996 | Val NLL -5.806 | LR 3.83e-03
# Epoch 164 | Time 1.52s | Train NLL -3.562 | Val NLL -4.649 | LR 3.82e-03
# Epoch 165 | Time 1.76s | Train NLL -4.764 | Val NLL -5.898 | LR 3.80e-03
# Epoch 166 | Time 1.73s | Train NLL -4.290 | Val NLL -4.768 | LR 3.79e-03
# Epoch 167 | Time 1.72s | Train NLL -6.022 | Val NLL -6.848 | LR 3.78e-03
# Epoch 168 | Time 1.53s | Train NLL -7.530 | Val NLL -7.599 | LR 3.76e-03
# Epoch 169 | Time 1.41s | Train NLL -7.204 | Val NLL -0.594 | LR 3.75e-03
# Epoch 170 | Time 1.45s | Train NLL -5.432 | Val NLL -5.620 | LR 3.74e-03
# Epoch 171 | Time 1.42s | Train NLL -6.416 | Val NLL -6.679 | LR 3.72e-03
# Epoch 172 | Time 1.35s | Train NLL -6.516 | Val NLL -1.459 | LR 3.71e-03
# Epoch 173 | Time 1.54s | Train NLL -4.699 | Val NLL -5.941 | LR 3.69e-03
# Epoch 174 | Time 1.48s | Train NLL -7.161 | Val NLL -6.893 | LR 3.68e-03
# Epoch 175 | Time 1.57s | Train NLL -7.576 | Val NLL -7.769 | LR 3.67e-03
# Epoch 176 | Time 1.55s | Train NLL -8.032 | Val NLL -7.774 | LR 3.65e-03
# Epoch 177 | Time 1.50s | Train NLL -5.244 | Val NLL -6.952 | LR 3.64e-03
# Epoch 178 | Time 1.65s | Train NLL -7.859 | Val NLL -8.047 | LR 3.62e-03
# Epoch 179 | Time 2.44s | Train NLL -7.764 | Val NLL -7.887 | LR 3.61e-03
# Epoch 180 | Time 1.72s | Train NLL -8.336 | Val NLL -3.736 | LR 3.60e-03
# Epoch 181 | Time 1.66s | Train NLL -3.718 | Val NLL -2.970 | LR 3.58e-03
# Epoch 182 | Time 1.44s | Train NLL -5.519 | Val NLL -1.050 | LR 3.57e-03
# Epoch 183 | Time 1.43s | Train NLL -2.757 | Val NLL -2.754 | LR 3.55e-03
# Epoch 184 | Time 1.55s | Train NLL -5.622 | Val NLL -4.902 | LR 3.54e-03
# Epoch 185 | Time 1.37s | Train NLL -6.704 | Val NLL -7.780 | LR 3.52e-03
# Epoch 186 | Time 1.39s | Train NLL -6.882 | Val NLL -3.465 | LR 3.51e-03
# Epoch 187 | Time 1.38s | Train NLL -6.755 | Val NLL -6.200 | LR 3.50e-03
# Epoch 188 | Time 1.42s | Train NLL -8.220 | Val NLL -8.258 | LR 3.48e-03
# Epoch 189 | Time 1.41s | Train NLL -6.190 | Val NLL -6.260 | LR 3.47e-03
# Epoch 190 | Time 1.50s | Train NLL -7.981 | Val NLL -8.503 | LR 3.45e-03
# Epoch 191 | Time 1.40s | Train NLL -7.766 | Val NLL -6.850 | LR 3.44e-03
# Epoch 192 | Time 1.55s | Train NLL -8.174 | Val NLL -8.930 | LR 3.42e-03
# Epoch 193 | Time 1.60s | Train NLL -6.849 | Val NLL -5.121 | LR 3.41e-03
# Epoch 194 | Time 1.33s | Train NLL -7.202 | Val NLL -8.024 | LR 3.39e-03
# Epoch 195 | Time 1.50s | Train NLL -8.706 | Val NLL -5.473 | LR 3.38e-03
# Epoch 196 | Time 1.40s | Train NLL -5.540 | Val NLL -1.362 | LR 3.36e-03
# Epoch 197 | Time 1.55s | Train NLL -4.252 | Val NLL -5.678 | LR 3.35e-03
# Epoch 198 | Time 1.48s | Train NLL -7.479 | Val NLL -7.806 | LR 3.33e-03
# Epoch 199 | Time 1.40s | Train NLL -8.480 | Val NLL -8.216 | LR 3.32e-03
# Epoch 200 | Time 1.58s | Train NLL -8.821 | Val NLL -6.843 | LR 3.30e-03
# Epoch 201 | Time 1.45s | Train NLL -2.717 | Val NLL -2.076 | LR 3.29e-03
# Epoch 202 | Time 1.40s | Train NLL -3.635 | Val NLL -4.681 | LR 3.27e-03
# Epoch 203 | Time 1.47s | Train NLL -5.877 | Val NLL -6.673 | LR 3.26e-03
# Epoch 204 | Time 1.42s | Train NLL -7.936 | Val NLL -8.083 | LR 3.24e-03
# Epoch 205 | Time 1.48s | Train NLL -8.205 | Val NLL -8.683 | LR 3.23e-03
# Epoch 206 | Time 1.40s | Train NLL -8.289 | Val NLL -5.376 | LR 3.21e-03
# Epoch 207 | Time 1.45s | Train NLL -6.865 | Val NLL -7.927 | LR 3.20e-03
# Epoch 208 | Time 1.48s | Train NLL -8.686 | Val NLL -8.288 | LR 3.18e-03
# Epoch 209 | Time 1.38s | Train NLL -7.520 | Val NLL -4.961 | LR 3.17e-03
# Epoch 210 | Time 1.38s | Train NLL -6.776 | Val NLL -8.020 | LR 3.15e-03
# Epoch 211 | Time 1.62s | Train NLL -8.818 | Val NLL -7.229 | LR 3.14e-03
# Epoch 212 | Time 1.43s | Train NLL -6.917 | Val NLL -6.977 | LR 3.12e-03
# Epoch 213 | Time 1.37s | Train NLL -7.810 | Val NLL -8.075 | LR 3.10e-03
# Epoch 214 | Time 1.42s | Train NLL -8.669 | Val NLL -6.302 | LR 3.09e-03
# Epoch 215 | Time 1.40s | Train NLL -7.902 | Val NLL -7.586 | LR 3.07e-03
# Epoch 216 | Time 1.45s | Train NLL -8.009 | Val NLL -8.399 | LR 3.06e-03
# Epoch 217 | Time 1.40s | Train NLL -3.299 | Val NLL -5.936 | LR 3.04e-03
# Epoch 218 | Time 1.36s | Train NLL -7.495 | Val NLL -8.232 | LR 3.03e-03
# Epoch 219 | Time 1.35s | Train NLL -6.841 | Val NLL -8.728 | LR 3.01e-03
# Epoch 220 | Time 1.39s | Train NLL -6.325 | Val NLL -5.143 | LR 3.00e-03
# Epoch 221 | Time 1.44s | Train NLL -6.430 | Val NLL -7.981 | LR 2.98e-03
# Epoch 222 | Time 1.37s | Train NLL -8.341 | Val NLL -8.320 | LR 2.97e-03
# Epoch 223 | Time 1.30s | Train NLL -8.537 | Val NLL -8.104 | LR 2.95e-03
# Epoch 224 | Time 1.35s | Train NLL -3.557 | Val NLL -4.119 | LR 2.93e-03
# Epoch 225 | Time 1.35s | Train NLL -0.816 | Val NLL -2.677 | LR 2.92e-03
# Epoch 226 | Time 1.68s | Train NLL -4.372 | Val NLL -3.539 | LR 2.90e-03
# Epoch 227 | Time 1.37s | Train NLL -4.497 | Val NLL -3.896 | LR 2.89e-03
# Epoch 228 | Time 1.45s | Train NLL -5.641 | Val NLL -6.857 | LR 2.87e-03
# Epoch 229 | Time 1.49s | Train NLL -8.032 | Val NLL -7.194 | LR 2.86e-03
# Epoch 230 | Time 1.36s | Train NLL -6.484 | Val NLL -5.265 | LR 2.84e-03
# Epoch 231 | Time 1.47s | Train NLL -7.262 | Val NLL -8.048 | LR 2.82e-03
# Epoch 232 | Time 1.45s | Train NLL -8.991 | Val NLL -6.645 | LR 2.81e-03
# Epoch 233 | Time 1.40s | Train NLL -8.476 | Val NLL -8.101 | LR 2.79e-03
# Epoch 234 | Time 1.46s | Train NLL -7.612 | Val NLL -7.002 | LR 2.78e-03
# Epoch 235 | Time 1.47s | Train NLL -7.837 | Val NLL -7.765 | LR 2.76e-03
# Epoch 236 | Time 1.45s | Train NLL -8.467 | Val NLL -6.686 | LR 2.75e-03
# Epoch 237 | Time 1.43s | Train NLL -9.113 | Val NLL -8.797 | LR 2.73e-03
# Epoch 238 | Time 1.37s | Train NLL -3.907 | Val NLL 3.872 | LR 2.71e-03
# Epoch 239 | Time 1.35s | Train NLL -2.676 | Val NLL -6.073 | LR 2.70e-03
# Epoch 240 | Time 1.39s | Train NLL -7.254 | Val NLL -8.070 | LR 2.68e-03
# Epoch 241 | Time 1.36s | Train NLL -5.528 | Val NLL -7.757 | LR 2.67e-03
# Epoch 242 | Time 1.60s | Train NLL -4.198 | Val NLL -2.798 | LR 2.65e-03
# Epoch 243 | Time 1.45s | Train NLL -4.166 | Val NLL -0.872 | LR 2.63e-03
# Epoch 244 | Time 1.43s | Train NLL -6.386 | Val NLL -8.256 | LR 2.62e-03
# Epoch 245 | Time 1.57s | Train NLL -8.213 | Val NLL -5.723 | LR 2.60e-03
# Epoch 246 | Time 1.55s | Train NLL -6.116 | Val NLL -7.265 | LR 2.59e-03
# Epoch 247 | Time 1.42s | Train NLL -6.613 | Val NLL -5.654 | LR 2.57e-03
# Epoch 248 | Time 1.42s | Train NLL -8.324 | Val NLL -8.527 | LR 2.56e-03
# Epoch 249 | Time 1.46s | Train NLL -8.033 | Val NLL -8.155 | LR 2.54e-03
# Epoch 250 | Time 1.52s | Train NLL -6.948 | Val NLL -8.093 | LR 2.52e-03
# Epoch 251 | Time 1.34s | Train NLL -8.361 | Val NLL -8.456 | LR 2.51e-03
# Epoch 252 | Time 1.39s | Train NLL -9.006 | Val NLL -3.595 | LR 2.49e-03
# Epoch 253 | Time 1.42s | Train NLL -3.226 | Val NLL -5.998 | LR 2.48e-03
# Epoch 254 | Time 1.37s | Train NLL -8.066 | Val NLL -6.595 | LR 2.46e-03
# Epoch 255 | Time 1.37s | Train NLL -8.473 | Val NLL -8.658 | LR 2.44e-03
# Epoch 256 | Time 1.33s | Train NLL -9.116 | Val NLL -6.696 | LR 2.43e-03
# Epoch 257 | Time 1.47s | Train NLL -7.372 | Val NLL -7.536 | LR 2.41e-03
# Epoch 258 | Time 1.35s | Train NLL -8.790 | Val NLL -8.637 | LR 2.40e-03
# Epoch 259 | Time 1.42s | Train NLL -9.058 | Val NLL -9.566 | LR 2.38e-03
# Epoch 260 | Time 1.37s | Train NLL -8.952 | Val NLL -9.146 | LR 2.37e-03
# Epoch 261 | Time 1.41s | Train NLL -8.674 | Val NLL -7.985 | LR 2.35e-03
# Epoch 262 | Time 1.43s | Train NLL -9.424 | Val NLL -9.573 | LR 2.33e-03
# Epoch 263 | Time 1.30s | Train NLL -8.492 | Val NLL -8.097 | LR 2.32e-03
# Epoch 264 | Time 1.40s | Train NLL -8.993 | Val NLL -8.766 | LR 2.30e-03
# Epoch 265 | Time 1.38s | Train NLL -8.865 | Val NLL -8.027 | LR 2.29e-03
# Epoch 266 | Time 1.35s | Train NLL -9.642 | Val NLL -9.516 | LR 2.27e-03
# Epoch 267 | Time 1.40s | Train NLL -8.707 | Val NLL -9.813 | LR 2.25e-03
# Epoch 268 | Time 1.39s | Train NLL -9.281 | Val NLL -8.435 | LR 2.24e-03
# Epoch 269 | Time 1.38s | Train NLL -9.193 | Val NLL -8.560 | LR 2.22e-03
# Epoch 270 | Time 1.33s | Train NLL -9.458 | Val NLL -8.452 | LR 2.21e-03
# Epoch 271 | Time 1.37s | Train NLL -9.705 | Val NLL -9.826 | LR 2.19e-03
# Epoch 272 | Time 1.39s | Train NLL -9.895 | Val NLL -8.620 | LR 2.18e-03
# Epoch 273 | Time 1.48s | Train NLL -9.781 | Val NLL -8.795 | LR 2.16e-03
# Epoch 274 | Time 1.33s | Train NLL -9.783 | Val NLL -8.633 | LR 2.14e-03
# Epoch 275 | Time 1.37s | Train NLL -10.098 | Val NLL -10.311 | LR 2.13e-03
# Epoch 276 | Time 1.33s | Train NLL -10.303 | Val NLL -10.295 | LR 2.11e-03
# Epoch 277 | Time 1.35s | Train NLL -9.912 | Val NLL -9.035 | LR 2.10e-03
# Epoch 278 | Time 1.36s | Train NLL -9.382 | Val NLL -9.263 | LR 2.08e-03
# Epoch 279 | Time 1.32s | Train NLL -9.966 | Val NLL -9.515 | LR 2.07e-03
# Epoch 280 | Time 1.40s | Train NLL -10.438 | Val NLL -10.188 | LR 2.05e-03
# Epoch 281 | Time 1.35s | Train NLL -8.595 | Val NLL -9.151 | LR 2.03e-03
# Epoch 282 | Time 1.31s | Train NLL -7.878 | Val NLL -8.175 | LR 2.02e-03
# Epoch 283 | Time 1.32s | Train NLL -9.488 | Val NLL -9.351 | LR 2.00e-03
# Epoch 284 | Time 1.38s | Train NLL -10.061 | Val NLL -10.597 | LR 1.99e-03
# Epoch 285 | Time 1.48s | Train NLL -9.116 | Val NLL -8.361 | LR 1.97e-03
# Epoch 286 | Time 1.35s | Train NLL -8.606 | Val NLL -6.950 | LR 1.96e-03
# Epoch 287 | Time 1.36s | Train NLL -8.343 | Val NLL -8.804 | LR 1.94e-03
# Epoch 288 | Time 1.53s | Train NLL -10.038 | Val NLL -9.879 | LR 1.93e-03
# Epoch 289 | Time 1.35s | Train NLL -10.731 | Val NLL -10.552 | LR 1.91e-03
# Epoch 290 | Time 1.35s | Train NLL -7.807 | Val NLL -7.736 | LR 1.90e-03
# Epoch 291 | Time 1.40s | Train NLL -7.244 | Val NLL -9.506 | LR 1.88e-03
# Epoch 292 | Time 1.35s | Train NLL -9.081 | Val NLL -9.795 | LR 1.86e-03
# Epoch 293 | Time 1.35s | Train NLL -9.902 | Val NLL -8.179 | LR 1.85e-03
# Epoch 294 | Time 1.53s | Train NLL -10.035 | Val NLL -10.412 | LR 1.83e-03
# Epoch 295 | Time 1.43s | Train NLL -10.630 | Val NLL -10.933 | LR 1.82e-03
# Epoch 296 | Time 1.45s | Train NLL -11.225 | Val NLL -11.119 | LR 1.80e-03
# Epoch 297 | Time 1.35s | Train NLL -7.852 | Val NLL -6.974 | LR 1.79e-03
# Epoch 298 | Time 1.49s | Train NLL -2.110 | Val NLL -5.051 | LR 1.77e-03
# Epoch 299 | Time 1.53s | Train NLL -5.305 | Val NLL -8.115 | LR 1.76e-03
# Epoch 300 | Time 1.47s | Train NLL -9.037 | Val NLL -8.953 | LR 1.74e-03
# Epoch 301 | Time 1.40s | Train NLL -9.696 | Val NLL -10.259 | LR 1.73e-03
# Epoch 302 | Time 1.47s | Train NLL -9.733 | Val NLL -6.756 | LR 1.71e-03
# Epoch 303 | Time 1.43s | Train NLL -9.109 | Val NLL -9.804 | LR 1.70e-03
# Epoch 304 | Time 1.49s | Train NLL -10.231 | Val NLL -9.640 | LR 1.68e-03
# Epoch 305 | Time 1.35s | Train NLL -10.337 | Val NLL -10.277 | LR 1.67e-03
# Epoch 306 | Time 1.35s | Train NLL -10.144 | Val NLL -9.356 | LR 1.65e-03
# Epoch 307 | Time 1.35s | Train NLL -10.502 | Val NLL -9.829 | LR 1.64e-03
# Epoch 308 | Time 1.35s | Train NLL -10.660 | Val NLL -10.824 | LR 1.62e-03
# Epoch 309 | Time 1.50s | Train NLL -11.101 | Val NLL -10.526 | LR 1.61e-03
# Epoch 310 | Time 1.38s | Train NLL -11.205 | Val NLL -10.282 | LR 1.59e-03
# Epoch 311 | Time 1.36s | Train NLL -11.136 | Val NLL -10.946 | LR 1.58e-03
# Epoch 312 | Time 1.53s | Train NLL -6.267 | Val NLL -5.536 | LR 1.56e-03
# Epoch 313 | Time 1.41s | Train NLL -7.962 | Val NLL -8.180 | LR 1.55e-03
# Epoch 314 | Time 1.36s | Train NLL -10.085 | Val NLL -8.753 | LR 1.53e-03
# Epoch 315 | Time 1.35s | Train NLL -10.963 | Val NLL -10.761 | LR 1.52e-03
# Epoch 316 | Time 1.43s | Train NLL -10.935 | Val NLL -10.508 | LR 1.50e-03
# Epoch 317 | Time 1.38s | Train NLL -11.125 | Val NLL -10.503 | LR 1.49e-03
# Epoch 318 | Time 1.36s | Train NLL -11.169 | Val NLL -9.531 | LR 1.48e-03
# Epoch 319 | Time 1.52s | Train NLL -9.965 | Val NLL -8.378 | LR 1.46e-03
# Epoch 320 | Time 1.33s | Train NLL -10.075 | Val NLL -9.825 | LR 1.45e-03
# Epoch 321 | Time 1.42s | Train NLL -10.798 | Val NLL -10.787 | LR 1.43e-03
# Epoch 322 | Time 1.38s | Train NLL -11.356 | Val NLL -11.055 | LR 1.42e-03
# Epoch 323 | Time 1.37s | Train NLL -11.271 | Val NLL -9.863 | LR 1.40e-03
# Epoch 324 | Time 1.85s | Train NLL -11.421 | Val NLL -10.831 | LR 1.39e-03
# Epoch 325 | Time 1.48s | Train NLL -11.450 | Val NLL -11.118 | LR 1.38e-03
# Epoch 326 | Time 1.75s | Train NLL -11.287 | Val NLL -12.004 | LR 1.36e-03
# Epoch 327 | Time 1.65s | Train NLL -11.095 | Val NLL -7.235 | LR 1.35e-03
# Epoch 328 | Time 1.37s | Train NLL -7.771 | Val NLL -7.879 | LR 1.33e-03
# Epoch 329 | Time 1.43s | Train NLL -9.133 | Val NLL -8.950 | LR 1.32e-03
# Epoch 330 | Time 1.38s | Train NLL -10.443 | Val NLL -9.231 | LR 1.31e-03
# Epoch 331 | Time 1.34s | Train NLL -9.374 | Val NLL -7.326 | LR 1.29e-03
# Epoch 332 | Time 1.26s | Train NLL -9.244 | Val NLL -9.519 | LR 1.28e-03
# Epoch 333 | Time 1.30s | Train NLL -10.494 | Val NLL -10.017 | LR 1.26e-03
# Epoch 334 | Time 1.33s | Train NLL -11.202 | Val NLL -10.741 | LR 1.25e-03
# Epoch 335 | Time 1.42s | Train NLL -9.696 | Val NLL -9.649 | LR 1.24e-03
# Epoch 336 | Time 1.30s | Train NLL -10.769 | Val NLL -10.864 | LR 1.22e-03
# Epoch 337 | Time 1.27s | Train NLL -11.437 | Val NLL -11.449 | LR 1.21e-03
# Epoch 338 | Time 1.30s | Train NLL -10.959 | Val NLL -10.885 | LR 1.20e-03
# Epoch 339 | Time 1.28s | Train NLL -10.697 | Val NLL -11.640 | LR 1.18e-03
# Epoch 340 | Time 1.23s | Train NLL -10.737 | Val NLL -10.564 | LR 1.17e-03
# Epoch 341 | Time 1.27s | Train NLL -7.776 | Val NLL -9.480 | LR 1.16e-03
# Epoch 342 | Time 1.25s | Train NLL -10.991 | Val NLL -11.162 | LR 1.14e-03
# Epoch 343 | Time 1.38s | Train NLL -11.033 | Val NLL -8.403 | LR 1.13e-03
# Epoch 344 | Time 1.33s | Train NLL -9.021 | Val NLL -10.463 | LR 1.12e-03
# Epoch 345 | Time 1.37s | Train NLL -10.553 | Val NLL -10.743 | LR 1.10e-03
# Epoch 346 | Time 1.37s | Train NLL -11.694 | Val NLL -11.806 | LR 1.09e-03
# Epoch 347 | Time 1.40s | Train NLL -11.824 | Val NLL -9.574 | LR 1.08e-03
# Epoch 348 | Time 1.55s | Train NLL -9.218 | Val NLL -5.978 | LR 1.06e-03
# Epoch 349 | Time 1.48s | Train NLL -9.787 | Val NLL -10.733 | LR 1.05e-03
# Epoch 350 | Time 1.63s | Train NLL -11.504 | Val NLL -11.433 | LR 1.04e-03
# Epoch 351 | Time 1.50s | Train NLL -12.140 | Val NLL -11.768 | LR 1.02e-03
# Epoch 352 | Time 1.41s | Train NLL -11.723 | Val NLL -10.923 | LR 1.01e-03
# Epoch 353 | Time 1.33s | Train NLL -9.377 | Val NLL -10.432 | LR 9.99e-04
# Epoch 354 | Time 1.30s | Train NLL -8.460 | Val NLL -10.344 | LR 9.86e-04
# Epoch 355 | Time 1.42s | Train NLL -11.212 | Val NLL -11.315 | LR 9.73e-04
# Epoch 356 | Time 1.37s | Train NLL -11.978 | Val NLL -11.890 | LR 9.61e-04
# Epoch 357 | Time 1.30s | Train NLL -11.083 | Val NLL -11.819 | LR 9.48e-04
# Epoch 358 | Time 1.38s | Train NLL -12.058 | Val NLL -11.605 | LR 9.36e-04
# Epoch 359 | Time 1.35s | Train NLL -12.219 | Val NLL -10.429 | LR 9.24e-04
# Epoch 360 | Time 1.32s | Train NLL -9.787 | Val NLL -11.506 | LR 9.11e-04
# Epoch 361 | Time 1.33s | Train NLL -10.910 | Val NLL -11.512 | LR 8.99e-04
# Epoch 362 | Time 1.37s | Train NLL -11.638 | Val NLL -11.579 | LR 8.87e-04
# Epoch 363 | Time 1.37s | Train NLL -12.230 | Val NLL -11.740 | LR 8.75e-04
# Epoch 364 | Time 1.34s | Train NLL -11.865 | Val NLL -9.118 | LR 8.63e-04
# Epoch 365 | Time 1.35s | Train NLL -8.257 | Val NLL -7.643 | LR 8.51e-04
# Epoch 366 | Time 1.46s | Train NLL -9.746 | Val NLL -10.637 | LR 8.39e-04
# Epoch 367 | Time 1.38s | Train NLL -11.317 | Val NLL -11.873 | LR 8.27e-04
# Epoch 368 | Time 1.31s | Train NLL -12.046 | Val NLL -11.986 | LR 8.15e-04
# Epoch 369 | Time 1.34s | Train NLL -12.344 | Val NLL -11.767 | LR 8.04e-04
# Epoch 370 | Time 1.38s | Train NLL -11.731 | Val NLL -9.311 | LR 7.92e-04
# Epoch 371 | Time 1.41s | Train NLL -10.186 | Val NLL -11.890 | LR 7.81e-04
# Epoch 372 | Time 1.43s | Train NLL -12.129 | Val NLL -12.542 | LR 7.69e-04
# Epoch 373 | Time 1.38s | Train NLL -12.429 | Val NLL -12.197 | LR 7.58e-04
# Epoch 374 | Time 1.37s | Train NLL -11.973 | Val NLL -9.669 | LR 7.46e-04
# Epoch 375 | Time 1.32s | Train NLL -10.631 | Val NLL -10.632 | LR 7.35e-04
# Epoch 376 | Time 1.40s | Train NLL -11.345 | Val NLL -11.663 | LR 7.24e-04
# Epoch 377 | Time 1.35s | Train NLL -12.419 | Val NLL -12.012 | LR 7.13e-04
# Epoch 378 | Time 1.37s | Train NLL -12.731 | Val NLL -11.909 | LR 7.02e-04
# Epoch 379 | Time 1.40s | Train NLL -11.665 | Val NLL -9.740 | LR 6.91e-04
# Epoch 380 | Time 1.32s | Train NLL -10.865 | Val NLL -9.403 | LR 6.80e-04
# Epoch 381 | Time 1.52s | Train NLL -11.900 | Val NLL -11.178 | LR 6.69e-04
# Epoch 382 | Time 1.37s | Train NLL -11.676 | Val NLL -11.928 | LR 6.58e-04
# Epoch 383 | Time 1.38s | Train NLL -12.630 | Val NLL -11.117 | LR 6.47e-04
# Epoch 384 | Time 1.38s | Train NLL -12.434 | Val NLL -12.459 | LR 6.37e-04
# Epoch 385 | Time 1.33s | Train NLL -12.760 | Val NLL -9.631 | LR 6.26e-04
# Epoch 386 | Time 1.35s | Train NLL -12.167 | Val NLL -11.151 | LR 6.16e-04
# Epoch 387 | Time 1.42s | Train NLL -12.833 | Val NLL -12.864 | LR 6.05e-04
# Epoch 388 | Time 1.39s | Train NLL -12.736 | Val NLL -12.383 | LR 5.95e-04
# Epoch 389 | Time 1.33s | Train NLL -13.009 | Val NLL -12.721 | LR 5.85e-04
# Epoch 390 | Time 1.37s | Train NLL -12.913 | Val NLL -12.945 | LR 5.75e-04
# Epoch 391 | Time 1.36s | Train NLL -12.728 | Val NLL -11.827 | LR 5.65e-04
# Epoch 392 | Time 1.43s | Train NLL -12.115 | Val NLL -12.152 | LR 5.55e-04
# Epoch 393 | Time 1.42s | Train NLL -12.667 | Val NLL -13.060 | LR 5.45e-04
# Epoch 394 | Time 1.40s | Train NLL -12.871 | Val NLL -11.670 | LR 5.35e-04
# Epoch 395 | Time 1.38s | Train NLL -12.711 | Val NLL -11.386 | LR 5.25e-04
# Epoch 396 | Time 1.40s | Train NLL -13.187 | Val NLL -13.475 | LR 5.15e-04
# Epoch 397 | Time 1.34s | Train NLL -12.671 | Val NLL -7.819 | LR 5.06e-04
# Epoch 398 | Time 0.93s | Train NLL -9.399 | Val NLL -9.710 | LR 4.96e-04
# Epoch 399 | Time 0.93s | Train NLL -12.111 | Val NLL -12.825 | LR 4.87e-04
# Epoch 400 | Time 1.00s | Train NLL -13.009 | Val NLL -13.157 | LR 4.77e-04
# Epoch 401 | Time 0.95s | Train NLL -13.256 | Val NLL -13.112 | LR 4.68e-04
# Epoch 402 | Time 0.95s | Train NLL -13.585 | Val NLL -13.604 | LR 4.59e-04
# Epoch 403 | Time 0.94s | Train NLL -12.612 | Val NLL -12.505 | LR 4.50e-04
# Epoch 404 | Time 0.96s | Train NLL -13.079 | Val NLL -12.571 | LR 4.41e-04
# Epoch 405 | Time 0.95s | Train NLL -13.262 | Val NLL -12.547 | LR 4.32e-04
# Epoch 406 | Time 0.97s | Train NLL -12.563 | Val NLL -13.544 | LR 4.23e-04
# Epoch 407 | Time 1.00s | Train NLL -13.053 | Val NLL -12.283 | LR 4.14e-04
# Epoch 408 | Time 0.92s | Train NLL -12.905 | Val NLL -13.367 | LR 4.05e-04
# Epoch 409 | Time 0.96s | Train NLL -13.364 | Val NLL -12.906 | LR 3.97e-04
# Epoch 410 | Time 1.25s | Train NLL -13.668 | Val NLL -12.141 | LR 3.88e-04
# Epoch 411 | Time 1.52s | Train NLL -11.681 | Val NLL -10.806 | LR 3.80e-04
# Epoch 412 | Time 1.40s | Train NLL -13.492 | Val NLL -13.814 | LR 3.72e-04
# Epoch 413 | Time 1.37s | Train NLL -13.766 | Val NLL -12.832 | LR 3.63e-04
# Epoch 414 | Time 1.35s | Train NLL -13.302 | Val NLL -13.084 | LR 3.55e-04
# Epoch 415 | Time 1.35s | Train NLL -13.656 | Val NLL -13.034 | LR 3.47e-04
# Epoch 416 | Time 1.38s | Train NLL -13.774 | Val NLL -13.510 | LR 3.39e-04
# Epoch 417 | Time 1.40s | Train NLL -12.799 | Val NLL -12.692 | LR 3.31e-04
# Epoch 418 | Time 1.38s | Train NLL -13.335 | Val NLL -12.795 | LR 3.23e-04
# Epoch 419 | Time 1.35s | Train NLL -13.566 | Val NLL -13.141 | LR 3.15e-04
# Epoch 420 | Time 1.37s | Train NLL -13.961 | Val NLL -13.504 | LR 3.08e-04
# Epoch 421 | Time 1.37s | Train NLL -14.192 | Val NLL -13.813 | LR 3.00e-04
# Epoch 422 | Time 1.35s | Train NLL -13.663 | Val NLL -13.583 | LR 2.93e-04
# Epoch 423 | Time 1.50s | Train NLL -14.055 | Val NLL -14.146 | LR 2.85e-04
# Epoch 424 | Time 1.44s | Train NLL -13.906 | Val NLL -14.218 | LR 2.78e-04
# Epoch 425 | Time 1.41s | Train NLL -14.018 | Val NLL -14.222 | LR 2.71e-04
# Epoch 426 | Time 1.38s | Train NLL -14.037 | Val NLL -13.722 | LR 2.64e-04
# Epoch 427 | Time 1.35s | Train NLL -14.206 | Val NLL -14.120 | LR 2.57e-04
# Epoch 428 | Time 1.40s | Train NLL -14.442 | Val NLL -14.019 | LR 2.50e-04
# Epoch 429 | Time 1.37s | Train NLL -14.146 | Val NLL -13.358 | LR 2.43e-04
# Epoch 430 | Time 1.37s | Train NLL -13.952 | Val NLL -14.250 | LR 2.36e-04
# Epoch 431 | Time 1.37s | Train NLL -14.459 | Val NLL -14.350 | LR 2.29e-04
# Epoch 432 | Time 1.45s | Train NLL -14.599 | Val NLL -14.687 | LR 2.23e-04
# Epoch 433 | Time 1.38s | Train NLL -14.344 | Val NLL -14.015 | LR 2.16e-04
# Epoch 434 | Time 1.35s | Train NLL -14.753 | Val NLL -14.463 | LR 2.10e-04
# Epoch 435 | Time 1.52s | Train NLL -14.591 | Val NLL -13.702 | LR 2.03e-04
# Epoch 436 | Time 1.42s | Train NLL -14.521 | Val NLL -14.419 | LR 1.97e-04
# Epoch 437 | Time 1.33s | Train NLL -14.812 | Val NLL -13.425 | LR 1.91e-04
# Epoch 438 | Time 1.45s | Train NLL -14.372 | Val NLL -14.795 | LR 1.85e-04
# Epoch 439 | Time 1.38s | Train NLL -13.598 | Val NLL -14.543 | LR 1.79e-04
# Epoch 440 | Time 1.40s | Train NLL -14.399 | Val NLL -14.761 | LR 1.73e-04
# Epoch 441 | Time 1.33s | Train NLL -15.054 | Val NLL -14.627 | LR 1.67e-04
# Epoch 442 | Time 1.37s | Train NLL -14.392 | Val NLL -12.815 | LR 1.62e-04
# Epoch 443 | Time 1.33s | Train NLL -13.585 | Val NLL -14.245 | LR 1.56e-04
# Epoch 444 | Time 1.43s | Train NLL -14.954 | Val NLL -14.904 | LR 1.51e-04
# Epoch 445 | Time 1.40s | Train NLL -15.208 | Val NLL -14.582 | LR 1.45e-04
# Epoch 446 | Time 1.40s | Train NLL -15.332 | Val NLL -15.195 | LR 1.40e-04
# Epoch 447 | Time 1.45s | Train NLL -15.469 | Val NLL -14.845 | LR 1.35e-04
# Epoch 448 | Time 1.35s | Train NLL -15.635 | Val NLL -14.823 | LR 1.30e-04
# Epoch 449 | Time 1.38s | Train NLL -15.291 | Val NLL -15.186 | LR 1.25e-04
# Epoch 450 | Time 1.45s | Train NLL -15.750 | Val NLL -15.327 | LR 1.20e-04
# Epoch 451 | Time 1.39s | Train NLL -15.361 | Val NLL -15.287 | LR 1.15e-04
# Epoch 452 | Time 1.41s | Train NLL -15.352 | Val NLL -15.082 | LR 1.10e-04
# Epoch 453 | Time 1.42s | Train NLL -15.545 | Val NLL -14.974 | LR 1.06e-04
# Epoch 454 | Time 1.36s | Train NLL -15.631 | Val NLL -15.414 | LR 1.01e-04
# Epoch 455 | Time 1.38s | Train NLL -15.729 | Val NLL -15.510 | LR 9.68e-05
# Epoch 456 | Time 1.35s | Train NLL -15.733 | Val NLL -15.332 | LR 9.25e-05
# Epoch 457 | Time 1.33s | Train NLL -15.842 | Val NLL -15.631 | LR 8.83e-05
# Epoch 458 | Time 1.30s | Train NLL -16.044 | Val NLL -15.744 | LR 8.42e-05
# Epoch 459 | Time 1.43s | Train NLL -16.138 | Val NLL -15.754 | LR 8.01e-05
# Epoch 460 | Time 1.33s | Train NLL -16.129 | Val NLL -15.699 | LR 7.62e-05
# Epoch 461 | Time 1.37s | Train NLL -16.268 | Val NLL -15.938 | LR 7.24e-05
# Epoch 462 | Time 1.38s | Train NLL -16.324 | Val NLL -15.828 | LR 6.86e-05
# Epoch 463 | Time 1.35s | Train NLL -16.291 | Val NLL -15.998 | LR 6.50e-05
# Epoch 464 | Time 1.39s | Train NLL -16.383 | Val NLL -15.919 | LR 6.14e-05
# Epoch 465 | Time 1.37s | Train NLL -16.409 | Val NLL -16.064 | LR 5.80e-05
# Epoch 466 | Time 1.36s | Train NLL -16.438 | Val NLL -16.034 | LR 5.46e-05
# Epoch 467 | Time 1.36s | Train NLL -16.513 | Val NLL -16.073 | LR 5.14e-05
# Epoch 468 | Time 1.45s | Train NLL -16.509 | Val NLL -16.132 | LR 4.82e-05
# Epoch 469 | Time 1.40s | Train NLL -16.576 | Val NLL -16.157 | LR 4.52e-05
# Epoch 470 | Time 1.28s | Train NLL -16.577 | Val NLL -16.063 | LR 4.22e-05
# Epoch 471 | Time 1.05s | Train NLL -16.592 | Val NLL -16.218 | LR 3.94e-05
# Epoch 472 | Time 1.02s | Train NLL -16.613 | Val NLL -16.268 | LR 3.66e-05
# Epoch 473 | Time 0.94s | Train NLL -16.678 | Val NLL -16.213 | LR 3.40e-05
# Epoch 474 | Time 0.98s | Train NLL -16.692 | Val NLL -16.295 | LR 3.14e-05
# Epoch 475 | Time 0.98s | Train NLL -16.725 | Val NLL -16.326 | LR 2.89e-05
# Epoch 476 | Time 1.00s | Train NLL -16.754 | Val NLL -16.338 | LR 2.66e-05
# Epoch 477 | Time 1.02s | Train NLL -16.669 | Val NLL -16.346 | LR 2.43e-05
# Epoch 478 | Time 1.00s | Train NLL -16.773 | Val NLL -16.360 | LR 2.22e-05
# Epoch 479 | Time 0.95s | Train NLL -16.783 | Val NLL -16.369 | LR 2.01e-05
# Epoch 480 | Time 0.95s | Train NLL -16.803 | Val NLL -16.390 | LR 1.82e-05
# Epoch 481 | Time 0.98s | Train NLL -16.820 | Val NLL -16.403 | LR 1.63e-05
# Epoch 482 | Time 1.00s | Train NLL -16.836 | Val NLL -16.415 | LR 1.45e-05
# Epoch 483 | Time 1.50s | Train NLL -16.843 | Val NLL -16.424 | LR 1.29e-05
# Epoch 484 | Time 1.39s | Train NLL -16.852 | Val NLL -16.431 | LR 1.13e-05
# Epoch 485 | Time 1.38s | Train NLL -16.841 | Val NLL -16.437 | LR 9.86e-06
# Epoch 486 | Time 1.45s | Train NLL -16.856 | Val NLL -16.443 | LR 8.50e-06
# Epoch 487 | Time 1.42s | Train NLL -16.871 | Val NLL -16.448 | LR 7.25e-06
# Epoch 488 | Time 1.40s | Train NLL -16.873 | Val NLL -16.453 | LR 6.09e-06
# Epoch 489 | Time 1.43s | Train NLL -16.875 | Val NLL -16.456 | LR 5.03e-06
# Epoch 490 | Time 1.35s | Train NLL -16.879 | Val NLL -16.459 | LR 4.08e-06
# Epoch 491 | Time 1.43s | Train NLL -16.871 | Val NLL -16.461 | LR 3.22e-06
# Epoch 492 | Time 1.35s | Train NLL -16.891 | Val NLL -16.463 | LR 2.47e-06
# Epoch 493 | Time 1.41s | Train NLL -16.896 | Val NLL -16.464 | LR 1.81e-06
# Epoch 494 | Time 1.45s | Train NLL -16.887 | Val NLL -16.466 | LR 1.26e-06
# Epoch 495 | Time 1.52s | Train NLL -16.854 | Val NLL -16.467 | LR 8.06e-07
# Epoch 496 | Time 1.35s | Train NLL -16.812 | Val NLL -16.467 | LR 4.53e-07
# Epoch 497 | Time 1.38s | Train NLL -16.890 | Val NLL -16.467 | LR 2.01e-07
# Epoch 498 | Time 1.40s | Train NLL -16.887 | Val NLL -16.468 | LR 5.03e-08
# Epoch 499 | Time 1.43s | Train NLL -16.888 | Val NLL -16.468 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 476.19
# Average absolute difference in CASUALTIES: 0.30

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
