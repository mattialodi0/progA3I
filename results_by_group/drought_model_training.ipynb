# %% [markdown]
# # Drought model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Drought'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 5.22s | Train NLL 6.733 | Val NLL -0.128 | LR 1.00e-03
# Epoch 001 | Time 1.83s | Train NLL -0.492 | Val NLL -1.148 | LR 2.00e-03
# Epoch 002 | Time 1.61s | Train NLL -0.940 | Val NLL -1.872 | LR 3.00e-03
# Epoch 003 | Time 1.65s | Train NLL -0.813 | Val NLL -0.537 | LR 4.00e-03
# Epoch 004 | Time 1.58s | Train NLL -1.319 | Val NLL 0.206 | LR 5.00e-03
# Epoch 005 | Time 1.53s | Train NLL -0.870 | Val NLL 1.305 | LR 5.00e-03
# Epoch 006 | Time 3.31s | Train NLL -0.824 | Val NLL -3.120 | LR 5.00e-03
# Epoch 007 | Time 2.08s | Train NLL -1.131 | Val NLL 0.136 | LR 5.00e-03
# Epoch 008 | Time 1.79s | Train NLL -2.168 | Val NLL -5.027 | LR 5.00e-03
# Epoch 009 | Time 1.75s | Train NLL -2.089 | Val NLL -4.232 | LR 5.00e-03
# Epoch 010 | Time 1.48s | Train NLL -2.240 | Val NLL -3.288 | LR 4.99e-03
# Epoch 011 | Time 1.52s | Train NLL -1.742 | Val NLL -1.443 | LR 4.99e-03
# Epoch 012 | Time 1.48s | Train NLL -2.053 | Val NLL -4.766 | LR 4.99e-03
# Epoch 013 | Time 1.58s | Train NLL -2.587 | Val NLL -2.994 | LR 4.99e-03
# Epoch 014 | Time 1.43s | Train NLL -3.048 | Val NLL -1.347 | LR 4.99e-03
# Epoch 015 | Time 1.48s | Train NLL -1.944 | Val NLL -4.084 | LR 4.98e-03
# Epoch 016 | Time 1.38s | Train NLL -0.223 | Val NLL -3.586 | LR 4.98e-03
# Epoch 017 | Time 1.40s | Train NLL -3.124 | Val NLL -2.132 | LR 4.98e-03
# Epoch 018 | Time 1.55s | Train NLL -2.786 | Val NLL -5.785 | LR 4.97e-03
# Epoch 019 | Time 1.45s | Train NLL -2.020 | Val NLL -3.622 | LR 4.97e-03
# Epoch 020 | Time 1.42s | Train NLL -4.191 | Val NLL -4.312 | LR 4.96e-03
# Epoch 021 | Time 1.43s | Train NLL -3.706 | Val NLL -5.466 | LR 4.96e-03
# Epoch 022 | Time 1.35s | Train NLL -3.692 | Val NLL -4.145 | LR 4.95e-03
# Epoch 023 | Time 1.43s | Train NLL -3.802 | Val NLL -5.100 | LR 4.95e-03
# Epoch 024 | Time 1.48s | Train NLL -3.467 | Val NLL -4.864 | LR 4.94e-03
# Epoch 025 | Time 1.55s | Train NLL -4.865 | Val NLL -6.287 | LR 4.94e-03
# Epoch 026 | Time 1.57s | Train NLL -3.581 | Val NLL -3.061 | LR 4.93e-03
# Epoch 027 | Time 1.67s | Train NLL -2.393 | Val NLL -1.643 | LR 4.93e-03
# Epoch 028 | Time 1.64s | Train NLL -3.009 | Val NLL -5.077 | LR 4.92e-03
# Epoch 029 | Time 1.46s | Train NLL -4.278 | Val NLL -5.031 | LR 4.91e-03
# Epoch 030 | Time 1.47s | Train NLL -3.045 | Val NLL -3.962 | LR 4.90e-03
# Epoch 031 | Time 1.50s | Train NLL -4.234 | Val NLL 0.463 | LR 4.90e-03
# Epoch 032 | Time 1.48s | Train NLL -2.729 | Val NLL -2.526 | LR 4.89e-03
# Epoch 033 | Time 1.50s | Train NLL -3.866 | Val NLL -5.327 | LR 4.88e-03
# Epoch 034 | Time 1.50s | Train NLL -2.510 | Val NLL -2.870 | LR 4.87e-03
# Epoch 035 | Time 1.53s | Train NLL -4.175 | Val NLL -4.096 | LR 4.86e-03
# Epoch 036 | Time 1.52s | Train NLL -0.685 | Val NLL -2.241 | LR 4.86e-03
# Epoch 037 | Time 1.67s | Train NLL -3.860 | Val NLL -6.229 | LR 4.85e-03
# Epoch 038 | Time 1.52s | Train NLL -4.248 | Val NLL -4.214 | LR 4.84e-03
# Epoch 039 | Time 1.45s | Train NLL -2.987 | Val NLL -4.875 | LR 4.83e-03
# Epoch 040 | Time 1.47s | Train NLL -3.880 | Val NLL -3.248 | LR 4.82e-03
# Epoch 041 | Time 1.60s | Train NLL -4.310 | Val NLL -2.357 | LR 4.81e-03
# Epoch 042 | Time 1.50s | Train NLL -2.408 | Val NLL -1.162 | LR 4.80e-03
# Epoch 043 | Time 1.47s | Train NLL -4.048 | Val NLL -5.142 | LR 4.79e-03
# Epoch 044 | Time 1.50s | Train NLL -2.524 | Val NLL -5.405 | LR 4.78e-03
# Epoch 045 | Time 1.50s | Train NLL -5.335 | Val NLL -2.967 | LR 4.77e-03
# Epoch 046 | Time 1.63s | Train NLL -4.438 | Val NLL -6.362 | LR 4.75e-03
# Epoch 047 | Time 1.57s | Train NLL -2.563 | Val NLL -5.223 | LR 4.74e-03
# Epoch 048 | Time 1.45s | Train NLL -4.475 | Val NLL -3.761 | LR 4.73e-03
# Epoch 049 | Time 1.63s | Train NLL -5.605 | Val NLL -6.491 | LR 4.72e-03
# Epoch 050 | Time 1.58s | Train NLL -5.531 | Val NLL -2.899 | LR 4.71e-03
# Epoch 051 | Time 1.63s | Train NLL -3.955 | Val NLL -4.730 | LR 4.69e-03
# Epoch 052 | Time 1.45s | Train NLL -3.180 | Val NLL -4.544 | LR 4.68e-03
# Epoch 053 | Time 1.53s | Train NLL -4.896 | Val NLL -4.653 | LR 4.67e-03
# Epoch 054 | Time 1.48s | Train NLL -4.910 | Val NLL -6.837 | LR 4.65e-03
# Epoch 055 | Time 1.58s | Train NLL -3.849 | Val NLL -6.393 | LR 4.64e-03
# Epoch 056 | Time 1.55s | Train NLL -3.847 | Val NLL -5.282 | LR 4.63e-03
# Epoch 057 | Time 1.43s | Train NLL -4.714 | Val NLL -5.850 | LR 4.61e-03
# Epoch 058 | Time 1.45s | Train NLL -5.059 | Val NLL -6.688 | LR 4.60e-03
# Epoch 059 | Time 1.48s | Train NLL -4.822 | Val NLL -5.135 | LR 4.58e-03
# Epoch 060 | Time 1.48s | Train NLL -3.134 | Val NLL -7.329 | LR 4.57e-03
# Epoch 061 | Time 1.62s | Train NLL -6.619 | Val NLL -7.775 | LR 4.55e-03
# Epoch 062 | Time 1.60s | Train NLL -3.616 | Val NLL -3.063 | LR 4.54e-03
# Epoch 063 | Time 1.47s | Train NLL -3.890 | Val NLL -6.767 | LR 4.52e-03
# Epoch 064 | Time 1.57s | Train NLL -4.832 | Val NLL -6.896 | LR 4.51e-03
# Epoch 065 | Time 1.60s | Train NLL -5.808 | Val NLL -6.341 | LR 4.49e-03
# Epoch 066 | Time 1.50s | Train NLL -5.629 | Val NLL -6.388 | LR 4.47e-03
# Epoch 067 | Time 1.47s | Train NLL -5.722 | Val NLL -3.140 | LR 4.46e-03
# Epoch 068 | Time 1.48s | Train NLL -4.881 | Val NLL -8.031 | LR 4.44e-03
# Epoch 069 | Time 1.57s | Train NLL -4.277 | Val NLL -4.334 | LR 4.42e-03
# Epoch 070 | Time 1.50s | Train NLL -4.927 | Val NLL -0.711 | LR 4.41e-03
# Epoch 071 | Time 1.45s | Train NLL -3.796 | Val NLL -6.581 | LR 4.39e-03
# Epoch 072 | Time 1.45s | Train NLL -6.619 | Val NLL -5.413 | LR 4.37e-03
# Epoch 073 | Time 1.55s | Train NLL -4.059 | Val NLL -4.894 | LR 4.35e-03
# Epoch 074 | Time 1.48s | Train NLL -4.037 | Val NLL -4.985 | LR 4.34e-03
# Epoch 075 | Time 1.55s | Train NLL -5.744 | Val NLL -5.893 | LR 4.32e-03
# Epoch 076 | Time 1.55s | Train NLL -4.609 | Val NLL -7.365 | LR 4.30e-03
# Epoch 077 | Time 1.52s | Train NLL -6.536 | Val NLL -8.065 | LR 4.28e-03
# Epoch 078 | Time 1.63s | Train NLL -4.517 | Val NLL -3.238 | LR 4.26e-03
# Epoch 079 | Time 1.49s | Train NLL -4.553 | Val NLL -7.147 | LR 4.24e-03
# Epoch 080 | Time 1.48s | Train NLL -6.226 | Val NLL -5.651 | LR 4.22e-03
# Epoch 081 | Time 1.47s | Train NLL -5.576 | Val NLL -7.936 | LR 4.21e-03
# Epoch 082 | Time 1.63s | Train NLL -6.026 | Val NLL -8.148 | LR 4.19e-03
# Epoch 083 | Time 1.55s | Train NLL 0.480 | Val NLL -3.868 | LR 4.17e-03
# Epoch 084 | Time 1.47s | Train NLL -4.224 | Val NLL -6.209 | LR 4.15e-03
# Epoch 085 | Time 1.47s | Train NLL -3.787 | Val NLL -7.107 | LR 4.13e-03
# Epoch 086 | Time 1.47s | Train NLL -5.637 | Val NLL -7.205 | LR 4.11e-03
# Epoch 087 | Time 1.43s | Train NLL -6.649 | Val NLL -3.654 | LR 4.09e-03
# Epoch 088 | Time 1.47s | Train NLL -2.120 | Val NLL -3.845 | LR 4.06e-03
# Epoch 089 | Time 1.50s | Train NLL -4.584 | Val NLL -5.294 | LR 4.04e-03
# Epoch 090 | Time 1.52s | Train NLL -5.761 | Val NLL -1.197 | LR 4.02e-03
# Epoch 091 | Time 1.47s | Train NLL -5.625 | Val NLL -3.922 | LR 4.00e-03
# Epoch 092 | Time 1.60s | Train NLL -4.176 | Val NLL -4.592 | LR 3.98e-03
# Epoch 093 | Time 1.47s | Train NLL -6.394 | Val NLL -8.351 | LR 3.96e-03
# Epoch 094 | Time 1.53s | Train NLL -6.335 | Val NLL -7.996 | LR 3.94e-03
# Epoch 095 | Time 1.50s | Train NLL -5.195 | Val NLL -6.166 | LR 3.92e-03
# Epoch 096 | Time 1.48s | Train NLL -5.423 | Val NLL -5.591 | LR 3.89e-03
# Epoch 097 | Time 1.50s | Train NLL -6.442 | Val NLL -8.465 | LR 3.87e-03
# Epoch 098 | Time 1.57s | Train NLL -7.187 | Val NLL -3.650 | LR 3.85e-03
# Epoch 099 | Time 1.50s | Train NLL -5.058 | Val NLL -7.491 | LR 3.83e-03
# Epoch 100 | Time 1.55s | Train NLL -6.875 | Val NLL -8.742 | LR 3.80e-03
# Epoch 101 | Time 1.47s | Train NLL -6.799 | Val NLL 1.118 | LR 3.78e-03
# Epoch 102 | Time 1.57s | Train NLL -1.052 | Val NLL -5.851 | LR 3.76e-03
# Epoch 103 | Time 1.53s | Train NLL -6.790 | Val NLL -8.410 | LR 3.73e-03
# Epoch 104 | Time 1.48s | Train NLL -3.227 | Val NLL -1.661 | LR 3.71e-03
# Epoch 105 | Time 1.48s | Train NLL -5.001 | Val NLL -7.459 | LR 3.69e-03
# Epoch 106 | Time 1.45s | Train NLL -6.284 | Val NLL -7.927 | LR 3.66e-03
# Epoch 107 | Time 1.43s | Train NLL -5.350 | Val NLL -3.361 | LR 3.64e-03
# Epoch 108 | Time 1.48s | Train NLL -6.226 | Val NLL -7.023 | LR 3.62e-03
# Epoch 109 | Time 1.47s | Train NLL -6.606 | Val NLL -8.138 | LR 3.59e-03
# Epoch 110 | Time 1.56s | Train NLL -6.173 | Val NLL -6.607 | LR 3.57e-03
# Epoch 111 | Time 1.50s | Train NLL -6.966 | Val NLL -7.785 | LR 3.55e-03
# Epoch 112 | Time 1.49s | Train NLL 0.256 | Val NLL -4.657 | LR 3.52e-03
# Epoch 113 | Time 1.41s | Train NLL -5.864 | Val NLL -7.446 | LR 3.50e-03
# Epoch 114 | Time 1.53s | Train NLL -6.717 | Val NLL -5.893 | LR 3.47e-03
# Epoch 115 | Time 1.50s | Train NLL -5.374 | Val NLL -5.559 | LR 3.45e-03
# Epoch 116 | Time 1.52s | Train NLL -5.696 | Val NLL -6.934 | LR 3.42e-03
# Epoch 117 | Time 1.45s | Train NLL -6.349 | Val NLL -8.277 | LR 3.40e-03
# Epoch 118 | Time 1.55s | Train NLL -6.543 | Val NLL -5.014 | LR 3.37e-03
# Epoch 119 | Time 1.63s | Train NLL -6.792 | Val NLL -7.425 | LR 3.35e-03
# Epoch 120 | Time 1.57s | Train NLL -7.231 | Val NLL -7.975 | LR 3.32e-03
# Epoch 121 | Time 1.48s | Train NLL -7.492 | Val NLL -6.683 | LR 3.30e-03
# Epoch 122 | Time 1.47s | Train NLL -5.361 | Val NLL -7.388 | LR 3.27e-03
# Epoch 123 | Time 1.52s | Train NLL -6.431 | Val NLL -8.844 | LR 3.25e-03
# Epoch 124 | Time 1.55s | Train NLL -7.828 | Val NLL -7.450 | LR 3.22e-03
# Epoch 125 | Time 1.55s | Train NLL -6.003 | Val NLL -7.997 | LR 3.20e-03
# Epoch 126 | Time 1.48s | Train NLL -8.225 | Val NLL -8.306 | LR 3.17e-03
# Epoch 127 | Time 1.52s | Train NLL -7.412 | Val NLL -9.330 | LR 3.14e-03
# Epoch 128 | Time 1.63s | Train NLL -8.290 | Val NLL -8.449 | LR 3.12e-03
# Epoch 129 | Time 1.48s | Train NLL -7.963 | Val NLL -4.461 | LR 3.09e-03
# Epoch 130 | Time 1.47s | Train NLL -5.658 | Val NLL -5.690 | LR 3.07e-03
# Epoch 131 | Time 1.45s | Train NLL -7.241 | Val NLL -8.433 | LR 3.04e-03
# Epoch 132 | Time 1.58s | Train NLL -8.759 | Val NLL -9.628 | LR 3.02e-03
# Epoch 133 | Time 1.53s | Train NLL -2.234 | Val NLL -4.335 | LR 2.99e-03
# Epoch 134 | Time 1.52s | Train NLL -5.568 | Val NLL -7.496 | LR 2.96e-03
# Epoch 135 | Time 1.45s | Train NLL -7.482 | Val NLL -5.935 | LR 2.94e-03
# Epoch 136 | Time 1.43s | Train NLL -5.647 | Val NLL -5.791 | LR 2.91e-03
# Epoch 137 | Time 1.57s | Train NLL -7.302 | Val NLL -7.840 | LR 2.88e-03
# Epoch 138 | Time 1.45s | Train NLL -5.958 | Val NLL -8.037 | LR 2.86e-03
# Epoch 139 | Time 1.50s | Train NLL -7.835 | Val NLL -7.140 | LR 2.83e-03
# Epoch 140 | Time 1.48s | Train NLL -5.256 | Val NLL -7.752 | LR 2.81e-03
# Epoch 141 | Time 1.45s | Train NLL -5.458 | Val NLL -5.569 | LR 2.78e-03
# Epoch 142 | Time 1.50s | Train NLL -6.869 | Val NLL -3.902 | LR 2.75e-03
# Epoch 143 | Time 1.47s | Train NLL -4.468 | Val NLL 0.141 | LR 2.73e-03
# Epoch 144 | Time 1.45s | Train NLL -2.500 | Val NLL -5.740 | LR 2.70e-03
# Epoch 145 | Time 1.48s | Train NLL -4.553 | Val NLL -4.790 | LR 2.67e-03
# Epoch 146 | Time 1.43s | Train NLL -6.191 | Val NLL -6.948 | LR 2.65e-03
# Epoch 147 | Time 1.52s | Train NLL -7.791 | Val NLL -8.961 | LR 2.62e-03
# Epoch 148 | Time 1.52s | Train NLL -8.340 | Val NLL -10.033 | LR 2.59e-03
# Epoch 149 | Time 1.57s | Train NLL -3.770 | Val NLL -3.054 | LR 2.57e-03
# Epoch 150 | Time 1.47s | Train NLL -5.367 | Val NLL -7.924 | LR 2.54e-03
# Epoch 151 | Time 1.45s | Train NLL -7.726 | Val NLL -6.370 | LR 2.51e-03
# Epoch 152 | Time 1.45s | Train NLL -5.864 | Val NLL -4.863 | LR 2.49e-03
# Epoch 153 | Time 1.46s | Train NLL -6.895 | Val NLL -9.289 | LR 2.46e-03
# Epoch 154 | Time 1.55s | Train NLL -8.269 | Val NLL -6.846 | LR 2.43e-03
# Epoch 155 | Time 1.52s | Train NLL -7.070 | Val NLL -8.637 | LR 2.41e-03
# Epoch 156 | Time 1.62s | Train NLL -6.062 | Val NLL -3.859 | LR 2.38e-03
# Epoch 157 | Time 1.47s | Train NLL -6.776 | Val NLL -9.382 | LR 2.35e-03
# Epoch 158 | Time 1.43s | Train NLL -8.856 | Val NLL -5.858 | LR 2.33e-03
# Epoch 159 | Time 1.48s | Train NLL -4.772 | Val NLL -7.633 | LR 2.30e-03
# Epoch 160 | Time 1.45s | Train NLL -8.174 | Val NLL -8.496 | LR 2.27e-03
# Epoch 161 | Time 1.47s | Train NLL -6.220 | Val NLL -7.198 | LR 2.25e-03
# Epoch 162 | Time 1.45s | Train NLL -7.678 | Val NLL -8.688 | LR 2.22e-03
# Epoch 163 | Time 1.43s | Train NLL -5.811 | Val NLL -7.281 | LR 2.19e-03
# Epoch 164 | Time 1.50s | Train NLL -8.248 | Val NLL -8.461 | LR 2.17e-03
# Epoch 165 | Time 1.62s | Train NLL -6.327 | Val NLL -1.862 | LR 2.14e-03
# Epoch 166 | Time 1.55s | Train NLL -4.320 | Val NLL -8.311 | LR 2.12e-03
# Epoch 167 | Time 1.48s | Train NLL -6.451 | Val NLL -3.662 | LR 2.09e-03
# Epoch 168 | Time 1.45s | Train NLL -2.489 | Val NLL -2.450 | LR 2.06e-03
# Epoch 169 | Time 1.45s | Train NLL -3.890 | Val NLL -5.995 | LR 2.04e-03
# Epoch 170 | Time 1.43s | Train NLL -5.072 | Val NLL -7.428 | LR 2.01e-03
# Epoch 171 | Time 1.43s | Train NLL -7.828 | Val NLL -9.034 | LR 1.98e-03
# Epoch 172 | Time 1.50s | Train NLL -8.003 | Val NLL 0.170 | LR 1.96e-03
# Epoch 173 | Time 1.45s | Train NLL -3.858 | Val NLL -6.920 | LR 1.93e-03
# Epoch 174 | Time 1.55s | Train NLL -7.733 | Val NLL -9.468 | LR 1.91e-03
# Epoch 175 | Time 1.48s | Train NLL -9.151 | Val NLL -6.532 | LR 1.88e-03
# Epoch 176 | Time 1.45s | Train NLL -7.413 | Val NLL -9.844 | LR 1.86e-03
# Epoch 177 | Time 1.47s | Train NLL -8.737 | Val NLL -8.297 | LR 1.83e-03
# Epoch 178 | Time 1.43s | Train NLL -6.826 | Val NLL -8.765 | LR 1.80e-03
# Epoch 179 | Time 1.48s | Train NLL -8.598 | Val NLL -4.870 | LR 1.78e-03
# Epoch 180 | Time 1.53s | Train NLL -8.988 | Val NLL -10.729 | LR 1.75e-03
# Epoch 181 | Time 1.52s | Train NLL -9.512 | Val NLL -8.018 | LR 1.73e-03
# Epoch 182 | Time 1.47s | Train NLL -6.945 | Val NLL -8.820 | LR 1.70e-03
# Epoch 183 | Time 1.58s | Train NLL -9.017 | Val NLL -10.455 | LR 1.68e-03
# Epoch 184 | Time 1.50s | Train NLL -9.934 | Val NLL -11.155 | LR 1.65e-03
# Epoch 185 | Time 1.55s | Train NLL -8.473 | Val NLL -10.358 | LR 1.63e-03
# Epoch 186 | Time 1.45s | Train NLL -8.878 | Val NLL -10.046 | LR 1.60e-03
# Epoch 187 | Time 1.50s | Train NLL -9.489 | Val NLL -10.543 | LR 1.58e-03
# Epoch 188 | Time 1.48s | Train NLL -10.281 | Val NLL -11.466 | LR 1.55e-03
# Epoch 189 | Time 1.55s | Train NLL -8.091 | Val NLL -10.765 | LR 1.53e-03
# Epoch 190 | Time 1.48s | Train NLL -7.760 | Val NLL -10.333 | LR 1.50e-03
# Epoch 191 | Time 1.65s | Train NLL -10.345 | Val NLL -11.294 | LR 1.48e-03
# Epoch 192 | Time 1.60s | Train NLL -10.507 | Val NLL -9.732 | LR 1.45e-03
# Epoch 193 | Time 1.60s | Train NLL -8.500 | Val NLL -5.827 | LR 1.43e-03
# Epoch 194 | Time 1.52s | Train NLL -7.730 | Val NLL -10.443 | LR 1.41e-03
# Epoch 195 | Time 1.52s | Train NLL -9.217 | Val NLL -11.054 | LR 1.38e-03
# Epoch 196 | Time 1.57s | Train NLL -10.820 | Val NLL -11.609 | LR 1.36e-03
# Epoch 197 | Time 1.57s | Train NLL -8.705 | Val NLL -4.385 | LR 1.34e-03
# Epoch 198 | Time 1.48s | Train NLL -5.684 | Val NLL -6.805 | LR 1.31e-03
# Epoch 199 | Time 1.50s | Train NLL -7.719 | Val NLL -9.933 | LR 1.29e-03
# Epoch 200 | Time 1.47s | Train NLL -7.482 | Val NLL -9.151 | LR 1.27e-03
# Epoch 201 | Time 1.60s | Train NLL -7.711 | Val NLL -9.449 | LR 1.24e-03
# Epoch 202 | Time 1.48s | Train NLL -9.599 | Val NLL -10.722 | LR 1.22e-03
# Epoch 203 | Time 1.55s | Train NLL -10.190 | Val NLL -10.766 | LR 1.20e-03
# Epoch 204 | Time 1.52s | Train NLL -10.458 | Val NLL -11.699 | LR 1.17e-03
# Epoch 205 | Time 1.57s | Train NLL -10.379 | Val NLL -11.429 | LR 1.15e-03
# Epoch 206 | Time 1.52s | Train NLL -7.953 | Val NLL -9.465 | LR 1.13e-03
# Epoch 207 | Time 1.50s | Train NLL -10.065 | Val NLL -8.744 | LR 1.11e-03
# Epoch 208 | Time 1.50s | Train NLL -8.886 | Val NLL -10.741 | LR 1.08e-03
# Epoch 209 | Time 1.48s | Train NLL -8.272 | Val NLL -7.643 | LR 1.06e-03
# Epoch 210 | Time 1.58s | Train NLL -9.938 | Val NLL -8.956 | LR 1.04e-03
# Epoch 211 | Time 1.52s | Train NLL -9.563 | Val NLL -11.139 | LR 1.02e-03
# Epoch 212 | Time 1.55s | Train NLL -10.601 | Val NLL -11.917 | LR 9.98e-04
# Epoch 213 | Time 1.53s | Train NLL -11.187 | Val NLL -10.749 | LR 9.77e-04
# Epoch 214 | Time 1.53s | Train NLL -9.928 | Val NLL -8.797 | LR 9.56e-04
# Epoch 215 | Time 1.48s | Train NLL -5.031 | Val NLL -7.007 | LR 9.35e-04
# Epoch 216 | Time 1.52s | Train NLL -8.936 | Val NLL -10.588 | LR 9.15e-04
# Epoch 217 | Time 1.54s | Train NLL -11.056 | Val NLL -11.600 | LR 8.94e-04
# Epoch 218 | Time 1.46s | Train NLL -11.515 | Val NLL -12.392 | LR 8.74e-04
# Epoch 219 | Time 1.68s | Train NLL -10.834 | Val NLL -8.421 | LR 8.54e-04
# Epoch 220 | Time 1.52s | Train NLL -5.738 | Val NLL -6.865 | LR 8.34e-04
# Epoch 221 | Time 1.53s | Train NLL -8.512 | Val NLL -8.703 | LR 8.14e-04
# Epoch 222 | Time 1.50s | Train NLL -9.969 | Val NLL -11.710 | LR 7.94e-04
# Epoch 223 | Time 1.47s | Train NLL -11.382 | Val NLL -12.178 | LR 7.75e-04
# Epoch 224 | Time 1.73s | Train NLL -11.433 | Val NLL -12.754 | LR 7.56e-04
# Epoch 225 | Time 2.47s | Train NLL -11.308 | Val NLL -11.621 | LR 7.37e-04
# Epoch 226 | Time 3.38s | Train NLL -11.022 | Val NLL -11.729 | LR 7.18e-04
# Epoch 227 | Time 4.94s | Train NLL -11.601 | Val NLL -11.869 | LR 7.00e-04
# Epoch 228 | Time 4.31s | Train NLL -11.379 | Val NLL -7.717 | LR 6.81e-04
# Epoch 229 | Time 4.03s | Train NLL -9.717 | Val NLL -10.040 | LR 6.63e-04
# Epoch 230 | Time 2.01s | Train NLL -9.870 | Val NLL -11.372 | LR 6.45e-04
# Epoch 231 | Time 2.84s | Train NLL -11.663 | Val NLL -12.099 | LR 6.27e-04
# Epoch 232 | Time 2.36s | Train NLL -12.004 | Val NLL -12.180 | LR 6.10e-04
# Epoch 233 | Time 1.93s | Train NLL -10.455 | Val NLL -8.790 | LR 5.93e-04
# Epoch 234 | Time 1.57s | Train NLL -11.511 | Val NLL -12.891 | LR 5.75e-04
# Epoch 235 | Time 1.68s | Train NLL -10.523 | Val NLL -8.246 | LR 5.59e-04
# Epoch 236 | Time 1.71s | Train NLL -8.519 | Val NLL -10.641 | LR 5.42e-04
# Epoch 237 | Time 1.62s | Train NLL -10.947 | Val NLL -10.526 | LR 5.25e-04
# Epoch 238 | Time 1.47s | Train NLL -10.402 | Val NLL -12.803 | LR 5.09e-04
# Epoch 239 | Time 3.13s | Train NLL -12.539 | Val NLL -13.374 | LR 4.93e-04
# Epoch 240 | Time 1.96s | Train NLL -12.868 | Val NLL -13.553 | LR 4.77e-04
# Epoch 241 | Time 1.85s | Train NLL -11.198 | Val NLL -8.253 | LR 4.62e-04
# Epoch 242 | Time 1.57s | Train NLL -11.209 | Val NLL -13.026 | LR 4.47e-04
# Epoch 243 | Time 1.68s | Train NLL -12.574 | Val NLL -13.367 | LR 4.32e-04
# Epoch 244 | Time 1.70s | Train NLL -12.967 | Val NLL -13.623 | LR 4.17e-04
# Epoch 245 | Time 1.65s | Train NLL -13.074 | Val NLL -13.668 | LR 4.02e-04
# Epoch 246 | Time 1.52s | Train NLL -12.008 | Val NLL -11.754 | LR 3.88e-04
# Epoch 247 | Time 1.37s | Train NLL -7.128 | Val NLL -12.676 | LR 3.74e-04
# Epoch 248 | Time 1.47s | Train NLL -11.783 | Val NLL -13.386 | LR 3.60e-04
# Epoch 249 | Time 1.47s | Train NLL -13.046 | Val NLL -13.864 | LR 3.46e-04
# Epoch 250 | Time 1.46s | Train NLL -13.209 | Val NLL -14.010 | LR 3.33e-04
# Epoch 251 | Time 1.90s | Train NLL -13.317 | Val NLL -14.178 | LR 3.20e-04
# Epoch 252 | Time 4.03s | Train NLL -13.582 | Val NLL -14.244 | LR 3.07e-04
# Epoch 253 | Time 1.71s | Train NLL -13.365 | Val NLL -14.060 | LR 2.94e-04
# Epoch 254 | Time 2.09s | Train NLL -13.508 | Val NLL -13.885 | LR 2.82e-04
# Epoch 255 | Time 2.80s | Train NLL -13.620 | Val NLL -14.312 | LR 2.69e-04
# Epoch 256 | Time 1.76s | Train NLL -13.700 | Val NLL -14.300 | LR 2.58e-04
# Epoch 257 | Time 1.86s | Train NLL -13.792 | Val NLL -14.098 | LR 2.46e-04
# Epoch 258 | Time 1.55s | Train NLL -13.910 | Val NLL -14.420 | LR 2.35e-04
# Epoch 259 | Time 1.59s | Train NLL -14.032 | Val NLL -14.890 | LR 2.23e-04
# Epoch 260 | Time 1.83s | Train NLL -14.092 | Val NLL -14.175 | LR 2.13e-04
# Epoch 261 | Time 1.76s | Train NLL -14.203 | Val NLL -14.926 | LR 2.02e-04
# Epoch 262 | Time 1.63s | Train NLL -14.346 | Val NLL -15.033 | LR 1.92e-04
# Epoch 263 | Time 1.94s | Train NLL -14.441 | Val NLL -15.011 | LR 1.81e-04
# Epoch 264 | Time 2.10s | Train NLL -14.577 | Val NLL -15.292 | LR 1.72e-04
# Epoch 265 | Time 1.66s | Train NLL -14.915 | Val NLL -15.387 | LR 1.62e-04
# Epoch 266 | Time 2.30s | Train NLL -14.973 | Val NLL -15.582 | LR 1.53e-04
# Epoch 267 | Time 2.13s | Train NLL -15.095 | Val NLL -15.438 | LR 1.44e-04
# Epoch 268 | Time 1.74s | Train NLL -15.204 | Val NLL -15.969 | LR 1.35e-04
# Epoch 269 | Time 1.87s | Train NLL -15.275 | Val NLL -15.681 | LR 1.27e-04
# Epoch 270 | Time 1.71s | Train NLL -15.370 | Val NLL -15.928 | LR 1.18e-04
# Epoch 271 | Time 1.76s | Train NLL -15.536 | Val NLL -16.062 | LR 1.10e-04
# Epoch 272 | Time 1.65s | Train NLL -15.592 | Val NLL -16.029 | LR 1.03e-04
# Epoch 273 | Time 1.77s | Train NLL -15.697 | Val NLL -16.449 | LR 9.52e-05
# Epoch 274 | Time 1.80s | Train NLL -15.891 | Val NLL -16.492 | LR 8.81e-05
# Epoch 275 | Time 1.69s | Train NLL -15.905 | Val NLL -16.526 | LR 8.12e-05
# Epoch 276 | Time 1.83s | Train NLL -16.072 | Val NLL -16.463 | LR 7.46e-05
# Epoch 277 | Time 1.75s | Train NLL -16.137 | Val NLL -16.733 | LR 6.83e-05
# Epoch 278 | Time 1.73s | Train NLL -16.235 | Val NLL -16.744 | LR 6.23e-05
# Epoch 279 | Time 1.71s | Train NLL -16.329 | Val NLL -16.851 | LR 5.65e-05
# Epoch 280 | Time 1.75s | Train NLL -16.418 | Val NLL -16.980 | LR 5.10e-05
# Epoch 281 | Time 1.75s | Train NLL -16.474 | Val NLL -17.008 | LR 4.58e-05
# Epoch 282 | Time 1.72s | Train NLL -16.527 | Val NLL -17.090 | LR 4.09e-05
# Epoch 283 | Time 1.66s | Train NLL -16.574 | Val NLL -17.124 | LR 3.62e-05
# Epoch 284 | Time 1.82s | Train NLL -16.650 | Val NLL -17.174 | LR 3.18e-05
# Epoch 285 | Time 1.72s | Train NLL -16.689 | Val NLL -17.220 | LR 2.77e-05
# Epoch 286 | Time 1.73s | Train NLL -16.721 | Val NLL -17.256 | LR 2.39e-05
# Epoch 287 | Time 1.63s | Train NLL -16.758 | Val NLL -17.289 | LR 2.04e-05
# Epoch 288 | Time 1.68s | Train NLL -16.790 | Val NLL -17.313 | LR 1.71e-05
# Epoch 289 | Time 1.70s | Train NLL -16.819 | Val NLL -17.338 | LR 1.42e-05
# Epoch 290 | Time 1.80s | Train NLL -16.833 | Val NLL -17.355 | LR 1.15e-05
# Epoch 291 | Time 1.69s | Train NLL -16.855 | Val NLL -17.373 | LR 9.07e-06
# Epoch 292 | Time 1.74s | Train NLL -16.863 | Val NLL -17.383 | LR 6.94e-06
# Epoch 293 | Time 1.64s | Train NLL -16.880 | Val NLL -17.393 | LR 5.10e-06
# Epoch 294 | Time 1.88s | Train NLL -16.888 | Val NLL -17.399 | LR 3.54e-06
# Epoch 295 | Time 1.72s | Train NLL -16.401 | Val NLL -17.404 | LR 2.27e-06
# Epoch 296 | Time 1.71s | Train NLL -16.902 | Val NLL -17.407 | LR 1.28e-06
# Epoch 297 | Time 1.74s | Train NLL -16.900 | Val NLL -17.408 | LR 5.67e-07
# Epoch 298 | Time 1.66s | Train NLL -16.907 | Val NLL -17.409 | LR 1.42e-07
# Epoch 299 | Time 1.76s | Train NLL -16.896 | Val NLL -17.409 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 35048.80
# Average absolute difference in CASUALTIES: 0.00

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
