# %% [markdown]
# # Heat model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Heat'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 6.20s | Train NLL 7.976 | Val NLL 2.875 | LR 1.00e-03
# Epoch 001 | Time 1.58s | Train NLL 0.409 | Val NLL -0.010 | LR 2.00e-03
# Epoch 002 | Time 1.02s | Train NLL -0.790 | Val NLL 0.328 | LR 3.00e-03
# Epoch 003 | Time 1.00s | Train NLL 0.322 | Val NLL 1.275 | LR 4.00e-03
# Epoch 004 | Time 1.03s | Train NLL -1.516 | Val NLL -1.504 | LR 5.00e-03
# Epoch 005 | Time 0.96s | Train NLL -0.971 | Val NLL 0.658 | LR 5.00e-03
# Epoch 006 | Time 0.96s | Train NLL -0.608 | Val NLL -1.400 | LR 5.00e-03
# Epoch 007 | Time 1.10s | Train NLL -0.973 | Val NLL -2.425 | LR 5.00e-03
# Epoch 008 | Time 2.05s | Train NLL -0.958 | Val NLL -2.978 | LR 5.00e-03
# Epoch 009 | Time 2.46s | Train NLL -1.592 | Val NLL 4.766 | LR 5.00e-03
# Epoch 010 | Time 1.05s | Train NLL -0.784 | Val NLL -2.287 | LR 4.99e-03
# Epoch 011 | Time 1.11s | Train NLL -1.968 | Val NLL -2.227 | LR 4.99e-03
# Epoch 012 | Time 1.18s | Train NLL -2.215 | Val NLL -3.379 | LR 4.99e-03
# Epoch 013 | Time 1.19s | Train NLL -3.197 | Val NLL -2.082 | LR 4.99e-03
# Epoch 014 | Time 1.12s | Train NLL -2.633 | Val NLL -2.123 | LR 4.99e-03
# Epoch 015 | Time 1.30s | Train NLL -1.253 | Val NLL -1.495 | LR 4.98e-03
# Epoch 016 | Time 1.13s | Train NLL -2.463 | Val NLL -0.469 | LR 4.98e-03
# Epoch 017 | Time 1.37s | Train NLL -2.094 | Val NLL -1.554 | LR 4.98e-03
# Epoch 018 | Time 1.44s | Train NLL -1.211 | Val NLL -0.396 | LR 4.97e-03
# Epoch 019 | Time 1.12s | Train NLL -1.899 | Val NLL -3.958 | LR 4.97e-03
# Epoch 020 | Time 1.05s | Train NLL -2.500 | Val NLL 1.099 | LR 4.96e-03
# Epoch 021 | Time 1.06s | Train NLL -2.285 | Val NLL 1.985 | LR 4.96e-03
# Epoch 022 | Time 1.01s | Train NLL -1.213 | Val NLL -2.126 | LR 4.95e-03
# Epoch 023 | Time 0.91s | Train NLL -3.463 | Val NLL -3.487 | LR 4.95e-03
# Epoch 024 | Time 1.12s | Train NLL -2.210 | Val NLL -2.159 | LR 4.94e-03
# Epoch 025 | Time 0.99s | Train NLL -2.320 | Val NLL -1.615 | LR 4.94e-03
# Epoch 026 | Time 1.09s | Train NLL -2.074 | Val NLL -3.179 | LR 4.93e-03
# Epoch 027 | Time 0.97s | Train NLL -3.974 | Val NLL -4.436 | LR 4.93e-03
# Epoch 028 | Time 0.95s | Train NLL -2.701 | Val NLL -2.455 | LR 4.92e-03
# Epoch 029 | Time 1.00s | Train NLL -2.613 | Val NLL -2.888 | LR 4.91e-03
# Epoch 030 | Time 0.93s | Train NLL -1.831 | Val NLL 0.884 | LR 4.90e-03
# Epoch 031 | Time 1.19s | Train NLL -1.053 | Val NLL -2.398 | LR 4.90e-03
# Epoch 032 | Time 1.10s | Train NLL -3.088 | Val NLL 2.742 | LR 4.89e-03
# Epoch 033 | Time 0.90s | Train NLL -1.176 | Val NLL -0.289 | LR 4.88e-03
# Epoch 034 | Time 0.91s | Train NLL -0.749 | Val NLL -2.948 | LR 4.87e-03
# Epoch 035 | Time 0.90s | Train NLL -4.357 | Val NLL -1.455 | LR 4.86e-03
# Epoch 036 | Time 1.04s | Train NLL -3.564 | Val NLL -1.674 | LR 4.86e-03
# Epoch 037 | Time 1.10s | Train NLL -3.354 | Val NLL -3.765 | LR 4.85e-03
# Epoch 038 | Time 1.32s | Train NLL -3.690 | Val NLL -3.801 | LR 4.84e-03
# Epoch 039 | Time 1.40s | Train NLL -3.974 | Val NLL -5.284 | LR 4.83e-03
# Epoch 040 | Time 1.39s | Train NLL -2.721 | Val NLL -2.303 | LR 4.82e-03
# Epoch 041 | Time 1.10s | Train NLL -4.247 | Val NLL -3.691 | LR 4.81e-03
# Epoch 042 | Time 1.32s | Train NLL -4.547 | Val NLL -4.742 | LR 4.80e-03
# Epoch 043 | Time 2.10s | Train NLL -3.342 | Val NLL -3.760 | LR 4.79e-03
# Epoch 044 | Time 1.33s | Train NLL -4.397 | Val NLL -3.918 | LR 4.78e-03
# Epoch 045 | Time 1.27s | Train NLL -3.499 | Val NLL -4.100 | LR 4.77e-03
# Epoch 046 | Time 1.34s | Train NLL -4.528 | Val NLL -5.491 | LR 4.75e-03
# Epoch 047 | Time 1.28s | Train NLL -4.399 | Val NLL -2.939 | LR 4.74e-03
# Epoch 048 | Time 1.22s | Train NLL -4.302 | Val NLL -4.291 | LR 4.73e-03
# Epoch 049 | Time 1.06s | Train NLL -4.880 | Val NLL -5.286 | LR 4.72e-03
# Epoch 050 | Time 1.12s | Train NLL -4.928 | Val NLL -4.570 | LR 4.71e-03
# Epoch 051 | Time 1.09s | Train NLL -2.846 | Val NLL -5.674 | LR 4.69e-03
# Epoch 052 | Time 1.06s | Train NLL -5.768 | Val NLL -4.015 | LR 4.68e-03
# Epoch 053 | Time 1.37s | Train NLL -3.466 | Val NLL -5.227 | LR 4.67e-03
# Epoch 054 | Time 1.82s | Train NLL -3.436 | Val NLL -3.836 | LR 4.65e-03
# Epoch 055 | Time 1.50s | Train NLL -5.168 | Val NLL -2.703 | LR 4.64e-03
# Epoch 056 | Time 1.22s | Train NLL -1.146 | Val NLL -2.298 | LR 4.63e-03
# Epoch 057 | Time 1.13s | Train NLL -3.717 | Val NLL -5.028 | LR 4.61e-03
# Epoch 058 | Time 1.17s | Train NLL -5.404 | Val NLL -4.764 | LR 4.60e-03
# Epoch 059 | Time 1.14s | Train NLL -4.614 | Val NLL -6.098 | LR 4.58e-03
# Epoch 060 | Time 1.06s | Train NLL -4.375 | Val NLL -3.955 | LR 4.57e-03
# Epoch 061 | Time 1.27s | Train NLL -3.192 | Val NLL -3.325 | LR 4.55e-03
# Epoch 062 | Time 1.01s | Train NLL -5.499 | Val NLL -5.843 | LR 4.54e-03
# Epoch 063 | Time 1.06s | Train NLL -6.183 | Val NLL -3.762 | LR 4.52e-03
# Epoch 064 | Time 0.88s | Train NLL -4.209 | Val NLL -4.895 | LR 4.51e-03
# Epoch 065 | Time 1.02s | Train NLL -4.874 | Val NLL -4.508 | LR 4.49e-03
# Epoch 066 | Time 1.11s | Train NLL -5.966 | Val NLL -6.802 | LR 4.47e-03
# Epoch 067 | Time 1.12s | Train NLL -2.044 | Val NLL -4.534 | LR 4.46e-03
# Epoch 068 | Time 1.37s | Train NLL -3.343 | Val NLL -4.933 | LR 4.44e-03
# Epoch 069 | Time 1.24s | Train NLL -6.052 | Val NLL -4.908 | LR 4.42e-03
# Epoch 070 | Time 1.25s | Train NLL -2.272 | Val NLL -2.285 | LR 4.41e-03
# Epoch 071 | Time 1.08s | Train NLL -3.195 | Val NLL -3.109 | LR 4.39e-03
# Epoch 072 | Time 1.05s | Train NLL -3.749 | Val NLL -4.610 | LR 4.37e-03
# Epoch 073 | Time 1.16s | Train NLL -4.407 | Val NLL -4.472 | LR 4.35e-03
# Epoch 074 | Time 0.97s | Train NLL -6.157 | Val NLL -4.965 | LR 4.34e-03
# Epoch 075 | Time 1.15s | Train NLL -5.479 | Val NLL -5.315 | LR 4.32e-03
# Epoch 076 | Time 1.05s | Train NLL -6.163 | Val NLL -3.066 | LR 4.30e-03
# Epoch 077 | Time 1.72s | Train NLL -5.191 | Val NLL -5.709 | LR 4.28e-03
# Epoch 078 | Time 1.54s | Train NLL -6.009 | Val NLL -5.693 | LR 4.26e-03
# Epoch 079 | Time 0.98s | Train NLL -6.368 | Val NLL -6.264 | LR 4.24e-03
# Epoch 080 | Time 1.09s | Train NLL -5.743 | Val NLL -4.856 | LR 4.22e-03
# Epoch 081 | Time 1.10s | Train NLL -6.557 | Val NLL -6.485 | LR 4.21e-03
# Epoch 082 | Time 1.69s | Train NLL -6.945 | Val NLL -6.037 | LR 4.19e-03
# Epoch 083 | Time 1.52s | Train NLL -6.317 | Val NLL -6.471 | LR 4.17e-03
# Epoch 084 | Time 1.23s | Train NLL -0.907 | Val NLL -2.985 | LR 4.15e-03
# Epoch 085 | Time 0.99s | Train NLL -5.198 | Val NLL -5.857 | LR 4.13e-03
# Epoch 086 | Time 1.09s | Train NLL -6.653 | Val NLL -7.266 | LR 4.11e-03
# Epoch 087 | Time 1.21s | Train NLL -7.103 | Val NLL -6.298 | LR 4.09e-03
# Epoch 088 | Time 1.21s | Train NLL -5.224 | Val NLL -6.124 | LR 4.06e-03
# Epoch 089 | Time 2.09s | Train NLL -6.146 | Val NLL -2.572 | LR 4.04e-03
# Epoch 090 | Time 1.84s | Train NLL -4.927 | Val NLL -5.331 | LR 4.02e-03
# Epoch 091 | Time 1.23s | Train NLL -6.343 | Val NLL -6.341 | LR 4.00e-03
# Epoch 092 | Time 1.30s | Train NLL -5.990 | Val NLL -5.866 | LR 3.98e-03
# Epoch 093 | Time 1.10s | Train NLL -6.397 | Val NLL -1.102 | LR 3.96e-03
# Epoch 094 | Time 1.43s | Train NLL -4.481 | Val NLL -6.535 | LR 3.94e-03
# Epoch 095 | Time 1.22s | Train NLL -6.837 | Val NLL -7.868 | LR 3.92e-03
# Epoch 096 | Time 1.11s | Train NLL -5.071 | Val NLL -1.507 | LR 3.89e-03
# Epoch 097 | Time 1.18s | Train NLL 0.154 | Val NLL -1.747 | LR 3.87e-03
# Epoch 098 | Time 0.93s | Train NLL -4.561 | Val NLL -5.956 | LR 3.85e-03
# Epoch 099 | Time 1.03s | Train NLL -5.689 | Val NLL -6.314 | LR 3.83e-03
# Epoch 100 | Time 1.08s | Train NLL -6.434 | Val NLL -5.326 | LR 3.80e-03
# Epoch 101 | Time 1.20s | Train NLL -5.425 | Val NLL -1.686 | LR 3.78e-03
# Epoch 102 | Time 1.11s | Train NLL -5.875 | Val NLL -6.674 | LR 3.76e-03
# Epoch 103 | Time 1.02s | Train NLL -5.855 | Val NLL -6.740 | LR 3.73e-03
# Epoch 104 | Time 1.04s | Train NLL -6.932 | Val NLL -6.067 | LR 3.71e-03
# Epoch 105 | Time 1.05s | Train NLL -7.359 | Val NLL -6.212 | LR 3.69e-03
# Epoch 106 | Time 1.12s | Train NLL -5.407 | Val NLL -2.874 | LR 3.66e-03
# Epoch 107 | Time 0.99s | Train NLL -2.947 | Val NLL -4.489 | LR 3.64e-03
# Epoch 108 | Time 1.25s | Train NLL -6.193 | Val NLL -6.802 | LR 3.62e-03
# Epoch 109 | Time 1.25s | Train NLL -6.549 | Val NLL -6.649 | LR 3.59e-03
# Epoch 110 | Time 1.18s | Train NLL -6.874 | Val NLL -6.777 | LR 3.57e-03
# Epoch 111 | Time 1.12s | Train NLL -6.360 | Val NLL -6.164 | LR 3.55e-03
# Epoch 112 | Time 1.01s | Train NLL -7.352 | Val NLL -5.607 | LR 3.52e-03
# Epoch 113 | Time 0.95s | Train NLL -7.263 | Val NLL -6.971 | LR 3.50e-03
# Epoch 114 | Time 1.23s | Train NLL -7.809 | Val NLL -8.183 | LR 3.47e-03
# Epoch 115 | Time 1.26s | Train NLL -5.272 | Val NLL -6.806 | LR 3.45e-03
# Epoch 116 | Time 1.23s | Train NLL -6.929 | Val NLL -3.359 | LR 3.42e-03
# Epoch 117 | Time 1.56s | Train NLL -2.568 | Val NLL -6.910 | LR 3.40e-03
# Epoch 118 | Time 1.36s | Train NLL -6.720 | Val NLL -6.267 | LR 3.37e-03
# Epoch 119 | Time 1.17s | Train NLL -6.894 | Val NLL -8.188 | LR 3.35e-03
# Epoch 120 | Time 1.27s | Train NLL -3.669 | Val NLL -3.787 | LR 3.32e-03
# Epoch 121 | Time 3.29s | Train NLL -5.664 | Val NLL -6.655 | LR 3.30e-03
# Epoch 122 | Time 1.98s | Train NLL -7.170 | Val NLL -6.005 | LR 3.27e-03
# Epoch 123 | Time 1.26s | Train NLL -7.208 | Val NLL -5.709 | LR 3.25e-03
# Epoch 124 | Time 1.20s | Train NLL -6.706 | Val NLL -0.524 | LR 3.22e-03
# Epoch 125 | Time 1.22s | Train NLL -3.476 | Val NLL -5.218 | LR 3.20e-03
# Epoch 126 | Time 1.52s | Train NLL -6.591 | Val NLL -7.259 | LR 3.17e-03
# Epoch 127 | Time 1.20s | Train NLL -6.816 | Val NLL -7.103 | LR 3.14e-03
# Epoch 128 | Time 1.09s | Train NLL -7.995 | Val NLL -8.537 | LR 3.12e-03
# Epoch 129 | Time 1.06s | Train NLL -6.491 | Val NLL -2.178 | LR 3.09e-03
# Epoch 130 | Time 1.29s | Train NLL -3.966 | Val NLL -5.407 | LR 3.07e-03
# Epoch 131 | Time 1.21s | Train NLL -7.097 | Val NLL -7.265 | LR 3.04e-03
# Epoch 132 | Time 1.23s | Train NLL -7.981 | Val NLL -7.908 | LR 3.02e-03
# Epoch 133 | Time 1.16s | Train NLL -8.534 | Val NLL -8.029 | LR 2.99e-03
# Epoch 134 | Time 1.30s | Train NLL -6.316 | Val NLL -5.222 | LR 2.96e-03
# Epoch 135 | Time 1.02s | Train NLL -6.266 | Val NLL -5.246 | LR 2.94e-03
# Epoch 136 | Time 1.02s | Train NLL -7.476 | Val NLL -6.132 | LR 2.91e-03
# Epoch 137 | Time 1.02s | Train NLL -6.985 | Val NLL -7.730 | LR 2.88e-03
# Epoch 138 | Time 1.08s | Train NLL -6.771 | Val NLL -4.336 | LR 2.86e-03
# Epoch 139 | Time 1.17s | Train NLL -5.833 | Val NLL -6.744 | LR 2.83e-03
# Epoch 140 | Time 1.10s | Train NLL -6.697 | Val NLL -7.327 | LR 2.81e-03
# Epoch 141 | Time 1.23s | Train NLL -7.261 | Val NLL -7.951 | LR 2.78e-03
# Epoch 142 | Time 1.35s | Train NLL -8.572 | Val NLL -8.685 | LR 2.75e-03
# Epoch 143 | Time 1.02s | Train NLL -7.990 | Val NLL -6.077 | LR 2.73e-03
# Epoch 144 | Time 1.06s | Train NLL -6.649 | Val NLL -3.401 | LR 2.70e-03
# Epoch 145 | Time 1.04s | Train NLL -6.165 | Val NLL -6.393 | LR 2.67e-03
# Epoch 146 | Time 1.08s | Train NLL -7.222 | Val NLL -6.852 | LR 2.65e-03
# Epoch 147 | Time 0.98s | Train NLL -8.207 | Val NLL -8.425 | LR 2.62e-03
# Epoch 148 | Time 0.98s | Train NLL -8.813 | Val NLL -6.521 | LR 2.59e-03
# Epoch 149 | Time 0.98s | Train NLL -4.666 | Val NLL -5.413 | LR 2.57e-03
# Epoch 150 | Time 0.96s | Train NLL -4.842 | Val NLL -6.314 | LR 2.54e-03
# Epoch 151 | Time 0.96s | Train NLL -7.669 | Val NLL -8.053 | LR 2.51e-03
# Epoch 152 | Time 0.92s | Train NLL -8.364 | Val NLL -6.255 | LR 2.49e-03
# Epoch 153 | Time 0.97s | Train NLL -7.884 | Val NLL -8.441 | LR 2.46e-03
# Epoch 154 | Time 1.13s | Train NLL -9.151 | Val NLL -8.559 | LR 2.43e-03
# Epoch 155 | Time 1.06s | Train NLL -8.938 | Val NLL -6.812 | LR 2.41e-03
# Epoch 156 | Time 0.95s | Train NLL -7.956 | Val NLL -5.594 | LR 2.38e-03
# Epoch 157 | Time 0.99s | Train NLL -7.202 | Val NLL -8.435 | LR 2.35e-03
# Epoch 158 | Time 0.95s | Train NLL -6.724 | Val NLL -7.377 | LR 2.33e-03
# Epoch 159 | Time 0.96s | Train NLL -7.688 | Val NLL -6.426 | LR 2.30e-03
# Epoch 160 | Time 0.98s | Train NLL -7.359 | Val NLL -7.375 | LR 2.27e-03
# Epoch 161 | Time 0.98s | Train NLL -8.589 | Val NLL -7.982 | LR 2.25e-03
# Epoch 162 | Time 1.04s | Train NLL -7.292 | Val NLL -4.241 | LR 2.22e-03
# Epoch 163 | Time 0.96s | Train NLL -7.628 | Val NLL -7.700 | LR 2.19e-03
# Epoch 164 | Time 0.97s | Train NLL -8.647 | Val NLL -8.282 | LR 2.17e-03
# Epoch 165 | Time 0.93s | Train NLL -8.728 | Val NLL -8.384 | LR 2.14e-03
# Epoch 166 | Time 1.11s | Train NLL -9.610 | Val NLL -9.528 | LR 2.12e-03
# Epoch 167 | Time 1.01s | Train NLL -8.616 | Val NLL -4.317 | LR 2.09e-03
# Epoch 168 | Time 0.98s | Train NLL -6.069 | Val NLL -4.904 | LR 2.06e-03
# Epoch 169 | Time 0.96s | Train NLL -6.359 | Val NLL -5.509 | LR 2.04e-03
# Epoch 170 | Time 1.08s | Train NLL -7.716 | Val NLL -7.912 | LR 2.01e-03
# Epoch 171 | Time 0.97s | Train NLL -8.928 | Val NLL -9.211 | LR 1.98e-03
# Epoch 172 | Time 0.98s | Train NLL -8.443 | Val NLL -7.967 | LR 1.96e-03
# Epoch 173 | Time 1.05s | Train NLL -5.918 | Val NLL -4.878 | LR 1.93e-03
# Epoch 174 | Time 0.99s | Train NLL -7.130 | Val NLL -7.953 | LR 1.91e-03
# Epoch 175 | Time 1.03s | Train NLL -8.203 | Val NLL -8.037 | LR 1.88e-03
# Epoch 176 | Time 0.96s | Train NLL -8.513 | Val NLL -8.671 | LR 1.86e-03
# Epoch 177 | Time 0.98s | Train NLL -9.317 | Val NLL -9.010 | LR 1.83e-03
# Epoch 178 | Time 1.03s | Train NLL -6.611 | Val NLL -8.509 | LR 1.80e-03
# Epoch 179 | Time 1.07s | Train NLL -7.146 | Val NLL -8.128 | LR 1.78e-03
# Epoch 180 | Time 1.12s | Train NLL -8.908 | Val NLL -8.728 | LR 1.75e-03
# Epoch 181 | Time 1.09s | Train NLL -8.243 | Val NLL -7.341 | LR 1.73e-03
# Epoch 182 | Time 1.08s | Train NLL -6.766 | Val NLL -8.797 | LR 1.70e-03
# Epoch 183 | Time 0.98s | Train NLL -9.307 | Val NLL -9.368 | LR 1.68e-03
# Epoch 184 | Time 0.95s | Train NLL -9.167 | Val NLL -5.501 | LR 1.65e-03
# Epoch 185 | Time 1.02s | Train NLL -8.351 | Val NLL -4.940 | LR 1.63e-03
# Epoch 186 | Time 1.00s | Train NLL -6.939 | Val NLL -3.347 | LR 1.60e-03
# Epoch 187 | Time 0.97s | Train NLL -7.301 | Val NLL -7.474 | LR 1.58e-03
# Epoch 188 | Time 0.95s | Train NLL -8.184 | Val NLL -8.712 | LR 1.55e-03
# Epoch 189 | Time 0.94s | Train NLL -8.063 | Val NLL -8.805 | LR 1.53e-03
# Epoch 190 | Time 1.07s | Train NLL -9.345 | Val NLL -9.347 | LR 1.50e-03
# Epoch 191 | Time 0.98s | Train NLL -9.200 | Val NLL -9.287 | LR 1.48e-03
# Epoch 192 | Time 0.98s | Train NLL -9.829 | Val NLL -9.450 | LR 1.45e-03
# Epoch 193 | Time 0.97s | Train NLL -9.049 | Val NLL -7.363 | LR 1.43e-03
# Epoch 194 | Time 0.97s | Train NLL -9.291 | Val NLL -8.211 | LR 1.41e-03
# Epoch 195 | Time 0.96s | Train NLL -5.043 | Val NLL -1.405 | LR 1.38e-03
# Epoch 196 | Time 0.94s | Train NLL -4.805 | Val NLL -9.265 | LR 1.36e-03
# Epoch 197 | Time 0.97s | Train NLL -9.241 | Val NLL -9.062 | LR 1.34e-03
# Epoch 198 | Time 0.94s | Train NLL -9.330 | Val NLL -9.167 | LR 1.31e-03
# Epoch 199 | Time 1.00s | Train NLL -9.814 | Val NLL -9.745 | LR 1.29e-03
# Epoch 200 | Time 0.99s | Train NLL -9.526 | Val NLL -9.030 | LR 1.27e-03
# Epoch 201 | Time 1.00s | Train NLL -7.844 | Val NLL -7.952 | LR 1.24e-03
# Epoch 202 | Time 1.05s | Train NLL -7.721 | Val NLL -5.997 | LR 1.22e-03
# Epoch 203 | Time 0.99s | Train NLL -7.769 | Val NLL -9.262 | LR 1.20e-03
# Epoch 204 | Time 0.97s | Train NLL -9.628 | Val NLL -9.237 | LR 1.17e-03
# Epoch 205 | Time 1.02s | Train NLL -9.333 | Val NLL -8.808 | LR 1.15e-03
# Epoch 206 | Time 1.00s | Train NLL -8.298 | Val NLL -10.095 | LR 1.13e-03
# Epoch 207 | Time 0.97s | Train NLL -7.409 | Val NLL -7.678 | LR 1.11e-03
# Epoch 208 | Time 0.96s | Train NLL -8.159 | Val NLL -8.690 | LR 1.08e-03
# Epoch 209 | Time 0.94s | Train NLL -9.678 | Val NLL -8.108 | LR 1.06e-03
# Epoch 210 | Time 0.98s | Train NLL -9.216 | Val NLL -8.917 | LR 1.04e-03
# Epoch 211 | Time 0.96s | Train NLL -8.001 | Val NLL -8.070 | LR 1.02e-03
# Epoch 212 | Time 1.00s | Train NLL -9.084 | Val NLL -9.138 | LR 9.98e-04
# Epoch 213 | Time 0.98s | Train NLL -9.050 | Val NLL -8.527 | LR 9.77e-04
# Epoch 214 | Time 1.06s | Train NLL -9.575 | Val NLL -9.805 | LR 9.56e-04
# Epoch 215 | Time 1.02s | Train NLL -10.179 | Val NLL -9.617 | LR 9.35e-04
# Epoch 216 | Time 0.96s | Train NLL -9.325 | Val NLL -9.470 | LR 9.15e-04
# Epoch 217 | Time 0.98s | Train NLL -9.600 | Val NLL -10.281 | LR 8.94e-04
# Epoch 218 | Time 1.00s | Train NLL -10.766 | Val NLL -10.681 | LR 8.74e-04
# Epoch 219 | Time 1.01s | Train NLL -10.654 | Val NLL -10.726 | LR 8.54e-04
# Epoch 220 | Time 0.97s | Train NLL -9.526 | Val NLL -10.684 | LR 8.34e-04
# Epoch 221 | Time 0.97s | Train NLL -9.484 | Val NLL -8.683 | LR 8.14e-04
# Epoch 222 | Time 1.00s | Train NLL -9.103 | Val NLL -5.404 | LR 7.94e-04
# Epoch 223 | Time 0.98s | Train NLL -9.168 | Val NLL -9.748 | LR 7.75e-04
# Epoch 224 | Time 0.94s | Train NLL -10.479 | Val NLL -10.088 | LR 7.56e-04
# Epoch 225 | Time 0.97s | Train NLL -10.479 | Val NLL -9.781 | LR 7.37e-04
# Epoch 226 | Time 1.07s | Train NLL -10.515 | Val NLL -9.053 | LR 7.18e-04
# Epoch 227 | Time 0.94s | Train NLL -8.444 | Val NLL -8.026 | LR 7.00e-04
# Epoch 228 | Time 0.99s | Train NLL -8.212 | Val NLL -9.283 | LR 6.81e-04
# Epoch 229 | Time 0.97s | Train NLL -10.624 | Val NLL -9.947 | LR 6.63e-04
# Epoch 230 | Time 0.99s | Train NLL -10.620 | Val NLL -10.927 | LR 6.45e-04
# Epoch 231 | Time 0.98s | Train NLL -11.186 | Val NLL -9.610 | LR 6.27e-04
# Epoch 232 | Time 1.01s | Train NLL -10.480 | Val NLL -11.061 | LR 6.10e-04
# Epoch 233 | Time 1.01s | Train NLL -11.077 | Val NLL -10.539 | LR 5.93e-04
# Epoch 234 | Time 0.95s | Train NLL -10.464 | Val NLL -7.903 | LR 5.75e-04
# Epoch 235 | Time 0.97s | Train NLL -8.575 | Val NLL -5.382 | LR 5.59e-04
# Epoch 236 | Time 0.99s | Train NLL -8.560 | Val NLL -10.163 | LR 5.42e-04
# Epoch 237 | Time 0.99s | Train NLL -10.351 | Val NLL -10.599 | LR 5.25e-04
# Epoch 238 | Time 1.05s | Train NLL -11.108 | Val NLL -11.037 | LR 5.09e-04
# Epoch 239 | Time 1.11s | Train NLL -11.589 | Val NLL -10.962 | LR 4.93e-04
# Epoch 240 | Time 0.97s | Train NLL -11.674 | Val NLL -10.562 | LR 4.77e-04
# Epoch 241 | Time 0.97s | Train NLL -11.601 | Val NLL -11.446 | LR 4.62e-04
# Epoch 242 | Time 0.92s | Train NLL -11.721 | Val NLL -11.434 | LR 4.47e-04
# Epoch 243 | Time 0.98s | Train NLL -11.321 | Val NLL -11.447 | LR 4.32e-04
# Epoch 244 | Time 0.93s | Train NLL -11.191 | Val NLL -10.596 | LR 4.17e-04
# Epoch 245 | Time 0.95s | Train NLL -10.820 | Val NLL -9.280 | LR 4.02e-04
# Epoch 246 | Time 0.98s | Train NLL -8.739 | Val NLL -6.632 | LR 3.88e-04
# Epoch 247 | Time 1.24s | Train NLL -10.239 | Val NLL -9.981 | LR 3.74e-04
# Epoch 248 | Time 1.22s | Train NLL -10.508 | Val NLL -8.756 | LR 3.60e-04
# Epoch 249 | Time 1.25s | Train NLL -11.156 | Val NLL -10.804 | LR 3.46e-04
# Epoch 250 | Time 1.35s | Train NLL -11.849 | Val NLL -11.741 | LR 3.33e-04
# Epoch 251 | Time 1.20s | Train NLL -12.134 | Val NLL -11.740 | LR 3.20e-04
# Epoch 252 | Time 1.28s | Train NLL -12.012 | Val NLL -11.989 | LR 3.07e-04
# Epoch 253 | Time 1.27s | Train NLL -11.536 | Val NLL -10.259 | LR 2.94e-04
# Epoch 254 | Time 1.24s | Train NLL -12.068 | Val NLL -12.150 | LR 2.82e-04
# Epoch 255 | Time 1.24s | Train NLL -12.487 | Val NLL -12.174 | LR 2.69e-04
# Epoch 256 | Time 1.26s | Train NLL -12.021 | Val NLL -9.704 | LR 2.58e-04
# Epoch 257 | Time 1.28s | Train NLL -11.879 | Val NLL -12.331 | LR 2.46e-04
# Epoch 258 | Time 1.37s | Train NLL -12.657 | Val NLL -12.420 | LR 2.35e-04
# Epoch 259 | Time 1.25s | Train NLL -12.714 | Val NLL -12.392 | LR 2.23e-04
# Epoch 260 | Time 1.27s | Train NLL -12.718 | Val NLL -12.045 | LR 2.13e-04
# Epoch 261 | Time 1.26s | Train NLL -12.715 | Val NLL -12.199 | LR 2.02e-04
# Epoch 262 | Time 1.34s | Train NLL -12.286 | Val NLL -12.365 | LR 1.92e-04
# Epoch 263 | Time 1.24s | Train NLL -12.730 | Val NLL -12.246 | LR 1.81e-04
# Epoch 264 | Time 1.22s | Train NLL -12.877 | Val NLL -12.266 | LR 1.72e-04
# Epoch 265 | Time 1.27s | Train NLL -12.919 | Val NLL -12.687 | LR 1.62e-04
# Epoch 266 | Time 1.21s | Train NLL -12.822 | Val NLL -12.267 | LR 1.53e-04
# Epoch 267 | Time 1.27s | Train NLL -12.582 | Val NLL -12.268 | LR 1.44e-04
# Epoch 268 | Time 1.27s | Train NLL -12.083 | Val NLL -10.399 | LR 1.35e-04
# Epoch 269 | Time 1.22s | Train NLL -11.299 | Val NLL -11.345 | LR 1.27e-04
# Epoch 270 | Time 1.21s | Train NLL -12.594 | Val NLL -12.319 | LR 1.18e-04
# Epoch 271 | Time 1.31s | Train NLL -13.171 | Val NLL -12.941 | LR 1.10e-04
# Epoch 272 | Time 1.23s | Train NLL -13.377 | Val NLL -13.020 | LR 1.03e-04
# Epoch 273 | Time 1.27s | Train NLL -13.449 | Val NLL -13.067 | LR 9.52e-05
# Epoch 274 | Time 1.35s | Train NLL -13.504 | Val NLL -13.126 | LR 8.81e-05
# Epoch 275 | Time 1.25s | Train NLL -13.561 | Val NLL -13.164 | LR 8.12e-05
# Epoch 276 | Time 1.25s | Train NLL -13.586 | Val NLL -13.226 | LR 7.46e-05
# Epoch 277 | Time 1.28s | Train NLL -13.672 | Val NLL -13.270 | LR 6.83e-05
# Epoch 278 | Time 1.31s | Train NLL -13.627 | Val NLL -13.303 | LR 6.23e-05
# Epoch 279 | Time 1.25s | Train NLL -13.746 | Val NLL -13.349 | LR 5.65e-05
# Epoch 280 | Time 1.25s | Train NLL -13.786 | Val NLL -13.381 | LR 5.10e-05
# Epoch 281 | Time 1.23s | Train NLL -13.829 | Val NLL -13.411 | LR 4.58e-05
# Epoch 282 | Time 1.26s | Train NLL -13.854 | Val NLL -13.438 | LR 4.09e-05
# Epoch 283 | Time 1.28s | Train NLL -13.874 | Val NLL -13.462 | LR 3.62e-05
# Epoch 284 | Time 1.28s | Train NLL -13.893 | Val NLL -13.484 | LR 3.18e-05
# Epoch 285 | Time 1.31s | Train NLL -13.925 | Val NLL -13.504 | LR 2.77e-05
# Epoch 286 | Time 1.03s | Train NLL -13.942 | Val NLL -13.522 | LR 2.39e-05
# Epoch 287 | Time 0.91s | Train NLL -13.882 | Val NLL -13.536 | LR 2.04e-05
# Epoch 288 | Time 0.89s | Train NLL -13.982 | Val NLL -13.550 | LR 1.71e-05
# Epoch 289 | Time 0.90s | Train NLL -13.982 | Val NLL -13.559 | LR 1.42e-05
# Epoch 290 | Time 0.85s | Train NLL -13.996 | Val NLL -13.569 | LR 1.15e-05
# Epoch 291 | Time 0.88s | Train NLL -13.984 | Val NLL -13.576 | LR 9.07e-06
# Epoch 292 | Time 0.88s | Train NLL -14.010 | Val NLL -13.580 | LR 6.94e-06
# Epoch 293 | Time 0.86s | Train NLL -13.913 | Val NLL -13.585 | LR 5.10e-06
# Epoch 294 | Time 0.84s | Train NLL -13.926 | Val NLL -13.588 | LR 3.54e-06
# Epoch 295 | Time 0.86s | Train NLL -14.016 | Val NLL -13.589 | LR 2.27e-06
# Epoch 296 | Time 1.13s | Train NLL -14.020 | Val NLL -13.590 | LR 1.28e-06
# Epoch 297 | Time 1.24s | Train NLL -14.009 | Val NLL -13.592 | LR 5.67e-07
# Epoch 298 | Time 1.35s | Train NLL -14.025 | Val NLL -13.592 | LR 1.42e-07
# Epoch 299 | Time 1.27s | Train NLL -14.018 | Val NLL -13.592 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 476.19
# Average absolute difference in CASUALTIES: 0.30

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
