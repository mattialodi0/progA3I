# %% [markdown]
# # Heavy Rain model training

# %% [markdown]
# #### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
from scipy.stats import gaussian_kde
import time
import math

import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import zuko

import utils

# %%
DATASET_PATH = Path("../datasets/disasters_merged_all_feats.csv")
EVENT_GROUP = 'Heavy Rain'
RUN_PATH = Path(f"../runs/flow_{EVENT_GROUP.lower()}.pt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# ### Group by event type

# %%
df['EVENT_GROUP'].value_counts()
# Out:
# EVENT_GROUP
# Wind           152966
# Hail            57980
# Storm           55795
# Flood           49691
# Freeze          39347
# Drought         20115
# Snow            19792
# Heat            14279
# Heavy Rain      10488
# Fog              4943
# Wildfire         2505
# Lightning        2261
# Debris Flow      1047
# Avalanche         203
# Name: count, dtype: int64

# %%
event_group_dfs = {
    'Hail': df[df['EVENT_GROUP'] == 'Hail'].drop(columns=['EVENT_GROUP', 'WIND_SPEED']),
    'Wind': df[df['EVENT_GROUP'] == 'Wind'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Storm': df[df['EVENT_GROUP'] == 'Storm'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Flood': df[df['EVENT_GROUP'] == 'Flood'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Freeze': df[df['EVENT_GROUP'] == 'Freeze'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Drought': df[df['EVENT_GROUP'] == 'Drought'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Snow': df[df['EVENT_GROUP'] == 'Snow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heat': df[df['EVENT_GROUP'] == 'Heat'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Heavy Rain': df[df['EVENT_GROUP'] == 'Heavy Rain'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Fog': df[df['EVENT_GROUP'] == 'Fog'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Wildfire': df[df['EVENT_GROUP'] == 'Wildfire'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Lightning': df[df['EVENT_GROUP'] == 'Lightning'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Debris Flow': df[df['EVENT_GROUP'] == 'Debris Flow'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
    'Avalanche': df[df['EVENT_GROUP'] == 'Avalanche'].drop(columns=['EVENT_GROUP', 'HAIL_SIZE']),
}

# %%
event_group_dfs['Hail'].head()
# Out:
#     DAMAGES  CASUALTIES  DURATION_HOURS  HAIL_SIZE  TIME_DAY_SIN  \
# 65      0.0           0             0.0       1.00      0.154204
# 72      0.0           0             0.0       0.88      0.353445
# 74      0.0           0             0.0       1.00      0.353445
# 76    100.0           0             0.0       1.75      0.353445
# 82      0.0           0             0.0       1.00      0.353445
#
#     TIME_DAY_COS  TIME_YEAR_NORM  PRECIPITATION   TMIN   TMAX  ...  SLOPE  \
# 65      0.988039             0.0        1404.65  11.66  22.69  ...   1.89
# 72      0.935455             0.0        1519.92  12.85  24.73  ...   6.01
# 74      0.935455             0.0        1478.56  12.41  24.58  ...   5.17
# 76      0.935455             0.0        1589.20  12.37  24.92  ...   7.35
# 82      0.935455             0.0        1437.68  12.31  24.38  ...   4.94
#
#     COV_BARREN  COV_CULTIVATED  COV_VEGETATION  COV_FOREST  COV_WATER  \
# 65       0.000           0.716           0.146       0.136      0.002
# 72       0.003           0.120           0.047       0.769      0.040
# 74       0.000           0.328           0.094       0.538      0.001
# 76       0.000           0.049           0.020       0.930      0.001
# 82       0.000           0.183           0.119       0.467      0.018
#
#     COV_SNOW_ICE  COV_URBAN  RIVER_DISTANCE  SEA_DISTANCE
# 65           0.0      0.000           256.4         415.3
# 72           0.0      0.021          1082.0         170.3
# 74           0.0      0.040           515.2         217.7
# 76           0.0      0.000           925.4         142.4
# 82           0.0      0.212           377.5         223.6
#
# [5 rows x 23 columns]

# %%
df = event_group_dfs[EVENT_GROUP]

# %% [markdown]
# ### Data normalization

# %%
TARGET_COLS = ["DAMAGES", "CASUALTIES"]

X_COLS = [
    'BEGIN_LAT', 'BEGIN_LON',
    'DURATION_HOURS', 'WIND_SPEED', # change with hail size for hail
    'TIME_DAY_SIN', 'TIME_DAY_COS', 'TIME_YEAR_NORM',
    'PRECIPITATION', 'TMIN', 'TMAX',
    'ELEVATION', 'SLOPE',
    'COV_BARREN', 'COV_CULTIVATED', 'COV_VEGETATION',
    'COV_FOREST', 'COV_WATER', 'COV_SNOW_ICE', 'COV_URBAN',
    'RIVER_DISTANCE', 'SEA_DISTANCE',
]

# %%
X = df[X_COLS].values.astype(np.float32)
Y = df[TARGET_COLS].values.astype(np.float32)

# %%
# targets log transformation
Y = np.log1p(Y)

# %%
# train-val-test split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
# standardize features and targets
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = x_scaler.fit_transform(X_train)
X_val   = x_scaler.transform(X_val)
X_test  = x_scaler.transform(X_test)

Y_train = y_scaler.fit_transform(Y_train)
Y_val   = y_scaler.transform(Y_val)
Y_test  = y_scaler.transform(Y_test)

# %% [markdown]
# ### Dataset split

# %%
# conversion to tensors and move to device
X_train = torch.tensor(X_train).to(device)
Y_train = torch.tensor(Y_train).to(device)

X_val = torch.tensor(X_val).to(device)
Y_val = torch.tensor(Y_val).to(device)

X_test = torch.tensor(X_test).to(device)
Y_test = torch.tensor(Y_test).to(device)

# %%
# data loaders
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds   = TensorDataset(X_val, Y_val)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model definition

# %%
EPOCHS = 300
BATCH_SIZE = 512
BASE_LR = 5e-3

# find warmup steps as function of epochs and dataset size
WARMUP_STEPS = int(0.1 * (len(train_ds) // BATCH_SIZE) * EPOCHS)

# %%
flow = zuko.flows.NSF(
    features=2,
    context=21,
    transforms=8,
    hidden_features=[256, 256, 256],
    bins=16,
)

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader   = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
flow = flow.to(device)
optimizer = torch.optim.Adam(flow.parameters(), lr=BASE_LR, weight_decay=1e-5)
total_steps = EPOCHS * len(train_loader)
warmup_steps = 5 * len(train_loader)

# %%
print(f"NSF model created with {sum(p.numel() for p in flow.parameters())} parameters")
# Out:
# NSF model created with 1295088 parameters

# %% [markdown]
# ### Model training

# %%
history = utils.TrainingHistory()
best_val_loss = float("inf")
best_state_dict = None
global_step = 0

for epoch in range(EPOCHS):
    t0 = time.time()
    flow.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad(set_to_none=True)
        loss = -flow(x).log_prob(y).mean()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        global_step += 1
        if global_step < warmup_steps:
            lr_scale = global_step / warmup_steps
        else:
            progress = (global_step - warmup_steps) / (total_steps - warmup_steps)
            lr_scale = 0.5 * (1 + math.cos(math.pi * progress))
        for pg in optimizer.param_groups:
            pg['lr'] = BASE_LR * lr_scale

    train_loss /= max(len(train_loader), 1)
    flow.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = -flow(x).log_prob(y).mean()
            val_loss += loss.item()

    val_loss /= max(len(val_loader), 1)
    history.train_losses.append(train_loss)
    history.val_losses.append(val_loss)
    history.lrs.append(optimizer.param_groups[0]["lr"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = flow.state_dict()
        torch.save(flow.state_dict(), RUN_PATH)


    print(
        f"Epoch {epoch:03d} | "
        f"Time {time.time()-t0:.2f}s | "
        f"Train NLL {train_loss:.3f} | "
        f"Val NLL {val_loss:.3f} | "
        f"LR {optimizer.param_groups[0]['lr']:.2e}"
    )

if best_state_dict is not None:
    flow.load_state_dict(best_state_dict)
# Out:
# Epoch 000 | Time 11.36s | Train NLL 3.374 | Val NLL 1.042 | LR 1.00e-03
# Epoch 001 | Time 1.00s | Train NLL 0.467 | Val NLL -0.811 | LR 2.00e-03
# Epoch 002 | Time 0.97s | Train NLL -0.778 | Val NLL -2.330 | LR 3.00e-03
# Epoch 003 | Time 0.88s | Train NLL -0.416 | Val NLL -2.166 | LR 4.00e-03
# Epoch 004 | Time 1.05s | Train NLL 2.028 | Val NLL 0.823 | LR 5.00e-03
# Epoch 005 | Time 0.92s | Train NLL -0.981 | Val NLL -2.997 | LR 5.00e-03
# Epoch 006 | Time 1.16s | Train NLL -0.293 | Val NLL -2.147 | LR 5.00e-03
# Epoch 007 | Time 1.13s | Train NLL -1.101 | Val NLL -1.898 | LR 5.00e-03
# Epoch 008 | Time 1.10s | Train NLL -2.021 | Val NLL -2.519 | LR 5.00e-03
# Epoch 009 | Time 1.24s | Train NLL 0.999 | Val NLL -0.606 | LR 5.00e-03
# Epoch 010 | Time 1.81s | Train NLL -0.665 | Val NLL -1.433 | LR 4.99e-03
# Epoch 011 | Time 2.51s | Train NLL -2.180 | Val NLL -1.654 | LR 4.99e-03
# Epoch 012 | Time 0.93s | Train NLL -0.471 | Val NLL -1.577 | LR 4.99e-03
# Epoch 013 | Time 0.89s | Train NLL -1.363 | Val NLL 1.196 | LR 4.99e-03
# Epoch 014 | Time 0.97s | Train NLL 0.340 | Val NLL 2.623 | LR 4.99e-03
# Epoch 015 | Time 1.01s | Train NLL -0.190 | Val NLL 0.111 | LR 4.98e-03
# Epoch 016 | Time 0.89s | Train NLL -0.121 | Val NLL -2.192 | LR 4.98e-03
# Epoch 017 | Time 0.99s | Train NLL -2.938 | Val NLL -3.567 | LR 4.98e-03
# Epoch 018 | Time 1.02s | Train NLL -0.882 | Val NLL -3.115 | LR 4.97e-03
# Epoch 019 | Time 0.90s | Train NLL -1.115 | Val NLL 0.648 | LR 4.97e-03
# Epoch 020 | Time 0.98s | Train NLL 1.431 | Val NLL 2.471 | LR 4.96e-03
# Epoch 021 | Time 0.87s | Train NLL -0.225 | Val NLL -3.560 | LR 4.96e-03
# Epoch 022 | Time 0.90s | Train NLL 0.603 | Val NLL -0.182 | LR 4.95e-03
# Epoch 023 | Time 0.86s | Train NLL 1.083 | Val NLL -0.808 | LR 4.95e-03
# Epoch 024 | Time 0.84s | Train NLL -0.964 | Val NLL -1.218 | LR 4.94e-03
# Epoch 025 | Time 0.88s | Train NLL -1.030 | Val NLL -2.488 | LR 4.94e-03
# Epoch 026 | Time 0.98s | Train NLL -2.358 | Val NLL -2.304 | LR 4.93e-03
# Epoch 027 | Time 0.84s | Train NLL 1.115 | Val NLL 0.662 | LR 4.93e-03
# Epoch 028 | Time 0.96s | Train NLL -0.885 | Val NLL -2.394 | LR 4.92e-03
# Epoch 029 | Time 1.05s | Train NLL 0.735 | Val NLL -0.777 | LR 4.91e-03
# Epoch 030 | Time 0.93s | Train NLL -0.854 | Val NLL -1.721 | LR 4.90e-03
# Epoch 031 | Time 0.88s | Train NLL -0.703 | Val NLL -3.744 | LR 4.90e-03
# Epoch 032 | Time 0.90s | Train NLL -1.070 | Val NLL -3.044 | LR 4.89e-03
# Epoch 033 | Time 0.83s | Train NLL -2.354 | Val NLL -3.504 | LR 4.88e-03
# Epoch 034 | Time 0.90s | Train NLL -2.597 | Val NLL -4.616 | LR 4.87e-03
# Epoch 035 | Time 0.97s | Train NLL -4.156 | Val NLL -0.079 | LR 4.86e-03
# Epoch 036 | Time 0.83s | Train NLL -0.273 | Val NLL -0.338 | LR 4.86e-03
# Epoch 037 | Time 0.85s | Train NLL -0.547 | Val NLL -1.991 | LR 4.85e-03
# Epoch 038 | Time 0.79s | Train NLL -2.605 | Val NLL -4.530 | LR 4.84e-03
# Epoch 039 | Time 0.85s | Train NLL -2.340 | Val NLL -3.020 | LR 4.83e-03
# Epoch 040 | Time 0.85s | Train NLL -2.142 | Val NLL -3.747 | LR 4.82e-03
# Epoch 041 | Time 0.83s | Train NLL -3.412 | Val NLL -2.703 | LR 4.81e-03
# Epoch 042 | Time 0.82s | Train NLL -2.012 | Val NLL -3.006 | LR 4.80e-03
# Epoch 043 | Time 0.80s | Train NLL -1.025 | Val NLL 1.367 | LR 4.79e-03
# Epoch 044 | Time 0.77s | Train NLL 0.759 | Val NLL -1.529 | LR 4.78e-03
# Epoch 045 | Time 0.85s | Train NLL -1.592 | Val NLL 0.390 | LR 4.77e-03
# Epoch 046 | Time 0.86s | Train NLL -1.556 | Val NLL -3.843 | LR 4.75e-03
# Epoch 047 | Time 0.77s | Train NLL -1.688 | Val NLL 1.329 | LR 4.74e-03
# Epoch 048 | Time 0.82s | Train NLL 0.125 | Val NLL -3.958 | LR 4.73e-03
# Epoch 049 | Time 0.83s | Train NLL -0.943 | Val NLL 2.261 | LR 4.72e-03
# Epoch 050 | Time 0.85s | Train NLL 0.228 | Val NLL -3.315 | LR 4.71e-03
# Epoch 051 | Time 0.80s | Train NLL -0.798 | Val NLL -0.648 | LR 4.69e-03
# Epoch 052 | Time 0.82s | Train NLL -1.543 | Val NLL -0.031 | LR 4.68e-03
# Epoch 053 | Time 0.92s | Train NLL -1.639 | Val NLL -3.249 | LR 4.67e-03
# Epoch 054 | Time 0.81s | Train NLL -3.372 | Val NLL -3.263 | LR 4.65e-03
# Epoch 055 | Time 0.82s | Train NLL -3.953 | Val NLL -6.965 | LR 4.64e-03
# Epoch 056 | Time 0.88s | Train NLL -1.422 | Val NLL 0.398 | LR 4.63e-03
# Epoch 057 | Time 0.82s | Train NLL -2.073 | Val NLL -3.102 | LR 4.61e-03
# Epoch 058 | Time 0.80s | Train NLL -2.522 | Val NLL -3.773 | LR 4.60e-03
# Epoch 059 | Time 0.77s | Train NLL -3.581 | Val NLL 2.308 | LR 4.58e-03
# Epoch 060 | Time 0.77s | Train NLL -1.557 | Val NLL -4.487 | LR 4.57e-03
# Epoch 061 | Time 0.79s | Train NLL -4.124 | Val NLL -3.740 | LR 4.55e-03
# Epoch 062 | Time 0.78s | Train NLL -3.515 | Val NLL -3.890 | LR 4.54e-03
# Epoch 063 | Time 0.77s | Train NLL -2.073 | Val NLL -3.862 | LR 4.52e-03
# Epoch 064 | Time 0.86s | Train NLL -3.848 | Val NLL -4.155 | LR 4.51e-03
# Epoch 065 | Time 0.78s | Train NLL -3.759 | Val NLL -5.797 | LR 4.49e-03
# Epoch 066 | Time 0.82s | Train NLL -4.812 | Val NLL -7.023 | LR 4.47e-03
# Epoch 067 | Time 0.78s | Train NLL -2.992 | Val NLL -4.736 | LR 4.46e-03
# Epoch 068 | Time 0.80s | Train NLL -3.864 | Val NLL 0.411 | LR 4.44e-03
# Epoch 069 | Time 0.88s | Train NLL -3.009 | Val NLL -4.160 | LR 4.42e-03
# Epoch 070 | Time 0.83s | Train NLL -4.045 | Val NLL -5.502 | LR 4.41e-03
# Epoch 071 | Time 0.92s | Train NLL -4.389 | Val NLL -3.221 | LR 4.39e-03
# Epoch 072 | Time 0.82s | Train NLL -1.913 | Val NLL -4.461 | LR 4.37e-03
# Epoch 073 | Time 0.77s | Train NLL -3.162 | Val NLL -5.840 | LR 4.35e-03
# Epoch 074 | Time 0.83s | Train NLL -4.036 | Val NLL -1.825 | LR 4.34e-03
# Epoch 075 | Time 0.79s | Train NLL -1.915 | Val NLL -1.478 | LR 4.32e-03
# Epoch 076 | Time 0.78s | Train NLL -1.474 | Val NLL -4.858 | LR 4.30e-03
# Epoch 077 | Time 0.83s | Train NLL -4.474 | Val NLL -0.928 | LR 4.28e-03
# Epoch 078 | Time 0.80s | Train NLL -2.151 | Val NLL -4.280 | LR 4.26e-03
# Epoch 079 | Time 0.79s | Train NLL -3.944 | Val NLL -1.521 | LR 4.24e-03
# Epoch 080 | Time 0.82s | Train NLL -3.545 | Val NLL -6.026 | LR 4.22e-03
# Epoch 081 | Time 0.85s | Train NLL -4.759 | Val NLL -7.096 | LR 4.21e-03
# Epoch 082 | Time 0.77s | Train NLL -5.379 | Val NLL -5.843 | LR 4.19e-03
# Epoch 083 | Time 0.82s | Train NLL -4.903 | Val NLL -6.010 | LR 4.17e-03
# Epoch 084 | Time 0.87s | Train NLL -5.981 | Val NLL -4.626 | LR 4.15e-03
# Epoch 085 | Time 0.81s | Train NLL -5.746 | Val NLL -7.040 | LR 4.13e-03
# Epoch 086 | Time 0.80s | Train NLL -6.187 | Val NLL -7.358 | LR 4.11e-03
# Epoch 087 | Time 0.83s | Train NLL -6.317 | Val NLL -7.869 | LR 4.09e-03
# Epoch 088 | Time 0.79s | Train NLL -3.617 | Val NLL -5.963 | LR 4.06e-03
# Epoch 089 | Time 0.88s | Train NLL -5.745 | Val NLL -7.701 | LR 4.04e-03
# Epoch 090 | Time 0.77s | Train NLL -4.884 | Val NLL -1.655 | LR 4.02e-03
# Epoch 091 | Time 0.77s | Train NLL -2.667 | Val NLL -5.876 | LR 4.00e-03
# Epoch 092 | Time 0.75s | Train NLL -0.618 | Val NLL -3.459 | LR 3.98e-03
# Epoch 093 | Time 0.77s | Train NLL -4.540 | Val NLL -4.912 | LR 3.96e-03
# Epoch 094 | Time 0.81s | Train NLL -1.383 | Val NLL -4.033 | LR 3.94e-03
# Epoch 095 | Time 0.80s | Train NLL -4.300 | Val NLL -6.486 | LR 3.92e-03
# Epoch 096 | Time 0.78s | Train NLL -4.877 | Val NLL -5.353 | LR 3.89e-03
# Epoch 097 | Time 0.78s | Train NLL -5.446 | Val NLL -6.507 | LR 3.87e-03
# Epoch 098 | Time 0.76s | Train NLL -4.699 | Val NLL -5.368 | LR 3.85e-03
# Epoch 099 | Time 0.82s | Train NLL -4.971 | Val NLL -4.721 | LR 3.83e-03
# Epoch 100 | Time 0.89s | Train NLL -4.604 | Val NLL -5.852 | LR 3.80e-03
# Epoch 101 | Time 0.88s | Train NLL -4.373 | Val NLL 0.438 | LR 3.78e-03
# Epoch 102 | Time 1.01s | Train NLL 0.273 | Val NLL -2.537 | LR 3.76e-03
# Epoch 103 | Time 1.16s | Train NLL -4.025 | Val NLL -4.822 | LR 3.73e-03
# Epoch 104 | Time 1.14s | Train NLL -4.395 | Val NLL -6.082 | LR 3.71e-03
# Epoch 105 | Time 1.06s | Train NLL -5.730 | Val NLL -7.087 | LR 3.69e-03
# Epoch 106 | Time 1.13s | Train NLL -6.308 | Val NLL -7.420 | LR 3.66e-03
# Epoch 107 | Time 1.07s | Train NLL -7.037 | Val NLL -8.380 | LR 3.64e-03
# Epoch 108 | Time 1.00s | Train NLL -5.900 | Val NLL -6.692 | LR 3.62e-03
# Epoch 109 | Time 0.89s | Train NLL -5.103 | Val NLL -8.058 | LR 3.59e-03
# Epoch 110 | Time 0.88s | Train NLL -6.320 | Val NLL -7.870 | LR 3.57e-03
# Epoch 111 | Time 0.87s | Train NLL -7.655 | Val NLL -3.849 | LR 3.55e-03
# Epoch 112 | Time 0.88s | Train NLL -3.171 | Val NLL -2.330 | LR 3.52e-03
# Epoch 113 | Time 0.91s | Train NLL -2.356 | Val NLL -4.371 | LR 3.50e-03
# Epoch 114 | Time 0.94s | Train NLL -4.851 | Val NLL -6.475 | LR 3.47e-03
# Epoch 115 | Time 0.90s | Train NLL -5.436 | Val NLL -6.602 | LR 3.45e-03
# Epoch 116 | Time 0.99s | Train NLL -5.721 | Val NLL -6.774 | LR 3.42e-03
# Epoch 117 | Time 0.89s | Train NLL -6.957 | Val NLL -8.694 | LR 3.40e-03
# Epoch 118 | Time 0.91s | Train NLL -7.132 | Val NLL -7.738 | LR 3.37e-03
# Epoch 119 | Time 0.85s | Train NLL -5.267 | Val NLL -7.154 | LR 3.35e-03
# Epoch 120 | Time 0.86s | Train NLL -6.016 | Val NLL -4.773 | LR 3.32e-03
# Epoch 121 | Time 0.85s | Train NLL -6.208 | Val NLL -7.970 | LR 3.30e-03
# Epoch 122 | Time 0.89s | Train NLL -7.653 | Val NLL -5.963 | LR 3.27e-03
# Epoch 123 | Time 0.93s | Train NLL -2.344 | Val NLL -3.597 | LR 3.25e-03
# Epoch 124 | Time 0.88s | Train NLL -3.927 | Val NLL -4.671 | LR 3.22e-03
# Epoch 125 | Time 0.95s | Train NLL -5.813 | Val NLL -7.396 | LR 3.20e-03
# Epoch 126 | Time 0.84s | Train NLL -7.069 | Val NLL -8.802 | LR 3.17e-03
# Epoch 127 | Time 0.82s | Train NLL -7.383 | Val NLL -8.315 | LR 3.14e-03
# Epoch 128 | Time 0.87s | Train NLL -5.109 | Val NLL -5.412 | LR 3.12e-03
# Epoch 129 | Time 0.84s | Train NLL -4.223 | Val NLL -6.834 | LR 3.09e-03
# Epoch 130 | Time 0.86s | Train NLL -5.895 | Val NLL -6.963 | LR 3.07e-03
# Epoch 131 | Time 0.83s | Train NLL -6.584 | Val NLL -8.148 | LR 3.04e-03
# Epoch 132 | Time 0.89s | Train NLL -7.223 | Val NLL -3.082 | LR 3.02e-03
# Epoch 133 | Time 0.86s | Train NLL -3.195 | Val NLL -6.069 | LR 2.99e-03
# Epoch 134 | Time 0.85s | Train NLL -6.161 | Val NLL -7.848 | LR 2.96e-03
# Epoch 135 | Time 0.87s | Train NLL -7.320 | Val NLL -8.954 | LR 2.94e-03
# Epoch 136 | Time 0.91s | Train NLL -6.504 | Val NLL -5.552 | LR 2.91e-03
# Epoch 137 | Time 0.82s | Train NLL -5.865 | Val NLL -7.546 | LR 2.88e-03
# Epoch 138 | Time 0.98s | Train NLL -7.350 | Val NLL -8.563 | LR 2.86e-03
# Epoch 139 | Time 0.93s | Train NLL -6.246 | Val NLL -5.404 | LR 2.83e-03
# Epoch 140 | Time 0.91s | Train NLL -5.744 | Val NLL -1.715 | LR 2.81e-03
# Epoch 141 | Time 0.85s | Train NLL -5.353 | Val NLL -8.055 | LR 2.78e-03
# Epoch 142 | Time 0.84s | Train NLL -7.305 | Val NLL -8.251 | LR 2.75e-03
# Epoch 143 | Time 0.95s | Train NLL -8.164 | Val NLL -8.839 | LR 2.73e-03
# Epoch 144 | Time 0.90s | Train NLL -5.420 | Val NLL -8.141 | LR 2.70e-03
# Epoch 145 | Time 0.87s | Train NLL -7.250 | Val NLL -8.320 | LR 2.67e-03
# Epoch 146 | Time 0.81s | Train NLL -7.709 | Val NLL -8.790 | LR 2.65e-03
# Epoch 147 | Time 0.84s | Train NLL -5.280 | Val NLL -5.403 | LR 2.62e-03
# Epoch 148 | Time 0.85s | Train NLL -5.960 | Val NLL -3.932 | LR 2.59e-03
# Epoch 149 | Time 0.81s | Train NLL -4.052 | Val NLL -3.257 | LR 2.57e-03
# Epoch 150 | Time 0.81s | Train NLL -4.713 | Val NLL -7.149 | LR 2.54e-03
# Epoch 151 | Time 0.83s | Train NLL -7.293 | Val NLL -8.388 | LR 2.51e-03
# Epoch 152 | Time 0.81s | Train NLL -8.391 | Val NLL -9.389 | LR 2.49e-03
# Epoch 153 | Time 0.84s | Train NLL -7.115 | Val NLL -8.572 | LR 2.46e-03
# Epoch 154 | Time 0.85s | Train NLL -8.290 | Val NLL -9.486 | LR 2.43e-03
# Epoch 155 | Time 0.79s | Train NLL -6.929 | Val NLL -8.392 | LR 2.41e-03
# Epoch 156 | Time 0.83s | Train NLL -6.822 | Val NLL -7.011 | LR 2.38e-03
# Epoch 157 | Time 0.81s | Train NLL -6.380 | Val NLL -6.510 | LR 2.35e-03
# Epoch 158 | Time 0.80s | Train NLL -6.768 | Val NLL -7.589 | LR 2.33e-03
# Epoch 159 | Time 0.82s | Train NLL -5.264 | Val NLL -7.057 | LR 2.30e-03
# Epoch 160 | Time 0.79s | Train NLL -6.959 | Val NLL -8.072 | LR 2.27e-03
# Epoch 161 | Time 0.90s | Train NLL -7.993 | Val NLL -8.641 | LR 2.25e-03
# Epoch 162 | Time 0.81s | Train NLL -7.626 | Val NLL -8.691 | LR 2.22e-03
# Epoch 163 | Time 0.83s | Train NLL -8.716 | Val NLL -9.893 | LR 2.19e-03
# Epoch 164 | Time 0.81s | Train NLL -8.029 | Val NLL -5.969 | LR 2.17e-03
# Epoch 165 | Time 0.81s | Train NLL -5.959 | Val NLL -0.997 | LR 2.14e-03
# Epoch 166 | Time 0.81s | Train NLL 0.189 | Val NLL -1.788 | LR 2.12e-03
# Epoch 167 | Time 0.81s | Train NLL -3.151 | Val NLL -5.149 | LR 2.09e-03
# Epoch 168 | Time 0.75s | Train NLL -4.926 | Val NLL -5.892 | LR 2.06e-03
# Epoch 169 | Time 0.78s | Train NLL -6.721 | Val NLL -7.107 | LR 2.04e-03
# Epoch 170 | Time 0.79s | Train NLL -4.992 | Val NLL -2.384 | LR 2.01e-03
# Epoch 171 | Time 0.79s | Train NLL -3.572 | Val NLL -7.723 | LR 1.98e-03
# Epoch 172 | Time 0.82s | Train NLL -7.374 | Val NLL -8.943 | LR 1.96e-03
# Epoch 173 | Time 0.80s | Train NLL -6.865 | Val NLL -7.474 | LR 1.93e-03
# Epoch 174 | Time 0.80s | Train NLL -5.774 | Val NLL -2.084 | LR 1.91e-03
# Epoch 175 | Time 0.81s | Train NLL -3.844 | Val NLL -6.529 | LR 1.88e-03
# Epoch 176 | Time 0.87s | Train NLL -5.464 | Val NLL -7.189 | LR 1.86e-03
# Epoch 177 | Time 0.83s | Train NLL -7.293 | Val NLL -8.664 | LR 1.83e-03
# Epoch 178 | Time 0.86s | Train NLL -8.439 | Val NLL -9.380 | LR 1.80e-03
# Epoch 179 | Time 0.89s | Train NLL -8.459 | Val NLL -9.393 | LR 1.78e-03
# Epoch 180 | Time 0.77s | Train NLL -8.702 | Val NLL -9.534 | LR 1.75e-03
# Epoch 181 | Time 0.76s | Train NLL -8.840 | Val NLL -9.189 | LR 1.73e-03
# Epoch 182 | Time 0.81s | Train NLL -8.916 | Val NLL -9.956 | LR 1.70e-03
# Epoch 183 | Time 0.78s | Train NLL -9.126 | Val NLL -8.369 | LR 1.68e-03
# Epoch 184 | Time 0.80s | Train NLL -6.553 | Val NLL -6.639 | LR 1.65e-03
# Epoch 185 | Time 0.78s | Train NLL -7.931 | Val NLL -8.754 | LR 1.63e-03
# Epoch 186 | Time 0.81s | Train NLL -8.656 | Val NLL -9.682 | LR 1.60e-03
# Epoch 187 | Time 0.82s | Train NLL -9.196 | Val NLL -9.821 | LR 1.58e-03
# Epoch 188 | Time 1.16s | Train NLL -9.458 | Val NLL -10.377 | LR 1.55e-03
# Epoch 189 | Time 0.96s | Train NLL -9.173 | Val NLL -9.654 | LR 1.53e-03
# Epoch 190 | Time 0.89s | Train NLL -9.563 | Val NLL -10.089 | LR 1.50e-03
# Epoch 191 | Time 0.84s | Train NLL -9.437 | Val NLL -9.427 | LR 1.48e-03
# Epoch 192 | Time 0.79s | Train NLL -9.552 | Val NLL -9.768 | LR 1.45e-03
# Epoch 193 | Time 0.82s | Train NLL -9.639 | Val NLL -10.142 | LR 1.43e-03
# Epoch 194 | Time 0.87s | Train NLL -9.614 | Val NLL -10.081 | LR 1.41e-03
# Epoch 195 | Time 1.00s | Train NLL -9.758 | Val NLL -9.995 | LR 1.38e-03
# Epoch 196 | Time 0.95s | Train NLL -9.800 | Val NLL -10.148 | LR 1.36e-03
# Epoch 197 | Time 0.96s | Train NLL -9.776 | Val NLL -10.305 | LR 1.34e-03
# Epoch 198 | Time 0.85s | Train NLL -9.926 | Val NLL -10.064 | LR 1.31e-03
# Epoch 199 | Time 0.90s | Train NLL -10.054 | Val NLL -10.705 | LR 1.29e-03
# Epoch 200 | Time 0.81s | Train NLL -10.269 | Val NLL -11.013 | LR 1.27e-03
# Epoch 201 | Time 0.83s | Train NLL -10.175 | Val NLL -11.152 | LR 1.24e-03
# Epoch 202 | Time 1.72s | Train NLL -10.354 | Val NLL -11.455 | LR 1.22e-03
# Epoch 203 | Time 2.50s | Train NLL -10.398 | Val NLL -11.446 | LR 1.20e-03
# Epoch 204 | Time 1.82s | Train NLL -8.998 | Val NLL -8.039 | LR 1.17e-03
# Epoch 205 | Time 1.05s | Train NLL -8.334 | Val NLL -9.759 | LR 1.15e-03
# Epoch 206 | Time 0.96s | Train NLL -9.670 | Val NLL -10.482 | LR 1.13e-03
# Epoch 207 | Time 0.69s | Train NLL -10.207 | Val NLL -10.863 | LR 1.11e-03
# Epoch 208 | Time 0.72s | Train NLL -10.455 | Val NLL -11.258 | LR 1.08e-03
# Epoch 209 | Time 0.74s | Train NLL -10.703 | Val NLL -11.337 | LR 1.06e-03
# Epoch 210 | Time 0.83s | Train NLL -10.873 | Val NLL -11.576 | LR 1.04e-03
# Epoch 211 | Time 0.76s | Train NLL -10.832 | Val NLL -11.702 | LR 1.02e-03
# Epoch 212 | Time 0.79s | Train NLL -10.889 | Val NLL -12.009 | LR 9.98e-04
# Epoch 213 | Time 0.88s | Train NLL -10.951 | Val NLL -12.001 | LR 9.77e-04
# Epoch 214 | Time 0.98s | Train NLL -9.980 | Val NLL -9.327 | LR 9.56e-04
# Epoch 215 | Time 0.92s | Train NLL -9.978 | Val NLL -11.770 | LR 9.35e-04
# Epoch 216 | Time 0.84s | Train NLL -10.940 | Val NLL -11.841 | LR 9.15e-04
# Epoch 217 | Time 0.78s | Train NLL -11.161 | Val NLL -11.908 | LR 8.94e-04
# Epoch 218 | Time 0.80s | Train NLL -11.359 | Val NLL -12.144 | LR 8.74e-04
# Epoch 219 | Time 1.61s | Train NLL -11.539 | Val NLL -12.261 | LR 8.54e-04
# Epoch 220 | Time 1.78s | Train NLL -11.215 | Val NLL -11.707 | LR 8.34e-04
# Epoch 221 | Time 0.84s | Train NLL -11.378 | Val NLL -11.962 | LR 8.14e-04
# Epoch 222 | Time 0.99s | Train NLL -11.557 | Val NLL -11.901 | LR 7.94e-04
# Epoch 223 | Time 0.78s | Train NLL -11.531 | Val NLL -12.259 | LR 7.75e-04
# Epoch 224 | Time 0.67s | Train NLL -11.574 | Val NLL -12.213 | LR 7.56e-04
# Epoch 225 | Time 0.67s | Train NLL -11.486 | Val NLL -12.317 | LR 7.37e-04
# Epoch 226 | Time 0.73s | Train NLL -11.673 | Val NLL -12.684 | LR 7.18e-04
# Epoch 227 | Time 1.29s | Train NLL -10.536 | Val NLL -8.225 | LR 7.00e-04
# Epoch 228 | Time 1.65s | Train NLL -7.126 | Val NLL -10.973 | LR 6.81e-04
# Epoch 229 | Time 1.24s | Train NLL -10.246 | Val NLL -11.670 | LR 6.63e-04
# Epoch 230 | Time 1.77s | Train NLL -11.172 | Val NLL -12.045 | LR 6.45e-04
# Epoch 231 | Time 1.34s | Train NLL -11.638 | Val NLL -12.409 | LR 6.27e-04
# Epoch 232 | Time 1.46s | Train NLL -11.895 | Val NLL -12.548 | LR 6.10e-04
# Epoch 233 | Time 1.90s | Train NLL -12.074 | Val NLL -12.493 | LR 5.93e-04
# Epoch 234 | Time 0.91s | Train NLL -12.162 | Val NLL -12.816 | LR 5.75e-04
# Epoch 235 | Time 1.58s | Train NLL -12.307 | Val NLL -13.194 | LR 5.59e-04
# Epoch 236 | Time 0.90s | Train NLL -12.505 | Val NLL -12.293 | LR 5.42e-04
# Epoch 237 | Time 0.80s | Train NLL -12.166 | Val NLL -12.506 | LR 5.25e-04
# Epoch 238 | Time 0.82s | Train NLL -12.387 | Val NLL -12.723 | LR 5.09e-04
# Epoch 239 | Time 0.80s | Train NLL -12.326 | Val NLL -12.761 | LR 4.93e-04
# Epoch 240 | Time 0.76s | Train NLL -12.528 | Val NLL -13.382 | LR 4.77e-04
# Epoch 241 | Time 0.78s | Train NLL -12.563 | Val NLL -13.122 | LR 4.62e-04
# Epoch 242 | Time 0.83s | Train NLL -12.666 | Val NLL -13.277 | LR 4.47e-04
# Epoch 243 | Time 0.76s | Train NLL -12.833 | Val NLL -13.355 | LR 4.32e-04
# Epoch 244 | Time 0.82s | Train NLL -12.815 | Val NLL -13.742 | LR 4.17e-04
# Epoch 245 | Time 1.04s | Train NLL -13.049 | Val NLL -14.023 | LR 4.02e-04
# Epoch 246 | Time 1.19s | Train NLL -12.926 | Val NLL -13.629 | LR 3.88e-04
# Epoch 247 | Time 0.78s | Train NLL -13.166 | Val NLL -13.433 | LR 3.74e-04
# Epoch 248 | Time 0.87s | Train NLL -13.120 | Val NLL -12.937 | LR 3.60e-04
# Epoch 249 | Time 0.82s | Train NLL -13.068 | Val NLL -14.296 | LR 3.46e-04
# Epoch 250 | Time 0.73s | Train NLL -13.385 | Val NLL -13.789 | LR 3.33e-04
# Epoch 251 | Time 0.87s | Train NLL -13.392 | Val NLL -14.348 | LR 3.20e-04
# Epoch 252 | Time 0.72s | Train NLL -13.570 | Val NLL -13.705 | LR 3.07e-04
# Epoch 253 | Time 0.73s | Train NLL -13.487 | Val NLL -14.004 | LR 2.94e-04
# Epoch 254 | Time 0.81s | Train NLL -13.639 | Val NLL -13.639 | LR 2.82e-04
# Epoch 255 | Time 0.79s | Train NLL -13.726 | Val NLL -14.344 | LR 2.69e-04
# Epoch 256 | Time 0.78s | Train NLL -13.831 | Val NLL -14.555 | LR 2.58e-04
# Epoch 257 | Time 0.80s | Train NLL -13.945 | Val NLL -15.009 | LR 2.46e-04
# Epoch 258 | Time 0.73s | Train NLL -14.161 | Val NLL -14.804 | LR 2.35e-04
# Epoch 259 | Time 0.75s | Train NLL -13.944 | Val NLL -14.440 | LR 2.23e-04
# Epoch 260 | Time 0.73s | Train NLL -14.213 | Val NLL -14.525 | LR 2.13e-04
# Epoch 261 | Time 0.85s | Train NLL -14.189 | Val NLL -15.030 | LR 2.02e-04
# Epoch 262 | Time 0.88s | Train NLL -14.338 | Val NLL -15.121 | LR 1.92e-04
# Epoch 263 | Time 0.80s | Train NLL -14.398 | Val NLL -15.104 | LR 1.81e-04
# Epoch 264 | Time 0.79s | Train NLL -14.709 | Val NLL -15.429 | LR 1.72e-04
# Epoch 265 | Time 0.76s | Train NLL -14.694 | Val NLL -15.260 | LR 1.62e-04
# Epoch 266 | Time 0.84s | Train NLL -14.617 | Val NLL -15.322 | LR 1.53e-04
# Epoch 267 | Time 0.76s | Train NLL -14.953 | Val NLL -15.609 | LR 1.44e-04
# Epoch 268 | Time 0.83s | Train NLL -14.988 | Val NLL -15.479 | LR 1.35e-04
# Epoch 269 | Time 0.88s | Train NLL -15.050 | Val NLL -15.791 | LR 1.27e-04
# Epoch 270 | Time 0.78s | Train NLL -15.036 | Val NLL -15.865 | LR 1.18e-04
# Epoch 271 | Time 0.82s | Train NLL -15.258 | Val NLL -15.892 | LR 1.10e-04
# Epoch 272 | Time 0.78s | Train NLL -15.243 | Val NLL -16.017 | LR 1.03e-04
# Epoch 273 | Time 0.75s | Train NLL -15.435 | Val NLL -16.054 | LR 9.52e-05
# Epoch 274 | Time 0.80s | Train NLL -15.472 | Val NLL -16.141 | LR 8.81e-05
# Epoch 275 | Time 0.78s | Train NLL -15.537 | Val NLL -16.149 | LR 8.12e-05
# Epoch 276 | Time 0.75s | Train NLL -15.579 | Val NLL -16.232 | LR 7.46e-05
# Epoch 277 | Time 0.78s | Train NLL -15.619 | Val NLL -16.284 | LR 6.83e-05
# Epoch 278 | Time 0.78s | Train NLL -15.689 | Val NLL -16.322 | LR 6.23e-05
# Epoch 279 | Time 0.75s | Train NLL -15.722 | Val NLL -16.363 | LR 5.65e-05
# Epoch 280 | Time 0.78s | Train NLL -15.761 | Val NLL -16.394 | LR 5.10e-05
# Epoch 281 | Time 0.82s | Train NLL -15.780 | Val NLL -16.419 | LR 4.58e-05
# Epoch 282 | Time 0.77s | Train NLL -15.802 | Val NLL -16.457 | LR 4.09e-05
# Epoch 283 | Time 0.82s | Train NLL -15.776 | Val NLL -16.483 | LR 3.62e-05
# Epoch 284 | Time 0.76s | Train NLL -15.894 | Val NLL -16.506 | LR 3.18e-05
# Epoch 285 | Time 0.80s | Train NLL -15.943 | Val NLL -16.527 | LR 2.77e-05
# Epoch 286 | Time 0.80s | Train NLL -15.929 | Val NLL -16.540 | LR 2.39e-05
# Epoch 287 | Time 0.87s | Train NLL -15.931 | Val NLL -16.558 | LR 2.04e-05
# Epoch 288 | Time 0.80s | Train NLL -15.972 | Val NLL -16.569 | LR 1.71e-05
# Epoch 289 | Time 0.78s | Train NLL -15.966 | Val NLL -16.579 | LR 1.42e-05
# Epoch 290 | Time 0.75s | Train NLL -15.997 | Val NLL -16.590 | LR 1.15e-05
# Epoch 291 | Time 0.80s | Train NLL -16.001 | Val NLL -16.597 | LR 9.07e-06
# Epoch 292 | Time 0.75s | Train NLL -15.969 | Val NLL -16.602 | LR 6.94e-06
# Epoch 293 | Time 0.83s | Train NLL -15.941 | Val NLL -16.607 | LR 5.10e-06
# Epoch 294 | Time 0.77s | Train NLL -16.012 | Val NLL -16.611 | LR 3.54e-06
# Epoch 295 | Time 0.75s | Train NLL -16.036 | Val NLL -16.612 | LR 2.27e-06
# Epoch 296 | Time 0.78s | Train NLL -15.953 | Val NLL -16.614 | LR 1.28e-06
# Epoch 297 | Time 0.76s | Train NLL -15.983 | Val NLL -16.615 | LR 5.67e-07
# Epoch 298 | Time 0.75s | Train NLL -16.016 | Val NLL -16.615 | LR 1.42e-07
# Epoch 299 | Time 0.78s | Train NLL -15.996 | Val NLL -16.615 | LR 0.00e+00

# %% [markdown]
# ### Model Evaluation

# %%
flow.load_state_dict(torch.load(RUN_PATH, weights_only=True))
flow.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
flow = flow.to(device)

# %%
# plot training curves (loss and learning rate)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.train_losses, label='Train Loss')
plt.plot(history.val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('NLL')
plt.title('Loss Curve')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.title('LR Schedule')
plt.legend()
plt.tight_layout()
plt.show()

# %%
utils.run_inference_and_plot(flow, test_loader, y_scaler, TARGET_COLS, device)

# %%
def compute_avg_true_pred_diff(flow, test_loader, y_scaler):
    flow.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            dist = flow(x_batch)
            y_hat = dist.sample().squeeze()
            y_true.append(y_batch.cpu())
            y_pred.append(y_hat.cpu())
    y_true = torch.cat(y_true, dim=0).numpy()
    y_pred = torch.cat(y_pred, dim=0).numpy()
    if y_true.ndim == 1:
        y_true = y_true.reshape(-1, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred.reshape(-1, 1)
    y_true = y_scaler.inverse_transform(y_true)
    y_pred = y_scaler.inverse_transform(y_pred)
    y_pred = np.expm1(np.clip(y_pred, -20, None))
    y_true = np.expm1(np.clip(y_true, -20, None))
    y_pred[:, 1] = np.floor(y_pred[:, 1]).clip(min=0)
    avg_diff_damages = np.mean(np.abs(y_true[:, 0] - y_pred[:, 0]))
    avg_diff_casualties = np.mean(np.abs(y_true[:, 1] - y_pred[:, 1]))
    print(f"Average absolute difference in {TARGET_COLS[0]}: {avg_diff_damages:.2f}")
    print(f"Average absolute difference in {TARGET_COLS[1]}: {avg_diff_casualties:.2f}") 

compute_avg_true_pred_diff(flow, test_loader, y_scaler)
# Out:
# Average absolute difference in DAMAGES: 11385.67
# Average absolute difference in CASUALTIES: 0.01

# %%
# Plot True log-damage histogram and Sampled log-damage histogram

# Get true log-damage and casualties from Y_test (already standardized)
true_log_damage = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 0]
true_log_casualties = y_scaler.inverse_transform(Y_test.cpu().numpy())[:, 1]

# Sample log-damage and casualties from flow using X_test as context
flow.eval()
sampled_log = []
with torch.no_grad():
    for i in range(0, X_test.shape[0], 512):
        x_batch = X_test[i:i+512]
        dist = flow(x_batch)
        y_hat = dist.sample()
        if y_hat.ndim == 1:
            y_hat = y_hat.unsqueeze(1)
        sampled_log.append(y_hat.cpu())
sampled_log = torch.cat(sampled_log, dim=0).numpy()
sampled_log_damage = y_scaler.inverse_transform(sampled_log)[:, 0]
sampled_log_casualties = y_scaler.inverse_transform(sampled_log)[:, 1]

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(true_log_damage, bins=30, alpha=0.6, label='True Log-Damage')
plt.hist(sampled_log_damage, bins=30, alpha=0.6, label='Sampled Log-Damage')
plt.xlabel('Log-Damage')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Damage Histogram')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(true_log_casualties, bins=30, alpha=0.6, label='True Log-Casualties')
plt.hist(sampled_log_casualties, bins=30, alpha=0.6, label='Sampled Log-Casualties')
plt.xlabel('Log-Casualties')
plt.ylabel('Frequency')
plt.title('True vs Sampled Log-Casualties Histogram')
plt.legend()

plt.tight_layout()
plt.show()
